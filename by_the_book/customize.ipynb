# %%
# %load_ext autoreload
# %autoreload 2
# !cd `pwd`

# %%
from pipeline.book import Book

# %%
B = Book()

# %%
rImg1 = B.batch(pages='47-48', batch=False, boxed=True)
# Out:
#   0.00s Batch of 2 pages
#   0.00s Start batch processing images
#   0.45s Done, footer at height  66%
#   0.56s     1 047.tif                                   66%
#   0.64s Done, footer at height 100%
#   0.76s     2 048.tif                                  100%
#   0.76s all done

# %%
rImg1.show(stage={"histogram"})
# Out:
# <div>histogram</div>

# %%
normalizeParams = dict(blurX=1, blurY=1)

rImg2 = B.batch(pages='47-48', batch=False, boxed=True, normalize=normalizeParams)
# Out:
#   0.00s Batch of 2 pages
#   0.00s Start batch processing images
#   0.66s Done, footer at height 100%
#   0.77s     1 047.tif                                  100%
#   0.74s Done, footer at height 100%
#   0.85s     2 048.tif                                  100%
#   0.85s all done

# %%
rImg2.show(stage={"histogram"})
# Out:
# <div>histogram</div>
