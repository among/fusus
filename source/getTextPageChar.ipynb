# %%
# %load_ext autoreload
# %autoreload 2
# !cd `pwd`

# %%
from unicodedata import normalize, decomposition, category
from fusus.lakhnawi import Lakhnawi, pprint
Lw = Lakhnawi()
Lw.setStyle()
# Out:
# <style>
# .r {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     direction: rtl;
# }
# .rc, .lc {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     background-color: white;
#     border: 2pt solid #ffcccc;
# }
# .rc {
#     direction: rtl;
# }
# .lc {
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# p {
#     text-align: left;
#     direction: ltr;
# }
# p.r {
#     text-align: right;
#     direction: rtl;
# }
# .l {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# .c {
#     font-family: monospace;
#     font-size: x-small;
#     direction: ltr;
# }
# .p {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     background-color: yellow;
#     direction: ltr;
# }
# .lrg {
#     font-size: xx-large;
#     font-weight: bold;
# }
# span.sp {
#     background-color: #00ff00;
# }
# td {
#     text-align: left ! important;
# }
# div.cn {
#     text-align: center
# }
# div.ch.p {
#     background-color: #ffeedd;
#     text-align: center
# }
# span.cni {
#     background-color: #eeeeee;
#     padding-top: 4pt;
#     padding-bottom: 4pt;
#     padding-left: 8pt;
#     padding-right: 8pt;
#     border: 2pt solid #66aaaa;
#     display: inline-block;
# }
# div.ch {
#     border: 2pt solid #cccccc;
#     background-color: #ddffff;
#     display: inline-flex;
#     flex-flow: column nowrap;
#     max-width: 10em;
# }
# div.sr {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# </style>

# %%
testPages = "103"
char = "\ue815"
Lw.drawPages(testPages)
# Out:
# <p><b>page 103</b></p>

# %%
Lw.getPages(testPages, refreshConfig=True)
Lw.showLines(testPages, search=char, every=False)
# Out:
# 	   1 (page  103)
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 1</th>
#     <th colspan=3>3 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 2</th>
#     <th colspan=3>106 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 3</th>
#     <th colspan=3>116 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 4</th>
#     <th colspan=3>27 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 5</th>
#     <th colspan=3>29 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 6</th>
#     <th colspan=3>113 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 7</th>
#     <th colspan=3>105 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 8</th>
#     <th colspan=3>123 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 9</th>
#     <th colspan=3>51 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 10</th>
#     <th colspan=3>108 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 11</th>
#     <th colspan=3>105 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 12</th>
#     <th colspan=3>82 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 13</th>
#     <th colspan=3>107 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 14</th>
#     <th colspan=3>116 characters</th>
# </tr>
# </table>

# %%
Lw.getPages(testPages, refreshConfig=True)
# Lw.showReplacements(isApplied=False)
Lw.showLines(testPages, search=char, orig=True, every=False)

# %%
memOrd = "\u0645"
memMed = "\ufee4"
xOrd = f"\u0627\u0644{memOrd}\u064e\u062b\u064e\u0627"
xMed = f"\u0627\u0644{memMed}\u064e\u062b\u064e\u0627"
Lw.showString(xOrd)
Lw.showString(normalize("NFKD", xOrd))
Lw.showString(normalize("NFKC", xOrd))
Lw.showString(xMed)
Lw.showString(normalize("NFKD", xMed))
Lw.showString(normalize("NFKC", xMed))
# Out:
# <p><span class="r">المَثَا</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0645</span></div>
#     <div class="cn"><span class="cni"><span class="rc">م</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER MEEM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">062b</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ث</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER THEH</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </div>
# <p><span class="r">المَثَا</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0645</span></div>
#     <div class="cn"><span class="cni"><span class="rc">م</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER MEEM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">062b</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ث</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER THEH</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </div>
# <p><span class="r">المَثَا</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0645</span></div>
#     <div class="cn"><span class="cni"><span class="rc">م</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER MEEM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">062b</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ث</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER THEH</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </div>
# <p><span class="r">الﻤَثَا</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">fee4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻤ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER MEEM MEDIAL FORM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">062b</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ث</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER THEH</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </div>
# <p><span class="r">المَثَا</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0645</span></div>
#     <div class="cn"><span class="cni"><span class="rc">م</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER MEEM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">062b</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ث</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER THEH</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </div>
# <p><span class="r">المَثَا</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0645</span></div>
#     <div class="cn"><span class="cni"><span class="rc">م</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER MEEM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">062b</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ث</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER THEH</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </div>

# %%
Lw.showLines(testPages, line=5, start=18, end=24)
# Out:
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 103</th>
#     <th colspan=2>line 5</th>
#     <th colspan=3>29 characters</th>
# </tr>
#
# <tr>
#     <td><b>18</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>3164</td>
#     <td>3196</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>19</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>3127</td>
#     <td>3164</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedf</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻟ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>20</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>3066</td>
#     <td>3127</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fee4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻤ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER MEEM MEDIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0645</span></div>
#     <div class="cn"><span class="cni"><span class="rc">م</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER MEEM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>21</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>2926</td>
#     <td>3066</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e825</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>22</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>3033</td>
#     <td>3066</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fe9c</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺜ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER THEH MEDIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">062b</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ث</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER THEH</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>23</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>2893</td>
#     <td>3033</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>24</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>3004</td>
#     <td>3034</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fe8e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺎ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF FINAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
# </table>

# %%
Lw.htmlPages(testPages)
# Out:
# <p class="r"><span class="r">٣٠١</span></p>
# <p class="r"><span class="r">وَقَدْ  عَلِمَ أَنَّ  صُورَةَ النَّـبَىِّ  صَلَّىٰ اللهُ  عَلَيهِ وَسَلَّمَ الَّتِي  شَا هَدَ هَا</span><span class="l">)</span><span class="r">١</span><span class="l"> (</span><span class="r">الحِسُّ</span></p>
# <p class="r"><span class="r">إِنَّهَا</span><span class="l">  173</span><span class="r">فِي المَدِ ينَةِ  مَدْ فُو نَةٌ، وَأَنَّ  صُورَةَ رُو حِهِ وَلَطِيفَتِهِ،  مَا شَا هَدَ هَا أَحَدٌ  مِنْ</span></p>
# <p class="r"><span class="r">أَحَدٍ وَلَا  مِنْ  نَفْسِهِ</span><span class="l">174.</span></p>
# <p class="r"><span class="r"> كُلُّ رُوحٍ  بِهٰذِهِ المَثَا بَةِ</span><span class="l">.</span></p>
# <p class="r"><span class="r"> فَيَتَجَسَّدُ  لَهُ رُوحُ النَّبِىِّ  فِي المَنَامِ  بِصُورَةِ  جَسَدِهِ كَمَا  مَاتَ  عَلَيهِ، لَا  يَخْـرِمُ</span></p>
# <p class="r"><span class="r"> مِنْهُ  شَيىًٔا</span><span class="l">  .</span><span class="r">فَهُوَ  مُحَمَّدٌ  عَلَيهِ السَّلَامُ، المَرْ ئِيُّ  مِنْ  حَيثُ رُو حُهُ،  فِي  صُورَةٍ</span></p>
# <p class="r"><span class="r"> جَسَدِ يَّةٍ  تُشْبِهُ المَدْ فُو نَةَ، لَا  يُمْكِنُ  لِشَيطَانٍ أَنْ  يَتَصَوَّرَ  بِصُورَةِ  جَسَدِهِ  صَلَّىٰ اللهُ</span></p>
# <p class="r"><span class="r"> عَلَيهِ وَسَلَّمَ،  عِصْمَةً  مِنَ اللهِ  فِي  حَقِّ الرَّا ئِيْ</span><span class="l">.</span></p>
# <p class="r"><span class="r">وَلِهٰذَا  مَنْ رآهُ  بِهٰذِهِ الصُّورَةِ  يَأ خُذُ  عَنْهُ  جَمِيعَ  مَا يَأ مُرُهُ  بِهِ، أَو  يَنْهَاهُ، أَو</span></p>
# <p class="r"><span class="r"> يُخْبِرُهُ،  كَمَا كَانَ  يَأ خُذُ  عَنْهُ  فِي الحَيَاةِ الدُّ نْـيَا  مِنَ الأَ حْـكَامِ  عَلىٰ  حَسَبِ</span></p>
# <p class="r"><span class="r"> مَا يَكُونُ  مِنْهُ اللَّفْظُ الدَّالُّ  عَلَيهِ  مِنْ  نصٍَّ، أَو  ظَا هِرٍ، أَو  مُجْمَلٍ، أَو  مَا كَانَ</span><span class="l">.</span></p>
# <p class="r"><span class="r"> فَإِنْ أَعْطَاهُ  شَيىًٔا،  فَإنَّ ذٰلِكَ الشَّيءَ  هُوَ الَّذِي  يَدْ خُلُهُ التَّعْبِيرُ،  فَإِنْ  خَرَجَ في</span></p>
# <p class="r"><span class="r">الحِسِّ</span><span class="l">)</span><span class="r">٢</span><span class="l"> (</span><span class="r">كَمَا كَانَ  فِي الخَيَالِ،  فَتِلْكَ رُؤ يَا لَا  تَعْبِيرَ  لَهَا</span><span class="l"> .</span><span class="r">وَبِهٰذَا القَدْرِ وَعَلَيهِ</span></p>

# %% [markdown]
# # Special cases

# %% [markdown]
# ## Allah
#
# The name of Allah contains tashkil that are provided automatically by the Unicode algorithm:

# %%
Lw.showString("اللهِ")

# %% [markdown]
# ## Impossible tashkil
#
# Here is a word with a bizarre set of accents.
#
# ![logo](logo.png)
#
# See line 3 below.

# %%
testPages = "185"
Lw.getPages(testPages, refreshConfig=True)
Lw.drawPages(testPages)
Lw.showLines(testPages, line="4", start=84, end=90)
Lw.showLines(testPages, line="5", start=101, end=109)
Lw.htmlPages(testPages)

# %% [markdown]
# # Getting the right LAM-ALEF ligature

# %%
testPages = "45"
Lw.drawPages(testPages)
Lw.getPages(testPages)
Lw.showLines(testPages, line=9, start=88, end=97)
Lw.showReplacements(rule=78)
Lw.htmlPages(testPages)

# %%
Lw.showString("\u0625\u0650\ufec3\u0652\u0644\u064e\u0627\u064e\u0642\u064f")
Lw.showString("\u0625\u0650\u0637\u0652\u0644\u064e\u0627\u064e\u0642\u064f")

# %%
Lw.showString("\ufefb \ufefc")

# %% [markdown]
# ## LAM-ALEF(wasla) does not come out right

# %% [markdown]
# Here is an example
#
# ![lamalefwasla](lamalefwasla.png)
#
# See line 10 below.

# %%
testPages = "34"
char = "\ue809"
Lw.drawPages(testPages)

# %%
Lw.showLines(testPages, search=char, orig=True)

# %% [markdown]
# If we render the string, we do not get the right ligature.
#
# Whereas when we replace the alef-wasla with an ordinary alef, the ligature comes out right:

# %%
alefWasla = "\u0671"
alefNorml = "\u0627"

Lw.showString(f"\u0644\u0650\u0644\u0652{alefWasla}\u0633\u0652\ufe98")
Lw.showString(f"\u0644\u0650\u0644\u0652{alefNorml}\u0633\u0652\ufe98")
