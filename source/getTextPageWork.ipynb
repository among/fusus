# %%
# %load_ext autoreload
# %autoreload 2
# !cd `pwd`

# %%
from fusus.lakhnawi import Lakhnawi, pprint
Lw = Lakhnawi()
Lw.setStyle()
# Out:
# <style>
# .r {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     direction: rtl;
# }
# .rc, .lc {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     background-color: white;
#     border: 2pt solid #ffcccc;
# }
# .rc {
#     direction: rtl;
# }
# .lc {
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# p {
#     text-align: left;
#     direction: ltr;
# }
# p.r {
#     text-align: right;
#     direction: rtl;
# }
# .l {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# .c {
#     font-family: monospace;
#     font-size: x-small;
#     direction: ltr;
# }
# .p {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     background-color: yellow;
#     direction: ltr;
# }
# .lrg {
#     font-size: xx-large;
#     font-weight: bold;
# }
# td {
#     text-align: left ! important;
# }
# div.cn {
#     text-align: center
# }
# div.ch.p {
#     background-color: #ffeedd;
#     text-align: center
# }
# span.cni {
#     background-color: #eeeeee;
#     padding-top: 4pt;
#     padding-bottom: 4pt;
#     padding-left: 8pt;
#     padding-right: 8pt;
#     border: 2pt solid #66aaaa;
#     display: inline-block;
# }
# div.ch {
#     border: 2pt solid #cccccc;
#     background-color: #ddffff;
#     display: inline-flex;
#     flex-flow: column nowrap;
#     max-width: 10em;
# }
# div.sr {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# </style>

# %%
testPages = "37"
char = "\ue85b"
Lw.drawPages(testPages)
# Out:
# <p><b>page 37</b></p>

# %%
Lw.getPages(testPages, refreshConfig=True)
Lw.showLines(testPages, search=char)
# Out:
# 	   1 (page   37)
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 37</th>
#     <th colspan=2>line 1</th>
#     <th colspan=3>2 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 37</th>
#     <th colspan=2>line 2</th>
#     <th colspan=3>114 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 37</th>
#     <th colspan=2>line 3</th>
#     <th colspan=3>131 characters</th>
# </tr>
#
# <tr>
#     <td><b>116</b></td>
#     <td>1127</td>
#     <td>1341</td>
#     <td>1180</td>
#     <td>1320</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e864</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>117</b></td>
#     <td>1127</td>
#     <td>1341</td>
#     <td>1281</td>
#     <td>1320</td>
#     <td>⌊34⌋</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">061b</span></div>
#     <div class="cn"><span class="cni"><span class="rc">؛</span></div>
#     <div class="cn"><span class="c">ARABIC SEMICOLON</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">061b</span></div>
#     <div class="cn"><span class="cni"><span class="rc">؛</span></div>
#     <div class="cn"><span class="c">ARABIC SEMICOLON</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0020</span></div>
#     <div class="cn"><span class="cni"><span class="lc"> </span></div>
#     <div class="cn"><span class="c">SPACE</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>118</b></td>
#     <td>1127</td>
#     <td>1341</td>
#     <td>1202</td>
#     <td>1247</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e80a</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>119</b></td>
#     <td>1127</td>
#     <td>1341</td>
#     <td>1062</td>
#     <td>1202</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e864</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>120</b></td>
#     <td>1127</td>
#     <td>1341</td>
#     <td>1160</td>
#     <td>1202</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e806</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>121</b></td>
#     <td>1127</td>
#     <td>1341</td>
#     <td>1020</td>
#     <td>1160</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e85b</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e85b</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>122</b></td>
#     <td>1127</td>
#     <td>1341</td>
#     <td>1089</td>
#     <td>1160</td>
#     <td>⌊34⌋</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0646</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ن</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER NOON</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0646</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ن</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER NOON</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>123</b></td>
#     <td>1127</td>
#     <td>1341</td>
#     <td>949</td>
#     <td>1089</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fc60</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﱠ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH FATHA ISOLATED FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fc60</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﱠ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH FATHA ISOLATED FORM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0020</span></div>
#     <div class="cn"><span class="cni"><span class="lc"> </span></div>
#     <div class="cn"><span class="c">SPACE</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>124</b></td>
#     <td>1127</td>
#     <td>1341</td>
#     <td>1024</td>
#     <td>1055</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>125</b></td>
#     <td>1127</td>
#     <td>1341</td>
#     <td>937</td>
#     <td>1024</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fefb</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻻ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE LAM WITH ALEF ISOLATED FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef7</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻷ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE LAM WITH ALEF WITH HAMZA ABOVE ISOLATED FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>126</b></td>
#     <td>1127</td>
#     <td>1341</td>
#     <td>797</td>
#     <td>937</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e85b</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
# </table>

# %%
Lw.getPages(testPages, refreshConfig=True)
# Lw.showReplacements(isApplied=True)
Lw.showLines(testPages, search=char, orig=True)
# Out:
# 	   1 (page   37)
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 37</th>
#     <th colspan=2>line 1</th>
#     <th colspan=3>2 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 37</th>
#     <th colspan=2>line 2</th>
#     <th colspan=3>114 characters</th>
# </tr>
#
# <tr>
#     <td><b>75</b></td>
#     <td>867</td>
#     <td>1081</td>
#     <td>2002</td>
#     <td>2045</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e806</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>76</b></td>
#     <td>867</td>
#     <td>1081</td>
#     <td>1888</td>
#     <td>2002</td>
#     <td>⌊34⌋</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">062a</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ت</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TEH</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">062a</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ت</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TEH</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>77</b></td>
#     <td>867</td>
#     <td>1081</td>
#     <td>1748</td>
#     <td>1888</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0020</span></div>
#     <div class="cn"><span class="cni"><span class="lc"> </span></div>
#     <div class="cn"><span class="c">SPACE</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>78</b></td>
#     <td>867</td>
#     <td>1081</td>
#     <td>1822</td>
#     <td>1854</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>79</b></td>
#     <td>867</td>
#     <td>1081</td>
#     <td>1736</td>
#     <td>1822</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fefb</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻻ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE LAM WITH ALEF ISOLATED FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef7</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻷ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE LAM WITH ALEF WITH HAMZA ABOVE ISOLATED FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>80</b></td>
#     <td>867</td>
#     <td>1081</td>
#     <td>1596</td>
#     <td>1736</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e85b</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>81</b></td>
#     <td>867</td>
#     <td>1081</td>
#     <td>1648</td>
#     <td>1736</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fea3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺣ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER HAH INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fea3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺣ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER HAH INITIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>82</b></td>
#     <td>867</td>
#     <td>1081</td>
#     <td>1508</td>
#     <td>1648</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e828</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>83</b></td>
#     <td>867</td>
#     <td>1081</td>
#     <td>1620</td>
#     <td>1647</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0640</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ـ</span></div>
#     <div class="cn"><span class="c">ARABIC TATWEEL</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0640</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ـ</span></div>
#     <div class="cn"><span class="c">ARABIC TATWEEL</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>84</b></td>
#     <td>867</td>
#     <td>1081</td>
#     <td>1641</td>
#     <td>1654</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>85</b></td>
#     <td>867</td>
#     <td>1081</td>
#     <td>1573</td>
#     <td>1620</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feee</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻮ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER WAW FINAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feee</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻮ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER WAW FINAL FORM</span></div>
# </div>
# </td>
# </tr>
# </table>

# %%
Lw.htmlPages(testPages)
# Out:
# <p class="r"><span class="r">٧٣</span></p>
# <p class="r"><span class="r">وَإِﻣَّﺎ أَنْ ﻳَﻜْﺸِﻒَ ﻟَﻪُ ﻋَﻦْ ﻋَﻴﻨِﻪِ اﻟﺜﱠﺎﺑِﺘَﺔِ، وَٱﻧْﺘِﻘَﺎلَاتِ اﻷَﺣْـﻮَالِ ﻋَﻠَﻴﻬَﺎ إِﻟَﲐ ﻣَﺎ لَا</span></p>
# <p class="r"><span class="r">ﻳَﺘَﻨَﺎﻫَﲐ وَﻫُﻮَ أَﻋْﻠَﲐ، ﻓَﺎِٕﻧﱠﻪُ ﻳَﻜُﻮنُ ﻓِﻲ ﻋِﻠْﻤِﻪِ ﺑِﻨَﻔْﺴِﻪِ ﺑِﻤَﻨْﺰِﻟَﺔِ ﻋِﻠْﻢِ اﻟﻠّٰﻪِ ﺑِﻪِ؛ لِأَنﱠ اﻷَﺧْﺬَ</span></p>
# <p class="r"><span class="r">ﻣِﻦْ ﻣَﻌْﺪَنٍ وَاﺣِﺪٍ</span><span class="l">.</span></p>
# <p class="r"><span class="r">إٍلﱠا أَﻧﱠﻪُ ﻣِﻦْ ﺟِﻬَﺔِ اﻟﻌَﺒْﺪِ ﻋِﻨَﺎﻳَﺔٌ ﻣِﻦَ اﻟﻠّٰﻪِ ﺳَﺒَﻘَﺖْ ﻟَﻪُ، ﻫِﻲَ ﻣِﻦْ ﺟُﻤْﻠَﺔِ أَﺣْـﻮَالِ</span></p>
# <p class="r"><span class="r">ﻋَﻴْﻨِﻪِ، ﻳَﻌْـﺮِﻓُﻬَﺎ ﺻَﺎﺣِﺐُ ﻫٰﺬَا اﻟﻜَﺸْﻒِ إِذَا أَﻃْﻠَﻌَﻪُ اﻟﻠّٰﻪُ ﻋَﻠَﲐ ذٰﻟِﻚَ ― أَىْ</span><span class="l"> :</span><span class="r">ﻋَﻠَﲐ</span></p>
# <p class="r"><span class="r">أَﺣْﻮَالِ ﻋَﻴﻨِﻪِ ― ﻓَﺎِٕﻧﱠﻪُ</span><span class="l"> 55</span><span class="r">ﻟَـﻴْﺲَ ﻓِﻲ وُﺳْﻊِ اﻟﻤَﺨْـﻠُﻮقِ إِذَا أَﻃْﻠَﻌَﻪُ اﻟﻠّٰﻪُ ﻋَﻠَﲐ أَﺣْـﻮَالِ</span></p>
# <p class="r"><span class="r">ﻋَﻴﻨِﻪِ اﻟﺜﱠﺎﺑِﺘَﺔِ اﻟﱠﺘِﻲ ﺗَﻘَﻊُ</span><span class="l">)</span><span class="r">١</span><span class="l"> (</span><span class="r">ﺻُﻮرَةُ اﻟﻮُﺟُﻮدِ ﻋَﻠَﻴﻬَﺎ، أَنْ ﻳَﻄﱠﻠِﻊَ ﻓِﻲ ﻫٰﺬِهِ اﻟﺤَﺎلِ ﻋَﻠَﲐ</span></p>
# <p class="r"><span class="r">ٱﻃﱢﻼَعِ اﻟﺤَﻖِّ ﻋَﻠَﲐ ﻫٰﺬِهِ اﻷَﻋْـﻴَﺎنِ اﻟﺜﱠﺎﺑِﺘَﺔِ ﻓِﻲ ﺣَﺎلِ ﻋَﺪَﻣِﻬَﺎ؛ لِأَﻧﱠﻬَﺎ</span><span class="l"> 56</span><span class="r">ﻧِﺴَﺐٌ ذَاﺗِﻴَّﺔٌ</span></p>
# <p class="r"><span class="r">لَا ﺻُﻮرَةَ ﻟَﻬَﺎ</span><span class="l">.</span></p>
# <p class="r"><span class="r">ﻓَﺒِﻬٰﺬَا اﻟﻘَﺪْرِ ﻧَﻘُﻮلُ إِنﱠ اﻟﻌِﻨَﺎﻳَﺔَ اﻻِٕﻟٰﻬِﻴَّﺔَ ﺳَﺒَﻘَﺖْ ﻟِﻬٰﺬَا اﻟﻌَﺒْﺪِ ﺑِﻬٰﺬِهِ اﻟﻤُﺴَﺎوَاةِ ﻓِﻲ</span></p>
# <p class="r"><span class="r">إِﻓَﺎدَةِ اﻟﻌِﻠْﻢِ</span><span class="l">.</span></p>
# <p class="r"><span class="l">)</span><span class="r">١</span><span class="l"> (</span><span class="r">ق</span><span class="l">) :</span><span class="r">ﻳﻘﻊ</span><span class="l">(</span><span class="r">، واﻟﺼﻮاب ﻣﺎأﺛﺒﺘﻨﺎه</span><span class="l">.</span></p>
# <p class="r"><span class="l"> .55</span><span class="r">ﺷﺮح اﻟﻘﻴﺼﺮي، ص ٥٢٤</span><span class="l">)» :</span><span class="r">ﻓَﺎِٕﻧﱠﻪُ</span><span class="l"> (</span><span class="r">اﻟﻀﻤﻴﺮ ﻟﻠﺸﺄن </span><span class="l">)</span><span class="r">ﻟَـﻴْﺲَ ﻓِﻲ وُﺳْﻊِ اﻟﻤَﺨْـﻠُﻮقِ إِذَا</span></p>
# <p class="r"><span class="r">أَﻃْﻠَﻌَﻪُ اﻟﻠّٰﻪُ ﻋَﻠَﲐ أَﺣْـﻮَالِ ﻋَﻴﻨِﻪِ اﻟﺜﱠﺎﺑِﺘَﺔِ اﻟﱠﺘِﻲ ﺗَﻘَﻊُ</span><span class="l"></span><span class="r">ﺻُﻮرَةُ اﻟﻮُﺟُﻮدِ ﻋَﻠَﻴﻬَﺎ أَنْ ﻳَﻄﱠﻠِﻊَ ﻓِﻲ ﻫٰﺬِهِ اﻟﺤَﺎلِ</span></p>
# <p class="r"><span class="r">ﻋَﻠَﲐ ٱﻃﱢﻼَعِ اﻟﺤَﻖِّ ﻋَﻠَﲐ ﻫٰﺬِهِ اﻷَﻋْـﻴَﺎنِ اﻟﺜﱠﺎﺑِﺘَﺔِ ﻓِﻲ ﺣَﺎلِ ﻋَﺪَﻣِﻬَﺎ لِأَﻧﱠﻬَﺎ</span><span class="l"></span><span class="r">ﻧِﺴَﺐٌ ذَاﺗِﻴَّﺔٌ لَا ﺻُﻮرَةَ</span></p>
# <p class="r"><span class="r">ﻟَﻬَﺎ</span><span class="l"> (</span><span class="r">ﻫٰﺬا ﺗﻌﻠﻴﻞ ﻟﻘﻮﻟﻪ</span><span class="l">) :</span><span class="r">إٍلﱠا أَﻧﱠﻪُ ﻣِﻦْ ﺟِﻬَﺔِ اﻟﻌَﺒْﺪِ ﻋِﻨَﺎﻳَﺔٌ ﻣِﻦَ اﻟﻠّٰﻪِ</span><span class="l"> (</span><span class="r">أي</span><span class="l"> :</span><span class="r">ﻟﻴﺲ ﰲ وﺳﻊ اﻟﻤﺨﻠﻮق</span></p>
# <p class="r"><span class="r">أﻧّﻪ إذا أﻃﻠﻌﻪ اﻟﻠّٰﻪ ﻋﻠﲐ أﺣﻮال ﻋﻴﻨﻪ اﻟﺜﺎﺑﺘﺔ ﺑﺤﺴﺐ اﻟﻌﻠﻢ أن ﻳﻄّﻠﻊ ﻋﻠﻴﻬﺎ ﺣﺎلَ اﻃّﻼﻋﻪ ﻋﻠﲐ</span></p>
# <p class="r"><span class="r">أﺣﻮاﻟﻬﺎﻛﺸﻔًﺎ وﺷﻬﻮدًاﻛﻢ ﻳﻄّﻠﻊ اﻟﺤﻖّ ﻋﻠﻴﻬﺎ ﺷﻬﻮدًا</span><span class="l">.«</span></p>
# <p class="r"><span class="l"> .56</span><span class="r">ﺷﺮح اﻟﻘﻴﺼﺮي، ص ٥٢٤‐٦٢٤</span><span class="l">» :</span><span class="r">وﺿﻤﻴﺮ </span><span class="l">)</span><span class="r">لِأَﻧﱠﻬَﺎ</span><span class="l"> (</span><span class="r">ﻋﺎﺋﺪ إﻟﲐ اﻷﻋﻴﺎن</span><span class="l"> …«</span><span class="r">وﻗﻴﻞ</span><span class="l">:</span></p>
# <p class="r"><span class="r">ﺿﻤﻴﺮ </span><span class="l">)</span><span class="r">لِأَﻧﱠﻬَﺎ</span><span class="l"> (</span><span class="r">ﻋﺎﺋﺪ إﻟﲐ اﻻﻃﻼع، وﺗﺄﻧﻴﺜﻪ ﺑﺎﻋﺘﺒﺎر اﻟﺨﱪ، وﻫﻮ اﻟﻨﱢﺴﺐ</span><span class="l"> .</span><span class="r">وﻓﻴﻪ ﻧﻈﺮ؛ إذ ﻻ</span></p>
# <p class="r"><span class="r">ﻳﺼﺪق ﻋﻠﲐ اﻻﻃﻼع أﻧﻪ ﻧِﺴَﺐٌ ذاﺗﻴﺔ، ﻷﻧﻪ ﻧﺴﺒﺔ ﻣﻦ اﻟﻨﱢﺴﺐ، ﻻ ﻛﻠﻬﺎ</span><span class="l">.«</span></p>

# %% [markdown]
# # Special cases

# %%
testPages = "185"
Lw.getPages(testPages, refreshConfig=True)
Lw.drawPages(testPages)
Lw.showLines(testPages, line="4", start=84, end=90)
Lw.showLines(testPages, line="5", start=101, end=109)
Lw.htmlPages(testPages)
# Out:
# 	   1 (page  185)
# <p><b>page 185</b></p>
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 185</th>
#     <th colspan=2>line 4</th>
#     <th colspan=3>102 characters</th>
# </tr>
#
# <tr>
#     <td><b>84</b></td>
#     <td>1387</td>
#     <td>1601</td>
#     <td>1295</td>
#     <td>1327</td>
#     <td>«9»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻴ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH MEDIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻴ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH MEDIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>85</b></td>
#     <td>1387</td>
#     <td>1601</td>
#     <td>1283</td>
#     <td>1297</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>86</b></td>
#     <td>1387</td>
#     <td>1601</td>
#     <td>1155</td>
#     <td>1295</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fc60</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﱠ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH FATHA ISOLATED FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0651</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ّ</span></div>
#     <div class="cn"><span class="c">ARABIC SHADDA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>87</b></td>
#     <td>1387</td>
#     <td>1601</td>
#     <td>1155</td>
#     <td>1295</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e81d</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fcf4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﳴ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH KASRA MEDIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>88</b></td>
#     <td>1387</td>
#     <td>1601</td>
#     <td>1245</td>
#     <td>1286</td>
#     <td>⌊34⌋</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fe94</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺔ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TEH MARBUTA FINAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fe94</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺔ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TEH MARBUTA FINAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>89</b></td>
#     <td>1387</td>
#     <td>1601</td>
#     <td>1105</td>
#     <td>1245</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e864</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0020</span></div>
#     <div class="cn"><span class="cni"><span class="lc"> </span></div>
#     <div class="cn"><span class="c">SPACE</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>90</b></td>
#     <td>1387</td>
#     <td>1601</td>
#     <td>1162</td>
#     <td>1211</td>
#     <td>«9»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fed3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻓ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER FEH INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fed3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻓ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER FEH INITIAL FORM</span></div>
# </div>
# </td>
# </tr>
# </table>
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 185</th>
#     <th colspan=2>line 5</th>
#     <th colspan=3>118 characters</th>
# </tr>
#
# <tr>
#     <td><b>101</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1332</td>
#     <td>1364</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>102</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1296</td>
#     <td>1332</td>
#     <td>«6»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedf</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻟ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedf</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻟ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM INITIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>103</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1286</td>
#     <td>1300</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>104</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1210</td>
#     <td>1290</td>
#     <td>«6»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedc</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻜ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER KAF MEDIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedc</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻜ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER KAF MEDIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>105</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1070</td>
#     <td>1210</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>106</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1200</td>
#     <td>1214</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>107</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1132</td>
#     <td>1205</td>
#     <td>«6»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feb8</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺸ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER SHEEN MEDIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feb8</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺸ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER SHEEN MEDIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>108</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1122</td>
#     <td>1136</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>109</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>992</td>
#     <td>1132</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
# </tr>
# </table>
# <p class="r"><span class="r">٥٨١</span></p>
# <p class="r"><span class="r">ﻳَﺘَﻜَﺮَّرُ، ﻓَﻴَﺼْﺪُقُ ﻋَﻠَﻴْﻪِ ﻓِﻲ اﻟﻬُﻮِﻳَّﺔ ﴿وَﺑَﺪَا ﻟَﻬُﻢْ ﻣِﻦَ ٱﻟﻠّٰﻪِ﴾ ﻓِﻲ ﻫُﻮِﻳَّﺘِﻪِ ﴿ﻣَﺎﻟَﻢْ</span></p>
# <p class="r"><span class="r">ﻳَﻜُﻮﻧُﻮا ﻳَﺤْﺘَﺴِﺒُﻮنَ﴾ </span><span class="l">]</span><span class="r">ﺳﻮرةاﻟﺰُّﻣَﺮ</span><span class="l">)</span><span class="r">٩٣</span><span class="l">:(</span><span class="r">٧٤</span><span class="l"> [</span><span class="r">ﻓِﻴﻬَﺎ ﻗَﺒﻞَﻛَﺸْﻒِ اﻟﻐِﻄَﺎءِ</span><span class="l">.</span></p>
# <p class="r"><span class="r">وَﻗَﺪْ ذَﻛَﺮْﻧَﺎ ﺻُﻮْرَةَ اﻟﺘَّﺮَﻗِﻲ ﺑَﻌﺪَ اﻟﻤَﻮْتِ ﻓِﻲ اﻟﻤَﻌَﺎرِفِ اﻻِٕﻟٰﻬَﻴَّﳴﺔِ ﻓِﻲﻛِﺘَﺎبِ</span></p>
# <p class="r"><span class="r">اﻟﺘَّﺠَﻠﱢـﻴَّﺎتِ ﻟَﻨَﺎ، </span><span class="l"> 298</span><span class="r">ﻋِﻨْﺪَ ذِﻛْﺮِﻧَﺎ ﻣَﻦْٱﺟْﺘَﻤَﻌْﻨَﺎ ﺑِﻪِ ﻣِﻦَ اﻟﻄَّﺎﺋِﻔَﺔِ ﻓِﻲ اﻟﻜَﺸْﻒِ، وَﻣَﺎ</span></p>
# <p class="r"><span class="r">أَﻓَﺪْﻧَﺎﻫُﻢْ ﰲ ﻫٰﺬِهِ اﻟﻤَﺴَﺄَﻟَﺔِ، ﻣِﻤَّﺎ ﻟَﻢْ ﻳَﻜُﻦْ ﻋِﻨْﺪَﻫَﻢْ</span><span class="l">299.</span></p>
# <p class="r"><span class="r">وَﻣِﻦْ أَﻋْﺠَﺐِ اﻷَﻣْﺮِ، أَﻧَّﻪُ ﻓِﻲ اﻟﺘَّﺮَﻗِﻲ دَاﺋِﻤًﺎ، وَﻻَ ﻳَﺸْﻌُـﺮُ ﺑِﺬٰﻟِﻚَ ﻟِﻠَّﻄَﺎﻓَﺔِ</span></p>
# <p class="r"><span class="r">وَاﻟﺤِﺠَﺎبِ وَرِﻗَّﺘِﻪِ، وَﺗَﺸَﺎﺑُﻪِ اﻟﺼُّﻮَرِ، ﻣِﺜْﻞَ ﻗَﻮْﻟَﻪُ</span><span class="l"> :</span><span class="r">﴿وَأُﺗُﻮا ﺑِﻪِ ﻣُﺘَﺸَـٰﺒِﻬًﺎ﴾ </span><span class="l">]</span><span class="r">ﺳﻮرةاﻟﺒﻘﺮة</span></p>
# <p class="r"><span class="l">)</span><span class="r">٢</span><span class="l">:(</span><span class="r">٥٢</span><span class="l">.[</span></p>
# <p class="r"><span class="r">وَﻟَﻴﺲَ ﻫُﻮَ</span><span class="l"> 300</span><span class="r">اﻟﻮَاﺣِﺪُ</span><span class="l"> 301</span><span class="r">ﻋَﲔَ اﻵﺧَـﺮِ، </span><span class="l"> 302</span><span class="r">ﻓَﺎِٕنَّ اﻟﺸَّﺒِﻴﻬَﲔِ ﻋِﻨﺪَ اﻟﻌَﺎرِفِ إِﻧَّﻬُﻤَﺎ</span></p>
# <p class="r"><span class="l">» .298</span><span class="r">وَﻗَﺪْ ذَﻛَﺮْﻧَﺎ ﺻُﻮْرْةَ اﻟﺘَّﺮَﻗِﻲ ﺑَﻌﺪَ اﻟﻤَﻮْتِ ﻓِﻲ اﻟﻤَﻌَﺎرِفِ اﻻِٕﻟٰﻬَﻴَّﳴﺔِ ﻓِﻲﻛِﺘَﺎبِ</span></p>
# <p class="r"><span class="r">اﻟﺘَّﺠَﻠﱢـﻴَّﺎتِ ﻟَﻨَﺎ</span><span class="l"> :«</span><span class="r">راﺟﻊ ﻣﺤﻴﻲ اﻟﺪﻳﻦ ﺑﻦ اﻟﻌﺮﺑﻲ، اﻟﺘﺠﻠﻴﺎت اﻹﻟٰﻬﻴﺔ، ﺗﺤﻘﻴﻖ ﻋﺜﻤﺎن</span></p>
# <p class="r"><span class="r">إﺳﻤﺎﻋﻴﻞ ﻳﺤﻴﲐ، ﻃﻬﺮان</span><span class="l"> :</span><span class="r">ﻣﺮﻛﺰِ ﻧﺸﺮِ داﻧﺸﮕﺎﻫﻰ، ٨٠٤١ﻫـ</span><span class="l">/</span><span class="r">٨٨٩١م، ص ٣٩٣، ﻓﻘﺮة ٤٣٣</span><span class="l">.</span></p>
# <p class="r"><span class="l"> .299</span><span class="r">أراد اﻟﻤﺼﻨﱢﻒ ﻗﺪس ﺳـﺮه ﺑﻘﻮﻟﻪ </span><span class="l">)</span><span class="r">ﻣَﻦْٱﺟْﺘَﻤَﻌْﻨَﺎ ﺑِﻪِ ﻣِﻦَ اﻟﻄَّﺎﺋِﻔَﺔِ ﻓِﻲ اﻟﻜَﺸْﻒِ</span><span class="l"> (</span><span class="r">ذا</span></p>
# <p class="r"><span class="r">اﻟﻨّﻮن اﻟﻤﺼﺮي، راﺟﻊ اﻟﺘّﺠﻠﻴّﺎت اﻹﻟٰﻬﻴّﺔ ﻣﻊ ﺗﻌﻠﻴﻘﺎت اﺑﻦ ﺳﻮدﻛﲔ، ﺗﺤﻘﻴﻖ ﻋﺜﻤﺎن ﻳﺤﻴﲐ،</span></p>
# <p class="r"><span class="r">ﻃﻬﺮان</span><span class="l"> :</span><span class="r">ﻣﺮﻛﺰ ﻧﺸﺮ داﻧﺸﮕﺎﻫﻰ ٨٠٤١ﻫـ</span><span class="l">/</span><span class="r">٨٨٩١م، ص ٣٩٣، اﻟﻔﻘﺮة رﻗﻢ ٤٣٣</span><span class="l">.</span></p>
# <p class="r"><span class="l"> .300</span><span class="r">ﺷﺮح اﻟﻘﻴﺼﺮي، ص ٩٨٧</span><span class="l">» :</span><span class="r">ﻳﺠﻮز أن ﻳﻜﻮن </span><span class="l">)</span><span class="r">ﻫُﻮَ</span><span class="l"> (</span><span class="r">ﺗﺄﻛﻴﺪًا ﻟﻠﻀﻤﻴﺮ اﻟﻤﺴﺘﱰ …</span></p>
# <p class="r"><span class="r">وﻳﺠﻮز أن ﻳﻜﻮن </span><span class="l">)</span><span class="r">ﻫُﻮَ</span><span class="l"> (</span><span class="r">ﺑﻤﻌﻨﲐ</span><span class="l">) :</span><span class="r">ذٰﻟِﻚَ</span><span class="l">.«(</span></p>
# <p class="r"><span class="l"> .301</span><span class="r">ﺷﺮح اﻟﻘﻴﺼﺮي، ص ٩٨٧</span><span class="l">» :</span><span class="r">و </span><span class="l">)</span><span class="r">اﻟﻮَاﺣِﺪُ</span><span class="l"> (</span><span class="r">ﻋﻄﻒ ﺑﻴﺎن ﻟﻪ</span><span class="l">.«</span></p>
# <p class="r"><span class="l"> .302</span><span class="r">ﺷﺮح اﻟﻘﻴﺼﺮي، ص ٩٨٧</span><span class="l">)» :</span><span class="r">ﻋَﲔَ اﻵﺧِﺮِ</span><span class="l"> (</span><span class="r">ﺧﱪ </span><span class="l">)</span><span class="r">ﻟَﻴﺲَ</span><span class="l">.«(</span></p>

# %% [markdown]
# # Getting the right LAM-ALEF ligature

# %%
testPages = "45"
Lw.drawPages(testPages)
Lw.getPages(testPages)
Lw.showLines(testPages, line=9, start=88, end=97)
Lw.showReplacements(rule=78)
Lw.htmlPages(testPages)
# Out:
# <p><b>page 45</b></p>
# 	   1 (page   45)
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 45</th>
#     <th colspan=2>line 9</th>
#     <th colspan=3>118 characters</th>
# </tr>
#
# <tr>
#     <td><b>88</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1528</td>
#     <td>1559</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>89</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1388</td>
#     <td>1528</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e845</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0655</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ٕ</span></div>
#     <div class="cn"><span class="c">ARABIC HAMZA BELOW</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>90</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1451</td>
#     <td>1528</td>
#     <td>«6»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fec3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻃ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TAH INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fec3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻃ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TAH INITIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>91</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1311</td>
#     <td>1451</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>92</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1441</td>
#     <td>1455</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>93</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1407</td>
#     <td>1445</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e80e</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>94</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1267</td>
#     <td>1407</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>95</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1358</td>
#     <td>1407</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e807</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>96</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1218</td>
#     <td>1358</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e86d</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>97</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1273</td>
#     <td>1358</td>
#     <td>⌊34⌋</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0642</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ق</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER QAF</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0642</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ق</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER QAF</span></div>
# </div>
# </td>
# </tr>
# </table>
# <p class="r"><span class="r">٥٤</span></p>
# <p class="r"><span class="r">ﻣَﺎﺷَﻔَﻊَ ﻋِﻨْﺪَ </span><span class="l">»</span><span class="r">اﻟﻤُﻨْﺘَﻘِﻢِ</span><span class="l"> «</span><span class="r">ﻓِﻲ أَﻫْﻞِ اﻟﺒَلَاءِ، إِﻻﱠ ﺑَﻌْﺪَ ﺷَﻔَﺎﻋَﺔِ اﻟﺸﱠﺎﻓِﻌِﻴْﻦَ، ﻓَﻔَﺎزَ ﻣُﺤَﻤَّﺪٌ</span></p>
# <p class="r"><span class="r">ﺻَﻠﱠﲐ اﻟﻠّٰﻪُ ﻋَﻠَﻴْﻪِ وَﺳَﻠﱠﻢَ ﺑِﺎﻟﺴِّﻴَﺎدَةِ ﻓِﻲ ﻫٰﺬَا اﻟﻤَﻘَﺎمِ اﻟﺨَﺎصِّ</span><span class="l"> .</span><span class="r">ﻓَﻤَﻦْ ﻓَﻬِﻢَ اﻟﻤَﺮَاﺗِﺐَِ</span></p>
# <p class="r"><span class="r">وَاﻟﻤَﻘَﺎﻣَﺎتِ، ﻟَﻢْ ﻳَﻌْﺴُﺮْ ﻋَﻠَﻴﻪِ ﻗَـﺒُﻮلُ ﻣِﺜْﻞِ ﻫٰﺬَا اﻟﻜَلَامِ</span><span class="l">.</span></p>
# <p class="r"><span class="r">وَأَﻣَّﺎ اﻟﻤِﻨَﺢُ اﻷَﺳْﻤَﺎﺋِﻴَّﺔُ</span><span class="l"> :</span><span class="r">ﻓَﭑﻋْﻠَﻢْ أَنﱠ ﻣَﻨْﺢَ اﻟﻠّٰﻪِ ﺗَﻌَﺎﻟَﲐ ﺧَﻠْﻘَﻪُ رَﺣْﻤَﺔً ﻣِﻨْﻪُ ﺑِﻬِﻢْ،</span></p>
# <p class="r"><span class="r">وَﻫِﻲَﻛُﻠﱠﻬَﺎ ﻣِﻦَ اﻷَﺳْﻤَﺎءِ، ﻓَﺎِٕﻣَّﺎ رَﺣْﻤَﺔٌ ﺧَﺎﻟِﺼَﺔٌ، ﻛﺎﻟﻄﱠـﻴِّﺐِ ﻣِﻦَ اﻟﺮِّزْقِ اﻟﱠﻠَﺬِﻳﺬِ ﻓِﻲ</span></p>
# <p class="r"><span class="r">اﻟﺪﱡﻧْﻴَﺎ اﻟﺨَﺎﻟِﺺِ ﻳَﻮمَ اﻟﻘِﻴَﺎﻣَﺔِ، وَﻳُﻌْﻄِﻲ ذٰﻟِﻚَ الٱﺳْﻢُ </span><span class="l">»</span><span class="r">اﻟﺮَّﺣْﻤٰﻦُ</span><span class="l">«</span><span class="r">، ﻓَﻬُﻮَ ﻋَﻄَﺎءٌ</span></p>
# <p class="r"><span class="r">رَﺣْﻤَﺎﻧِﻲٌّ</span><span class="l"> .</span><span class="r">وَإِﻣَّﺎ رَﺣْﻤَﺔٌ ﻣُﻤْﺘَـﺰِﺟَﺔُ، ﻛﺸُﺮْبِ اﻟﺪﱠوَاءِ اﻟﻜَﺮِهِ اﻟﱠﺬِي ﻳَﻌْﻘُﺐُ ﺷُﺮْﺑُﻪُ</span></p>
# <p class="r"><span class="r">اﻟﺮَّاﺣَﺔَ، وَﻫُﻮَ ﻋَﻄَﺎءٌ إِﻟٰﻬِﻲِّ، ﻓَﺎِٕنﱠ اﻟﻌَﻄَﺎءَ اﻻِٕﻟٰﻬِﻲَّ، ﻻَ ﻳَﺘَﻤَﻜﱠﻦُ إِﻃْلَاَقُ ﻋَﻄَﺎﺋِﻪِ ﻣِﻨْﻪُ</span></p>
# <p class="r"><span class="r">ﻣِﻦْ ﻏَﻴﺮِ أَنْ ﻳَﻜُﻮنَ ﻋَﻠَﲐ ﻳَﺪِ ﺳَﺎدِنٍ ﻣِﻦْ ﺳَﺪَﻧَﺔِ اﻷَﺳْﻤَﺎءِ</span><span class="l">.</span></p>
# <p class="r"><span class="r">ﻓَﺘَﺎرَةً ﻳُﻌْﻄِﻲ اﻟﻠّٰﻪُ اﻟﻌَﺒْﺪَ ﻋَﻠَﲐ ﻳَﺪَيِ </span><span class="l">»</span><span class="r">اﻟﺮَّﺣْﻤٰﻦِ</span><span class="l">«</span><span class="r">، </span><span class="l">)</span><span class="r">١</span><span class="l"> (</span><span class="r">ﻓَﻴْﺨْﻠُﺺُ اﻟﻌَﻄَﺎءُ ﻣِﻦَ</span></p>
# <p class="r"><span class="r">اﻟﺸﱠﻮْبِ اﻟﱠﺬِي ﻻَ ﻳُلَاﺋِﻢُ اﻟﻄﱠـﺒْﻊَ ﻓِﻲ اﻟﻮَﻗْﺖَ </span><span class="l">]</span><span class="r">٩ ﻇﻬﺮ</span><span class="l"> [</span><span class="r">أَوْ ﻻَ ﻳُﻨِﻴﻞُ اﻟﻐَﺮضََ وَﻣَﺎ</span></p>
# <p class="r"><span class="r">أَﺷْﺒَﻪَ ذٰﻟِﻚَ</span><span class="l">.</span></p>
# <p class="r"><span class="r">وَﺗَﺎرَةً ﻳُﻌْﻄِﻲ اﻟﻠّٰﻪُ ﻋَﻠَﲐ ﻳَﺪَيِ </span><span class="l">»</span><span class="r">اﻟﻮَاﺳِﻊِ</span><span class="l"> «</span><span class="r">ﻓَـﻴَﻌُﻢُّ</span><span class="l">.</span></p>
# <p class="r"><span class="r">أَوْ ﻋَﻠَﲐ ﻳِﺪَيِ </span><span class="l">»</span><span class="r">اﻟﺤَﻜِﻴْﻢِ</span><span class="l"> «</span><span class="r">ﻓَـﻴَﻨْﻈُـﺮُ ﻓِﻲ اﻷَﺻْﻠَﺢِ ﻓِﻲ اﻟﻮَﻗْﺖِ</span><span class="l">.</span></p>
# <p class="r"><span class="r">أَوْ ﻋَﻠَﲐ ﻳَﺪِ </span><span class="l">»</span><span class="r">اﻟﻮَاﻫِﺐِ</span><span class="l"> «</span><span class="r">ﻓَـﻴُﻌْﻄِﻲ ﻟِﻴُﻨْﻌِﻢَ، ﻻَ ﻳَﻜُﻮنُ ﻣَﻊَ </span><span class="l">»</span><span class="r">اﻟﻮَاﻫِﺐِ</span><span class="l"> «</span><span class="r">ﺗَﻜْﻠِﻴْﻒُ</span></p>
# <p class="r"><span class="r">اﻟﻤُﻌْﻄِﻲ ﻟَﻪُ ﺑِﻌِﻮضٍَ ﻋَﻠَﲐ ذٰﻟِﻚَ ﻣِﻦ ﺷُـﻜْﺮٍ أَوْ ﻋَﻤَﻞٍ</span><span class="l">.</span></p>
# <p class="r"><span class="r">أَوْ ﻋَﻠَﲐ ﻳَﺪِ </span><span class="l">»</span><span class="r">اﻟﺠَﺒَّﺎرِ</span><span class="l"> «</span><span class="r">ﻓَـﻴَﻨْﻈُـﺮُ ﻓِﻲ اﻟﻤَﻮْﻃِﻦِ وَﻣَﺎ ﻳَﺴْﺘَﺤِﻘﱡﻪُ</span><span class="l">.</span></p>
# <p class="r"><span class="r">أَوْ ﻋَﻠَﲐ ﻳَﺪِ </span><span class="l">»</span><span class="r">اﻟﻐَﻔﱠﺎرِ</span><span class="l"> «</span><span class="r">ﻓَـﻴَﻨْﻈُـﺮُ اﻟﻤَﺤَﻞَّ، وَﻣَﺎ ﻫُﻮَ ﻋَﻠَﻴْﻪِ، ﻓَﺎِٕنْﻛَﺎنَ ﻋَﻠَﲐ ﺣَﺎلٍ</span></p>
# <p class="r"><span class="l">)</span><span class="r">١</span><span class="l"> (</span><span class="r">ق</span><span class="l"> :</span><span class="r">وردت اﻟﻜﻠﻤﺔ ﺑﺎﻟﻤﱳ ﻫٰﻜﺬا</span><span class="l">) :</span><span class="r">اﻟﺮﺣﻤﺎن</span><span class="l">.(</span></p>

# %%
Lw.showString("\u0625\u0650\ufec3\u0652\u0644\u064e\u0627\u064e\u0642\u064f")
Lw.showString("\u0625\u0650\u0637\u0652\u0644\u064e\u0627\u064e\u0642\u064f")
# Out:
# <p><span class="r">إِﻃْلَاَقُ</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">0625</span></div>
#     <div class="cn"><span class="cni"><span class="rc">إ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF WITH HAMZA BELOW</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">fec3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻃ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TAH INITIAL FORM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0642</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ق</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER QAF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064f</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ُ</span></div>
#     <div class="cn"><span class="c">ARABIC DAMMA</span></div>
# </div>
# </div>
# <p><span class="r">إِطْلَاَقُ</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">0625</span></div>
#     <div class="cn"><span class="cni"><span class="rc">إ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF WITH HAMZA BELOW</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0637</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ط</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TAH</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0642</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ق</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER QAF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064f</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ُ</span></div>
#     <div class="cn"><span class="c">ARABIC DAMMA</span></div>
# </div>
# </div>

# %%
Lw.showString("\ufefb \ufefc")
# Out:
# <p><span class="r">ﻻ ﻼ</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">fefb</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻻ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE LAM WITH ALEF ISOLATED FORM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0020</span></div>
#     <div class="cn"><span class="cni"><span class="lc"> </span></div>
#     <div class="cn"><span class="c">SPACE</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">fefc</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻼ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE LAM WITH ALEF FINAL FORM</span></div>
# </div>
# </div>
