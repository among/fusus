# %%
# %load_ext autoreload
# %autoreload 2
# !cd `pwd`

# %%
from fusus.lakhnawi import Lakhnawi, pprint
Lw = Lakhnawi()
Lw.setStyle()
# Out:
# <style>
# .r {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     direction: rtl;
# }
# .rc, .lc {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     background-color: white;
#     border: 2pt solid #ffcccc;
# }
# .rc {
#     direction: rtl;
# }
# .lc {
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# p {
#     text-align: left;
#     direction: ltr;
# }
# p.r {
#     text-align: right;
#     direction: rtl;
# }
# .l {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# .c {
#     font-family: monospace;
#     font-size: x-small;
#     direction: ltr;
# }
# .p {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     background-color: yellow;
#     direction: ltr;
# }
# .lrg {
#     font-size: xx-large;
#     font-weight: bold;
# }
# td {
#     text-align: left ! important;
# }
# div.cn {
#     text-align: center
# }
# div.ch.p {
#     background-color: #ffeedd;
#     text-align: center
# }
# span.cni {
#     background-color: #eeeeee;
#     padding-top: 4pt;
#     padding-bottom: 4pt;
#     padding-left: 8pt;
#     padding-right: 8pt;
#     border: 2pt solid #66aaaa;
#     display: inline-block;
# }
# div.ch {
#     border: 2pt solid #cccccc;
#     background-color: #ddffff;
#     display: inline-flex;
#     flex-flow: column nowrap;
#     max-width: 10em;
# }
# div.sr {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# </style>

# %%
testPages = "359"
char = "\ue85c"
Lw.drawPages(testPages)
# Out:
# <p><b>page 359</b></p>

# %%
Lw.getPages(testPages, refreshConfig=True)
Lw.showLines(testPages, search=char)
# Out:
# 	   1 (page  359)
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 359</th>
#     <th colspan=2>line 1</th>
#     <th colspan=3>3 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 359</th>
#     <th colspan=2>line 2</th>
#     <th colspan=3>24 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 359</th>
#     <th colspan=2>line 3</th>
#     <th colspan=3>116 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 359</th>
#     <th colspan=2>line 4</th>
#     <th colspan=3>128 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 359</th>
#     <th colspan=2>line 5</th>
#     <th colspan=3>120 characters</th>
# </tr>
#
# <tr>
#     <td><b>107</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1084</td>
#     <td>1224</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fc62</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﱢ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH KASRA ISOLATED FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fc62</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﱢ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH KASRA ISOLATED FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>108</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1141</td>
#     <td>1222</td>
#     <td>⌊34⌋</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef2</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻲ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH FINAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef2</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻲ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH FINAL FORM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0020</span></div>
#     <div class="cn"><span class="cni"><span class="lc"> </span></div>
#     <div class="cn"><span class="c">SPACE</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>109</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1063</td>
#     <td>1107</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e80a</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>110</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>923</td>
#     <td>1063</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>111</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1020</td>
#     <td>1063</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e806</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>112</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>880</td>
#     <td>1020</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e85c</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e85c</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>113</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>948</td>
#     <td>1020</td>
#     <td>«2»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fecb</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻋ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER AIN INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fecb</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻋ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER AIN INITIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>114</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>808</td>
#     <td>948</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e8eb</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>115</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>873</td>
#     <td>946</td>
#     <td>«2»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fec4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻄ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TAH MEDIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fec4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻄ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TAH MEDIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>116</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>940</td>
#     <td>954</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>117</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>865</td>
#     <td>879</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
# </table>

# %%
Lw.getPages(testPages, refreshConfig=True)
# Lw.showReplacements(isApplied=False)
Lw.showLines(testPages, search=char, orig=True)
# Out:
# 	   1 (page  359)
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 359</th>
#     <th colspan=2>line 1</th>
#     <th colspan=3>3 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 359</th>
#     <th colspan=2>line 2</th>
#     <th colspan=3>24 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 359</th>
#     <th colspan=2>line 3</th>
#     <th colspan=3>116 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 359</th>
#     <th colspan=2>line 4</th>
#     <th colspan=3>128 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 359</th>
#     <th colspan=2>line 5</th>
#     <th colspan=3>120 characters</th>
# </tr>
#
# <tr>
#     <td><b>107</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1084</td>
#     <td>1224</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fc62</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﱢ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH KASRA ISOLATED FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fc62</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﱢ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH KASRA ISOLATED FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>108</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1141</td>
#     <td>1222</td>
#     <td>⌊34⌋</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef2</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻲ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH FINAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef2</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻲ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH FINAL FORM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0020</span></div>
#     <div class="cn"><span class="cni"><span class="lc"> </span></div>
#     <div class="cn"><span class="c">SPACE</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>109</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1063</td>
#     <td>1107</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e80a</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>110</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>923</td>
#     <td>1063</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>111</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1020</td>
#     <td>1063</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e806</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0623</span></div>
#     <div class="cn"><span class="cni"><span class="rc">أ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF WITH HAMZA ABOVE</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>112</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>880</td>
#     <td>1020</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e85c</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064f</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ُ</span></div>
#     <div class="cn"><span class="c">ARABIC DAMMA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>113</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>948</td>
#     <td>1020</td>
#     <td>«2»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fecb</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻋ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER AIN INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fecb</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻋ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER AIN INITIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>114</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>808</td>
#     <td>948</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e8eb</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>115</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>873</td>
#     <td>946</td>
#     <td>«2»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fec4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻄ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TAH MEDIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fec4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻄ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TAH MEDIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>116</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>940</td>
#     <td>954</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>117</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>865</td>
#     <td>879</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
# </table>

# %%
Lw.htmlPages(testPages)
# Out:
# <p class="r"><span class="r">٩٥٣</span></p>
# <p class="r"><span class="r">ﻟِﻠﺮُّوحِ اﻟﻤُﺪَﺑَّـﺮِ ﻟَﻪُ</span><span class="l">.</span></p>
# <p class="r"><span class="r">وَالأَﻧْﺒِﻴَﺎءُ ﻟَﻬُﻢْ ﻟِﺴَﺎنُ اﻟﻈﱠﺎﻫِﺮُ، ﺑِﻪِ ﻳَﺘَـﻜَﻠﱠﻤُﻮنَ ﻟِﻌُﻤُﻮمِ اﻟﺨِﻄَﺎبِ، وَٱﻋْﺘِﻤَﺎدِﻫِﻢْ</span></p>
# <p class="r"><span class="r">ﻋَﻠﲐ ﻓَﻬْﻢِ اﻟﻌَﺎﻟِﻢِ اﻟﺴَّﺎﻣِﻊِ، ﻓَلَا ﺗَﻌْﺘَﺒِﺮُ اﻟﺮُّﺳُﻞُ إِلﱠا اﻟﻌَﺎﻣَّﺔَ، ﻟِﻌِﻠْﻤِﻬِﻢْ ﺑِﻤَﺮْﺗَـﺒَﺔِ أَﻫْﻞِ</span></p>
# <p class="r"><span class="r">اﻟﻔَﻬْﻢِ ﻛَﻤَﺎ ﻧَﺒَّﻪَ ﻋَﻠَﻴﻪِ اﻟﺴَّلَامُ ﻋَﻠﲐ ﻫٰﺬِهِ اﻟﺮُّﺗْﺒَﺔِ ﻓِﻲ اﻟﻌَﻄَﺎﻳَﺎ ﻓَﻘَﺎلَ</span><span class="l">» :</span><span class="r">إِﻧﱢﻲ لَأُﻋْﻄِﻲَ</span></p>
# <p class="r"><span class="r">اﻟﺮَّﺟُﻞَ، وَﻏَﻴﺮُهُ أَﺣَﺐُّ إِﻟَﻲَّ ﻣِﻨْﻪُ ﻣَﺨَﺎﻓَﺔَ أَنْ ﻳُﻜِﺒَّﻪُ اﻟﻠّٰﻪُ ﻓِﻲ اﻟﻨﱠﺎرِ</span><span class="l">563.«</span></p>
# <p class="r"><span class="r">ﻓَﭑﻋْﺘَـﺒَﺮَ اﻟﻀَّﻌِﻴﻒَ اﻟﻌَﻘْﻞَ وَاﻟﻨﱠﻈْـﺮَ اﻟﱠﺬِي ﻏَﻠَﺐَ ﻋَﻠَﻴﻪِ اﻟﻄﱠﻤَﻊُ وَاﻟﻄَـﺒْﻊُ</span><span class="l">564.</span></p>
# <p class="r"><span class="r">ﻓَـﻜَﺬَا ﻣَﺎﺟَﺎؤُوا ﺑِﻪِ ﻣِﻦَ اﻟﻌُﻠُﻮمِ، ﺟَﺎؤُوا ﺑِﻪِ، </span><span class="l"> 565</span><span class="r">وَﻋَﻠَﻴﻪِ ﺧِﻠْﻌَﺔُ أَدْﻧَﲐ اﻟﻔُﻬُﻮمِ،</span></p>
# <p class="r"><span class="r">ﻛﺎﺻّﻮرة</span><span class="l">.«</span></p>
# <p class="r"><span class="l">» .563</span><span class="r">إِﻧﱢﻲ لَأُﻋْﻄِﻲَ اﻟﺮَّﺟُﻞَ، وَﻏَﻴﺮَهُ أَﺣَﺐُّ إِﻟَﻲَّ ﻣِﻨْﻪُ ﻣَﺨَﺎﻓَﺔَ أَنْ ﻳُﻜِﺒَّﻪُ اﻟﻠّٰﻪُ ﻓِﻲ اﻟﻨﱠﺎرِ</span><span class="l">:«</span></p>
# <p class="r"><span class="r">اﻟﺒﺨﺎري، اﻟﺠﺎﻣﻊ اﻟﺼﺤﻴﺢ، ﻛﺘﺎب اﻹﻳﻤﺎن، ﺑﺎب إن ﻟﻢ ﻳﻜﻦ اﻹﺳﻼم ﻋﻠﲐ اﻟﺤﻘﻴﻘﺔ وﻛﺎن</span></p>
# <p class="r"><span class="r">ﻋﻠﲐ اﻻﺳﺘﺴﻼم أو اﻟﺨﻮف ﻣﻦ اﻟﻘﺘﻞ، ﺟـ ١، ص ١١، رﻗﻢ اﻟﺤﺪﻳﺚ ٧٢؛ﻛﺘﺎب اﻟﺰﻛﺎة،</span></p>
# <p class="r"><span class="r">ﺑﺎب ﻗﻮل اﻟﻠّٰﻪ </span><span class="l">)</span><span class="r">لَا ﻳَﺴْﺄَﻟُﻮنَ ٱﻟﻨﱠﺎسَ إِﻟْﺤَﻔًﺎ</span><span class="l">(</span><span class="r">، ﺟـ ١، ص ٠٨٢، رﻗﻢ اﻟﺤﺪﻳﺚ ٢٠٥١</span><span class="l"> .</span><span class="r">ﻣﺴﻠﻢ،</span></p>
# <p class="r"><span class="r">اﻟﺠﺎﻣﻊ اﻟﺼﺤﻴﺢ، ﻛﺘﺎب اﻹﻳﻤﺎن،، ﺑﺎب ﺗﺄﻟﻒ ﻗﻠﺐ ﻣَﻦ ﻳﺨﺎف ﻋﻠﲐ إﻳﻤﺎﻧﻪ ﻟﻀﻌﻔﻪ، ﺟـ ١،</span></p>
# <p class="r"><span class="r">ص ٥٧، رﻗﻢ اﻟﺤﺪﻳﺚ ٥٩٣، ٦٩٣، ٧٩٣، ٨٩٣، ﻛﺘﺎب اﻟﺰﻛﺎة، ﺑﺎب إﻋﻄﺎء ﻣَﻦ ﻳُﺨﺎف</span></p>
# <p class="r"><span class="r">ﻋﻠﲐ إﻳﻤﺎﻧﻪ، ﺟـ ١، ص ٤١٤، رﻗﻢ اﻟﺤﺪﻳﺚ ٠٨٤٢، ١٨٤٢، ٢٨٤٢</span><span class="l"> .</span><span class="r">أﺑﻮ داود، اﻟﺴﲍ، ﻛﺘﺎب</span></p>
# <p class="r"><span class="r">اﻟﺴﻨّﺔ، ﺑﺎب اﻟﺪﻟﻴﻞ ﻋﻠﲐ زﻳﺎدة اﻹﻳﻤﺎن وﻧﻘﺼﺎﻧﻪ، ﺟـ ٢، ص ٧٨٧، رﻗﻢ اﻟﺤﺪﻳﺚ ٥٨٦٤ و</span></p>
# <p class="r"><span class="r">٧٨٦٤</span><span class="l"> .</span><span class="r">اﻟﻨﱠﺴﺎﺋﻲ، اﻟﺴﲍ، ﻛﺘﺎب اﻹﻳﻤﺎن وﺷﺮاﺋﻌﻪ، ﺑﺎب ﺗﺄوﻳﻞ ﻗﻮﻟﻪ ﻋﺰّ وﺟﻞّ</span><span class="l">) :</span><span class="r">ﻗَﺎﻟَﺖِ</span></p>
# <p class="r"><span class="r">ٱلأَﻋْﺮَابُ ءَاﻣَﻨﱠﺎ</span><span class="l">(</span><span class="r">، ﺟـ ٢، ص ٩٨٢، رﻗﻢ اﻟﺤﺪﻳﺚ ٩٠٠٥ و ٠١٠٥</span><span class="l">.</span></p>
# <p class="r"><span class="l"> .564</span><span class="r">ﻣﺎ ﺟﺎء ﰲ ﺷﺮح اﻟﻘﻴﺼﺮي، ص ١٣١١</span><span class="l">» :</span><span class="r">ﺑﻔﺘﺢ اﻟﺒﺎء …</span><span class="l">«</span><span class="r">، ﻏﻠﻂ، وﺻﻮاﺑﻪ</span><span class="l">:</span></p>
# <p class="r"><span class="l">)</span><span class="r">اﻟﻄّﺒْﻊُ</span><span class="l"> (</span><span class="r">ﺑﺴﻜﻮن اﻟﺒﺎء وﻟﻴﺲ ﺑﻔﺘﺤﻬﺎ، راﺟﻊ ﻟﺴﺎن اﻟﻌﺮب، ﻣﺎدة</span><span class="l">) :</span><span class="r">ﻃﺒﻊ</span><span class="l">.(</span></p>
# <p class="r"><span class="l"> .565</span><span class="r">ﺷﺮح اﻟﻘﻴﺼﺮي، ص ١٣١١</span><span class="l">» :</span><span class="r">أي</span><span class="l"> :</span><span class="r">ﺟﺎؤوا ﺑﻤﺎ ﺟﺎؤوا ﺑﻪ </span><span class="l">)</span><span class="r">وَﻋَﻠَﻴﻪِ ﺧِﻠْﻌَﺔُ أَدْﻧَﲐ</span></p>
# <p class="r"><span class="r">اﻟﻔُﻬُﻮمِ</span><span class="l"> (</span><span class="r">أي</span><span class="l"> :</span><span class="r">وﻋﻠﻴﻪ ﺧِﻠﻌﺔ وﻟﺒﺎس ﻳﻔﻬﻤﻪ ﻣﻦ ﻟﻪ أدﻧﲐ ﻓﻬﻢ</span><span class="l">.«</span></p>

# %% [markdown]
# # Special cases

# %% [markdown]
# ## Impossible tashkil
#
# Here is a word with a bizarre set of accents.
#
# ![logo](logo.png)
#
# See line 3 below.

# %%
testPages = "185"
Lw.getPages(testPages, refreshConfig=True)
Lw.drawPages(testPages)
Lw.showLines(testPages, line="4", start=84, end=90)
Lw.showLines(testPages, line="5", start=101, end=109)
Lw.htmlPages(testPages)
# Out:
# 	   1 (page  185)
# <p><b>page 185</b></p>
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 185</th>
#     <th colspan=2>line 4</th>
#     <th colspan=3>102 characters</th>
# </tr>
#
# <tr>
#     <td><b>84</b></td>
#     <td>1387</td>
#     <td>1601</td>
#     <td>1295</td>
#     <td>1327</td>
#     <td>«9»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻴ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH MEDIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻴ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH MEDIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>85</b></td>
#     <td>1387</td>
#     <td>1601</td>
#     <td>1283</td>
#     <td>1297</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>86</b></td>
#     <td>1387</td>
#     <td>1601</td>
#     <td>1155</td>
#     <td>1295</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fc60</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﱠ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH FATHA ISOLATED FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fc60</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﱠ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH FATHA ISOLATED FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>87</b></td>
#     <td>1387</td>
#     <td>1601</td>
#     <td>1155</td>
#     <td>1295</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e81d</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fcf4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﳴ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH KASRA MEDIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>88</b></td>
#     <td>1387</td>
#     <td>1601</td>
#     <td>1245</td>
#     <td>1286</td>
#     <td>⌊34⌋</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fe94</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺔ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TEH MARBUTA FINAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fe94</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺔ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TEH MARBUTA FINAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>89</b></td>
#     <td>1387</td>
#     <td>1601</td>
#     <td>1105</td>
#     <td>1245</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e864</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0020</span></div>
#     <div class="cn"><span class="cni"><span class="lc"> </span></div>
#     <div class="cn"><span class="c">SPACE</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>90</b></td>
#     <td>1387</td>
#     <td>1601</td>
#     <td>1162</td>
#     <td>1211</td>
#     <td>«9»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fed3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻓ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER FEH INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fed3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻓ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER FEH INITIAL FORM</span></div>
# </div>
# </td>
# </tr>
# </table>
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 185</th>
#     <th colspan=2>line 5</th>
#     <th colspan=3>118 characters</th>
# </tr>
#
# <tr>
#     <td><b>101</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1332</td>
#     <td>1364</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>102</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1296</td>
#     <td>1332</td>
#     <td>«6»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedf</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻟ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedf</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻟ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM INITIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>103</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1286</td>
#     <td>1300</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>104</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1210</td>
#     <td>1290</td>
#     <td>«6»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedc</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻜ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER KAF MEDIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedc</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻜ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER KAF MEDIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>105</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1070</td>
#     <td>1210</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>106</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1200</td>
#     <td>1214</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>107</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1132</td>
#     <td>1205</td>
#     <td>«6»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feb8</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺸ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER SHEEN MEDIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feb8</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺸ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER SHEEN MEDIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>108</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>1122</td>
#     <td>1136</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>109</b></td>
#     <td>1647</td>
#     <td>1861</td>
#     <td>992</td>
#     <td>1132</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
# </tr>
# </table>
# <p class="r"><span class="r">٥٨١</span></p>
# <p class="r"><span class="r">ﻳَﺘَﻜَﺮَّرُ، ﻓَﻴَﺼْﺪُقُ ﻋَﻠَﻴْﻪِ ﻓِﻲ اﻟﻬُﻮِﻳَّﺔ ﴿وَﺑَﺪَا ﻟَﻬُﻢْ ﻣِﻦَ ٱﻟﻠّٰﻪِ﴾ ﻓِﻲ ﻫُﻮِﻳَّﺘِﻪِ ﴿ﻣَﺎﻟَﻢْ</span></p>
# <p class="r"><span class="r">ﻳَﻜُﻮﻧُﻮا ﻳَﺤْﺘَﺴِﺒُﻮنَ﴾ </span><span class="l">]</span><span class="r">ﺳﻮرةاﻟﺰُّﻣَﺮ</span><span class="l">)</span><span class="r">٩٣</span><span class="l">:(</span><span class="r">٧٤</span><span class="l"> [</span><span class="r">ﻓِﻴﻬَﺎ ﻗَﺒﻞَﻛَﺸْﻒِ اﻟﻐِﻄَﺎءِ</span><span class="l">.</span></p>
# <p class="r"><span class="r">وَﻗَﺪْ ذَﻛَﺮْﻧَﺎ ﺻُﻮْرَةَ اﻟﺘﱠﺮَﻗِﻲ ﺑَﻌﺪَ اﻟﻤَﻮْتِ ﻓِﻲ اﻟﻤَﻌَﺎرِفِ اﻻِٕﻟٰﻬَﻴﱠﳴﺔِ ﻓِﻲﻛِﺘَﺎبِ</span></p>
# <p class="r"><span class="r">اﻟﺘﱠﺠَﻠﱢـﻴَّﺎتِ ﻟَﻨَﺎ، </span><span class="l"> 298</span><span class="r">ﻋِﻨْﺪَ ذِﻛْﺮِﻧَﺎ ﻣَﻦْٱﺟْﺘَﻤَﻌْﻨَﺎ ﺑِﻪِ ﻣِﻦَ اﻟﻄﱠﺎﺋِﻔَﺔِ ﻓِﻲ اﻟﻜَﺸْﻒِ، وَﻣَﺎ</span></p>
# <p class="r"><span class="r">أَﻓَﺪْﻧَﺎﻫُﻢْ ﰲ ﻫٰﺬِهِ اﻟﻤَﺴَﺄَﻟَﺔِ، ﻣِﻤَّﺎ ﻟَﻢْ ﻳَﻜُﻦْ ﻋِﻨْﺪَﻫَﻢْ</span><span class="l">299.</span></p>
# <p class="r"><span class="r">وَﻣِﻦْ أَﻋْﺠَﺐِ اﻷَﻣْﺮِ، أَﻧﱠﻪُ ﻓِﻲ اﻟﺘﱠﺮَﻗِﻲ دَاﺋِﻤًﺎ، وَلَا ﻳَﺸْﻌُـﺮُ ﺑِﺬٰﻟِﻚَ ﻟِﻠﱠﻄَﺎﻓَﺔِ</span></p>
# <p class="r"><span class="r">وَاﻟﺤِﺠَﺎبِ وَرِﻗﱠﺘِﻪِ، وَﺗَﺸَﺎﺑُﻪِ اﻟﺼُّﻮَرِ، ﻣِﺜْﻞَ ﻗَﻮْﻟَﻪُ</span><span class="l"> :</span><span class="r">﴿وَأُﺗُﻮا ﺑِﻪِ ﻣُﺘَﺸَـٰﺒِﻬًﺎ﴾ </span><span class="l">]</span><span class="r">ﺳﻮرةاﻟﺒﻘﺮة</span></p>
# <p class="r"><span class="l">)</span><span class="r">٢</span><span class="l">:(</span><span class="r">٥٢</span><span class="l">.[</span></p>
# <p class="r"><span class="r">وَﻟَﻴﺲَ ﻫُﻮَ</span><span class="l"> 300</span><span class="r">اﻟﻮَاﺣِﺪُ</span><span class="l"> 301</span><span class="r">ﻋَﲔَ اﻵﺧَـﺮِ، </span><span class="l"> 302</span><span class="r">ﻓَﺎِٕنﱠ اﻟﺸﱠﺒِﻴﻬَﲔِ ﻋِﻨﺪَ اﻟﻌَﺎرِفِ إِﻧﱠﻬُﻤَﺎ</span></p>
# <p class="r"><span class="l">» .298</span><span class="r">وَﻗَﺪْ ذَﻛَﺮْﻧَﺎ ﺻُﻮْرْةَ اﻟﺘﱠﺮَﻗِﻲ ﺑَﻌﺪَ اﻟﻤَﻮْتِ ﻓِﻲ اﻟﻤَﻌَﺎرِفِ اﻻِٕﻟٰﻬَﻴﱠﳴﺔِ ﻓِﻲﻛِﺘَﺎبِ</span></p>
# <p class="r"><span class="r">اﻟﺘﱠﺠَﻠﱢـﻴَّﺎتِ ﻟَﻨَﺎ</span><span class="l"> :«</span><span class="r">راﺟﻊ ﻣﺤﻴﻲ اﻟﺪﻳﻦ ﺑﻦ اﻟﻌﺮﺑﻲ، اﻟﺘﺠﻠﻴﺎت اﻹﻟٰﻬﻴﺔ، ﺗﺤﻘﻴﻖ ﻋﺜﻤﺎن</span></p>
# <p class="r"><span class="r">إﺳﻤﺎﻋﻴﻞ ﻳﺤﻴﲐ، ﻃﻬﺮان</span><span class="l"> :</span><span class="r">ﻣﺮﻛﺰِ ﻧﺸﺮِ داﻧﺸﮕﺎﻫﻰ، ٨٠٤١ﻫـ</span><span class="l">/</span><span class="r">٨٨٩١م، ص ٣٩٣، ﻓﻘﺮة ٤٣٣</span><span class="l">.</span></p>
# <p class="r"><span class="l"> .299</span><span class="r">أراد اﻟﻤﺼﻨﱢﻒ ﻗﺪس ﺳـﺮه ﺑﻘﻮﻟﻪ </span><span class="l">)</span><span class="r">ﻣَﻦْٱﺟْﺘَﻤَﻌْﻨَﺎ ﺑِﻪِ ﻣِﻦَ اﻟﻄﱠﺎﺋِﻔَﺔِ ﻓِﻲ اﻟﻜَﺸْﻒِ</span><span class="l"> (</span><span class="r">ذا</span></p>
# <p class="r"><span class="r">اﻟﻨّﻮن اﻟﻤﺼﺮي، راﺟﻊ اﻟﺘّﺠﻠﻴّﺎت اﻹﻟٰﻬﻴّﺔ ﻣﻊ ﺗﻌﻠﻴﻘﺎت اﺑﻦ ﺳﻮدﻛﲔ، ﺗﺤﻘﻴﻖ ﻋﺜﻤﺎن ﻳﺤﻴﲐ،</span></p>
# <p class="r"><span class="r">ﻃﻬﺮان</span><span class="l"> :</span><span class="r">ﻣﺮﻛﺰ ﻧﺸﺮ داﻧﺸﮕﺎﻫﻰ ٨٠٤١ﻫـ</span><span class="l">/</span><span class="r">٨٨٩١م، ص ٣٩٣، اﻟﻔﻘﺮة رﻗﻢ ٤٣٣</span><span class="l">.</span></p>
# <p class="r"><span class="l"> .300</span><span class="r">ﺷﺮح اﻟﻘﻴﺼﺮي، ص ٩٨٧</span><span class="l">» :</span><span class="r">ﻳﺠﻮز أن ﻳﻜﻮن </span><span class="l">)</span><span class="r">ﻫُﻮَ</span><span class="l"> (</span><span class="r">ﺗﺄﻛﻴﺪًا ﻟﻠﻀﻤﻴﺮ اﻟﻤﺴﺘﱰ …</span></p>
# <p class="r"><span class="r">وﻳﺠﻮز أن ﻳﻜﻮن </span><span class="l">)</span><span class="r">ﻫُﻮَ</span><span class="l"> (</span><span class="r">ﺑﻤﻌﻨﲐ</span><span class="l">) :</span><span class="r">ذٰﻟِﻚَ</span><span class="l">.«(</span></p>
# <p class="r"><span class="l"> .301</span><span class="r">ﺷﺮح اﻟﻘﻴﺼﺮي، ص ٩٨٧</span><span class="l">» :</span><span class="r">و </span><span class="l">)</span><span class="r">اﻟﻮَاﺣِﺪُ</span><span class="l"> (</span><span class="r">ﻋﻄﻒ ﺑﻴﺎن ﻟﻪ</span><span class="l">.«</span></p>
# <p class="r"><span class="l"> .302</span><span class="r">ﺷﺮح اﻟﻘﻴﺼﺮي، ص ٩٨٧</span><span class="l">)» :</span><span class="r">ﻋَﲔَ اﻵﺧِﺮِ</span><span class="l"> (</span><span class="r">ﺧﱪ </span><span class="l">)</span><span class="r">ﻟَﻴﺲَ</span><span class="l">.«(</span></p>

# %% [markdown]
# # Getting the right LAM-ALEF ligature

# %%
testPages = "45"
Lw.drawPages(testPages)
Lw.getPages(testPages)
Lw.showLines(testPages, line=9, start=88, end=97)
Lw.showReplacements(rule=78)
Lw.htmlPages(testPages)
# Out:
# <p><b>page 45</b></p>
# 	   1 (page   45)
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 45</th>
#     <th colspan=2>line 9</th>
#     <th colspan=3>118 characters</th>
# </tr>
#
# <tr>
#     <td><b>88</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1528</td>
#     <td>1559</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>89</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1388</td>
#     <td>1528</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e845</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0655</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ٕ</span></div>
#     <div class="cn"><span class="c">ARABIC HAMZA BELOW</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>90</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1451</td>
#     <td>1528</td>
#     <td>«6»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fec3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻃ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TAH INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fec3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻃ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TAH INITIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>91</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1311</td>
#     <td>1451</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>92</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1441</td>
#     <td>1455</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>93</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1407</td>
#     <td>1445</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e80e</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>94</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1267</td>
#     <td>1407</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>95</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1358</td>
#     <td>1407</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e807</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>96</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1218</td>
#     <td>1358</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e86d</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>97</b></td>
#     <td>2687</td>
#     <td>2901</td>
#     <td>1273</td>
#     <td>1358</td>
#     <td>⌊34⌋</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0642</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ق</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER QAF</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0642</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ق</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER QAF</span></div>
# </div>
# </td>
# </tr>
# </table>
# <p class="r"><span class="r">٥٤</span></p>
# <p class="r"><span class="r">ﻣَﺎﺷَﻔَﻊَ ﻋِﻨْﺪَ </span><span class="l">»</span><span class="r">اﻟﻤُﻨْﺘَﻘِﻢِ</span><span class="l"> «</span><span class="r">ﻓِﻲ أَﻫْﻞِ اﻟﺒَلَاءِ، إِﻻﱠ ﺑَﻌْﺪَ ﺷَﻔَﺎﻋَﺔِ اﻟﺸﱠﺎﻓِﻌِﻴْﻦَ، ﻓَﻔَﺎزَ ﻣُﺤَﻤَّﺪٌ</span></p>
# <p class="r"><span class="r">ﺻَﻠﱠﲐ اﻟﻠّٰﻪُ ﻋَﻠَﻴْﻪِ وَﺳَﻠﱠﻢَ ﺑِﺎﻟﺴِّﻴَﺎدَةِ ﻓِﻲ ﻫٰﺬَا اﻟﻤَﻘَﺎمِ اﻟﺨَﺎصِّ</span><span class="l"> .</span><span class="r">ﻓَﻤَﻦْ ﻓَﻬِﻢَ اﻟﻤَﺮَاﺗِﺐَِ</span></p>
# <p class="r"><span class="r">وَاﻟﻤَﻘَﺎﻣَﺎتِ، ﻟَﻢْ ﻳَﻌْﺴُﺮْ ﻋَﻠَﻴﻪِ ﻗَـﺒُﻮلُ ﻣِﺜْﻞِ ﻫٰﺬَا اﻟﻜَلَامِ</span><span class="l">.</span></p>
# <p class="r"><span class="r">وَأَﻣَّﺎ اﻟﻤِﻨَﺢُ اﻷَﺳْﻤَﺎﺋِﻴَّﺔُ</span><span class="l"> :</span><span class="r">ﻓَﭑﻋْﻠَﻢْ أَنﱠ ﻣَﻨْﺢَ اﻟﻠّٰﻪِ ﺗَﻌَﺎﻟَﲐ ﺧَﻠْﻘَﻪُ رَﺣْﻤَﺔً ﻣِﻨْﻪُ ﺑِﻬِﻢْ،</span></p>
# <p class="r"><span class="r">وَﻫِﻲَﻛُﻠﱠﻬَﺎ ﻣِﻦَ اﻷَﺳْﻤَﺎءِ، ﻓَﺎِٕﻣَّﺎ رَﺣْﻤَﺔٌ ﺧَﺎﻟِﺼَﺔٌ، ﻛﺎﻟﻄﱠـﻴِّﺐِ ﻣِﻦَ اﻟﺮِّزْقِ اﻟﱠﻠَﺬِﻳﺬِ ﻓِﻲ</span></p>
# <p class="r"><span class="r">اﻟﺪﱡﻧْﻴَﺎ اﻟﺨَﺎﻟِﺺِ ﻳَﻮمَ اﻟﻘِﻴَﺎﻣَﺔِ، وَﻳُﻌْﻄِﻲ ذٰﻟِﻚَ الٱﺳْﻢُ </span><span class="l">»</span><span class="r">اﻟﺮَّﺣْﻤٰﻦُ</span><span class="l">«</span><span class="r">، ﻓَﻬُﻮَ ﻋَﻄَﺎءٌ</span></p>
# <p class="r"><span class="r">رَﺣْﻤَﺎﻧِﻲٌّ</span><span class="l"> .</span><span class="r">وَإِﻣَّﺎ رَﺣْﻤَﺔٌ ﻣُﻤْﺘَـﺰِﺟَﺔُ، ﻛﺸُﺮْبِ اﻟﺪﱠوَاءِ اﻟﻜَﺮِهِ اﻟﱠﺬِي ﻳَﻌْﻘُﺐُ ﺷُﺮْﺑُﻪُ</span></p>
# <p class="r"><span class="r">اﻟﺮَّاﺣَﺔَ، وَﻫُﻮَ ﻋَﻄَﺎءٌ إِﻟٰﻬِﻲِّ، ﻓَﺎِٕنﱠ اﻟﻌَﻄَﺎءَ اﻻِٕﻟٰﻬِﻲَّ، ﻻَ ﻳَﺘَﻤَﻜﱠﻦُ إِﻃْلَاَقُ ﻋَﻄَﺎﺋِﻪِ ﻣِﻨْﻪُ</span></p>
# <p class="r"><span class="r">ﻣِﻦْ ﻏَﻴﺮِ أَنْ ﻳَﻜُﻮنَ ﻋَﻠَﲐ ﻳَﺪِ ﺳَﺎدِنٍ ﻣِﻦْ ﺳَﺪَﻧَﺔِ اﻷَﺳْﻤَﺎءِ</span><span class="l">.</span></p>
# <p class="r"><span class="r">ﻓَﺘَﺎرَةً ﻳُﻌْﻄِﻲ اﻟﻠّٰﻪُ اﻟﻌَﺒْﺪَ ﻋَﻠَﲐ ﻳَﺪَيِ </span><span class="l">»</span><span class="r">اﻟﺮَّﺣْﻤٰﻦِ</span><span class="l">«</span><span class="r">، </span><span class="l">)</span><span class="r">١</span><span class="l"> (</span><span class="r">ﻓَﻴْﺨْﻠُﺺُ اﻟﻌَﻄَﺎءُ ﻣِﻦَ</span></p>
# <p class="r"><span class="r">اﻟﺸﱠﻮْبِ اﻟﱠﺬِي ﻻَ ﻳُلَاﺋِﻢُ اﻟﻄﱠـﺒْﻊَ ﻓِﻲ اﻟﻮَﻗْﺖَ </span><span class="l">]</span><span class="r">٩ ﻇﻬﺮ</span><span class="l"> [</span><span class="r">أَوْ ﻻَ ﻳُﻨِﻴﻞُ اﻟﻐَﺮضََ وَﻣَﺎ</span></p>
# <p class="r"><span class="r">أَﺷْﺒَﻪَ ذٰﻟِﻚَ</span><span class="l">.</span></p>
# <p class="r"><span class="r">وَﺗَﺎرَةً ﻳُﻌْﻄِﻲ اﻟﻠّٰﻪُ ﻋَﻠَﲐ ﻳَﺪَيِ </span><span class="l">»</span><span class="r">اﻟﻮَاﺳِﻊِ</span><span class="l"> «</span><span class="r">ﻓَـﻴَﻌُﻢُّ</span><span class="l">.</span></p>
# <p class="r"><span class="r">أَوْ ﻋَﻠَﲐ ﻳِﺪَيِ </span><span class="l">»</span><span class="r">اﻟﺤَﻜِﻴْﻢِ</span><span class="l"> «</span><span class="r">ﻓَـﻴَﻨْﻈُـﺮُ ﻓِﻲ اﻷَﺻْﻠَﺢِ ﻓِﻲ اﻟﻮَﻗْﺖِ</span><span class="l">.</span></p>
# <p class="r"><span class="r">أَوْ ﻋَﻠَﲐ ﻳَﺪِ </span><span class="l">»</span><span class="r">اﻟﻮَاﻫِﺐِ</span><span class="l"> «</span><span class="r">ﻓَـﻴُﻌْﻄِﻲ ﻟِﻴُﻨْﻌِﻢَ، ﻻَ ﻳَﻜُﻮنُ ﻣَﻊَ </span><span class="l">»</span><span class="r">اﻟﻮَاﻫِﺐِ</span><span class="l"> «</span><span class="r">ﺗَﻜْﻠِﻴْﻒُ</span></p>
# <p class="r"><span class="r">اﻟﻤُﻌْﻄِﻲ ﻟَﻪُ ﺑِﻌِﻮضٍَ ﻋَﻠَﲐ ذٰﻟِﻚَ ﻣِﻦ ﺷُـﻜْﺮٍ أَوْ ﻋَﻤَﻞٍ</span><span class="l">.</span></p>
# <p class="r"><span class="r">أَوْ ﻋَﻠَﲐ ﻳَﺪِ </span><span class="l">»</span><span class="r">اﻟﺠَﺒَّﺎرِ</span><span class="l"> «</span><span class="r">ﻓَـﻴَﻨْﻈُـﺮُ ﻓِﻲ اﻟﻤَﻮْﻃِﻦِ وَﻣَﺎ ﻳَﺴْﺘَﺤِﻘﱡﻪُ</span><span class="l">.</span></p>
# <p class="r"><span class="r">أَوْ ﻋَﻠَﲐ ﻳَﺪِ </span><span class="l">»</span><span class="r">اﻟﻐَﻔﱠﺎرِ</span><span class="l"> «</span><span class="r">ﻓَـﻴَﻨْﻈُـﺮُ اﻟﻤَﺤَﻞَّ، وَﻣَﺎ ﻫُﻮَ ﻋَﻠَﻴْﻪِ، ﻓَﺎِٕنْﻛَﺎنَ ﻋَﻠَﲐ ﺣَﺎلٍ</span></p>
# <p class="r"><span class="l">)</span><span class="r">١</span><span class="l"> (</span><span class="r">ق</span><span class="l"> :</span><span class="r">وردت اﻟﻜﻠﻤﺔ ﺑﺎﻟﻤﱳ ﻫٰﻜﺬا</span><span class="l">) :</span><span class="r">اﻟﺮﺣﻤﺎن</span><span class="l">.(</span></p>

# %%
Lw.showString("\u0625\u0650\ufec3\u0652\u0644\u064e\u0627\u064e\u0642\u064f")
Lw.showString("\u0625\u0650\u0637\u0652\u0644\u064e\u0627\u064e\u0642\u064f")
# Out:
# <p><span class="r">إِﻃْلَاَقُ</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">0625</span></div>
#     <div class="cn"><span class="cni"><span class="rc">إ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF WITH HAMZA BELOW</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">fec3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻃ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TAH INITIAL FORM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0642</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ق</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER QAF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064f</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ُ</span></div>
#     <div class="cn"><span class="c">ARABIC DAMMA</span></div>
# </div>
# </div>
# <p><span class="r">إِطْلَاَقُ</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">0625</span></div>
#     <div class="cn"><span class="cni"><span class="rc">إ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF WITH HAMZA BELOW</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0637</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ط</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TAH</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0642</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ق</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER QAF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064f</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ُ</span></div>
#     <div class="cn"><span class="c">ARABIC DAMMA</span></div>
# </div>
# </div>

# %%
Lw.showString("\ufefb \ufefc")
# Out:
# <p><span class="r">ﻻ ﻼ</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">fefb</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻻ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE LAM WITH ALEF ISOLATED FORM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0020</span></div>
#     <div class="cn"><span class="cni"><span class="lc"> </span></div>
#     <div class="cn"><span class="c">SPACE</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">fefc</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻼ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE LAM WITH ALEF FINAL FORM</span></div>
# </div>
# </div>

# %% [markdown]
# ## LAM-ALEF(wasla) does not come out right

# %% [markdown]
# Here is an example
#
# ![lamalefwasla](lamalefwasla.png)
#
# See line 10 below.

# %%
testPages = "34"
char = "\ue809"
Lw.drawPages(testPages)
# Out:
# <p><b>page 34</b></p>

# %%
Lw.showLines(testPages, search=char, orig=True)
# Out:
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 34</th>
#     <th colspan=2>line 1</th>
#     <th colspan=3>2 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 34</th>
#     <th colspan=2>line 2</th>
#     <th colspan=3>100 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 34</th>
#     <th colspan=2>line 3</th>
#     <th colspan=3>10 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 34</th>
#     <th colspan=2>line 4</th>
#     <th colspan=3>54 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 34</th>
#     <th colspan=2>line 5</th>
#     <th colspan=3>107 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 34</th>
#     <th colspan=2>line 6</th>
#     <th colspan=3>110 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 34</th>
#     <th colspan=2>line 7</th>
#     <th colspan=3>53 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 34</th>
#     <th colspan=2>line 8</th>
#     <th colspan=3>110 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 34</th>
#     <th colspan=2>line 9</th>
#     <th colspan=3>42 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 34</th>
#     <th colspan=2>line 10</th>
#     <th colspan=3>67 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 34</th>
#     <th colspan=2>line 11</th>
#     <th colspan=3>102 characters</th>
# </tr>
#
# <tr>
#     <td><b>49</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>2192</td>
#     <td>2229</td>
#     <td>«11»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedf</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻟ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedf</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻟ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM INITIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>50</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>2052</td>
#     <td>2192</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e864</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>51</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>2180</td>
#     <td>2194</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>52</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>2144</td>
#     <td>2182</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e80e</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>53</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>2004</td>
#     <td>2144</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>54</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>2095</td>
#     <td>2144</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e809</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0671</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ٱ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF WASLA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>55</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>2014</td>
#     <td>2095</td>
#     <td>«11»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feb3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺳ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER SEEN INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feb3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺳ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER SEEN INITIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>56</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>2002</td>
#     <td>2015</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>57</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1874</td>
#     <td>2014</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e828</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>58</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1971</td>
#     <td>2003</td>
#     <td>«11»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fe98</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺘ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TEH MEDIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fe98</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺘ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TEH MEDIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>59</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1831</td>
#     <td>1971</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e864</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
# </tr>
# </table>

# %% [markdown]
# If we render the string, we do not get the right ligature.
#
# Whereas when we replace the alef-wasla with an ordinary alef, the ligature comes out right:

# %%
alefWasla = "\u0671"
alefNorml = "\u0627"

Lw.showString(f"\u0644\u0650\u0644\u0652{alefWasla}\u0633\u0652\ufe98")
Lw.showString(f"\u0644\u0650\u0644\u0652{alefNorml}\u0633\u0652\ufe98")
# Out:
# <p><span class="r">لِلْٱسْﺘ</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0671</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ٱ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF WASLA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0633</span></div>
#     <div class="cn"><span class="cni"><span class="rc">س</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER SEEN</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">fe98</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺘ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TEH MEDIAL FORM</span></div>
# </div>
# </div>
# <p><span class="r">لِلْاسْﺘ</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0633</span></div>
#     <div class="cn"><span class="cni"><span class="rc">س</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER SEEN</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">fe98</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺘ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TEH MEDIAL FORM</span></div>
# </div>
# </div>
