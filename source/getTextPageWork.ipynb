# %%
# %load_ext autoreload
# %autoreload 2
# !cd `pwd`

# %%
from fusus.lakhnawi import Lakhnawi, pprint
Lw = Lakhnawi()
Lw.setStyle()
# Out:
# <style>
# .r {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     direction: rtl;
# }
# .rc, .lc {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     background-color: white;
#     border: 2pt solid #ffcccc;
# }
# .rc {
#     direction: rtl;
# }
# .lc {
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# p {
#     text-align: left;
#     direction: ltr;
# }
# p.r {
#     text-align: right;
#     direction: rtl;
# }
# .l {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# .c {
#     font-family: monospace;
#     font-size: x-small;
#     direction: ltr;
# }
# .p {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     background-color: yellow;
#     direction: ltr;
# }
# .lrg {
#     font-size: xx-large;
#     font-weight: bold;
# }
# td {
#     text-align: left ! important;
# }
# div.cn {
#     text-align: center
# }
# div.ch.p {
#     background-color: #ffeedd;
#     text-align: center
# }
# span.cni {
#     background-color: #eeeeee;
#     padding-top: 4pt;
#     padding-bottom: 4pt;
#     padding-left: 8pt;
#     padding-right: 8pt;
#     border: 2pt solid #66aaaa;
#     display: inline-block;
# }
# div.ch {
#     border: 2pt solid #cccccc;
#     background-color: #ddffff;
#     display: inline-flex;
#     flex-flow: column nowrap;
#     max-width: 10em;
# }
# div.sr {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# </style>

# %%
testPages = "61"
char = "\ue84d"
Lw.getPages(testPages, refreshConfig=True)
Lw.showLines(testPages, search=char)
# Out:
# 	   1 (page   61)
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 1</th>
#     <th colspan=3>2 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 2</th>
#     <th colspan=3>52 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 3</th>
#     <th colspan=3>112 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 4</th>
#     <th colspan=3>110 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 5</th>
#     <th colspan=3>117 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 6</th>
#     <th colspan=3>63 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 7</th>
#     <th colspan=3>110 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 8</th>
#     <th colspan=3>107 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 9</th>
#     <th colspan=3>102 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 10</th>
#     <th colspan=3>50 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 11</th>
#     <th colspan=3>96 characters</th>
# </tr>
#
# <tr>
#     <td><b>61</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>2005</td>
#     <td>2036</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>62</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1865</td>
#     <td>2005</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e845</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0655</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ٕ</span></div>
#     <div class="cn"><span class="c">ARABIC HAMZA BELOW</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>63</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1960</td>
#     <td>2005</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e80a</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fefb</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻻ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE LAM WITH ALEF ISOLATED FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>64</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1820</td>
#     <td>1960</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fc60</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﱠ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH FATHA ISOLATED FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fcf2</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﳲ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH FATHA MEDIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>65</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1918</td>
#     <td>1960</td>
#     <td>⌊34⌋</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e806</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>66</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1778</td>
#     <td>1918</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e84d</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e84d</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0020</span></div>
#     <div class="cn"><span class="cni"><span class="lc"> </span></div>
#     <div class="cn"><span class="c">SPACE</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>67</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1852</td>
#     <td>1884</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>68</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1712</td>
#     <td>1852</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e845</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0655</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ٕ</span></div>
#     <div class="cn"><span class="c">ARABIC HAMZA BELOW</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>69</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1812</td>
#     <td>1852</td>
#     <td>«2»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻳ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻳ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH INITIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>70</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1804</td>
#     <td>1817</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>71</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1672</td>
#     <td>1812</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e8f4</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="

# %%
Lw.getPages(testPages, refreshConfig=True)
Lw.showLines(testPages, search=char, orig=True)
# Out:
# 	   1 (page   61)
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 1</th>
#     <th colspan=3>2 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 2</th>
#     <th colspan=3>52 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 3</th>
#     <th colspan=3>112 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 4</th>
#     <th colspan=3>110 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 5</th>
#     <th colspan=3>117 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 6</th>
#     <th colspan=3>63 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 7</th>
#     <th colspan=3>110 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 8</th>
#     <th colspan=3>107 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 9</th>
#     <th colspan=3>102 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 10</th>
#     <th colspan=3>50 characters</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 61</th>
#     <th colspan=2>line 11</th>
#     <th colspan=3>96 characters</th>
# </tr>
#
# <tr>
#     <td><b>61</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>2005</td>
#     <td>2036</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>62</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1865</td>
#     <td>2005</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e845</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0655</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ٕ</span></div>
#     <div class="cn"><span class="c">ARABIC HAMZA BELOW</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>63</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1960</td>
#     <td>2005</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e80a</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fefb</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻻ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE LAM WITH ALEF ISOLATED FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>64</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1820</td>
#     <td>1960</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fc60</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﱠ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH FATHA ISOLATED FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0651</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ّ</span></div>
#     <div class="cn"><span class="c">ARABIC SHADDA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>65</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1918</td>
#     <td>1960</td>
#     <td>⌊34⌋</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e806</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>66</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1778</td>
#     <td>1918</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e84d</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0653</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ٓ</span></div>
#     <div class="cn"><span class="c">ARABIC MADDAH ABOVE</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0020</span></div>
#     <div class="cn"><span class="cni"><span class="lc"> </span></div>
#     <div class="cn"><span class="c">SPACE</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>67</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1852</td>
#     <td>1884</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>68</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1712</td>
#     <td>1852</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e845</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0655</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ٕ</span></div>
#     <div class="cn"><span class="c">ARABIC HAMZA BELOW</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>69</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1812</td>
#     <td>1852</td>
#     <td>«2»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻳ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻳ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH INITIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <td><b>70</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1804</td>
#     <td>1817</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td></td>
# </tr>
#
# <tr>
#     <td><b>71</b></td>
#     <td>3207</td>
#     <td>3421</td>
#     <td>1672</td>
#     <td>1812</td>
#     <td></td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><spa

# %%
Lw.htmlPages(testPages)
# Out:
# <p class="r"><span class="r">١٦</span></p>
# <p class="r"><span class="r">اﻷَﻣْﺮَ ﻟَﻪُﻛُﻠَّﻪُ، ﻓَﺄﺟَﺎﺑُﻮهُ ﻣَﻜْـﺮًاﻛَﻤَﺎ دَﻋَﺎﻫُﻢْ</span><span class="l">.</span></p>
# <p class="r"><span class="r">ﻓَﺠَﺎءَ اﻟﻤُﺤَﻤَّﺪِيُّ وَﻋَﻠِﻢَ أَنَّ اﻟﺪَّﻋْﻮَةَ إِﻟَﲐ اﻟﻠّٰﻪِ، ﻣَﺎﻫِﻲَ ﻣِﻦْ ﺣَﻴﺚُ ﻫُﻮِﻳَّﺘُﻪُ، وَإِﻧَّﻤَﺎ</span></p>
# <p class="r"><span class="r">ﻫِﻲَ ﻣِﻦْ ﺣَﻴﺚُ أَﺳْﻤَﺎؤهُ ﻓَﻘَﺎلَ</span><span class="l"> :</span><span class="r">﴿ﻳَﻮمَ ﻧَﺤْﺸُﺮُ ٱﻟﻤُﺘَّﻘَـﻴْﻦَ إِﻟَﲐ ٱﻟﺮَّﺣْﻤٰﻦِ وَﻓْﺪًا﴾، </span><span class="l">]</span><span class="r">ﺳﻮرة</span></p>
# <p class="r"><span class="r">ﻣﺮﻳﻢ</span><span class="l">)</span><span class="r">٩١</span><span class="l">:(</span><span class="r">٥٨</span><span class="l"> [</span><span class="r">ﻓَﺠَﺎءَ ﺑِﺤَﺮْفِ اﻟﻐَﺎﻳَﺔِ، وَﻗَﺮَﻧَﻬَﺎ ﺑِﺎلٱﺳْﻢِ، ﻓَﻌَﺮَﻓَﻨَﺎ أَنَّ اﻟﻌَﺎﻟَﻢَﻛَﺎنَ ﺗَﺤْﺖَ</span></p>
# <p class="r"><span class="r">ﺣِﻴﻄَﺔِ ٱﺳْﻢٍ إِﻟٰﻬِﻲٍّ، </span><span class="l">)</span><span class="r">١</span><span class="l"> (</span><span class="r">أَوْﺟَﺐَ ﻋَﻠَﻴﻬِﻢْ أَنْ ﻳَﻜُﻮﻧُﻮا ﻣُﺘَّﻘِﲔَ</span><span class="l">.</span></p>
# <p class="r"><span class="r">ﻓَ ﻘَ ﺎﻟُ ﻮا ﻓِ ﻲ ﻣَ ﻜْ ﺮِﻫِ ﻢْ</span><span class="l"> :</span><span class="r">﴿ﻻَﺗَ ﺬَرُنَّ ءَاﻟِ ﻬَ ﺘَ ـﻜُ ﻢْ وَﻻَ ﺗَ ﺬَرُنَّ وَدٍّا وَﻻَ ﺳُ ﻮَاﻋً ﺎ</span></p>
# <p class="r"><span class="r">وَﻻَﻳَﻐُﻮْثَ وَﻳَﻌُﻮْقَ وَﻧَﺴْﺮًا﴾، </span><span class="l">]</span><span class="r">ﺳﻮرةﻧﻮح</span><span class="l">)</span><span class="r">١٧</span><span class="l">:(</span><span class="r">٣٢</span><span class="l"> [</span><span class="r">ﻓَﺎِٕﻧَّﻬُﻢْ إِذَا ﺗَﺮَﻛُﻮﻫُﻢْ، ﺟَﻬِﻠُﻮا ﻣَﻦِ</span></p>
# <p class="r"><span class="r">اﻟﺤَﻖِّ ﻋَﻠَﲐ ﻗَﺪَرِ ﻣَﺎﺗَﺮَﻛُﻮا ﻣِﻦْ ﻫٰﺆﻻَءِ، ﻓَﺎِٕنَّ ﻟِﻠْﺤَﻖِّ ― ﻓِﻲﻛُﻞِّ ﻣَﻌْـﺒُﻮدٍ ― وَﺟْﻬًﺎ</span></p>
# <p class="r"><span class="r">ﻳَﻌْـﺮِﻓُﻪُ ﻣَﻦْ ﻋَـﺮَﻓَﻪُ، وَﻳَﺠْﻬَﻠُﻪُ ﻣَﻦْ ﺟَﻬِﻠَﻪُ</span><span class="l">.</span></p>
# <p class="r"><span class="r">ﻓِﻲ اﻟﻤُﺤَﻤَّﺪِﻳَّﲔَ</span><span class="l"> :</span><span class="r">﴿وَﻗَﻀَﲐ رَﺑُّﻚَ أَﻻَّ ﺗَﻌْﺒُﺪُوٓا إِﻻَّٓ إِﻳَّﺎهُ﴾، </span><span class="l">]</span><span class="r">ﺳﻮرةاﻹﺳﺮﱝ</span><span class="l">)</span><span class="r">٧١</span><span class="l">:(</span><span class="r">٣٢</span><span class="l">[</span></p>
# <p class="r"><span class="r">أَيْ</span><span class="l"> :</span><span class="r">ﺣَﻜَﻢَ</span><span class="l"> .</span><span class="r">ﻓَﺎﻟﻌَﺎﻟِﻢُ</span><span class="l">)</span><span class="r">٢</span><span class="l"> (</span><span class="r">ﻳَﻌْﻠَﻢُ ﻣَﻦْ ﻋُﺒِﺪَ</span><span class="l">)</span><span class="r">٣</span><span class="l"> (</span><span class="r">وﻓِﻲ أَيِّ ﺻُﻮرَةٍ ﻇَﻬَﺮَ ﺣَﺘّﲐ ﻋُﺒِﺪَ، </span><span class="l">)</span><span class="r">٤</span><span class="l"> (</span><span class="r">وَأَنَّ</span></p>
# <p class="r"><span class="r">اﻟﺘَّﻔْﺮِﻳﻖَ وَاﻟﻜَﺜْﺮَةَ ﻛَﺎﻷَﻋْﻀَﺎءِ ﻓِﻲ اﻟﺼُّﻮرَةِ اﻟﻤَﺤْﺴُﻮﺳَﺔِ، وَﻛَﺎﻟﻘُﻮَﱝ اﻟﻤَﻌْﻨَﻮِﻳَّﺔِ ﻓِﻲ</span></p>
# <p class="r"><span class="r">اﻟﺼُّﻮرَةِ اﻟﺮُّوﺣَﺎﻧِﻴَّﺔِ</span><span class="l">.</span></p>
# <p class="r"><span class="r">ﻓَﻤَﺎ ﻋُﺒِﺪَ ﻏَـﻴْـﺮُ اﻟﻠّٰﻪِ ﻓِﻲﻛُﻞِّ ﻣَﻌْـﺒُﻮدٍ</span><span class="l">.</span></p>
# <p class="r"><span class="r">ﻓَﺎﻷَدْﻧَﲐ ﻣَﻦ ﺗَﺨَﻴَّﻞَ ﻓِﻴﻪِ اﻷُﻟُﻮﻫِﻴَّﺔَ، ﻓَﻠَﻮﻻَ ﻫٰﺬَا اﻟﺘَّﺨَـﻴُّﻞُ</span><span class="l">)</span><span class="r">٥</span><span class="l"> (</span><span class="r">ﻣَﺎﻋُﺒِﺪَ اﻟﺤَﺠَﺮُ</span></p>
# <p class="r"><span class="l">)</span><span class="r">١</span><span class="l"> (</span><span class="r">ق</span><span class="l">) :</span><span class="r">اﻻﺳﻢ اﻻﻫﻰ</span><span class="l">(</span><span class="r">، واﻟﻼم أﻟﻒ ﻣﺸﻄﻮﺑﺔ</span><span class="l">.</span></p>
# <p class="r"><span class="l">)</span><span class="r">٢</span><span class="l"> (</span><span class="r">ق</span><span class="l"> :</span><span class="r">وردت اﻟﻜﻠﻤﺔ ﻣﺸﻜﻮﻟﺔ ﻫٰـﻜﺬا </span><span class="l">)</span><span class="r">ﻓﺎﻟﻌﺎﻟِﻢ</span><span class="l">.(</span></p>
# <p class="r"><span class="l">)</span><span class="r">٣</span><span class="l"> (</span><span class="r">ق</span><span class="l"> :</span><span class="r">وردت اﻟﻜﻠﻤﺔ ﻣﺸﻜﻮﻟﺔ ﻫٰـﻜﺬا </span><span class="l">)</span><span class="r">ﻋُﺒﺪ</span><span class="l">.(</span></p>
# <p class="r"><span class="l">)</span><span class="r">٤</span><span class="l"> (</span><span class="r">ق</span><span class="l"> :</span><span class="r">وردت اﻟﻜﻠﻤﺔ ﻣﺸﻜﻮﻟﺔ ﻫٰـﻜﺬا </span><span class="l">)</span><span class="r">ﻋُﺒﺪ</span><span class="l">.(</span></p>
# <p class="r"><span class="l">)</span><span class="r">٥</span><span class="l"> (</span><span class="r">ق</span><span class="l"> :</span><span class="r">وردت اﻟﻌﺒﺎرة </span><span class="l">)</span><span class="r">ﻓﻠﻮﻻ ﻫٰﺬا اﻟﺘﺨﻴﻞ</span><span class="l"> (</span><span class="r">ﻣﺮﺗﲔ ﰲ اﻟﻤﱳ، وأﺷﺎر اﻟﻨﺎﺳﺦ إﻟﲐ ﺣﺬف</span></p>
# <p class="r"><span class="r">اﻷوﻟﲐ ﺑﺨﻂ أﻓﻘﻲ ﻓﻮﻗﻬﺎ</span><span class="l">.</span></p>

# %%
Lw.drawPages(testPages)
# Out:
# <p><b>page 61</b></p>

# %%
Lw.showString("الإِلٰهِيُّةِ")
# Out:
# <p><span class="r">الإِلٰهِيُّةِ</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0625</span></div>
#     <div class="cn"><span class="cni"><span class="rc">إ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF WITH HAMZA BELOW</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0670</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ٰ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER SUPERSCRIPT ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0647</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ه</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER HEH</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064a</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ي</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064f</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ُ</span></div>
#     <div class="cn"><span class="c">ARABIC DAMMA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0651</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ّ</span></div>
#     <div class="cn"><span class="c">ARABIC SHADDA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0629</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ة</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TEH MARBUTA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </div>
