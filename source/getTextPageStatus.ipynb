# %%
# %load_ext autoreload
# %autoreload 2
# !cd `pwd`

# %%
from fusus.lakhnawi import Lakhnawi, pprint
Lw = Lakhnawi()
Lw.setStyle()
# Out:
# <style>
# .r {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     direction: rtl;
# }
# .rc, .lc {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     background-color: white;
#     border: 2pt solid #ffcccc;
# }
# .rc {
#     direction: rtl;
# }
# .lc {
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# p {
#     text-align: left;
#     direction: ltr;
# }
# p.r {
#     text-align: right;
#     direction: rtl;
# }
# .l {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# .c {
#     font-family: monospace;
#     font-size: x-small;
#     direction: ltr;
# }
# .p {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     background-color: yellow;
#     direction: ltr;
# }
# .lrg {
#     font-size: xx-large;
#     font-weight: bold;
# }
# span.sp {
#     background-color: #00ff00;
# }
# td {
#     text-align: left ! important;
# }
# div.cn {
#     text-align: center
# }
# div.ch.p {
#     background-color: #ffeedd;
#     text-align: center
# }
# span.cni {
#     background-color: #eeeeee;
#     padding-top: 4pt;
#     padding-bottom: 4pt;
#     padding-left: 8pt;
#     padding-right: 8pt;
#     border: 2pt solid #66aaaa;
#     display: inline-block;
# }
# div.ch {
#     border: 2pt solid #cccccc;
#     background-color: #ddffff;
#     display: inline-flex;
#     flex-flow: column nowrap;
#     max-width: 10em;
# }
# div.sr {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# </style>

# %%
examples = (16, 23, 60, 69)
pages = {i: Lw.getPageObj(i) for i in examples}
Lw.getPages(None, onlyFnRules=True)
# Out:
# 	 438

# %%
testPages = None
Lw.getPages(testPages, refreshConfig=True)
# Out:
# 	 438

# %%
Lw.showUsedChars(testPages, onlyPuas=True, onlyPresentational=False, long=False, byOcc=True)
# Out:
# <p><b>0 private use characters in 0 occurences
# on 0 pages</b></p>
# <table>
# </table>

# %%
Lw.showUsedChars(testPages, onlyPuas=False, onlyPresentational=False, long=False, byOcc=False)
# Out:
# <p><b>144 characters in 443605 occurences
# on 438 pages</b></p>
# <table>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0020</span></div>
#     <div class="cn"><span class="cni"><span class="lc"> </span></div>
#     <div class="cn"><span class="c">SPACE</span></div>
# </div>
# </td>
#     <td><b>84885</b> on <i>438</i> pages</td>
#     <td>e.g. page 433 with <b>685</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0021</span></div>
#     <div class="cn"><span class="cni"><span class="lc">!</span></div>
#     <div class="cn"><span class="c">EXCLAMATION MARK</span></div>
# </div>
# </td>
#     <td><b>8</b> on <i>8</i> pages</td>
#     <td>e.g. page 41 with <b>1</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0028</span></div>
#     <div class="cn"><span class="cni"><span class="lc">(</span></div>
#     <div class="cn"><span class="c">LEFT PARENTHESIS</span></div>
# </div>
# </td>
#     <td><b>1216</b> on <i>372</i> pages</td>
#     <td>e.g. page 217 with <b>11</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0029</span></div>
#     <div class="cn"><span class="cni"><span class="lc">)</span></div>
#     <div class="cn"><span class="c">RIGHT PARENTHESIS</span></div>
# </div>
# </td>
#     <td><b>1214</b> on <i>372</i> pages</td>
#     <td>e.g. page 217 with <b>11</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">002c</span></div>
#     <div class="cn"><span class="cni"><span class="lc">,</span></div>
#     <div class="cn"><span class="c">COMMA</span></div>
# </div>
# </td>
#     <td><b>9</b> on <i>1</i> page</td>
#     <td>e.g. page 430 with <b>9</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">002d</span></div>
#     <div class="cn"><span class="cni"><span class="lc">-</span></div>
#     <div class="cn"><span class="c">HYPHEN-MINUS</span></div>
# </div>
# </td>
#     <td><b>2</b> on <i>1</i> page</td>
#     <td>e.g. page 430 with <b>2</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">002e</span></div>
#     <div class="cn"><span class="cni"><span class="lc">.</span></div>
#     <div class="cn"><span class="c">FULL STOP</span></div>
# </div>
# </td>
#     <td><b>2707</b> on <i>414</i> pages</td>
#     <td>e.g. page 432 with <b>22</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">002f</span></div>
#     <div class="cn"><span class="cni"><span class="lc">/</span></div>
#     <div class="cn"><span class="c">SOLIDUS</span></div>
# </div>
# </td>
#     <td><b>7</b> on <i>2</i> pages</td>
#     <td>e.g. page 426 with <b>4</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0030</span></div>
#     <div class="cn"><span class="cni"><span class="lc">0</span></div>
#     <div class="cn"><span class="c">DIGIT ZERO</span></div>
# </div>
# </td>
#     <td><b>128</b> on <i>91</i> pages</td>
#     <td>e.g. page 381 with <b>5</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0031</span></div>
#     <div class="cn"><span class="cni"><span class="lc">1</span></div>
#     <div class="cn"><span class="c">DIGIT ONE</span></div>
# </div>
# </td>
#     <td><b>243</b> on <i>129</i> pages</td>
#     <td>e.g. page 70 with <b>7</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0032</span></div>
#     <div class="cn"><span class="cni"><span class="lc">2</span></div>
#     <div class="cn"><span class="c">DIGIT TWO</span></div>
# </div>
# </td>
#     <td><b>242</b> on <i>134</i> pages</td>
#     <td>e.g. page 139 with <b>6</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0033</span></div>
#     <div class="cn"><span class="cni"><span class="lc">3</span></div>
#     <div class="cn"><span class="c">DIGIT THREE</span></div>
# </div>
# </td>
#     <td><b>239</b> on <i>133</i> pages</td>
#     <td>e.g. page 208 with <b>7</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0034</span></div>
#     <div class="cn"><span class="cni"><span class="lc">4</span></div>
#     <div class="cn"><span class="c">DIGIT FOUR</span></div>
# </div>
# </td>
#     <td><b>241</b> on <i>134</i> pages</td>
#     <td>e.g. page 268 with <b>7</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0035</span></div>
#     <div class="cn"><span class="cni"><span class="lc">5</span></div>
#     <div class="cn"><span class="c">DIGIT FIVE</span></div>
# </div>
# </td>
#     <td><b>236</b> on <i>134</i> pages</td>
#     <td>e.g. page 347 with <b>8</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0036</span></div>
#     <div class="cn"><span class="cni"><span class="lc">6</span></div>
#     <div class="cn"><span class="c">DIGIT SIX</span></div>
# </div>
# </td>
#     <td><b>188</b> on <i>117</i> pages</td>
#     <td>e.g. page 391 with <b>8</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0037</span></div>
#     <div class="cn"><span class="cni"><span class="lc">7</span></div>
#     <div class="cn"><span class="c">DIGIT SEVEN</span></div>
# </div>
# </td>
#     <td><b>128</b> on <i>95</i> pages</td>
#     <td>e.g. page 171 with <b>6</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0038</span></div>
#     <div class="cn"><span class="cni"><span class="lc">8</span></div>
#     <div class="cn"><span class="c">DIGIT EIGHT</span></div>
# </div>
# </td>
#     <td><b>128</b> on <i>88</i> pages</td>
#     <td>e.g. page 56 with <b>5</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0039</span></div>
#     <div class="cn"><span class="cni"><span class="lc">9</span></div>
#     <div class="cn"><span class="c">DIGIT NINE</span></div>
# </div>
# </td>
#     <td><b>131</b> on <i>86</i> pages</td>
#     <td>e.g. page 378 with <b>5</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">003a</span></div>
#     <div class="cn"><span class="cni"><span class="lc">:</span></div>
#     <div class="cn"><span class="c">COLON</span></div>
# </div>
# </td>
#     <td><b>1512</b> on <i>362</i> pages</td>
#     <td>e.g. page 435 with <b>21</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">003d</span></div>
#     <div class="cn"><span class="cni"><span class="lc">=</span></div>
#     <div class="cn"><span class="c">EQUALS SIGN</span></div>
# </div>
# </td>
#     <td><b>1</b> on <i>1</i> page</td>
#     <td>e.g. page 433 with <b>1</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0041</span></div>
#     <div class="cn"><span class="cni"><span class="lc">A</span></div>
#     <div class="cn"><span class="c">LATIN CAPITAL LETTER A</span></div>
# </div>
# </td>
#     <td><b>2</b> on <i>1</i> page</td>
#     <td>e.g. page 430 with <b>2</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0042</span></div>
#     <div class="cn"><span class="cni"><span class="lc">B</span></div>
#     <div class="cn"><span class="c">LATIN CAPITAL LETTER B</span></div>
# </div>
# </td>
#     <td><b>4</b> on <i>2</i> pages</td>
#     <td>e.g. page 430 with <b>3</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0043</span></div>
#     <div class="cn"><span class="cni"><span class="lc">C</span></div>
#     <div class="cn"><span class="c">LATIN CAPITAL LETTER C</span></div>
# </div>
# </td>
#     <td><b>2</b> on <i>1</i> page</td>
#     <td>e.g. page 430 with <b>2</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0045</span></div>
#     <div class="cn"><span class="cni"><span class="lc">E</span></div>
#     <div class="cn"><span class="c">LATIN CAPITAL LETTER E</span></div>
# </div>
# </td>
#     <td><b>5</b> on <i>1</i> page</td>
#     <

# %%
Lw.showReplacements()
# Out:
# <p><b>112 characters in 135053 occurences
# on 438 pages</b></p>
# <table>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fe91</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺑ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER BEH INITIAL FORM</span></div>
# </div>
# </td>
#     <td><b>6432</b> on <i>437</i> pages</td>
#     <td>e.g. page 436 with <b>60</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fecb</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻋ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER AIN INITIAL FORM</span></div>
# </div>
# </td>
#     <td><b>5734</b> on <i>435</i> pages</td>
#     <td>e.g. page 431 with <b>43</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻳ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH INITIAL FORM</span></div>
# </div>
# </td>
#     <td><b>5501</b> on <i>437</i> pages</td>
#     <td>e.g. page 134 with <b>32</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feaa</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺪ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER DAL FINAL FORM</span></div>
# </div>
# </td>
#     <td><b>5167</b> on <i>437</i> pages</td>
#     <td>e.g. page 100 with <b>49</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fe94</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺔ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TEH MARBUTA FINAL FORM</span></div>
# </div>
# </td>
#     <td><b>5069</b> on <i>435</i> pages</td>
#     <td>e.g. page 4 with <b>62</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fecc</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻌ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER AIN MEDIAL FORM</span></div>
# </div>
# </td>
#     <td><b>4590</b> on <i>437</i> pages</td>
#     <td>e.g. page 146 with <b>27</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fee6</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻦ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER NOON FINAL FORM</span></div>
# </div>
# </td>
#     <td><b>4586</b> on <i>435</i> pages</td>
#     <td>e.g. page 434 with <b>51</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef2</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻲ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH FINAL FORM</span></div>
# </div>
# </td>
#     <td><b>4104</b> on <i>433</i> pages</td>
#     <td>e.g. page 101 with <b>35</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fe98</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺘ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TEH MEDIAL FORM</span></div>
# </div>
# </td>
#     <td><b>3988</b> on <i>436</i> pages</td>
#     <td>e.g. page 404 with <b>28</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fee2</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻢ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER MEEM FINAL FORM</span></div>
# </div>
# </td>
#     <td><b>3980</b> on <i>427</i> pages</td>
#     <td>e.g. page 239 with <b>37</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fee7</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻧ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER NOON INITIAL FORM</span></div>
# </div>
# </td>
#     <td><b>3959</b> on <i>431</i> pages</td>
#     <td>e.g. page 433 with <b>39</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fed8</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻘ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER QAF MEDIAL FORM</span></div>
# </div>
# </td>
#     <td><b>3944</b> on <i>436</i> pages</td>
#     <td>e.g. page 22 with <b>24</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feec</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻬ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER HEH MEDIAL FORM</span></div>
# </div>
# </td>
#     <td><b>3924</b> on <i>431</i> pages</td>
#     <td>e.g. page 433 with <b>31</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feeb</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻫ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER HEH INITIAL FORM</span></div>
# </div>
# </td>
#     <td><b>3693</b> on <i>434</i> pages</td>
#     <td>e.g. page 308 with <b>21</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fe92</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺒ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER BEH MEDIAL FORM</span></div>
# </div>
# </td>
#     <td><b>3487</b> on <i>435</i> pages</td>
#     <td>e.g. page 432 with <b>34</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedc</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻜ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER KAF MEDIAL FORM</span></div>
# </div>
# </td>
#     <td><b>3469</b> on <i>431</i> pages</td>
#     <td>e.g. page 73 with <b>27</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fea4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺤ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER HAH MEDIAL FORM</span></div>
# </div>
# </td>
#     <td><b>3205</b> on <i>430</i> pages</td>
#     <td>e.g. page 269 with <b>24</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feb4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺴ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER SEEN MEDIAL FORM</span></div>
# </div>
# </td>
#     <td><b>3072</b> on <i>431</i> pages</td>
#     <td>e.g. page 379 with <b>28</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedb</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻛ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER KAF INITIAL FORM</span></div>
# </div>
# </td>
#     <td><b>3044</b> on <i>430</i> pages</td>
#     <td>e.g. page 223 with <b>28</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fe97</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺗ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER TEH INITIAL FORM</span></div>
# </div>
# </td>
#     <td><b>2777</b> on <i>432</i> pages</td>
#     <td>e.g. page 19 with <b>22</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fea3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺣ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER HAH INITIAL FORM</span></div>
# </div>
# </td>
#     <td><b>2660</b> on <i>420</i> pages</td>
#     <td>e.g. page 307 with <b>25</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fc90</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﲐ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE ALEF MAKSURA WITH SUPERSCRIPT ALEF FINAL FORM</span></div>
# </div>
# </td>
#     <td><b>2647</b> on <i>426</i> pages</td>
#     <td>e.g. page 343 with <b>24</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feac</span></div>
#     <div class="cn"><span class="c
# <p><b>107 rules with
# 338502 applications on 438 pages</b></p>
# <table>
#
# <tr>
#     <th>rule 1</th>
#     <td><b>122350</b> x applied on <i>428</i> pages</td>
#     <td>e.g. page 435 with 697 applications</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td></td>
# </tr>
#
# <tr>
#     <th>rule 2</th>
#     <td><b>25195</b> x applied on <i>434</i> pages</td>
#     <td>e.g. page 52 with 116 applications</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e825</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 86</th>
#     <td><b>23536</b> x applied on <i>438</i> pages</td>
#     <td>e.g. page 351 with 99 applications</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedf</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻟ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM INITIAL FORM</span></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0644</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ل</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 56</th>
#     <td><b>18346</b> x applied on <i>437</i> pages</td>
#     <td>e.g. page 433 with 110 applications</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fe8e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺎ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF FINAL FORM</span></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 14</th>
#     <td><b>16037</b> x applied on <i>433</i> pages</td>
#     <td>e.g. page 336 with 83 applications</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e864</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 52</th>
#     <td><b>9234</b> x applied on <i>437</i> pages</td>
#     <td>e.g. page 319 with 54 applications</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feae</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﺮ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER REH FINAL FORM</span></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0631</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ر</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER REH</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 82</th>
#     <td><b>9162</b> x applied on <i>438</i> pages</td>
#     <td>e.g. page 74 with 56 applications</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">feee</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻮ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER WAW FINAL FORM</span></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0648</span></div>
#     <div class="cn"><span class="cni"><span class="rc">و</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER WAW</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 23</th>
#     <td><b>9105</b> x applied on <i>428</i> pages</td>
#     <td>e.g. page 398 with 74 applications</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e828</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 103</th>
#     <td><b>8539</b> x applied on <i>438</i> pages</td>
#     <td>e.g. page 33 with 44 applications</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fef4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻴ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH MEDIAL FORM</span></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064a</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ي</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER YEH</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 49</th>
#     <td><b>8522</b> x applied on <i>438</i> pages</td>
#     <td>e.g. page 100 with 48 applications</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fee3</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻣ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER MEEM INITIAL FORM</span></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0645</span></div>
#     <div class="cn"><span class="cni"><span class="rc">م</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER MEEM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 9</th>
#     <td><b>8236</b> x applied on <i>431</i> pages</td>
#     <td>e.g. page 357 with 47 applications</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e826</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064f</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ُ</span></div>
#     <div class="cn"><span class="c">ARABIC DAMMA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 50</th>
#     <td><b>7892</b> x applied on <i>438</i> pages</td>
#     <td>e.g. page 74 with 39 applications</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fee4</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻤ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER MEEM MEDIAL FORM</span></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0645</span></div>
#     <div class="cn"><span class="cni"><span class="rc">م</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER MEEM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 6</th>
#     <td><b>7407</b> x applied on <i>429</i> pages</td>
#     <td>e.g. page 197 with 43 applications</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e8e8</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 87</th>
#     <td><b>6987</b> x applied on <i>437</i> pages</td>
#     <td>e.g. page 42 with 38 applications</td>
#     <td>
# <div clas
