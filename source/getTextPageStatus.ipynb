# %%
# %load_ext autoreload
# %autoreload 2
# !cd `pwd`

# %%
from fusus.lakhnawi import Lakhnawi, pprint
Lw = Lakhnawi()
Lw.setStyle()
# Out:
# <style>
# .r {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     direction: rtl;
# }
# .rc, .lc {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     background-color: white;
#     border: 2pt solid #ffcccc;
# }
# .rc {
#     direction: rtl;
# }
# .lc {
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# p {
#     text-align: left;
#     direction: ltr;
# }
# p.r {
#     text-align: right;
#     direction: rtl;
# }
# .l {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# .c {
#     font-family: monospace;
#     font-size: x-small;
#     direction: ltr;
# }
# .p {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     background-color: yellow;
#     direction: ltr;
# }
# .lrg {
#     font-size: xx-large;
#     font-weight: bold;
# }
# td {
#     text-align: left ! important;
# }
# div.cn {
#     text-align: center
# }
# div.ch.p {
#     background-color: #ffeedd;
#     text-align: center
# }
# span.cni {
#     background-color: #eeeeee;
#     padding-top: 4pt;
#     padding-bottom: 4pt;
#     padding-left: 8pt;
#     padding-right: 8pt;
#     border: 2pt solid #66aaaa;
#     display: inline-block;
# }
# div.ch {
#     border: 2pt solid #cccccc;
#     background-color: #ddffff;
#     display: inline-flex;
#     flex-flow: column nowrap;
#     max-width: 10em;
# }
# div.sr {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# </style>

# %%
testPages = None
Lw.getPages(testPages, refreshConfig=True)
Lw.showUsedChars(testPages, onlyPuas=True, long=False, byOcc=True)
Lw.showReplacements()
# Out:
# 	 438
# <p><b>46 private use characters in 1989 occurences
# on 400 pages</b></p>
# <table>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e815</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>363</b> on <i>208</i> pages</td>
#     <td>e.g. page 322 with <b>7</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e840</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>251</b> on <i>148</i> pages</td>
#     <td>e.g. page 172 with <b>8</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e8de</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>172</b> on <i>114</i> pages</td>
#     <td>e.g. page 46 with <b>4</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e83f</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>110</b> on <i>69</i> pages</td>
#     <td>e.g. page 33 with <b>4</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e8f6</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>108</b> on <i>71</i> pages</td>
#     <td>e.g. page 112 with <b>6</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e82e</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>101</b> on <i>69</i> pages</td>
#     <td>e.g. page 110 with <b>4</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e82f</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>98</b> on <i>74</i> pages</td>
#     <td>e.g. page 141 with <b>4</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e8e7</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>95</b> on <i>68</i> pages</td>
#     <td>e.g. page 158 with <b>5</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e834</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>94</b> on <i>61</i> pages</td>
#     <td>e.g. page 300 with <b>6</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e85c</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>91</b> on <i>70</i> pages</td>
#     <td>e.g. page 203 with <b>4</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e8e6</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>88</b> on <i>75</i> pages</td>
#     <td>e.g. page 283 with <b>4</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e837</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>61</b> on <i>38</i> pages</td>
#     <td>e.g. page 274 with <b>5</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e829</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>54</b> on <i>45</i> pages</td>
#     <td>e.g. page 258 with <b>3</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e8f5</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>46</b> on <i>40</i> pages</td>
#     <td>e.g. page 28 with <b>2</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e8ee</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>41</b> on <i>31</i> pages</td>
#     <td>e.g. page 369 with <b>4</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e80a</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>28</b> on <i>26</i> pages</td>
#     <td>e.g. page 234 with <b>2</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e838</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>23</b> on <i>20</i> pages</td>
#     <td>e.g. page 16 with <b>2</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e8f8</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>23</b> on <i>19</i> pages</td>
#     <td>e.g. page 311 with <b>3</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e808</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>21</b> on <i>19</i> pages</td>
#     <td>e.g. page 234 with <b>2</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e812</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>18</b> on <i>15</i> pages</td>
#     <td>e.g. page 136 with <b>2</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e816</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>14</b> on <i>12</i> pages</td>
#     <td>e.g. page 64 with <b>2</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e835</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>12</b> on <i>11</i> pages</td>
#     <td>e.g. page 103 with <b>2</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e8fb</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>10</b> on <i>9</i> pages</td>
#     <td>e.g. page 355 with <b>2</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e818</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>10</b> on <i>8</i> pages</td>
#     <td>e.g. page 425 with <b>3</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e87f</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>8</b> on <i>8</i> pages</td>
#     <td>e.g. page 91 with <b>1</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e83a</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>7</b> on <i>7</i> pages</td>
#     <td>e.g. page 135 with <b>1</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e800</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>5</b> on <i>5</i> pages</td>
#     <td>e.g. page 12 with <b>1</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e80e</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>4</b> on <i>4</i> pages</td>
#     <td>e.g. page 34 with <b>1</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span cl
# <table>
# <tr>
#     <th>rule 12</th>
#     <td><b>122757</b> x applied on <i>428</i> pages</td>
#     <td>e.g. page 435 with 699 applicaitons</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td></td>
# </tr>
#
# <tr>
#     <th>rule 15</th>
#     <td><b>25195</b> x applied on <i>434</i> pages</td>
#     <td>e.g. page 52 with 116 applicaitons</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e825</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 27</th>
#     <td><b>16037</b> x applied on <i>433</i> pages</td>
#     <td>e.g. page 336 with 83 applicaitons</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e864</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 18</th>
#     <td><b>9106</b> x applied on <i>429</i> pages</td>
#     <td>e.g. page 398 with 74 applicaitons</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e828</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0652</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ْ</span></div>
#     <div class="cn"><span class="c">ARABIC SUKUN</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 16</th>
#     <td><b>8236</b> x applied on <i>431</i> pages</td>
#     <td>e.g. page 357 with 47 applicaitons</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e826</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064f</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ُ</span></div>
#     <div class="cn"><span class="c">ARABIC DAMMA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 32</th>
#     <td><b>7407</b> x applied on <i>429</i> pages</td>
#     <td>e.g. page 197 with 43 applicaitons</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e8e8</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 33</th>
#     <td><b>4587</b> x applied on <i>425</i> pages</td>
#     <td>e.g. page 355 with 31 applicaitons</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e8e9</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064f</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ُ</span></div>
#     <div class="cn"><span class="c">ARABIC DAMMA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 37</th>
#     <td><b>4147</b> x applied on <i>416</i> pages</td>
#     <td>e.g. page 38 with 28 applicaitons</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fc60</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﱠ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH FATHA ISOLATED FORM</span></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0651</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ّ</span></div>
#     <div class="cn"><span class="c">ARABIC SHADDA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 20</th>
#     <td><b>2715</b> x applied on <i>418</i> pages</td>
#     <td>e.g. page 30 with 34 applicaitons</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e830</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fcf2</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﳲ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH FATHA MEDIAL FORM</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 24</th>
#     <td><b>2581</b> x applied on <i>404</i> pages</td>
#     <td>e.g. page 295 with 20 applicaitons</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e845</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0655</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ٕ</span></div>
#     <div class="cn"><span class="c">ARABIC HAMZA BELOW</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 1</th>
#     <td><b>2540</b> x applied on <i>396</i> pages</td>
#     <td>e.g. page 38 with 25 applicaitons</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="p">e815</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0623</span></div>
#     <div class="cn"><span class="cni"><span class="rc">أ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF WITH HAMZA ABOVE</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 29</th>
#     <td><b>1554</b> x applied on <i>367</i> pages</td>
#     <td>e.g. page 247 with 16 applicaitons</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e888</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><span class="lrg">⇒</span></td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0650</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ِ</span></div>
#     <div class="cn"><span class="c">ARABIC KASRA</span></div>
# </div>
# </td>
# </tr>
#
# <tr>
#     <th>rule 17</th>
#     <td><b>1436</b> x applied on <i>304</i> pages</td>
#     <td>e.g. page 4 with 36 applicaitons</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e827</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
