# %% [markdown]
# # Pipeline
#
# See [usage](https://among.github.io/fusus/use/).
#
# See [example](https://github.com/among/fusus/blob/master/example/doExample.ipynb).
#
# How to read this notebook:
#
# 1.  *best experience*
#     get this repository on your computer and run `jupyter lab`.
#     Also install the table of contents extension in Jupyter Lab, since this is a lengthy notebook
#     You can run the code cells now.
# 1.  *good reading experience*
#     read it on [NbViewer](https://nbviewer.jupyter.org/github/among/fusus/blob/master/example/doExample.ipynb)
# 1.  *suboptimal*
#     read it directly on [GitHub](https://github.com/among/fusus/blob/master/example/doExample.ipynb)
#     (long time to load)

# %% [markdown]
# # The beginning
#
# Enable autoloading of changed code.
#
# Change the directory to where this notebook resides on disk, i.e. near the book's scanned pages directory.

# %%
# %load_ext autoreload
# %autoreload 2
# !cd `pwd`

# %%
import fusus

# %% [markdown]
# Import the fusus package.
#
# See [install](https://among.github.io/fusus/about/install.html).

# %%
from fusus.book import Book

# %% [markdown]
# Initialize the processing line.

# %%
B = Book()
# Out:
#   0.01s Loading for Kraken: ~/github/among/fusus/model/arabic_generalized.mlmodel
#   0.99s model loaded

# %%
page = B.process(pages=132, doOcr=True, batch=False)
# Out:
#   0.00s Batch of 1 pages: 132
#   0.00s Start batch processing images
#    |     5.61s     1 132.jpg
#   5.61s all done

# %%
page.show(stage="ocr")
# Out:
# {'1-l': [(0,
#           [[('ا', (0, 76, 913, 76), 0.9960569),
#             ('ٔ', (0, 76, 913, 76), 0.59949136),
#             ('ع', (0, 76, 913, 76), 0.99741036),
#             ('م', (0, 76, 913, 76), 0.99962294),
#             (' ', (0, 76, 913, 76), 0.9989152),
#             ('م', (0, 76, 913, 76), 0.9997329),
#             ('ن', (0, 76, 913, 76), 0.9990701),
#             (' ', (0, 76, 913, 76), 0.999529),
#             ('ا', (0, 76, 913, 76), 0.9967399),
#             ('ل', (0, 76, 913, 76), 0.99901533),
#             ('م', (0, 76, 913, 76), 0.9982584),
#             ('ب', (0, 76, 913, 76), 0.99948186),
#             ('ا', (0, 76, 913, 76), 0.9994887),
#             ('د', (0, 76, 913, 76), 0.9996605),
#             ('ى', (0, 76, 913, 76), 0.9989073),
#             ('ء', (0, 76, 913, 76), 0.9966619),
#             (' ', (0, 76, 913, 76), 0.99693334),
#             ('و', (0, 76, 913, 76), 0.99832183),
#             ('ه', (0, 76, 913, 76), 0.9479286),
#             ('و', (0, 76, 913, 76), 0.99918014),
#             (' ', (0, 76, 913, 76), 0.9834064),
#             ('م', (0, 76, 913, 76), 0.97511464),
#             ('ا', (0, 76, 913, 76), 0.9983631),
#             (' ', (0, 76, 913, 76), 0.6583303),
#             ('ي', (0, 76, 913, 76), 0.9999063),
#             ('ت', (0, 76, 913, 76), 0.9345798),
#             ('و', (0, 76, 913, 76), 0.99998224),
#             ('ق', (0, 76, 913, 76), 0.5287972),
#             ('ف', (0, 76, 913, 76), 0.9992275),
#             (' ', (0, 76, 913, 76), 0.9965462),
#             ('ع', (0, 76, 913, 76), 0.9993824),
#             ('ل', (0, 76, 913, 76), 0.99996567),
#             ('ي', (0, 76, 913, 76), 0.99996555),
#             ('ه', (0, 76, 913, 76), 0.99968815),
#             (' ', (0, 76, 913, 76), 0.84538627),
#             ('ا', (0, 76, 913, 76), 0.99985754),
#             ('ل', (0, 76, 913, 76), 0.9994124),
#             ('م', (0, 76, 913, 76), 0.9894113),
#             ('س', (0, 76, 913, 76), 0.99839324),
#             ('ة', (0, 83, 913, 83), 0.94228506),
#             (' ', (0, 83, 913, 83), 0.6767204),
#             ('.', (0, 83, 913, 83), 0.99753714),
#             (' ', (0, 83, 913, 83), 0.9972223),
#             ('ف', (0, 83, 913, 83), 0.7202431),
#             ('ت', (0, 83, 913, 83), 0.9994542),
#             ('ا', (0, 83, 913, 83), 0.81981575),
#             ('ٔ', (0, 83, 913, 83), 0.9999362),
#             ('م', (0, 83, 913, 83), 0.9999839),
#             ('ل', (0, 83, 913, 83), 0.99999774),
#             (' ', (0, 83, 913, 83), 0.99960643),
#             ('!', (0, 83, 913, 83), 0.99850744)]])],
#  '1-r': [(0,
#           [[('ا', (0, 76, 915, 76), 0.99762887),
#             ('ٔ', (0, 76, 915, 76), 0.99514884),
#             ('ع', (0, 76, 915, 76), 0.99938774),
#             ('م', (0, 76, 915, 76), 0.9991467),
#             (' ', (0, 76, 915, 76), 0.99880576),
#             ('م', (0, 76, 915, 76), 0.99347854),
#             ('ن', (0, 76, 915, 76), 0.96917176),
#             (' ', (0, 76, 915, 76), 0.9992343),
#             ('م', (0, 76, 915, 76), 0.998801),
#             ('ق', (0, 76, 915, 76), 0.97462904),
#             ('د', (0, 76, 915, 76), 0.99816006),
#             ('م', (0, 76, 915, 76), 0.9798052),
#             ('ة', (0, 76, 915, 76), 0.9469029),
#             (' ', (0, 76, 915, 76), 0.9979274),
#             ('ا', (0, 76, 915, 76), 0.92598855),
#             ('ل', (0, 76, 915, 76), 0.99947447),
#             ('ع', (0, 76, 915, 76), 0.99943835),
#             ('ل', (0, 76, 915, 76), 0.55553967),
#             ('م', (0, 76, 915, 76), 0.87829447),
#             (' ', (0, 76, 915, 76), 0.999972),
#             ('ب', (0, 76, 915, 76), 0.9676415),
#             ('ي', (0, 76, 915, 76), 0.9997291),
#             ('ن', (0, 76, 915, 76), 0.98302126),
#             ('ه', (0, 76, 915, 76), 0.80431134),
#             ('م', (0, 76, 915, 76), 0.99985886),
#             ('ا', (0, 76, 915, 76), 0.9577074),
#             (' ', (0, 76, 915, 76), 0.99990284),
#             ('ع', (0, 76, 915, 76), 0.9991732),
#             ('م', (0, 76, 915, 76), 0.99990296),
#             ('و', (0, 76, 915, 76), 0.96793294),
#             ('م', (0, 76, 915, 76), 0.99993),
#             (' ', (0, 76, 915, 76), 0.99983966),
#             ('و', (0, 76, 915, 76), 0.9924061),
#             ('خ', (0, 76, 915, 76), 0.99991095),
#             ('ص', (0, 76, 915, 76), 0.99999774),
#             ('و', (0, 76, 915, 76), 0.9934441),
#             ('ص', (0, 42, 915, 42), 0.956185)]]),
#          (1,
#           [[('م', (0, 70, 915, 70), 0.9105202),
#             ('ط', (0, 70, 915, 70), 0.9935504),
#             ('ل', (0, 70, 915, 70), 0.99934894),
#             ('ق', (0, 70, 915, 70), 0.99886286),
#             (' ', (0, 70, 915, 70), 0.9999747),
#             ('.', (0, 70, 915, 70), 0.99895525)]]),
#          (2,
#           [[('و', (0, 93, 915, 93), 0.54863167),
#             ('ا', (0, 93, 915, 93), 0.9993037),
#             ('ل', (0, 93, 915, 93), 0.99965274),
#             ('ف', (0, 93, 915, 93), 0.9965778),
#             ('ر', (0, 93, 915, 93), 0.99670273),
#             ('ق', (0, 93, 915, 93), 0.99898535),
#             (' ', (0, 93, 915, 93), 0.99681264),
#             ('ب', (0, 93, 915, 93), 0.99545836),
#             ('ي', (0, 93, 915, 93), 0.9997316),
#             ('ن', (0, 93, 915, 93), 0.99883646),
#             (' ', (0, 93, 915, 93), 0.88642776),
#             ('ا', (0, 93, 915, 93), 0.9947483),
#             ('ل', (0, 93, 915, 93), 0.998872),
#             ('م', (0, 93, 915, 93), 0.588591),
#             ('ق', (0, 93, 915, 93), 0.99898905),
#             ('د', (0, 93, 915, 93), 0.99998546),
#             ('م', (0, 93, 915, 93), 0.9999479),
#             ('ة', (0, 93, 915, 93), 0.99993527),
#             (' ', (0, 93, 915, 93), 0.99993634),
#             ('و', (0, 93, 915, 93), 0.9999199),
#             ('ا', (0, 93, 915, 93), 0.99996185),
#             ('ل', (0, 93, 915, 93), 0.9999654),
#             ('م', (0, 93, 915, 93), 0.98261917),
#             ('ب', (0, 93, 915, 93), 0.9951342),
#             ('ا', (0, 93, 915, 93), 0.99972695),
#             ('د', (0, 93, 915, 93), 0.9999447),
#             ('ى', (0, 93, 915, 93), 0.98977965),
#             ('ء', (0, 93, 915, 93), 0.99977416),
#             (' ', (0, 93, 915, 93), 0.99975544),
#             ('ا', (0, 93, 915, 93), 0.99998176),
#             ('ٔ', (0, 93, 915, 93), 0.94670755),
#             ('ن', (0, 93, 915, 93), 0.9999553),
#             (' ', (0, 93, 915, 93), 0.8831951),
#             ('ا', (0, 93, 915, 93), 0.9999138),
#             ('ل', (0, 93, 915, 93), 0.9998642),
#             ('م', (0, 93, 915, 93), 0.9987956),
#             ('ق', (0, 93, 915, 93), 0.54992276),
#             ('د', (0, 81, 915, 81), 0.7312817),
#             ('م', (0, 52, 915, 52), 0.9993411),
#             ('ة', (0, 30, 915, 30), 0.9996507)]])],
#  '2-': [(0,
#          [[('6', (0, 5, 1108, 5), 0.9794114),
#            ('0', (0, 40, 1108, 40), 0.99514353),
#            ('5', (0, 111, 1108, 111), 0.9998795),
#            ('9', (0, 111, 1108, 111), 0.99999714)]])]}

# %%
page.show(stage="histogram")
# Out:
# {'normalizedC', 'gray', 'layout', 'normalized', 'histogram', 'orig', 'cleanh', 'boxed', 'markData', 'demarginedC', 'ocr', 'clean', 'demargined', 'rotated'}
# <div>histogram </div>

# %%
binary = page.stages["binary"]
clean = page.stages["clean"]

# %%
cleanIm = PILFromArray(clean)

# %%
binary

# %%
type(binary)
# Out:
# numpy.ndarray

# %%
binary
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
page.show(stage="segments")
# Out:
#     33s Will skip illegal stages: segments
# {'normalized', 'clean', 'rotated', 'gray', 'binary', 'ocrData', 'markData', 'demargined', 'orig'}

# %%
from kraken.pageseg import segment
from fusus.lib import PILFromArray
from kraken.binarization import nlbin

# %%
im = PILFromArray(binary)

# %%
im.mode
# Out:
# 'L'

# %%
segment(im)
# Out:
# {'text_direction': 'horizontal-lr',
#  'boxes': [[124, 367, 2081, 469],
#   [125, 464, 1106, 557],
#   [1845, 478, 2080, 564],
#   [659, 557, 1959, 640],
#   [1008, 719, 1200, 768]],
#  'script_detection': False}

# %%
segment(binary)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-4d1bf36d55de> in <module>
# ----> 1 segment(binary)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/kraken/pageseg.py in segment(im, text_direction, scale, maxcolseps, black_colseps, no_hlines, pad, mask, skip_order)
#     420     logger.info('Segmenting {}'.format(im_str))
#     421
# --> 422     if im.mode != '1' and not is_bitonal(im):
#     423         logger.error('Image {} is not bi-level'.format(im_str))
#     424         raise KrakenInputException('Image {} is not bi-level'.format(im_str))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'mode'
