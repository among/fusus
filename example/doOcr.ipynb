# %% [markdown]
# # Pipeline
#
# See [usage](https://among.github.io/fusus/use/).
#
# See [example](https://github.com/among/fusus/blob/master/example/doExample.ipynb).
#
# How to read this notebook:
#
# 1.  *best experience*
#     get this repository on your computer and run `jupyter lab`.
#     Also install the table of contents extension in Jupyter Lab, since this is a lengthy notebook
#     You can run the code cells now.
# 1.  *good reading experience*
#     read it on [NbViewer](https://nbviewer.jupyter.org/github/among/fusus/blob/master/example/doExample.ipynb)
# 1.  *suboptimal*
#     read it directly on [GitHub](https://github.com/among/fusus/blob/master/example/doExample.ipynb)
#     (long time to load)

# %% [markdown]
# # The beginning
#
# Enable autoloading of changed code.
#
# Change the directory to where this notebook resides on disk, i.e. near the book's scanned pages directory.

# %%
# %load_ext autoreload
# %autoreload 2
# !cd `pwd`

# %%
import fusus

# %% [markdown]
# Import the fusus package.
#
# See [install](https://among.github.io/fusus/about/install.html).

# %%
from fusus.book import Book

# %% [markdown]
# Initialize the processing line.

# %%
B = Book()
# Out:
#   0.01s Loading for Kraken: ~/github/among/fusus/model/arabic_generalized.mlmodel
#   0.98s model loaded

# %%
page = B.process(pages=132, doOcr=True, batch=False)
# Out:
#   0.00s Batch of 1 pages: 132
#   0.00s Start batch processing images
#    |     5.55s     1 132.jpg
#   5.55s all done

# %%
page.show(stage="proof")
# Out:
# <div>proof </div>

# %%
page.show(stage="ocrw")
# Out:
# stripe	column	line	left	top	right	bottom	confidence	text
# 1	l	0	973	373	1028	449	90	أعم
# 1	l	0	911	373	946	449	100	من
# 1	l	0	733	373	884	449	100	المبادىء
# 1	l	0	623	373	678	449	98	وهو
# 1	l	0	561	373	589	449	99	ما
# 1	l	0	465	373	541	449	89	يتوقف
# 1	l	0	349	373	403	449	100	عليه
# 1	l	0	204	373	328	449	98	المسائل
# 1	l	0	129	373	163	449	100	بلا
# 1	l	1	923	458	1021	544	98	واسطة
# 1	l	1	712	458	859	544	99	والمقدمة
# 1	l	1	656	458	677	544	98	ما
# 1	l	1	557	458	635	544	94	يتوقف
# 1	l	1	431	458	487	544	98	عليه
# 1	l	1	291	458	410	544	99	المسائل
# 1	l	1	129	458	248	544	95	بواسطة
# 1	l	2	1012	553	1035	636	88	أو
# 1	l	2	952	553	975	636	88	لا
# 1	l	2	824	553	922	636	86	واسطة
# 1	l	2	793	553	801	636	100	.
# 1	l	2	695	553	763	636	92	فتأمل
# 1	l	2	665	553	665	636	100	!
# 1	r	0	2006	380	2078	456	100	أعم
# 1	r	0	1933	380	1982	456	98	من
# 1	r	0	1783	380	1903	456	98	مقدمة
# 1	r	0	1663	380	1765	456	87	العلم
# 1	r	0	1506	380	1614	456	95	بينهما
# 1	r	0	1380	380	1476	456	99	عموم
# 1	r	0	1211	380	1362	456	99	وخصوص
# 1	r	1	2008	471	2072	541	98	مطلق
# 1	r	1	1967	471	1967	541	100	.
# 1	r	2	1855	550	1951	643	92	والفرق
# 1	r	2	1781	550	1818	643	100	بين
# 1	r	2	1627	550	1752	643	94	المقدمة
# 1	r	2	1427	550	1604	643	100	والمبادىء
# 1	r	2	1354	550	1383	643	98	أن
# 1	r	2	1199	550	1331	643	90	المقدمة
# 2		0	568	3068	1651	3179	100	6059

# %%
page.show(stage="ocr")
# Out:
# stripe	column	line	left	top	right	bottom	confidence	text
# 1	l	0	1028	373	1028	449	100	ا
# 1	l	0	1021	373	1021	449	60	ٔ
# 1	l	0	1001	373	1007	449	100	ع
# 1	l	0	973	373	980	449	100	م
# 1	l	0	939	373	946	449	100	م
# 1	l	0	911	373	918	449	100	ن
# 1	l	0	884	373	884	449	100	ا
# 1	l	0	870	373	877	449	100	ل
# 1	l	0	850	373	850	449	100	م
# 1	l	0	829	373	829	449	100	ب
# 1	l	0	808	373	815	449	100	ا
# 1	l	0	795	373	795	449	100	د
# 1	l	0	767	373	767	449	100	ى
# 1	l	0	733	373	733	449	100	ء
# 1	l	0	671	373	678	449	100	و
# 1	l	0	644	373	644	449	95	ه
# 1	l	0	623	373	623	449	100	و
# 1	l	0	582	373	589	449	98	م
# 1	l	0	561	373	568	449	100	ا
# 1	l	0	541	373	541	449	100	ي
# 1	l	0	527	373	527	449	93	ت
# 1	l	0	513	373	513	449	100	و
# 1	l	0	486	373	486	449	53	ق
# 1	l	0	465	373	472	449	100	ف
# 1	l	0	397	373	403	449	100	ع
# 1	l	0	376	373	383	449	100	ل
# 1	l	0	362	373	362	449	100	ي
# 1	l	0	349	373	349	449	100	ه
# 1	l	0	321	373	328	449	100	ا
# 1	l	0	307	373	314	449	100	ل
# 1	l	0	287	373	287	449	99	م
# 1	l	0	259	373	266	449	100	س
# 1	l	0	232	373	239	449	100	ا
# 1	l	0	218	373	225	449	100	ي
# 1	l	0	211	373	211	449	100	ٔ
# 1	l	0	204	373	204	449	88	ل
# 1	l	0	163	373	163	449	100	ب
# 1	l	0	143	373	150	449	100	ل
# 1	l	0	129	373	136	449	100	ا
# 1	l	1	1021	458	1021	544	100	و
# 1	l	1	1000	458	1007	544	100	ا
# 1	l	1	979	458	986	544	100	س
# 1	l	1	944	458	944	544	100	ط
# 1	l	1	923	458	923	544	89	ة
# 1	l	1	859	458	859	544	100	و
# 1	l	1	838	458	838	544	100	ا
# 1	l	1	824	458	831	544	97	ل
# 1	l	1	796	458	803	544	100	م
# 1	l	1	782	458	782	544	100	ق
# 1	l	1	761	458	761	544	96	د
# 1	l	1	733	458	733	544	100	م
# 1	l	1	712	458	712	544	100	ة
# 1	l	1	677	458	677	544	99	م
# 1	l	1	656	458	663	544	98	ا
# 1	l	1	635	458	635	544	97	ي
# 1	l	1	621	458	621	544	99	ت
# 1	l	1	600	458	607	544	100	و
# 1	l	1	578	458	578	544	75	ق
# 1	l	1	557	458	564	544	100	ف
# 1	l	1	487	458	487	544	93	ع
# 1	l	1	466	458	466	544	100	ل
# 1	l	1	452	458	452	544	100	ي
# 1	l	1	431	458	438	544	100	ه
# 1	l	1	403	458	410	544	100	ا
# 1	l	1	396	458	396	544	91	ل
# 1	l	1	368	458	375	544	100	م
# 1	l	1	347	458	354	544	100	س
# 1	l	1	319	458	319	544	100	ا
# 1	l	1	305	458	312	544	100	ي
# 1	l	1	298	458	298	544	99	ٔ
# 1	l	1	291	458	291	544	100	ل
# 1	l	1	248	458	248	544	100	ب
# 1	l	1	227	458	234	544	100	و
# 1	l	1	206	458	213	544	100	ا
# 1	l	1	192	458	192	544	72	س
# 1	l	1	150	458	150	544	100	ط
# 1	l	1	129	458	129	544	100	ة
# 1	l	2	1027	553	1035	636	100	ا
# 1	l	2	1020	553	1020	636	97	ٔ
# 1	l	2	1012	553	1012	636	67	و
# 1	l	2	975	553	975	636	77	ل
# 1	l	2	952	553	959	636	100	ا
# 1	l	2	922	553	922	636	100	و
# 1	l	2	899	553	907	636	99	ا
# 1	l	2	884	553	884	636	40	س
# 1	l	2	839	553	846	636	99	ط
# 1	l	2	824	553	824	636	94	ة
# 1	l	2	793	553	801	636	100	.
# 1	l	2	763	553	763	636	72	ف
# 1	l	2	748	553	748	636	100	ت
# 1	l	2	741	553	741	636	82	ا
# 1	l	2	726	553	733	636	100	ٔ
# 1	l	2	711	553	718	636	100	م
# 1	l	2	695	553	703	636	100	ل
# 1	l	2	665	553	665	636	100	!
# 1	r	0	2078	380	2078	456	100	ا
# 1	r	0	2066	380	2072	456	100	ٔ
# 1	r	0	2048	380	2054	456	100	ع
# 1	r	0	2006	380	2006	456	100	م
# 1	r	0	1976	380	1982	456	99	م
# 1	r	0	1933	380	1933	456	97	ن
# 1	r	0	1897	380	1903	456	100	م
# 1	r	0	1879	380	1885	456	97	ق
# 1	r	0	1843	380	1843	456	100	د
# 1	r	0	1819	380	1819	456	98	م
# 1	r	0	1783	380	1783	456	95	ة
# 1	r	0	1759	380	1765	456	93	ا
# 1	r	0	1747	380	1753	456	100	ل
# 1	r	0	1723	380	1729	456	100	ع
# 1	r	0	1705	380	1711	456	56	ل
# 1	r	0	1663	380	1669	456	88	م
# 1	r	0	1614	380	1614	456	97	ب
# 1	r	0	1596	380	1602	456	100	ي
# 1	r	0	1584	380	1584	456	98	ن
# 1	r	0	1566	380	1566	456	80	ه
# 1	r	0	1536	380	1542	456	100	م
# 1	r	0	1506	380	1506	456	96	ا
# 1	r	0	1470	380	1476	456	100	ع
# 1	r	0	1446	380	1452	456	100	م
# 1	r	0	1416	380	1416	456	97	و
# 1	r	0	1380	380	1386	456	100	م
# 1	r	0	1356	380	1362	456	99	و
# 1	r	0	1326	380	1332	456	100	خ
# 1	r	0	1289	380	1295	456	100	ص
# 1	r	0	1247	380	1247	456	99	و
# 1	r	0	1211	380	1211	456	96	ص
# 1	r	1	2072	471	2072	541	91	م
# 1	r	1	2043	471	2043	541	99	ط
# 1	r	1	2025	471	2025	541	100	ل
# 1	r	1	2008	471	2008	541	100	ق
# 1	r	1	1967	471	1967	541	100	.
# 1	r	2	1951	550	1951	643	55	و
# 1	r	2	1929	550	1936	643	100	ا
# 1	r	2	1922	550	1922	643	100	ل
# 1	r	2	1899	550	1907	643	100	ف
# 1	r	2	1885	550	1885	643	100	ر
# 1	r	2	1855	550	1863	643	100	ق
# 1	r	2	1818	550	1818	643	100	ب
# 1	r	2	1804	550	1804	643	100	ي
# 1	r	2	1781	550	1781	643	100	ن
# 1	r	2	1752	550	1752	643	99	ا
# 1	r	2	1737	550	1745	643	100	ل
# 1	r	2	1715	550	1715	643	59	م
# 1	r	2	1693	550	1693	643	100	ق
# 1	r	2	1671	550	1678	643	100	د
# 1	r	2	1641	550	1649	643	100	م
# 1	r	2	1627	550	1627	643	100	ة
# 1	r	2	1597	550	1604	643	100	و
# 1	r	2	1575	550	1582	643	100	ا
# 1	r	2	1567	550	1567	643	100	ل
# 1	r	2	1538	550	1545	643	98	م
# 1	r	2	1523	550	1523	643	100	ب
# 1	r	2	1508	550	1508	643	100	ا
# 1	r	2	1486	550	1494	643	100	د
# 1	r	2	1464	550	1464	643	99	ى
# 1	r	2	1427	550	1427	643	100	ء
# 1	r	2	1376	550	1383	643	100	ا
# 1	r	2	1368	550	1368	643	95	ٔ
# 1	r	2	1354	550	1361	643	100	ن
# 1	r	2	1324	550	1331	643	100	ا
# 1	r	2	1309	550	1317	643	100	ل
# 1	r	2	1287	550	1287	643	100	م
# 1	r	2	1272	550	1272	643	55	ق
# 1	r	2	1250	550	1250	643	73	د
# 1	r	2	1221	550	1221	643	100	م
# 1	r	2	1199	550	1206	643	100	ة
# 2		0	568	3068	568	3179	98	6
# 2		0	603	3068	603	3179	100	0
# 2		0	1621	3068	1621	3179	100	5
# 2		0	1651	3068	1651	3179	100	9

# %%
page.show(stage="layout")
# Out:
# <div>layout </div>

# %%
page.show(stage="clean")
# Out:
# {'normalizedC', 'gray', 'layout', 'normalized', 'histogram', 'orig', 'cleanh', 'boxed', 'markData', 'demarginedC', 'ocr', 'clean', 'demargined', 'rotated'}
# <div>histogram </div>

# %%
binary = page.stages["binary"]
clean = page.stages["clean"]

# %%
cleanIm = PILFromArray(clean)

# %%
binary

# %%
type(binary)
# Out:
# numpy.ndarray

# %%
binary
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
page.show(stage="segments")
# Out:
#     33s Will skip illegal stages: segments
# {'normalized', 'clean', 'rotated', 'gray', 'binary', 'ocrData', 'markData', 'demargined', 'orig'}

# %%
from kraken.pageseg import segment
from fusus.lib import PILFromArray
from kraken.binarization import nlbin

# %%
im = PILFromArray(binary)

# %%
im.mode
# Out:
# 'L'

# %%
segment(im)
# Out:
# {'text_direction': 'horizontal-lr',
#  'boxes': [[124, 367, 2081, 469],
#   [125, 464, 1106, 557],
#   [1845, 478, 2080, 564],
#   [659, 557, 1959, 640],
#   [1008, 719, 1200, 768]],
#  'script_detection': False}

# %%
segment(binary)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-4d1bf36d55de> in <module>
# ----> 1 segment(binary)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/kraken/pageseg.py in segment(im, text_direction, scale, maxcolseps, black_colseps, no_hlines, pad, mask, skip_order)
#     420     logger.info('Segmenting {}'.format(im_str))
#     421
# --> 422     if im.mode != '1' and not is_bitonal(im):
#     423         logger.error('Image {} is not bi-level'.format(im_str))
#     424         raise KrakenInputException('Image {} is not bi-level'.format(im_str))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'mode'
