# %% [markdown]
# # Black borders are removed from a page

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from fusus.book import Book

# %%
B = Book(cd="~/github/among/fusus/example")

# %%
# cd to the book directory
# !cd `pwd`

# %%
def checkBorder(pageNum):
    page = B.process(pageNum, batch=False, uptoLayout=True)
    page.show("gray,normalized")
    return page

# %%
page = checkBorder(101)
# Out:
#   0.00s Batch of 1 pages: 101
#   0.00s Start batch processing images
# 22 1584 11 2258    1 101.jpg
#    |      |      |    2m 59s     1 101.jpg
#   1.22s all done
# <hr>
# <div><b>gray</b> </div>
# <hr>
# <div><b>normalized</b> </div>

# %%
page = checkBorder(102)
# Out:
#   0.00s Batch of 1 pages: 102
#   0.00s Start batch processing images
# 0 1557 14 2258     1 102.jpg
#    |      |      |    3m 35s     1 102.jpg
#   1.37s all done
# <hr>
# <div><b>gray</b> </div>
# <hr>
# <div><b>normalized</b> </div>

# %%
page = checkBorder(112)
# Out:
#   0.00s Batch of 1 pages: 112
#   0.00s Start batch processing images
# 0 2141 0 3028s     1 112.jpg
#    |      |      |    4m 13s     1 112.jpg
#   2.23s all done
# <hr>
# <div><b>gray</b> </div>
# <hr>
# <div><b>normalized</b> </div>
