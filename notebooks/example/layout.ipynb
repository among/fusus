# %% [markdown]
# # Layout detection

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from fusus.book import Book

# %%
B = Book(cd="~/github/among/fusus/example")

# %%
# cd to the book directory
# !cd `pwd`

# %%
page = B.process(101, batch=False, uptoLayout=True)
# Out:
#   0.00s Batch of 1 pages: 101
#   0.00s Start batch processing images
#    |      |      |    -0.00s     1 101.jpg
#   1.42s all done

# %%
page.show("orig,layout", width=400)
# Out:
# <hr>
# <div><b>orig</b> </div>
# <hr>
# <div><b>layout</b> </div>
