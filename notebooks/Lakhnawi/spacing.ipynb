# %% [markdown]
# # Spacing clustering
#
# We inspect the horizontal spacing between words.
#
# We choose a particularly critical page.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from fusus.lakhnawi import Lakhnawi
from fusus.lib import dh

# %%
Lw = Lakhnawi()
Lw.setStyle()
# Out:
# <style>
# *,
# *:before,
# *:after {
#     box-sizing: border-box;
# }
#
# @page {
#   size: A4;
#   margin: 2cm;
# }
#
# div.window {
#     display: flex;
#     flex-flow: row nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     min-width: 1000pt;
#     height: 99vh;
# }
# div.sidebar {
#     flex: 1 1 300pt;
#     display: flex;
#     flex-flow: row nowrap;
#     border-right: 1pt solid var(--fog-rim);
#     padding-left: 8px;
#     padding-right: 12px;
#     height: 99vh;
#     overflow: auto;
#     -webkit-overflow-scrolling: touch;
# }
# div.toc {
#     flex: 1 1 50pt;
# }
# div.pages {
#     flex: 0 0 700pt;
# }
# div.pages.bypage {
#     height: 99vh;
#     overflow: auto;
#     -webkit-overflow-scrolling: touch;
# }
# div.page {
#     margin-right: 1cm;
#     padding-left: 0.5cm;
#     max-width: 600pt;
#     min-width: 600pt;
#     width: 600pt;
# }
# div.pagec {
#     margin-right: 1cm;
#     padding-right: 10%;
#     width: 90%;
# ...

# %% [markdown]
# ## Page 186

# %%
Lw.drawPages(186)
# Out:
# <p><b>page 186</b></p>

# %% [markdown]
# We focus on the last few lines above the footnote:

# %%
Lw.drawPages(186, clip=(160, 300))
# Out:
# <p><b>page 186</b></p>

# %%
Lw.getPages(186)
# Out:
# 	   1 (page  186)

# %% [markdown]
# Here is the HTML:

# %%
Lw.htmlPages(186)
# Out:
# <div class="pagec">
# <div class="phead"><a name="p186">186</a></div>
#
# <p class="r"><span class="r">شَبِيهَانِ غَيرَانِ.  </span></p>
#
# <p class="r"><span class="r">وَصَاحِبُ التَّحْقِيقِ يَرَىٰ الكَثْرَةَ فِي الوَ احِدِ.  كَمَا نَعْل َمُ أَنَّ مَدْ لُولَ الأَسْمَا ءِ</span></p>
#
# <p class="r"><span class="r">الإِلٰهِيَّةِ،  وَإِنْ ٱخْتَلَفَتْ حَقَائِقُهَا وَكَـثُـرَتْ،  أَنَّهَا عَيْنٌ وَاحِدَةٌ.  </span></p>
#
# <p class="r"><span class="r">فَهٰذِهِ كَثْرَةٌ مَعْقُوْلَةٌ،  فِي وَاحِدِ العَيْنِ،  فَتُـكَوِّنُ فِي الت َّجَلِّي كَثْرَةً مَشْهُودَةً</span></p>
#
# <p class="r"><span class="r">فِِي عَـينٍ وَاحِدَةٍ،  </span></p>
#
# <p class="r"><span class="r">كَمَا أَنَّ الهَيُولَىٰ تُـؤخَذُ فِي حَدِّ كُلِّ صُورَةٍ،  مَعَ كَثْرَةِ الصُّوَرِ</span></p>
#
# </div>

# %% [markdown]
# There was something strange in the last line (6), but now it is OK.

# %%
Lw.showLines(186, line=6)
# Out:
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 186</th>
#     <th colspan=2>line 6</th>
#     <th colspan=3>103 characters</th>
# </tr>
#
# <tr>
#     <td><b>1</b></td>
#     <td>2167</td>
#     <td>2381</td>
#     <td>3764</td>
#     <td>3838</td>
#     <td>«0»</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fedb</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻛ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER KAF INITIAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">0643</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ك</span></div>
# ...
