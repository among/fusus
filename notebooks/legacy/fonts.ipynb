# %%
import os
import re
import pprint
from unicodedata import name as uname

from IPython.display import display, HTML, Image

import fitz

PP = pprint.PrettyPrinter(indent=4)

# %%
PLACE = "Lakhnawi"
NAME = f"Font report {PLACE}"
SOURCE = f"../_local/source/{PLACE}/{NAME}.pdf"

# %%
PRIVATE_RE = re.compile(r"""[\ue000-\uf8ff]""")

def postText(data):
    print(PRIVATE_RE.sub("", data))

# %%
ENTITY_RE = re.compile(r"""&#x([0-9a-f]{1,4});""", re.S)

PUA_LOW = int("e000", base=16)
PUA_HIGH = int("f8ff", base=16)


def entityRepl(match):
    code = match.group(1)
    unicode = int(code, base=16)
    return f"[{code}]" if PUA_LOW <= unicode <= PUA_HIGH else chr(unicode)
    

PRIVATE_ENTITY_RE = re.compile(
    r"""
    &\#x
    (?:
        (?:
            e
            [0-9a-f]{3}
        )
        |
        (?:
            f
            [0-8]
            [0-9a-f]{2}
        )
    )
    ;
    """,
    re.S | re.X,
)

# %%
LINES_RE = re.compile(r"""<line\b[^>]*>(.*?)</line>""", re.S)
CHARS_RE = re.compile(r"""<char\b[^>]*>(.*?)/>""", re.S)
CHAR_RE = re.compile(r'''\bc="([^"]*)"''', re.S)


CSS = """
<style>
.ar {
    font-family: normal, sans-serif;
    font-size: 30pt;
}
"""

display(HTML(CSS))
# Out:
# <style>
# .ar {
#     font-family: normal, sans-serif;
#     font-size: 30pt;
# }

# %%
doc = fitz.open(SOURCE)

# %%
def process(page, result):
    textPage = page.getTextPage()
    data = textPage.extractText()
    # print(data)
    result.append(data)

# %%
result = []

for page in doc:
    process(page, result)

# %%
singles = {}
doubles = {}
warnings = {}

U_LINE_RE = re.compile(r"""^U\+([0-9a-f]{4})([0-9a-f ]*)$""", re.I)
HEX_RE = re.compile(r"""^[0-9a-f]{4}$""", re.I)


for (p, page) in enumerate(result):
    for (ln, line) in enumerate(page.split("\n")):
        if line.startswith("U+"):
            match = U_LINE_RE.match(line)
            if not match:
                warnings.setdefault(p, {}).setdefault(ln, dict(text=line, errors=[]))["errors"].append("strange uline")
                continue
            (main, rest) = match.group(1, 2)
            main = main.lower()
            second = None
            rest = rest.replace(" ", "")
            if rest:
                if HEX_RE.match(rest):
                    second = rest.lower()
                else:
                    warnings.setdefault(p, {}).setdefault(ln, dict(text=line, errors=[]))["errors"].append("strange second")
            if second:
                doubles.setdefault(main, {}).setdefault(second, []).append((p, ln))
            else:
                singles.setdefault(main, []).append((p, ln))
            
PP.pprint(warnings)
# Out:
# {}

# %%
for main in singles:
    if main in doubles:
        print(f"{main} is double and single")
        for second in doubles[main]:
            print(f"\t{second}")
# Out:
# 06cc is double and single
# 	fbfc
# 0627 is double and single
# 	fe8d
# 0623 is double and single
# 	fe83
# 0645 is double and single
# 	fee1
# 060c is double and single
# 	066c
# 0650 is double and single
# 	fe7a

# %%
for main in doubles:
    if len(doubles[main]) > 1:
        print(f"{main} is double with multiple seconds")
        for second in doubles[main]:
            print(f"\t{second}")

# %%
for main in sorted(doubles):
    second = list(doubles[main])[0]
    print(f"{main} {second}")
# Out:
# 0000 007f
# 060c 066c
# 0621 fe80
# 0622 fe81
# 0623 fe83
# 0624 fe85
# 0625 fe87
# 0626 fe89
# 0627 fe8d
# 0628 fe8f
# 0629 fe93
# 062a fe95
# 062b fe99
# 062c fe9d
# 062d fea1
# 062e fea5
# 062f fea9
# 0630 feab
# 0631 fead
# 0632 feaf
# 0633 feb1
# 0634 feb5
# 0635 feb9
# 0636 febd
# 0637 fec1
# 0638 fec5
# 0639 fec9
# 063a fecd
# 0641 fed1
# 0642 fed5
# 0643 fed9
# 0644 fedd
# 0645 fee1
# 0646 fee5
# 0647 fee9
# 0648 feed
# 0649 feef
# 064a fef1
# 064b fe70
# 064c fe72
# 064d fe74
# 064e fe76
# 064f fe78
# 0650 fe7a
# 0651 fe7c
# 0652 fe7e
# 0660 06f0
# 0661 06f1
# 0662 06f2
# 0663 06f3
# 0667 06f7
# 0668 06f8
# 0669 06f9
# 0671 fb50
# 06af fb92
# 06ba fb9e
# 06cc fbfc
# 2010 2011

# %%
print({main: list(doubles[main].keys())[0] for main in doubles})
# Out:
# {'0627': 'fe8d', '0635': 'feb9', '0648': 'feed', '0647': 'fee9', '0651': 'fe7c', '0633': 'feb1', '0663': '06f3', '0668': '06f8', '062a': 'fe95', '0661': '06f1', '0662': '06f2', '0660': '06f0', '0645': 'fee1', '0631': 'fead', '062f': 'fea9', '0642': 'fed5', '0637': 'fec1', '062c': 'fe9d', '0630': 'feab', '2010': '2011', '0669': '06f9', '0623': 'fe83', '0628': 'fe8f', '0646': 'fee5', '0622': 'fe81', '0625': 'fe87', '0652': 'fe7e', '064e': 'fe76', '0667': '06f7', '064f': 'fe78', '0650': 'fe7a', '0632': 'feaf', '0644': 'fedd', '0621': 'fe80', '064d': 'fe74', '064a': 'fef1', '0641': 'fed1', '062d': 'fea1', '063a': 'fecd', '0629': 'fe93', '0643': 'fed9', '0671': 'fb50', '064b': 'fe70', '064c': 'fe72', '0649': 'feef', '0639': 'fec9', '0636': 'febd', '062b': 'fe99', '0000': '007f', '0624': 'fe85', '062e': 'fea5', '0634': 'feb5', '06ba': 'fb9e', '0638': 'fec5', '06af': 'fb92', '06cc': 'fbfc', '0626': 'fe89', '060c': '066c'}

# %%
regex = []
for main in sorted(doubles)[1:]:
    second = list(doubles[main])[0]
    regex.append(f"{chr(int(main, base=16))}{chr(int(second, base=16))}")
print("(\n\t  " + "\n\t| ".join(regex) + "\n)")
# Out:
# (
# 	  ،٬
# 	| ءﺀ
# 	| آﺁ
# 	| أﺃ
# 	| ؤﺅ
# 	| إﺇ
# 	| ئﺉ
# 	| اﺍ
# 	| بﺏ
# 	| ةﺓ
# 	| تﺕ
# 	| ثﺙ
# 	| جﺝ
# 	| حﺡ
# 	| خﺥ
# 	| دﺩ
# 	| ذﺫ
# 	| رﺭ
# 	| زﺯ
# 	| سﺱ
# 	| شﺵ
# 	| صﺹ
# 	| ضﺽ
# 	| طﻁ
# 	| ظﻅ
# 	| عﻉ
# 	| غﻍ
# 	| فﻑ
# 	| قﻕ
# 	| كﻙ
# 	| لﻝ
# 	| مﻡ
# 	| نﻥ
# 	| هﻩ
# 	| وﻭ
# 	| ىﻯ
# 	| يﻱ
# 	| ًﹰ
# 	| ٌﹲ
# 	| ٍﹴ
# 	| َﹶ
# 	| ُﹸ
# 	| ِﹺ
# 	| ّﹼ
# 	| ْﹾ
# 	| ٠۰
# 	| ١۱
# 	| ٢۲
# 	| ٣۳
# 	| ٧۷
# 	| ٨۸
# 	| ٩۹
# 	| ٱﭐ
# 	| گﮒ
# 	| ںﮞ
# 	| یﯼ
# 	| ‐‑
# )

# %%
rows = []
rows.append("<table>")

for main in sorted(doubles)[1:]:
    second = list(doubles[main])[0]
    
    n1 = int(main, base=16)
    n2 = int(second, base=16)
    
    c1 = chr(n1)
    c2 = chr(n2)
    
    un1 = uname(c1)
    un2 = uname(c2)
    
    rows.append(f"""\
<tr>
    <td>main</td>
    <td class="ar">{c1}</td>
    <td>{main}</td>
    <td>{un1}</td>
</tr>
<tr>
    <td>second</td>
    <td class="ar">{c2}</td>
    <td>{second}</td>
    <td>{un2}</td>
</tr>
""")
rows.append("</table>")

display(HTML("".join(rows)))
# Out:
# <table><tr>
#     <td>main</td>
#     <td class="ar">،</td>
#     <td>060c</td>
#     <td>ARABIC COMMA</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">٬</td>
#     <td>066c</td>
#     <td>ARABIC THOUSANDS SEPARATOR</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ء</td>
#     <td>0621</td>
#     <td>ARABIC LETTER HAMZA</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺀ</td>
#     <td>fe80</td>
#     <td>ARABIC LETTER HAMZA ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">آ</td>
#     <td>0622</td>
#     <td>ARABIC LETTER ALEF WITH MADDA ABOVE</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺁ</td>
#     <td>fe81</td>
#     <td>ARABIC LETTER ALEF WITH MADDA ABOVE ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">أ</td>
#     <td>0623</td>
#     <td>ARABIC LETTER ALEF WITH HAMZA ABOVE</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺃ</td>
#     <td>fe83</td>
#     <td>ARABIC LETTER ALEF WITH HAMZA ABOVE ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ؤ</td>
#     <td>0624</td>
#     <td>ARABIC LETTER WAW WITH HAMZA ABOVE</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺅ</td>
#     <td>fe85</td>
#     <td>ARABIC LETTER WAW WITH HAMZA ABOVE ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">إ</td>
#     <td>0625</td>
#     <td>ARABIC LETTER ALEF WITH HAMZA BELOW</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺇ</td>
#     <td>fe87</td>
#     <td>ARABIC LETTER ALEF WITH HAMZA BELOW ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ئ</td>
#     <td>0626</td>
#     <td>ARABIC LETTER YEH WITH HAMZA ABOVE</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺉ</td>
#     <td>fe89</td>
#     <td>ARABIC LETTER YEH WITH HAMZA ABOVE ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ا</td>
#     <td>0627</td>
#     <td>ARABIC LETTER ALEF</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺍ</td>
#     <td>fe8d</td>
#     <td>ARABIC LETTER ALEF ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ب</td>
#     <td>0628</td>
#     <td>ARABIC LETTER BEH</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺏ</td>
#     <td>fe8f</td>
#     <td>ARABIC LETTER BEH ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ة</td>
#     <td>0629</td>
#     <td>ARABIC LETTER TEH MARBUTA</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺓ</td>
#     <td>fe93</td>
#     <td>ARABIC LETTER TEH MARBUTA ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ت</td>
#     <td>062a</td>
#     <td>ARABIC LETTER TEH</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺕ</td>
#     <td>fe95</td>
#     <td>ARABIC LETTER TEH ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ث</td>
#     <td>062b</td>
#     <td>ARABIC LETTER THEH</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺙ</td>
#     <td>fe99</td>
#     <td>ARABIC LETTER THEH ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ج</td>
#     <td>062c</td>
#     <td>ARABIC LETTER JEEM</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺝ</td>
#     <td>fe9d</td>
#     <td>ARABIC LETTER JEEM ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ح</td>
#     <td>062d</td>
#     <td>ARABIC LETTER HAH</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺡ</td>
#     <td>fea1</td>
#     <td>ARABIC LETTER HAH ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">خ</td>
#     <td>062e</td>
#     <td>ARABIC LETTER KHAH</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺥ</td>
#     <td>fea5</td>
#     <td>ARABIC LETTER KHAH ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">د</td>
#     <td>062f</td>
#     <td>ARABIC LETTER DAL</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺩ</td>
#     <td>fea9</td>
#     <td>ARABIC LETTER DAL ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ذ</td>
#     <td>0630</td>
#     <td>ARABIC LETTER THAL</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺫ</td>
#     <td>feab</td>
#     <td>ARABIC LETTER THAL ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ر</td>
#     <td>0631</td>
#     <td>ARABIC LETTER REH</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺭ</td>
#     <td>fead</td>
#     <td>ARABIC LETTER REH ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ز</td>
#     <td>0632</td>
#     <td>ARABIC LETTER ZAIN</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺯ</td>
#     <td>feaf</td>
#     <td>ARABIC LETTER ZAIN ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">س</td>
#     <td>0633</td>
#     <td>ARABIC LETTER SEEN</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺱ</td>
#     <td>feb1</td>
#     <td>ARABIC LETTER SEEN ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ش</td>
#     <td>0634</td>
#     <td>ARABIC LETTER SHEEN</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺵ</td>
#     <td>feb5</td>
#     <td>ARABIC LETTER SHEEN ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ص</td>
#     <td>0635</td>
#     <td>ARABIC LETTER SAD</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺹ</td>
#     <td>feb9</td>
#     <td>ARABIC LETTER SAD ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ض</td>
#     <td>0636</td>
#     <td>ARABIC LETTER DAD</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﺽ</td>
#     <td>febd</td>
#     <td>ARABIC LETTER DAD ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ط</td>
#     <td>0637</td>
#     <td>ARABIC LETTER TAH</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﻁ</td>
#     <td>fec1</td>
#     <td>ARABIC LETTER TAH ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ظ</td>
#     <td>0638</td>
#     <td>ARABIC LETTER ZAH</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﻅ</td>
#     <td>fec5</td>
#     <td>ARABIC LETTER ZAH ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ع</td>
#     <td>0639</td>
#     <td>ARABIC LETTER AIN</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﻉ</td>
#     <td>fec9</td>
#     <td>ARABIC LETTER AIN ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">غ</td>
#     <td>063a</td>
#     <td>ARABIC LETTER GHAIN</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﻍ</td>
#     <td>fecd</td>
#     <td>ARABIC LETTER GHAIN ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ف</td>
#     <td>0641</td>
#     <td>ARABIC LETTER FEH</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﻑ</td>
#     <td>fed1</td>
#     <td>ARABIC LETTER FEH ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ق</td>
#     <td>0642</td>
#     <td>ARABIC LETTER QAF</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﻕ</td>
#     <td>fed5</td>
#     <td>ARABIC LETTER QAF ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ك</td>
#     <td>0643</td>
#     <td>ARABIC LETTER KAF</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﻙ</td>
#     <td>fed9</td>
#     <td>ARABIC LETTER KAF ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ل</td>
#     <td>0644</td>
#     <td>ARABIC LETTER LAM</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﻝ</td>
#     <td>fedd</td>
#     <td>ARABIC LETTER LAM ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">م</td>
#     <td>0645</td>
#     <td>ARABIC LETTER MEEM</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﻡ</td>
#     <td>fee1</td>
#     <td>ARABIC LETTER MEEM ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ن</td>
#     <td>0646</td>
#     <td>ARABIC LETTER NOON</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﻥ</td>
#     <td>fee5</td>
#     <td>ARABIC LETTER NOON ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">ه</td>
#     <td>0647</td>
#     <td>ARABIC LETTER HEH</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﻩ</td>
#     <td>fee9</td>
#     <td>ARABIC LETTER HEH ISOLATED FORM</td>
# </tr>
# <tr>
#     <td>main</td>
#     <td class="ar">و</td>
#     <td>0648</td>
#     <td>ARABIC LETTER WAW</td>
# </tr>
# <tr>
#     <td>second</td>
#     <td class="ar">ﻭ</td>
#     <td>fe
