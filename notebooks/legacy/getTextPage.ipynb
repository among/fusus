# %%
# %load_ext autoreload
# %autoreload 2
# !cd `pwd`

# %%
from fusus.lakhnawi import Lakhnawi, pprint

# %%
Lw = Lakhnawi()

# %%
Lw.setStyle()
# Out:
# <style>
# *,
# *:before,
# *:after {
#     box-sizing: border-box;
# }
#
# .r {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     direction: rtl;
#     unicode-bidi: isolate-override;
# }
# .rc, .lc {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     background-color: white;
#     border: 2pt solid #ffcccc;
# }
# .rc {
#     direction: rtl;
#     unicode-bidi: isolate-override;
# }
# .lc {
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# p {
#     text-align: left;
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# p.r {
#     text-align: right;
#     direction: rtl;
#     unicode-bidi: isolate-override;
# }
# .l {
#     font-family: normal, sans-serif;
#     font-size: xx-large;
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# .c {
#     font-family: monospace;
#     font-size: x-small;
#     direction: ltr;
#     unicode-bidi: isolate-override;
# }
# .p {
#     font-family: monospace;
# ...

# %%
Lw.showReplacements()
# Out:
# <p><b>93 rules with
# 0 applications on 0 pages</b></p>
# <table>
#
# <tr>
#     <th>rule 1</th>
#     <td class="al"><b>0</b> x applied on <i>0</i> pages</td>
#     <td class="al"></td>
#     <td class="al">
# <div class="ch">
#     <div class="cn"><span class="p">e821</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td class="al"><span class="lrg">⇒</span></td>
#     <td class="al"></td>
# </tr>
#
# <tr>
#     <th>rule 2</th>
#     <td class="al"><b>0</b> x applied on <i>0</i> pages</td>
#     <td class="al"></td>
#     <td class="al">
# <div class="ch">
#     <div class="cn"><span class="p">e825</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td class="al"><span class="lrg">⇒</span></td>
#     <td class="al">
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
# ...

# %%
Lw.showString("\ufc62")
Lw.showString("\ufcf2")
# Out:
# <p><span class="r">ﱢ</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">fc62</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﱢ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH KASRA ISOLATED FORM</span></div>
# </div>
# </div>
# <p><span class="r">ﳲ</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">fcf2</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﳲ</span></div>
#     <div class="cn"><span class="c">ARABIC LIGATURE SHADDA WITH FATHA MEDIAL FORM</span></div>
# </div>
# </div>

# %%
Lw.drawPages(testPages)

# %%
Lw.plainPages(testPages)
# Out:
# ١٠١
# اﻟَّﺬِي ﺛَﺒَﺖَ ﻋِﻨْﺪَهُ، أَﻧَّﻪُ ― ﻋَﻠَﻴﻪِ اﻟﺴﳲﻼَمُ ― ﻗَﺎلَ» :ﻣَﻦْ رَآﻧِﻲ ﻓِﻲ اﻟﻨَّﻮمِ، ﻓَﻘَﺪْ
# رآﻧِﻲ ﻓِﻲ اﻟﻴَﻘِﻈَﺔِ، ﻓَﺎِٕنَّاﻟﺸَّﻴْﻄَﺎنَ ﻻَ ﻳَﺘَﻤَـﺜَّﻞُ ﻋَﻠﲐ ﺻُﻮرَﺗِﻲ«،  171ﻓَﺮآهُ ﺑَﻘِﻲﳳ ﺑْﻦ⌊e826⌋
# ﻣَﺨْـﻠَﺪٍ، وَﺳَﻘَﺎهُ اﻟﻨَّﺒِﻲُ ﺻَﻠَّﲐ اﻟﻠّٰﻪُ ﻋَﻠَﻴﻪِ وَﺳَﻠَّﻢَ ﻓِﻲ ﻫٰﺬِهِ اﻟﺮﳳؤﻳَﺎ ﻟَـﺒَﻨًﺎ، ﻓَﺼَﺪَّقَ ﺑَﻘِﻲ⌊e831⌋
# ﻣﺴﻨﺪ اﻹﻣﺎم أﺣﻤﺪ، ﻫﻢ ﻧﻘﻄﺔ اﻟﺒﺪاﻳﺔ) .ﻓﻬﻮ ﻳﺬﻛﺮ ﻋﺪدًا ﻣﻦ اﻟﺼﺤﺎﺑﺔ ﻻ ﻳﻘﻞ ﻋﻦ ٠٠٣١
# ﺻﺤﺎﺑﻴًﺎ(، ﻏﻴﺮ أن أﺣﺎدﻳﺚﻛﻞ راوٍ ﺗﺮﺗﺐ ﺑﺤﺴﺐ اﻷﺑﻮاب اﻟﻔﻘﻬﻴﺔ .وﻟﻴﺲ ﻣﻤﺎ ﻳﺜﻴﺮ
# اﻟﺪﻫﺸﺔ أن ﻫﺬا اﻟﻨﻮع ﻣﻦ اﻟﺠﻮاﻣﻊ ﻗﺪ ﺣﻠﺖ ﻣﺤﻠﻪ اﻟﻜﺘﺐ اﻟﺴﺘﺔ ﺣﺘﲐ ﰲ اﻟﺒﻠﺪان اﻟﺘﻲ
# ﻧﺸﺄ ﻓﻴﻬﺎ .وﺛﻤﺔ ﺳﺒﺐ آﺧﺮ ﻳﻌﺰى إﻟﻴﻪ إﺧﻔﺎق ﻣُﺴﻨﺪ ﺑﻘﻲ ﺑﻦ ﻣﺨﻠﺪ :وﻫﻮ أﻧﻪ ﻟﻢ ﺗﻜﻦ ﻟﻤﺆﻟﻔﻪ
# ﺳﻤﻌﺔ ﻃﻴﺒﺔ ﺑﲔ أﻗﺮاﻧﻪ، ﺑﺴﺒﺐ ﻣﻮﻗﻔﻪ اﻟﻤﺴﺘﻘﻞ ﻣﻦ اﻟﻤﺴﺎﺋﻞ اﻟﻔﻘﻬﻴﺔ ﰲ ﻋﺼﺮه .وﻛﺄي ﻓﻘﻴﻪ
# ﻣﺴﺘﻘﻞ ﻋﺎﻧﲐﻛﺜﻴﺮًا ﻣﻦ زﻣﺮة اﻟﻔﻘﻬﺎء .وﻳﺒﺪو أن ﻣﺴﻨﺪ ﺑَﺒﻘﻲ ﺑﻦ ﻣﺨﻠﺪ ﻗﺪ دُرِس ﺧﻼل ﻓﱰة
# زﻣﻨﻴﺔ ﻗﺼﻴﺮة، ﺣﻴﺚﻛﺘﺐ اﺑﻦ أﺧﻲ رﻓﻴﻊ )ت ٣١٣ﻫـ (ﻣﺨﺘﺼﺮًا ﻟﻪ.«
# » .171ﻣَﻦْ رَآﻧِﻲ ﻓِﻲ اﻟﻨَّﻮمِ، ﻓَﻘَﺪْ رآﻧِﻲ ﻓِﻲ اﻟﻴَﻘِﻈَﺔِ، ﻓَﺎِٕنَّاﻟﺸَّﻴْﻄَﺎنَ ﻻَ ﻳَﺘَﻤَـﺜَّﻞُ ﻋَﻠﲐ
# ...

# %%
Lw.showUsedChars(testPages, onlyPuas=True, long=False)

# %%
Lw.showString("\u0627\ufedf\u0651\u064e\ufeac\u064a")
# Out:
# <p><span class="r">اﻟَّﺬي</span></p>
# <div class="sr">
# <div class="ch">
#     <div class="cn"><span class="c">0627</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ا</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER ALEF</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">fedf</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻟ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER LAM INITIAL FORM</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">0651</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ّ</span></div>
#     <div class="cn"><span class="c">ARABIC SHADDA</span></div>
# </div>
#
# <div class="ch">
#     <div class="cn"><span class="c">064e</span></div>
#     <div class="cn"><span class="cni"><span class="rc">َ</span></div>
#     <div class="cn"><span class="c">ARABIC FATHA</span></div>
# </div>
#
# <div class="ch">
# ...

# %%
Lw.showString("مثًﹰ،")

# %%
testPages = None
Lw.getPages(testPages, refreshConfig=True)

# %%
Lw.showUsedChars(testPages, onlyPuas=True, long=False, byOcc=True)
# Out:
# <p><b>50 private use characters in 4652 occurences
# on 418 pages</b></p>
# <table>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e85b</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>803</b> on <i>315</i> pages</td>
#     <td>e.g. page 37 with <b>9</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e824</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>646</b> on <i>262</i> pages</td>
#     <td>e.g. page 23 with <b>12</b> occurrences</td>
# </tr>
#
# <tr>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="p">e863</span></div>
#     <div class="cn"><span class="cni">??</span></div>
#     <div class="cn"></div>
# </div>
# </td>
#     <td><b>477</b> on <i>187</i> pages</td>
#     <td>e.g. page 30 with <b>30</b> occurrences</td>
# ...

# %%
testPages = "100-103"
Lw.getPages(testPages, refreshConfig=True)
Lw.htmlPages(testPages)
# Out:
# <p class="r"><span class="r">٠٠١</span></p>
# <p class="r"><span class="r">ﻛَﻤَﺎ ﻓَﻌَﻞَ ﺑَﻘِﻲﳳ ﺑْﻦُ ﻣَﺨْـﻠَﺪٍ اﻻِٕﻣَﺎمُ ﺻَﺎﺣِﺐُ اﻟﻤُﺴْﻨَﺪِ، </span><span class="l"> 170</span><span class="r">ﺳَﻤِﻊَ ﻓِﻲ اﻟﺨَـﺒَﺮِ</span></p>
# <p class="r"><span class="l"> .170</span><span class="r">ﻫﻮ أﺑﻮ ﻋﺒﺪ اﻟﺮﺣﻤٰﻦ ﺑَﻘِﻲﳳ ﺑْﻦُ ﻣَﺨْـﻠَﺪٍ ﺑﻦ ﻳﺰﻳﺪ اﻷﻧﺪﻟﺴﻲّ اﻟﻘﺮﻃﺒﻲّ وُﻟِﺪَ ﺑﻘُﺮﻃﺒﺔ</span></p>
# <p class="r"><span class="r">ﺳﻨﺔ ٢٠٢ﻫـ</span><span class="l">/</span><span class="r">٧١٨م</span><span class="l"> .(</span><span class="r">ﺧﺮج إﻟﲐ اﻟﻤﺸﺮق ﻟﻄﻠﺐ ﻋﻠﻢ اﻟﺤﺪﻳﺚ ﺳﻨﺔ ٨١٢ﻫـ</span><span class="l">/</span><span class="r">٣٣٨م وﻋﺎد إﻟﲐ</span></p>
# <p class="r"><span class="r">اﻷﻧﺪﻟﺲ ﺳﻨﺔ ٣٥٢ﻫـ</span><span class="l">/</span><span class="r">٧٦٨م</span><span class="l"> .</span><span class="r">ﺳﻤﻊ اﻟﺤﺪﻳﺚ ﻣﻦ ﻳﺤﻴﲐ ﺑﻦ ﻣَﻌِﲔ </span><span class="l">)</span><span class="r">ت</span><span class="l"> .</span><span class="r">٣٢٢ﻫـ</span><span class="l">/</span><span class="r">٧٣٨م</span><span class="l">(</span></p>
# ...

# %%
Lw.showLines(testPages, 3, "105-120")
# Out:
# <table>
# <tr>
#     <th>seq</th>
#     <th>top</th>
#     <th>bottom</th>
#     <th>left</th>
#     <th>right</th>
#     <th>spacing</th>
#     <th>font</th>
#     <th>size</th>
#     <th>orig char</th>
#     <th>char</th>
# </tr>
#
# <tr>
#     <th colspan=3>page 101</th>
#     <th colspan=2>line 3</th>
#     <th colspan=3>106 characters</th>
# </tr>
#
# <tr>
#     <td><b>105</b></td>
#     <td>1127</td>
#     <td>1341</td>
#     <td>790</td>
#     <td>862</td>
#     <td>True</td>
#     <td>XWZar</td>
#     <td>14.0pt</td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fee6</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻦ</span></div>
#     <div class="cn"><span class="c">ARABIC LETTER NOON FINAL FORM</span></div>
# </div>
# </td>
#     <td>
# <div class="ch">
#     <div class="cn"><span class="c">fee6</span></div>
#     <div class="cn"><span class="cni"><span class="rc">ﻦ</span></div>
# ...
