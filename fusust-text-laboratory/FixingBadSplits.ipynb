# %% [markdown]
# # Fixing badly extracted lines, which split on letters not words

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import arabicABC as abc

# %%
fusus = pd.read_csv('fusus.csv')
fusus = fusus.fillna('')

# %% [markdown]
# ### We can look at square brackets, which seem to be used after a Quran citation.

# %%
fusus[fusus.word.str.contains(pat=abc.QURANCLOSE) & fusus.word.str.contains(pat='\[') & ~fusus.word.str.contains(pat='سورة')]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 14569   162     7       1     1         r  345.0  243.0  379.0  264.0
# 40108   396    11       1     1         r  227.0  347.0  303.0  368.0
#
#                          word             short haspunct punctAfter  \
# 14569                 ـٰبِ﴾[س              ب﴾[س       ﴾[
# 40108  أَنْفُسَهُمْ﴾[الأنعام:  أنفسهم﴾[الأنعام:      ﴾[:
#
#       punctBefore QunawiMS poetryMeter poetryVerse fass
# 14569                  29b
# 40108                  76a

# %% [markdown]
# In one case, the line was not extracted correctly.

# %%
fusus[(fusus['page']==162) & (fusus.line==7)]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 14567   162     7       1     1         r  386.0  243.0  402.0  264.0
# 14568   162     7       1     1         r  381.0  243.0  385.0  264.0
# 14569   162     7       1     1         r  345.0  243.0  379.0  264.0
# 14570   162     7       1     1         r  325.0  247.0  344.0  262.0
# 14571   162     7       1     1         r  316.0  247.0  324.0  262.0
# 14572   162     7       1     1         r  279.0  247.0  314.0  262.0
# 14573   162     7       1     1         r  260.0  243.0  279.0  264.0
# 14574   162     7       1     1         r  252.0  243.0  259.0  264.0
# 14575   162     7       1     1         r  241.0  243.0  252.0  264.0
# 14576   162     7       1     1         r  236.0  243.0  240.0  264.0
# 14577   162     7       1     1         r  222.0  243.0  234.0  264.0
# 14578   162     7       1     1         r  203.0  243.0  221.0  264.0
# 14579   162     7       1     1         r  195.0  243.0  203.0  264.0
# 14580   162     7       1     1         r  177.0  243.0  194.0  264.0
# 14581   162     7       1     1         r  164.0  243.0  176.0  264.0
# 14582   162     7       1     1         r  154.0  243.0  164.0  264.0
# 14583   162     7       1     1         r  144.0  243.0  152.0  264.0
# 14584   162     7       1     1         r  128.0  243.0  142.0  264.0
# 14585   162     7       1     1         r  114.0  243.0  128.0  264.0
# 14586   162     7       1     1         r  106.0  243.0  113.0  264.0
# 14587   162     7       1     1         r   86.0  243.0  106.0  264.0
# 14588   162     7       1     1         r   79.0  243.0   85.0  264.0
#
#           word  short haspunct punctAfter punctBefore QunawiMS poetryMeter  \
# 14567   الأَلْ   الأل                                      29b
# 14568       بَ      ب                                      29b
# 14569  ـٰبِ﴾[س   ب﴾[س       ﴾[                             29b
# 14570    ورةال  ورةال                                      29b
# 14571    زُّمَ     زم                                      29b
# 14572    ر:٩]،  ر:٩]،     :٩]،                             29b
# 14573     وَهُ     وه                                      29b
# 14574       مْ      م                                      29b
# 14575       ال     ال                                      29b
# 14576      نَّ      ن                                      29b
# 14577      اظِ     اظ                                      29b
# 14578    رُونَ    رون                                      29b
# 14579       فِ      ف                                      29b
# 14580      يلُ     يل                                      29b
# 14581      بِّ      ب                                      29b
# 14582       ال     ال                                      29b
# 14583       شَ      ش                                      29b
# 14584     يءِ،     يء                   ،                  29b
# 14585     الَّ     ال                                      29b
# 14586      ذِي     ذي                                      29b
# 14587       هُ      ه                                      29b
# 14588       وَ      و                                      29b
#
#       poetryVerse fass
# 14567
# 14568
# 14569
# 14570
# 14571
# 14572
# 14573
# 14574
# 14575
# 14576
# 14577
# 14578
# 14579
# 14580
# 14581
# 14582
# 14583
# 14584
# 14585
# 14586
# 14587
# 14588

# %% [markdown]
# ### This actually happened in more cases. It seems we first need to fix this.

# %%
fusus[(fusus['page']==162) & (fusus.line==7)].short.str.len()
# Out:
# 14567    4
# 14568    1
# 14569    4
# 14570    5
# 14571    2
# 14572    5
# 14573    2
# 14574    1
# 14575    2
# 14576    1
# 14577    2
# 14578    3
# 14579    1
# 14580    2
# 14581    1
# 14582    2
# 14583    1
# 14584    2
# 14585    2
# 14586    2
# 14587    1
# 14588    1
# Name: short, dtype: int64

# %%
fusus[(fusus['page']==162) & (fusus.line==7)].short.str.len().describe()
# Out:
# count    22.000000
# mean      2.136364
# std       1.283427
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       2.000000
# max       5.000000
# Name: short, dtype: float64

# %%
fusus.short.str.len().describe()
# Out:
# count    41532.000000
# mean         4.256814
# std          1.948673
# min          0.000000
# 25%          3.000000
# 50%          4.000000
# 75%          5.000000
# max         23.000000
# Name: short, dtype: float64

# %% [markdown]
# I created a subset of the dataframe, to ensure easy calculation before we attempt to calculate on the entire text. Let's call it `testdf`

# %%
testdf = fusus[fusus.QunawiMS=="3b"]

# %% [markdown]
# After testing with this I came up with the next code for which I replaced `testdf` with `fusus` to calculate on the entire text. We print out all lines for which the mean length of each row (should be word) is less than 3 and which has at least one row with length 1 (zeroes are removed).

# %%
for name, group in fusus.groupby(['page', 'line']):
    lengtes = group.short.str.len().tolist()
    lengtes = [i for i in lengtes if i != 0]
    if lengtes:
        if (np.mean(lengtes) < 3)&(np.min(lengtes)==1):
            print(name)
            print(np.mean(lengtes))
            print(" ")
# Out:
# (35, 9)
# 2.0869565217391304
#
# (61, 6)
# 1.875
#
# (77, 6)
# 1.6333333333333333
#
# (82, 2)
# 1.6538461538461537
#
# (151, 8)
# 1.68
#
# (154, 3)
# 1.3571428571428572
#
# (162, 7)
# 2.1363636363636362
#
# (186, 6)
# 1.4230769230769231
#
# (237, 11)
# 1.76
#
# (245, 8)
# 2.3529411764705883
#
# (266, 2)
# 1.1818181818181819
#
# (268, 9)
# 1.64
#
# (290, 10)
# 1.7083333333333333
#
# (300, 6)
# 1.3571428571428572
#
# (307, 10)
# 1.4615384615384615
#
# (314, 4)
# 2.933333333333333
#
# (320, 6)
# 2.0
#
# (324, 8)
# 1.7083333333333333
#
# (331, 9)
# 2.6666666666666665
#
# (372, 4)
# 2.45
#
# (381, 4)
# 1.56
#
# (382, 6)
# 1.5357142857142858

# %% [markdown]
# Let's test on one of these and we see we got a positive hit

# %%
fusus[(fusus['page']==381) & (fusus.line==4)]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 38635   381     4       1     1         r  379.0  165.0  383.0  186.0
# 38636   381     4       1     1         r  368.0  165.0  377.0  186.0
# 38637   381     4       1     1         r  361.0  165.0  366.0  186.0
# 38638   381     4       1     1         r  353.0  165.0  361.0  186.0
# 38639   381     4       1     1         r  339.0  165.0  351.0  186.0
# 38640   381     4       1     1         r  331.0  165.0  339.0  186.0
# 38641   381     4       1     1         r  307.0  165.0  329.0  186.0
# 38642   381     4       1     1         r  294.0  165.0  305.0  186.0
# 38643   381     4       1     1         r  280.0  165.0  292.0  186.0
# 38644   381     4       1     1         r  270.0  165.0  280.0  186.0
# 38645   381     4       1     1         r  252.0  165.0  268.0  186.0
# 38646   381     4       1     1         r  239.0  165.0  250.0  186.0
# 38647   381     4       1     1         r  214.0  165.0  239.0  186.0
# 38648   381     4       1     1         r  199.0  165.0  214.0  186.0
# 38649   381     4       1     1         r  182.0  165.0  197.0  186.0
# 38650   381     4       1     1         r  173.0  165.0  180.0  186.0
# 38651   381     4       1     1         r  166.0  165.0  173.0  186.0
# 38652   381     4       1     1         r  155.0  165.0  164.0  186.0
# 38653   381     4       1     1         r  148.0  165.0  155.0  186.0
# 38654   381     4       1     1         r  138.0  165.0  146.0  186.0
# 38655   381     4       1     1         r  116.0  165.0  138.0  186.0
# 38656   381     4       1     1         r  109.0  165.0  114.0  186.0
# 38657   381     4       1     1         r   97.0  165.0  109.0  186.0
# 38658   381     4       1     1         r   90.0  165.0   95.0  186.0
# 38659   381     4       1     1         r   87.0  165.0   88.0  186.0
#
#           word short haspunct punctAfter punctBefore QunawiMS poetryMeter  \
# 38635       فَ     ف                                      73a
# 38636   إِنَّ   إن                                      73a
# 38637       هُ     ه                                      73a
# 38638       قَ     ق                                      73a
# 38639      الَ    ال                                      73a
# 38640       فِ     ف                                      73a
# 38641      يحَ    يح                                      73a
# 38642     دِيْ    دي                                      73a
# 38643       ثِ     ث                                      73a
# 38644       ال    ال                                      73a
# 38645   دَّجَّ    دج                                      73a
# 38646     الِ:    ال                   :                  73a
# 38647  «إِنَّ   إن                               «      73a
# 38648     أَحَ    أح                                      73a
# 38649     دَكُ    دك                                      73a
# 38650       مْ     م                                      73a
# 38651       لَ     ل                                      73a
# 38652       نْ     ن                                      73a
# 38653       يَ     ي                                      73a
# 38654    ـرَىٰ    رى                                      73a
# 38655    رَبَّ    رب                                      73a
# 38656       هُ     ه                                      73a
# 38657       حَ     ح                                      73a
# 38658      تَّ     ت                                      73a
# 38659       ىٰ     ى                                      73a
#
#       poetryVerse fass
# 38635
# 38636
# 38637
# 38638
# 38639
# 38640
# 38641
# 38642
# 38643
# 38644
# 38645
# 38646
# 38647
# 38648
# 38649
# 38650
# 38651
# 38652
# 38653
# 38654
# 38655
# 38656
# 38657
# 38658
# 38659

# %% [markdown]
# Are there other ways to find these lines with bad splitting?

# %%
for name, group in fusus.groupby(['page', 'line']):
    lengtes = group.short.str.len().tolist()
    lengtes = [i for i in lengtes if i != 0]
    if lengtes:
        if (lengtes.count(1)>3):
            print(name)
            print(np.mean(lengtes))
            print(" ")
# Out:
# (35, 9)
# 2.0869565217391304
#
# (61, 6)
# 1.875
#
# (77, 6)
# 1.6333333333333333
#
# (82, 2)
# 1.6538461538461537
#
# (151, 8)
# 1.68
#
# (154, 3)
# 1.3571428571428572
#
# (162, 7)
# 2.1363636363636362
#
# (186, 6)
# 1.4230769230769231
#
# (237, 11)
# 1.76
#
# (245, 8)
# 2.3529411764705883
#
# (266, 2)
# 1.1818181818181819
#
# (268, 9)
# 1.64
#
# (290, 10)
# 1.7083333333333333
#
# (300, 6)
# 1.3571428571428572
#
# (307, 10)
# 1.4615384615384615
#
# (320, 6)
# 2.0
#
# (324, 8)
# 1.7083333333333333
#
# (372, 4)
# 2.45
#
# (381, 4)
# 1.56
#
# (382, 6)
# 1.5357142857142858
