# %% [markdown]
# # Annotating the Fusus for Quran citations
# All citations from the quran seem to be cited accurately by the edition. The task is, thus, to extract the information from the `word` column. This is not easy since there is no one single pattern that picks up all Quran citations. Let's explore.

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import arabicABC as abc

# %%
fusus = pd.read_csv('fusus.csv', dtype={"page":int, "line":int, "column":int, "span":int, "direction": str, 
                                        "left":"Int64", "top":"Int64", "right":"Int64", "bottom":"Int64", 
                                        "word":str, "short":str, "haspunct":str, "punctAfter":str, "punctBefore":str, 
                                        "QunawiMS":str, "poetryMeter":str, "poetryVerse":"Int64", "fass":"Int64", "lwcvl":str, 
                                        "quran":str})
fusus.word = fusus.word.fillna('')
fusus.short = fusus.short.fillna('')
fusus.haspunct = fusus.haspunct.fillna('')
fusus.punctAfter = fusus.punctAfter.fillna('')
fusus.punctBefore = fusus.punctBefore.fillna('')
fusus.poetryMeter = fusus.poetryMeter.fillna('')
fusus.lwcvl = fusus.lwcvl.fillna('')
fusus.quran = fusus.quran.fillna('')

# %%
fusus
# Out:
#        page  line  column  span direction  left  top  right  bottom  \
# 0         8     2       1     1         r   356  197    384     218
# 1         8     2       1     1         r   341  197    356     218
# 2         8     2       1     1         r   312  197    341     218
# 3         8     2       1     1         r   274  197    312     218
# 4         8     2       1     1         r   260  197    274     218
# ...     ...   ...     ...   ...       ...   ...  ...    ...     ...
# 39498   409     5       1     1         r   331  191    356     212
# 39499   409     5       1     1         r   305  191    331     212
# 39500   409     5       1     1         r   284  191    305     212
# 39501   409     5       1     1         r   266  191    284     212
# 39502   409     5       1     1         r   165  191    266     212
#
#                word         short haspunct punctAfter punctBefore QunawiMS  \
# 0          الحَمْدُ         الحمد                                       1b
# 1             لِلهِ           لله                                       1b
# 2       مُـنَـزِّلِ          منزل                                       1b
# 3          الحِكَمِ         الحكم                                       1b
# 4            عَلَىٰ           على                                       1b
# ...             ...           ...      ...        ...         ...      ...
# 39498      يُقُوْلُ          يقول                                      78a
# 39499       ٱلحَقُّ          ٱلحق                                      78a
# 39500        وَهُوُ           وهو                                      78a
# 39501       يَهْدِي          يهدي                                      78a
# 39502  ٱلسَّبِيْلَ﴾  ٱلسَّبِيْلَ﴾                  ﴾.                  78a
#
#       poetryMeter  poetryVerse  fass lwcvl quran
# 0                         <NA>     0
# 1                         <NA>     0
# 2                         <NA>     0
# 3                         <NA>     0
# 4                         <NA>     0
# ...           ...          ...   ...   ...   ...
# 39498                     <NA>    27
# 39499                     <NA>    27
# 39500                     <NA>    27
# 39501                     <NA>    27
# 39502                     <NA>    27        33:4
#
# [39503 rows x 20 columns]

# %%
fusus['word'].replace("", np.nan, inplace=True)
fusus.dropna(subset=['word'],inplace=True)

# %%
fusus.to_csv('fusus.csv',index=False)

# %% [markdown]
# ### Different elements of a Quran citation

# %%
print(fusus[fusus.word.str.contains(pat=abc.QURANCLOSE)].shape)
print(fusus[fusus.word.str.contains(pat=abc.QURANOPEN)].shape)
print(fusus[fusus.word.str.contains(pat="\[")].shape)
print(fusus[fusus.word.str.contains(pat="\]")].shape)
print(fusus[fusus.short.str.contains(pat="\[")].shape)
print(fusus[fusus.short.str.contains(pat="\]")].shape)
print(fusus[fusus.word.str.contains(pat="سورة")].shape)
# Out:
# (520, 20)
# (520, 20)
# (97, 20)
# (97, 20)
# (96, 20)
# (96, 20)
# (79, 20)

# %% [markdown]
# ### Generally you would think that ﴾﴿ indicates a Quran citation.  ﴿ gives 520 and ﴾ gives 520. So there seem to be 520 Quran citations.
# But note that the chapter titles were also adorned with these brackets (which have since been cleaned).

# %%
sura = fusus.iloc[fusus[fusus.short.str.contains(pat=abc.QURANCLOSE)&~fusus.short.str.contains(pat='\[')].index+1]
sura[sura.short.str.contains(pat='\[')&sura.short.str.contains(pat='\]')]
# Out:
# Empty DataFrame
# Columns: [page, line, column, span, direction, left, top, right, bottom, word, short, haspunct, punctAfter, punctBefore, QunawiMS, poetryMeter, poetryVerse, fass, lwcvl, quran]
# Index: []

# %%
noclose = fusus[fusus.short.str.contains(pat=abc.QURANCLOSE)&fusus.short.str.contains(pat='\[')]
close = noclose[noclose.short.str.contains(pat='\]')]

# %% [markdown]
# index numbers

# %%
endwords = close[close.short.str.contains(pat=':')].short.str.split(abc.QURANCLOSE).str[1].str.split(']').str[0].str.split('[').str[1].str.split(":").str[1].index

# %% [markdown]
# verse numbers

# %%
verseNumber = []
for i in close[close.short.str.contains(pat=':')].short.str.split(abc.QURANCLOSE).str[1].str.split(']').str[0].str.split('[').str[1].str.split(":").str[1].tolist():
    verseNumber.append(int(str(list(map(int, re.findall(r'\d+', i)))[0])[::-1]))

# %% [markdown]
# sura numbers

# %%
suraNumber = []
for y in close[close.short.str.contains(pat=':')].short.str.split(abc.QURANCLOSE).str[1].str.split(']').str[0].str.split('[').str[1].str.split(":").str[0].str.replace("سورة", "").str.replace(" ","").tolist():
    suraNumber.append(abc.QURAN_SURAS[y])

# %% [markdown]
# Mass change it

# %%
# for i in range(400):
#     fusus.iloc[endwords[i], fusus.columns.get_loc("quran")] = str(suraNumber[i])+":"+str(verseNumber[i])
#     fusus.iloc[endwords[i], fusus.columns.get_loc("word")] = fusus.iloc[endwords[i]].word.split("[")[0]
#     fusus.iloc[endwords[i], fusus.columns.get_loc("short")] = fusus.iloc[endwords[i]].word.split("[")[0]

# %%
suras = []
for i in close.short.str.split(abc.QURANCLOSE).tolist():
    suras.append(i[1])
suras
    # cleansuras = []
# for i in suras:
#     new = i.replace(':', '').replace('سورة','').replace('[','').replace(']','').replace('،','').replace('.','').replace('١','').replace('٢','').replace('٣','').replace('٤','').replace('٥','').replace('٦','').replace('٧','').replace('٨','').replace('٩','').replace('٠','').replace('أ','').replace('؛','').replace('–','').replace('‐','').replace('؟','')
#     cleansuras.append(new)
# usedSuras = list(set(cleansuras))
# Out:
# ['[هود:٣٢١]',
#  '،[سورةالبقرة:٠٣].',
#  '،[سورةص:٥٧]',
#  '.[سورةالنساء:١]',
#  '؛[سورةالنساء:١]',
#  '[سورةغافر٠٦]',
#  '[سورةمحمد:١٣]',
#  '[سورةالحجر:١٢]',
#  '[سورةطه:٠٥]',
#  '[سورةفصلت:٣٥]',
#  '[سورةفصلت:٣٥]',
#  '[سورةفصلت:٣٥]',
#  '.[سورةفصلت:٣٥]',
#  '،[سورةالفاتحة:٢]أ',
#  '[سورةالشورى:١١]',
#  '[سورةالشورى:١١]',
#  '[سورةالشورى:١١]',
#  '[سورةالشورى:١١]',
#  '[سورةنوح٨]،',
#  '[سورةنوح:٩]،',
#  '.[سورةنوح:٠١]',
#  '.[سورةنوح:٥–٦].',
#  '[سورةالبقرة:٠١١]',
#  '[سورةالشورى:١١]',
#  '[سورةنوح:٥]',
#  '[سورةنوح:٥]',
#  '،[سورةالشورى:١١]',
#  '،[سورةنوح:٧]',
#  '[سورةالشورى:١١]',
#  '[سورةنوح١١]',
#  '[سورةنوح:٢١]',
#  '،[سورةنوح:١٢].',
#  '،[سورةالبقرة:٦١]',
#  '[سورةالحديد:٧].',
#  '،[سورةالإسراء:٢]',
#  '،[سورةنوح:٢٢]',
#  '[سورةيوسف٨٠١]',
#  '.[سورةيوسف:٨٠١]',
#  '،[سورةمريم٥٨]',
#  '،[سورةنوح:٣٢]',
#  '،[سورةالإسرى:٣٢]',
#  '[سورةالرعد:٣٣]',
#  '.[سورةالزمر:٣]',
#  '[سورةالحج:٤٣]',
#  '؛[سورةالحج:٤٣]',
#  '[سورةنوح:٤٢]',
#  '[سورةنوح:٤٢]',
#  '[سورةنوح:٤٢]',
#  '،[سورةالبقرة:٠٢].',
#  '؛[سورةنوح:٥٢]',
#  '[سورةنوح:٥٢]',
#  '،[سورةالتكوير:٦]',
#  '.[سورةنوح:٥٢]',
#  '،[سورةالرحمن٩٢]',
#  '[سورةنوح:٦٢]',
#  '[سورةطه:٥٥]',
#  '[سورةنوح:٦٢]',
#  '[سورةنوح:٧].',
#  '.[سورةنوح:٧]',
#  '،[سورةنوح:٦٢]',
#  '[سورةنوح٧٢]',
#  '[سورةنوح:٧٢]',
#  '[سورةنوح:٧٢]',
#  '[سورةنوح:٨٢]',
#  '[سورةالأنعام:١٩].',
#  '[سورةنوح:٨٢]',
#  '[سورةنوح:٨٢]',
#  '،[سورةنوح:٨٢]',
#  '[سورةنوح:٨٢]',
#  '[سورةنوح:٨٢]',
#  ':[سورةنوح:٨٢]',
#  '[سورةنوح:٨٢]',
#  '[سورةالقصص:٨٨]',
#  '[سورةمريم:٧٥].',
#  '[سورةمحمد:٥٣]',
#  '[سورةمحمد:٥٣]،',
#  '[سورةطه:٥]،',
#  '[سورةالقصص٨٨]،',
#  '[سورةهود:٣٢١]،',
#  '[سورةالنمل٠٦].',
#  '[سورةمريم:٧٥]،',
#  '[سورةالبقرة:٠٣]،',
#  '[سورةص:٥٧]،',
#  '[سورةهود:٣٢١]',
#  '.[سورةالبقرة:٧٦]',
#  '[سورةالأنعام:٩٤١]،',
#  '[سورةالقلم:٢٤]',
#  '[سورةالأنعام٩٤١].',
#  '[سورةالصافات:٤٦١].',
#  '[سورةالأحزاب:٤].',
#  '[سورةالصافات:٢٠١]،',
#  '[سورةالصافات:٤٠١‐٥٠١]،',
#  '[سورةيوسف:٣٤].',
#  '[سورةالصافات:٦٠١]',
#  '[سورةالأنعام:٨٣].',
#  '[سورةالأنفال:٩٢].',
#  '[سورةطه:٠٥]،',
#  '[سورةالفجر:٨٢]',
#  '[سورةالفجر:٨٢–٩٢]',
#  '[سورةالفجر:٩٢]',
#  '[سورةالبينة:٨]',
#  '[سورةابراهيم:٧٤].',
#  '[سورةالأحقاف:٦١]',
#  '[سورةمريم:٤٥].',
#  '[سورةالبقرة:٢٣١]،',
#  '[سورةآلعمران:٩١]،',
#  '[سورةالحديد:٧٢].',
#  '[سورةالحديد:٧٢]',
#  '[سورةالحديد:٧٢]',
#  '[سورةالحديد:٧٢].',
#  '[سورةالحديد:٧٢]',
#  '[سورةالحديد:٧٢]',
#  '[سورةالحديد:٧٢]،',
#  '[سورةالفرقان:٩١]؛',
#  '[سورةالأحقاف:٦١]،',
#  '[سورةالأنعام:٩٤١]',
#  '[سورةهود:٢١١]،',
#  '[سورةالأحقاف:٩]،',
#  '[سورةيوسف:٤]',
#  '[سورةيوسف:٥].',
#  '[سورةيوسف:٥]،',
#  '[سورةيوسف:٠٠١]،',
#  '[سورةيوسف:٠٠١]،',
#  '[سورةيوسف:٠٠١]',
#  '[سورةالفرقان:٥٤]،',
#  '[سورةالفرقان:٥٤]،',
#  '[سورةالفرقان:٦٤].',
#  '[سورةهود:٣٢١].',
#  '[سورةالإخلاص:١]',
#  '[سورةالإخلاص:٢]',
#  '[سورةالإخلاص:٣]',
#  '[سورةالإخلاص:٣]',
#  '[سورةالإخلاص:٤]',
#  '[سورةالإخلاص:١]',
#  '[سورةفاطر:٥١].',
#  '[سورةهود:٦٥].',
#  '[سورةالفاتحة٧].',
#  '[سورةالفرقان:٣٥؛]',
#  '[سورةالفرقان:٣٥؛]',
#  '[سورةالرعد٤]',
#  '[سورةالمائدة:٦٦].',
#  '[سورةمريم:٦٨]',
#  '[سورةالواقعة:٥٨]',
#  '[سورةق٢٢].',
#  '[سورةق:٦١]',
#  '[سورةالأحقاف٤٢]',
#  '[سورةالأحقاف:٤٢]،',
#  '[سورةالأحقاف:٥٢]،',
#  '[سورةالأعراف٣٣].',
#  '[سورةهود:٦٥]،',
#  '[سورةالعنكبوت٧٤]،',
#  '[سورةالشورى:١١]',
#  '[سورةالشورى:١١]',
#  '[سورةهود:٧٥]',
#  '[سورةالبقرة٩٢]،',
#  '[سورةالزمر:٩]،',
#  '[سورةالبقرة:٥١١].',
#  '[سورةالبقرة٥١١].',
#  '[سورةالنساء:٥١١]',
#  '[سورةالنحل٠٤]',
#  '[سورةيس:٢٨]،',
#  '[سورةهود:٥٦].',
#  '،[سورةهود:٧٦].',
#  '[سورةعبس:٨٣]،',
#  '[سورةعبس:٩٣]',
#  '[سورةعبس:٩٣]',
#  '[سورةالأنعام:٩٤١].',
#  '[سورةالأحزاب٤].',
#  '[سورةطه:٠٥].',
#  '[سورةطه:٤١١]',
#  '[سورةق:٧٣]',
#  '[سورةآلعمران٢٢]،',
#  '[سورةآلعمران:٢٢].',
#  '[سورةق:٧٣].',
#  '[سورةق:٧٣]،',
#  '[سورةق:٧٣]،',
#  '[سورةالزمر:٧٤]',
#  '[سورةالزمر:٧٤]',
#  '[سورةالبقرة٥٢].',
#  '[سورةالكهف:٤٠١]،',
#  '[سورةق:٥١].',
#  '[سورةهود:٠٨]',
#  '[سورةهود:٠٨]،',
#  '[سورةهود٠٨]،',
#  '[سورةهود:٠٨]،',
#  '[سورةالروم:٤٥]',
#  '[سورةالروم:٤٥]',
#  '[سورةالروم٤٥]،',
#  '[سورةالروم:٤٥]،',
#  '[سورةالحج:٥]',
#  '[سورةهود:٠٨]',
#  '[سورةالروم:٦‐٧].',
#  '[سورةالبقرة:٨٨؛]',
#  '[سورةالمزمل:٩]،',
#  '[سورةالحديد:٧]،',
#  '[سورةالمزمل:٩].',
#  '[سورةالأحقاف:٩].',
#  '[سورةالقصص:٦٥].',
#  '[سورةالقصص:٦٥]،',
#  '[سورةالقصص:٦٥].',
#  '[سورةق:٩٢]',
#  '[سورةق:٩٢]،',
#  '[سورةالأعراف:٠٦١]',
#  '[سورةق:٧٣]،',
#  '[سورةالأنعام:٩٤١].',
#  '[سورةالبقرة:٣٥٢].',
#  '[سورةالإسراء:٥٥].',
#  '[سورةالنحل:١٧].',
#  '[سورةطه:٠٥]،',
#  '[سورةالبقرة:٩٥٢].',
#  '[سورةالبقرة:٠٦٢]،',
#  '[سورةالبقرة:٩٥٢]،',
#  '[سورةالبقرة:٩٥٢]،',
#  '[سورةطه:٠٥]،',
#  '[سورةطه:٠٥]،',
#  '[سورةالبقرة:٨٥٢]،',
#  '[سورةالشورى:٨٢].',
#  '[سورةطه:٤١١].',
#  '[سورةالقلم:٢٤]،',
#  '[سورةالقلم:٢٤]',
#  '[سورةالقلم:٢٤]،',
#  '[سورةمريم:٩١]',
#  '[سورةمريم:٩١]',
#  '[سورةالنساء:١٧١].',
#  '[سورةآلعمران:٩٤].',
#  '[سورةالمائدة:٠١١]،',
#  '[سورةآلعمران:٩٤].',
#  '[سورةآلعمران:٩٤].',
#  '[سورةآلعمران٩٤].',
#  '[سورةآلعمران:٧٤]،',
#  '[سورةالتوبة:٩٢]،',
#  '[سورةالمائدة٧١]،',
#  '[سورةآلعمران٧٤]،',
#  '[سورةآلعمران:٧٤]؟',
#  '[سورةآلعمران:٧٤]',
#  '[سورةالأنعام:٢٢١]',
#  '[سورةص٥٧]',
#  '[سورةص٥٧]،',
#  '[سورةمحمد:١٣].',
#  '[سورةالمائدة٦١١].',
#  '[سورةالمائدة:٦١١].',
#  '[سورةالمائدة:٦١١]',
#  '[سورةالمائدة:٦١١]،',
#  '[سورةالمائدة:٦١١]',
#  '[سورةالمائدة٦١١].',
#  '[سورةالمائدة:٦١١]',
#  '[سورةالمائدة٧١١]،،',
#  '[سورةالمائدة:٧١١]',
#  '[سورةالمائدة:٧١١].',
#  '[سورةالمائدة:٧١١]،',
#  '[سورةالمائدة:٧١١]،',
#  '[سورةالمائدة٧١١]',
#  '[سورةالمائدة:٧١١].',
#  '[سورةالمائدة:٧١١]،',
#  '[سورةالمائدة:٧١١]',
#  '[سورةالمائدة:٧١١]',
#  '[سورةالمائدة:٧١١]',
#  '[سورةالمائدة٧١١]',
#  '[سورةالمائدة:٧١١]',
#  '[سورةالمائدة:٧١١].',
#  '[سورةالمائدة٧١١]',
#  '[سورةالمائدة:٧١١]،',
#  '[سورةالمائدة:٨١١].',
#  '[سورةالفتح:٥٢]',
#  '[سورةالمائدة:٨١١].',
#  '[سورةالمائدة:٨١١].',
#  '[سورةالمائدة:٨١١].',
#  '[سورةالمائدة:٨١١]',
#  '[سورةالمائدة:٨١١]',
#  '،[سورةالمائدة:٦١١]',
#  '[سورةالمائدة:٧١١]،',
#  '[سورةالمائدة:٨١١].',
#  '[سورةالمائدة:٨١١].',
#  '[سورةالنمل:٠٣]،',
#  '[سورةالنمل٠٣]',
#  '[سورةالنمل:٠٣]،',
#  '[سورةالأنعام:٢١]',
#  '[سورةالأعراف:٦٥١]،',
#  '[سورةالشورى:١١]',
#  '[سورةالشورى:١١]،',
#  '[سورةالنمل:٩٢]',
#  '[سورةق:٥١].',
#  '[سورةص:٠٣]،',
#  '[سورةالأنبياء:٩٧]',
#  '[سورةالأنبياء:٩٧].',
#  '[سورةالنمل:٢٤]',
#  '[سورةالنمل:٤٤]',
#  '[سورةالنمل:٤٤]',
#  '[سورةالنمل:٢٤].',
#  '[سورةالنمل٤٤]',
#  '[سورةالنمل:٤٤].',
#  '[سورةالأعراف:٢٢١؛]',
#  '،[اقتباسسورةيونس:٠٩]',
#  '[سورةالأعراف:٢٢١؛]',
#  '[سورةالنمل٤٤]،',
#  '[سورةالحديد:٤]،',
#  '[سورةالنمل٤٤]،',
#  '[سورةص:٦٣]،',
#  '[سورةص:٩٣]،',
#  '[سورةص:٩٣]',
#  '[سورةص٩٣].',
#  '[سورةالأنعام:٤٨]،',
#  '[سورةص٣٤]،',
#  '[سورةمريم:٣٥]',
#  '[سورةسبأ:٠١]',
#  '[سورةسبأ:٣١]،',
#  '[سورةالإسراء:٣]',
#  '[سورةص:٦٢]',
#  '[سورةص:٦٢]',
#  '[سورةص:٦٢]',
#  '[سورةالبقرة:٠٣]',
#  '[سورةص:٦٢]',
#  '[سورةالبقرة٤٢١]',
#  '[سورةص:٦٢].',
#  '[سورةالأنعام:٠٩].',
#  '[سورةالأنبيا:٢٢].',
#  '[سورةالأنفال:١٦].',
#  '[سورةالشورى:٠٤]؟',
#  '[سورةالشورى:٠٤]؛',
#  '[سورةالبقرة:٩٧١]',
#  '[سورةهود:٣٢١]',
#  '[سورةهود:٣٢١]',
#  '[سورةهود٣٢١].',
#  '[سورةالأنبياء:٠٣]',
#  '[سورةالنحل:٠٥]',
#  '[سورةالأنعام:٨١و١٦].',
#  '[سورةالمائدة:٦٦]،',
#  '[سورةالمائدة:٦٦].',
#  '[سورةالمائدة:٦٦]',
#  '[سورةالمائدة:٦٦]',
#  '[سورةالمائدة:٦٦]',
#  '[سورةص:٢٤]،',
#  '[سورةهود:٣٢١]،',
#  '[سورةهود:٣٢١]،',
#  '[سورةالحديد٣،]',
#  '[سورةص:٧١،]',
#  '[سورةالأحزاب:٧٥].',
#  '[سورةمريم:٧].',
#  '[سورةمريم:٥]،',
#  '[سورةالتحريم:١١].',
#  '[سورةمريم:٦]',
#  '[سورةمريم:٣٣]',
#  '[سورةالأعراف:٦٥١].',
#  '[سورةالأعراف٦٥١]،',
#  '[سورةالفتح٢]',
#  '[سورةالشورى:١١]',
#  '[سورةالشورى:١١]،',
#  '[سورةالصافات:٠٨١].',
#  '[سورةالأنعام:٤٢١].',
#  '[سورةالأنعام:٤٢١]؛',
#  '[سورةغافر:٠٦]،',
#  '[سورةالبقرة:٦٨١]',
#  '[سورةالأنفال٧١]،',
#  '[سورةلقمان:٢١].',
#  '[سورةلقمان:٦١].',
#  '[سورةالأنعام:٣].',
#  '[سورةلقمان:٦١].',
#  '[سورةالأحزاب:٤٣].',
#  '[سورةمحمد:١٣].',
#  '[سورةلقمان:٦١]،',
#  '[سورةلقمان:٦١]،',
#  '[سورةالزلزال:٧‐٨].',
#  '[سورةالبقرة:٦٢].',
#  '[سورةالبقرة:٦٢]،',
#  '[سورةالإسراء٠١١]',
#  '[سورةمريم:٣٥]،',
#  '[سورةمريم:٣٥]،',
#  '[سورةطه:٤٩]،',
#  '[سورةطه:٤٩]،',
#  '[سورةالأعراف:٠٥١].',
#  '[سورةطه:٤٩]،',
#  '[سورةطه:٥٩]؟',
#  '[سورةالزخرف٢٣].',
#  '[سورةالزخرف٢٣].',
#  '[سورةالرحمن:٩٢].',
#  '[سورةالجاثية:٣٢]،',
#  '[سورةالجاثية:٣٢]،',
#  '[سورةالجاثية:٣٢]',
#  '[سورةالجاثية٣٢]،',
#  '[سورةالزمر٣]',
#  '[سورةص٥]',
#  '[سورةالزمر:٣].',
#  '[سورةالرعد:٣٣]',
#  '[سورةآلعمران:١٣].',
#  '[سورةالأنعام:٣٠١]',
#  '[سورةالأنعام٣٠١]',
#  '[سورةالأنعام:٣٠١].',
#  '[سورةالنحل:٩].',
#  '[سورةالأنبياء٠٣]،',
#  '[سورةالجاثية٣١]،',
#  '[سورةالأنعام:٢٢١]',
#  '[سورةالأنعام:٢٢١]',
#  '[سورةالأنعام:٢٢١]،',
#  '[سورةالأنعام٢٢١]',
#  '[سورةالأنعام:٢٢١]',
#  '[سورةالحج:٥]،',
#  '[سورةالحج:٥]',
#  '[سورةالحج:٥].أ',
#  '[سورةالقصص:٩].',
#  '[اقتباسسورةيوسف٧٨]',
#  '[سورةالمائدة٨٤]،',
#  '[سورةطه:٠٤].',
#  '[سورةالكهف:٢٨]،',
#  '[سورةالشعراء١٢]',
#  '[سورةالقصص:٤٢]',
#  '[سورةالقصص:٤٢]',
#  '[سورةالقصص:٤٢]',
#  '[سورةالكهف:٨٦]،',
#  '[سورةالحشر:٧]،',
#  '[سورةالكهف:٦٧]،',
#  '[سورةالكهف:٨٧]،',
#  '[سورةالكهف:٨٦]،',
#  '[سورةالشعراء:١٢]،',
#  '[سورةالشعراء:١٢]،',
#  '[سورةالشعراء:٧٢]',
#  '؟[سورةالشعراء٣٢]',
#  '[سورةالشعراء:٤٢].',
#  '[سورةالقلم:١٥]،',
#  '[سورةالشعراء:٨٢]،',
#  '[سورةالشعراء:٤٢]،',
#  '[سورةالشعراء:٤٢]',
#  '[سورةالشعراء:٩٢].',
#  '[سورةالشعراء:٠٣]؟',
#  '[سورةالشعراء:١٣]،',
#  '[سورةالزخرف٤٥]',
#  '[سورةالشعراء:٢٣]،',
#  '[سورةالشعراء:٢٣]،',
#  '[سورةالفرقان:٠٧]،',
#  '[سورةالنازعات:٤٢]',
#  '[سورةطه:٢٧]',
#  '[سورةطه:٢٧]',
#  '[سورةالنازعات:٤٢]،',
#  '[سورةالأنبياء:٢]',
#  '[سورةالشعراء:٥]',
#  '[سورةغافر:٥٨]',
#  '[سورةيونس:٨٩]،',
#  '[سورةيونس:٨٩].',
#  '[سورةيونس:٢٩].',
#  '[سورةيونس:٢٩]،',
#  '[سورةالحجر:٩٢؛].',
#  '[سورةمحمد:١٣]',
#  '[سورةالسجدة:٥]',
#  '[سورةالسجدة:٥]،',
#  '[سورةالتوبة:٧٣]،',
#  '[سورةالبقرة:٨٢٢]،',
#  '[سورةطه:٠٥]،',
#  '[سورةغافر:٥١]',
#  '[سورةالأعراف:٦٥١]',
#  '[سورةالنور:٦٢].',
#  '[سورةالحجر:٦٢،]',
#  '[سورةالعنكبوت٢٥]',
#  '[سورةالعنكبوت٢٥]',
#  '[الأنعام:٢١]،',
#  '[سورةالبقرة:٢٥١].',
#  '،[سورةالفاتحة٢،]',
#  '[سورةق:٧٣]،',
#  '[سورةق:٧٣].',
#  '[سورةالعنكبوت:٥٤]',
#  '[سورةالعنكبوت:٥٤]',
#  '[سورةالعنكبوت:٥٤].',
#  '[سورةق:٧٣].',
#  '[سورةالقيامة٤١–٥١]،',
#  '[سورةالنور:١٤]',
#  '[سورةالإسراء:٤٤]',
#  '[سورةالإسراء:٤٤]',
#  '[سورةالأحزاب:٤].']

# %%
list(map(int, re.findall(r'\d+', '٩٦٢')))[0]
# Out:
# 962

# %%
fusus.iloc[38963, fusus.columns.get_loc("word")] += fusus.iloc[38964, fusus.columns.get_loc("word")]
fusus.iloc[38963, fusus.columns.get_loc("short")] += fusus.iloc[38964, fusus.columns.get_loc("short")]
fusus.iloc[38963, fusus.columns.get_loc("haspunct")] += fusus.iloc[38964, fusus.columns.get_loc("haspunct")]
fusus.iloc[38964, fusus.columns.get_loc("word")] = ""
fusus.iloc[38964, fusus.columns.get_loc("short")] = ""

# %%
fusus[fusus.short.str.contains(pat=abc.QURANCLOSE)&fusus.short.str.contains(pat='\[')].word.str.split(abc.QURANCLOSE).str[1].to_csv("66.csv",index=True)

# %%
SliceAndDice(39334,1)

# %%
fusus.iloc[5247, fusus.columns.get_loc("word")][:2]
# Out:
# '٥]'

# %% [markdown]
# ### Note that in the edition it gives the sura number. This has not come through in the extraction and it is not at all available.
# Some minor cleaning was done: in two cases brackets were left in, and in two cases normal brackets were used instead of Quran-brackets.

# %%
98+357+10+6+6+13+14+14+17
# Out:
# 535

# %% [markdown]
# ### Does the word `سورة` always follow a Quran-close-bracket?
# 98 have in the same row. 357 in the next. 10 in 2 rows down. 6 in 3 rows down. 6 in 4 rows down. 13 in 5 rows down. 14 in 6 rows down. 14 in 7 rows down. 17 in 8 rows down. Which is 535, or 15 more than the actual total number, which shows there is already some crude overlap

# %%
fusus[fusus.word.str.contains(pat=abc.QURANCLOSE) & fusus.word.str.contains(pat='سورة')]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 2020     28     9       1     1         r  138.0  304.0  225.0  325.0
# 2024     28    10       1     1         r  236.0  330.0  325.0  351.0
# 5132     56     8       1     1         r  173.0  285.0  262.0  306.0
# 5137     57     1       1     1         r  284.0   87.0  372.0  108.0
# 5181     57     6       1     1         r  268.0  217.0  343.0  238.0
# ...     ...   ...     ...   ...       ...    ...    ...    ...    ...
# 40982   405     4       1     1         r   79.0  165.0  157.0  186.0
# 41127   407     2       1     1         r  173.0  113.0  262.0  134.0
# 41177   407     7       1     1         r  232.0  243.0  331.0  264.0
# 41187   407     8       1     1         r  193.0  269.0  295.0  290.0
# 41363   409     5       1     1         r  165.0  191.0  266.0  212.0
#
#                             word                 short haspunct punctAfter  \
# 2020   وَنِسَـآءً﴾.[سورةالنساء:   ونساء﴾.[سورةالنساء:     ﴾.[:
# 2024    رَبَّـكُمْ﴾؛[سورةالنساء:    ربكم﴾؛[سورةالنساء:     ﴾؛[:
# 5132          شَيءٌ﴾[سورةالشورى:      شيء﴾[سورةالشورى:      ﴾[:
# 5137     ٱلبَصِيْرُ﴾[سورةالشورى:   ٱلبصير﴾[سورةالشورى:      ﴾[:
# 5181        غَفَّارًا﴾.[سورةنوح:      غفارا﴾.[سورةنوح:     ﴾.[:
# ...                          ...                   ...      ...        ...
# 40982       مَعَاذِيْـرَهُ﴾[سورة         معاذيره﴾[سورة       ﴾[
# 41127  وَتَسْبِيحَهُ﴾[سورةالنور:   وتسبيحه﴾[سورةالنور:      ﴾[:
# 41177   بِحَمْدِهِ﴾[سورةالإسراء:   بحمده﴾[سورةالإسراء:      ﴾[:
# 41187  ﴿بِحَمْدِهِ﴾[سورةالإسراء:  ﴿بحمده﴾[سورةالإسراء:     ﴿﴾[:
# 41363  ٱلسَّبِيْلَ﴾[سورةالأحزاب:  ٱلسبيل﴾[سورةالأحزاب:      ﴾[:
#
#       punctBefore QunawiMS poetryMeter poetryVerse fass
# 2020                    5b
# 2024                    5b
# 5132                   11b
# 5137                   11b
# 5181                   11b
# ...           ...      ...         ...         ...  ...
# 40982                  77b
# 41127                  77b
# 41177                  78a
# 41187                  78a
# 41363                  78a
#
# [98 rows x 18 columns]

# %%
total = 0
for q in fusus[fusus.word.str.contains(pat=abc.QURANCLOSE)].index.tolist():
    if 'سورة' in fusus.iloc[q+1].word:
        total += 1
#         print(str(q+1) + " has " + fusus.iloc[q+1].word)
print(total)
# Out:
# 357

# %% [markdown]
# ### Another way is to look at square brackets, which seem to be used after a Quran citation.
# Here we can already find two cases in which the word `سورة` is not found.

# %%
fusus.iloc[fusus[fusus.short.str.contains(pat='\]')].index-1]
# Out:
#        page  line  column  span direction  left  top  right  bottom  \
# 43        9     4       1     1         r   206  165    219     186
# 58        9     5       1     1         r   104  191    124     212
# 66        9     6       1     1         r   223  217    236     238
# 279      13     5       1     1         r   157  207    196     225
# 430      16     7       1     1         r   387  247    402     262
# ...     ...   ...     ...   ...       ...   ...  ...    ...     ...
# 40444   405     8       1     1         r   210  273    264     288
# 40553   407     2       1     1         r   173  113    262     134
# 40602   407     7       1     1         r   232  243    331     264
# 40612   407     8       1     1         r   193  269    295     290
# 40788   409     5       1     1         r   165  191    266     212
#
#                             word                 short haspunct punctAfter  \
# 43                           [وَ                    [و        [
# 58                          [٧٢٦                  [٧٢٦     [٧٢٦
# 66                           [وَ                    [و        [
# 279                      الصّفحة                الصفحة
# 430                        [هود:                 [هود:       [:
# ...                          ...                   ...      ...        ...
# 40444               سورةالأحزاب:           سورةالأحزاب                   :
# 40553  وَتَسْبِيحَهُ﴾[سورةالنور:   وتسبيحه﴾[سورةالنور:      ﴾[:
# 40602   بِحَمْدِهِ﴾[سورةالإسراء:   بحمده﴾[سورةالإسراء:      ﴾[:
# 40612  ﴿بِحَمْدِهِ﴾[سورةالإسراء:  ﴿بحمده﴾[سورةالإسراء:     ﴿﴾[:
# 40788  ٱلسَّبِيْلَ﴾[سورةالأحزاب:  ٱلسبيل﴾[سورةالأحزاب:      ﴾[:
#
#       punctBefore QunawiMS poetryMeter  poetryVerse  fass lwcvl quran
# 43                      1b                     <NA>     0
# 58                      1b                     <NA>     0
# 66                      1b                     <NA>     0
# 279                     2a                     <NA>     0
# 430                     2b                     <NA>     1
# ...           ...      ...         ...          ...   ...   ...   ...
# 40444                  77b                     <NA>    27
# 40553                  77b                     <NA>    27
# 40602                  78a                     <NA>    27
# 40612                  78a                     <NA>    27
# 40788                  78a                     <NA>    27
#
# [504 rows x 20 columns]

# %%
fusus.haspunct.unique().tolist()
# Out:
# ['',
#  '[',
#  ']',
#  '[٧٢٦',
#  ':.',
#  '―',
#  '﴿',
#  '﴾',
#  '[:',
#  '٣٢١]',
#  '﴾،',
#  '٠٣].',
#  '«»،',
#  '«».',
#  '«»',
#  '٥٧]',
#  '»،',
#  '﴾.[:',
#  '١]',
#  '﴾؛[:',
#  '٠٦]',
#  '١٣]',
#  '؟!',
#  '١٢]',
#  ':٠٥]',
#  '–',
#  '٣٥]',
#  '﴾.',
#  '٢]:',
#  '﴾[:',
#  '١١]',
#  '﴿﴾',
#  '٨]،',
#  '٩]،',
#  '٠١]',
#  ':﴿',
#  '٥–٦].',
#  '٠١١]',
#  '٥]',
#  '﴿﴾[:',
#  '٧]',
#  '﴾[',
#  '٢١]',
#  '١٢].',
#  '٦١]',
#  '٧].',
#  '٢]',
#  '٢٢]',
#  '٨٠١]',
#  '٥٨]',
#  '٣٢]',
#  '٣٣]',
#  '»؟',
#  '٣]',
#  '٤٣]',
#  '٤٢]',
#  '٠٢].',
#  '٥٢]',
#  '٦]',
#  '«»؛',
#  '٩٢]',
#  '٦٢]',
#  ':٥٥]',
#  '﴿﴾،',
#  '٧٢]',
#  '٨٢]',
#  '١٩].',
#  '﴾:[:',
#  '٨٨]',
#  '٧٥].',
#  '٥٣]',
#  '٥٣]،',
#  '١]،',
#  ':٥]،',
#  '٨٨]،',
#  '٣٢١]،',
#  '٠٦].',
#  '٧٥]،',
#  '٠٣]،',
#  '٥٧]،',
#  '[]',
#  '؟﴿',
#  '٢٠١].',
#  '٧٠١].',
#  ']،',
#  '٧٦]',
#  '٩٤١]،',
#  '؟»',
#  '٢٤]',
#  '٩٤١].',
#  '﴾؛',
#  '﴿﴾:',
#  '»:',
#  '٤٦١].',
#  '.:',
#  '٤].',
#  '٢٠١]،',
#  '٤٠١‐٥٠١]،',
#  '٣٤].',
#  '٦٠١]',
#  '٨٣].',
#  '٩٢].',
#  ':٠٥]،',
#  '٨٢–٩٢]',
#  '[]]',
#  '٨]',
#  '٧٤].',
#  '٤٥].',
#  '٢٣١]،',
#  '٩١]،',
#  '٧٢].',
#  '٧٢]،',
#  '٩١]؛',
#  '٦١]،',
#  '٩٤١]',
#  '٢١١]،',
#  ':«',
#  '٤]',
#  '٥].',
#  '٥]،',
#  '٠٠١]،',
#  '٠٠١]',
#  '٥٤]،',
#  '٦٤].',
#  '٣٢١].',
#  '«»؟',
#  '٣].',
#  '٥١].',
#  '٦٥].',
#  '٣٥؛',
#  '٢١]،',
#  '٦٦].',
#  '٦٨]',
#  '٢٢].',
#  '٢١].',
#  '..',
#  '٤٢]،',
#  '٥٢]،',
#  '٣٣].',
#  '[٦٨٥].',
#  '٦٥]،',
#  '٧٤]،',
#  '٩٢]،',
#  '؛:',
#  '﴾[:٩]،',
#  '٥١١].',
#  '٥١١]',
#  '٠٤]',
#  '٢٨]،',
#  '٥٦].',
#  '٧٦].',
#  '٨٣]،',
#  '٩٣]',
#  '٤٣].',
#  '؟».',
#  ':٠٥].',
#  ':٤١١]',
#  '٧٣]',
#  '٢٢]،',
#  '٧٣].',
#  '٧٣]،',
#  '٦٦١].',
#  '٧٤]',
#  '٥٢].',
#  '٤٠١]،',
#  '٠٨]',
#  '٠٨]،',
#  '٤٥]',
#  '٤٥]،',
#  '٦‐٧].',
#  '٨٨؛',
#  '٥٥١]،',
#  '٧]،',
#  '٩].',
#  '٢٧٢].',
#  '٠٦١]',
#  '٣٥٢].',
#  '٥٥].',
#  '١٧].',
#  '٩٥٢].',
#  '٠٦٢]،',
#  '٩٥٢]،',
#  '٨٥٢]،',
#  '٨٢].',
#  ':٤١١].',
#  '٢٤]،',
#  '«»:',
#  '٩١]',
#  '١٧١].',
#  '٩٤].',
#  '٠١١]،',
#  '٧١]،',
#  '٧٤]؟',
#  '٢٢١]',
#  '١٣].',
#  '٦١١].',
#  '٦١١]',
#  '٦١١]،',
#  '٧١١]،،',
#  '٧١١]',
#  '٧١١].',
#  '٧١١]،',
#  '٣٤]،',
#  '١٥١]،',
#  '﴾[٧١١]',
#  '٨١١].',
#  '٨١١]',
#  '٠٣]',
#  '﴿ی',
#  ':﴿﴾',
#  '٦٥١]،',
#  '١١]،',
#  '……………',
#  '٩٧]',
#  '٩٧].',
#  '٤٤]',
#  '٢٤].',
#  '٤٤].',
#  '٢٢١؛',
#  '٨٤]،',
#  '٠٩]',
#  '٨٤].',
#  '٤٤]،',
#  '٤]،',
#  '٦٣]،',
#  '٣١]،',
#  '٩٣]،',
#  '٩٣].',
#  ':٤١١]،',
#  '١٢]،',
#  '٤٨]،',
#  '٤٢١]',
#  '٦٢].',
#  '٠٩].',
#  '—',
#  '١٦].',
#  '٠٤]؟',
#  '٠٤]؛',
#  '٩٧١]',
#  '٩٦]',
#  '٠٥]',
#  '٨١١٦].',
#  '٦٦]،',
#  '٦٦]',
#  '٣،',
#  '٩٢،',
#  '١٠١]؛',
#  '٣٨‐٤٨]،',
#  '٧١،',
#  '٠٣،',
#  '١١].',
#  '«،',
#  '٦٥١].',
#  '٠٨١].',
#  '٤٢١].',
#  '٤٢١]؛',
#  '٠٦]،',
#  '٦٨١]',
#  '٩٦٢].',
#  '٧١].',
#  '٦١].',
#  '٧‐٨].',
#  '٦٢]،',
#  '٣١].',
#  '﴾[٠١١]',
#  '٣٥]،',
#  ':٤٩]،',
#  '٠٥١].',
#  ':٥٩]؟',
#  '٢٣].',
#  '٣٢]،',
#  '٣٠١]',
#  '٣٠١].',
#  '٢٢١]،',
#  '٥].:',
#  '٧٨]',
#  ':٠٤].',
#  '!»',
#  '٨٦]،',
#  '٦٧]،',
#  '٨٧]،',
#  '﴾؟',
#  '٤٢].',
#  '١٥]،',
#  '٨٢]،',
#  '٠٣]؟',
#  '١٣]،',
#  '٢٣]،',
#  '٠٧]،',
#  ':٢٧]',
#  '٢]﴿',
#  '٨٩]،',
#  '٨٩].',
#  '٢٩].',
#  '﴾[:٢٩]،',
#  '٩٢؛',
#  '٢٧].',
#  '…»',
#  '٨٢٢]،',
#  '٥١]',
#  '٦٥١]',
#  '٦٢،',
#  '٨٢،',
#  '٢٥]',
#  '٢٥١].',
#  '٢،',
#  '٥٤]',
#  '٥٤].',
#  '٤١–٥١]،',
#  '١٤]',
#  '[…]',
#  '[؟]',
#  '[٠٣٦']

# %%
def SliceAndDice(r, l):
    fusus.iloc[r-1, fusus.columns.get_loc("word")] += fusus.iloc[r, fusus.columns.get_loc("word")][:l]
    fusus.iloc[r-1, fusus.columns.get_loc("short")] += fusus.iloc[r, fusus.columns.get_loc("word")][:l]
    fusus.iloc[r-1, fusus.columns.get_loc("haspunct")] += fusus.iloc[r, fusus.columns.get_loc("haspunct")]
    fusus.iloc[r, fusus.columns.get_loc("word")] = fusus.iloc[r, fusus.columns.get_loc("word")][l:]
    fusus.iloc[r, fusus.columns.get_loc("short")] = fusus.iloc[r, fusus.columns.get_loc("short")][l:]
    fusus.iloc[r, fusus.columns.get_loc("haspunct")] = ""

# %%
def AddAndSpread(r):
    fusus.iloc[r-2, fusus.columns.get_loc("word")] += fusus.iloc[r, fusus.columns.get_loc("word")]
    fusus.iloc[r-2, fusus.columns.get_loc("short")] += fusus.iloc[r, fusus.columns.get_loc("short")]
    fusus.iloc[r-2, fusus.columns.get_loc("haspunct")] += fusus.iloc[r, fusus.columns.get_loc("haspunct")]
    fusus.iloc[r, fusus.columns.get_loc("word")] = ""
    fusus.iloc[r, fusus.columns.get_loc("short")] = ""
    fusus.iloc[r, fusus.columns.get_loc("haspunct")] = ""
    fusus.iloc[r-1, fusus.columns.get_loc("word")] = ""
    fusus.iloc[r-1, fusus.columns.get_loc("short")] = ""
    fusus.iloc[r-1, fusus.columns.get_loc("haspunct")] = ""

# %%
SliceAndDice(33082,2)

# %%
fusus[(fusus.quran=="")&(fusus.word.str.contains(pat=abc.QURANCLOSE))]
# Out:
#        page  line  column  span direction  left  top  right  bottom  \
# 2562     34    11       1     1         r   127  347    149     368
# 5058     57     4       1     1         r   109  165    147     186
# 5290     59     2       1     1         r    79  113    140     134
# 5421     60     9       1     1         r    79  295    135     316
# 5457     61     3       1     1         r   104  139    135     160
# ...     ...   ...     ...   ...       ...   ...  ...    ...     ...
# 38873   398    10       1     1         r   183  304    215     322
# 38895   398    12       1     1         r   208  348    246     366
# 38926   398    15       1     1         r   237  414    259     432
# 38948   399     3       1     1         r   210  135    262     156
# 39465   405     4       1     1         r    79  165    157     186
#
#                                       word                        short  \
# 2562                  لَكُمْ﴾[سورةغافر:٠٦]             لكم﴾[سورةغافر٠٦]
# 5058                ﴿جِهَارًا﴾[سورةنوح:٨]،           ﴿جهارا﴾[سورةنوح٨]،
# 5290               مِدْرَارًا﴾[سورةنوح:١١]           مدرارا﴾[سورةنوح١١]
# 5421                  اللهِ﴾[سورةيوسف:٨٠١]           الله﴾[سورةيوسف٨٠١]
# 5457                وَفْدًا﴾،[سورةمريم:٥٨]           وفدا﴾،[سورةمريم٥٨]
# ...                                    ...                          ...
# 38873                          الدِّيْنِ﴾،                      الدين﴾،
# 38895                      نَسْتَعِْيْنُ﴾،                     نستعين﴾،
# 38926                            لِّيْنَ﴾،                        لين﴾،
# 38948     العَـٰلَمِيْنَ﴾،[سورةالفاتحة:٢،]     العلمين﴾،[سورةالفاتحة٢،]
# 39465  مَعَاذِيْـرَهُ﴾[سورةالقيامة:٤١–٥١]،  معاذيره﴾[سورةالقيامة٤١–٥١]،
#
#         haspunct punctAfter punctBefore QunawiMS poetryMeter  poetryVerse  \
# 2562       ﴾[٠٦]                              6b                     <NA>
# 5058      ﴿﴾[٨]،                             11b                     <NA>
# 5290       ﴾[١١]                             12a                     <NA>
# 5421      ﴾[٨٠١]                             12b                     <NA>
# 5457      ﴾،[٥٨]                             12b                     <NA>
# ...          ...        ...         ...      ...         ...          ...
# 38873         ﴾،                             76b                     <NA>
# 38895         ﴾،                             76b                     <NA>
# 38926         ﴾،                             76b                     <NA>
# 38948     ﴾،[٢،]                             76b                     <NA>
# 39465  ﴾[٤١–٥١]،                             77b                     <NA>
#
#        fass lwcvl quran
# 2562      2
# 5058      3
# 5290      3
# 5421      3
# 5457      3
# ...     ...   ...   ...
# 38873    27
# 38895    27
# 38926    27
# 38948    27
# 39465    27
#
# [120 rows x 20 columns]

# %%
fusus.iloc[iqtibas-2]
# Out:
#        page  line  column  span direction  left  top  right  bottom  \
# 13188   152    13       1     1         r   159  399    189     420
# 13271   153     7       1     1         r   276  243    318     264
# 13281   153     8       1     1         r   125  269    155     290
# 13563   156     1       1     1         r   284   87    325     108
# 20261   217     2       1     1         r   215  113    233     134
# 20286   217     5       1     1         r   239  191    284     212
# 26972   286    13       1     1         r   204  399    239     420
# 27202   288     4       1     1         r   184  209    202     230
# 27823   293    12       1     1         r   266  373    304     394
# 31090   324     4       1     1         r   364  165    402     186
# 31220   326     4       1     1         r   276  172    322     193
# 31832   330    14       1     1         r    79  425    106     446
# 32466   336     7       1     1         r    79  243    125     264
# 32529   336    13       1     1         r    79  399    124     420
# 33577   346     3       1     1         r   174  139    196     160
# 36297   367    14       1     1         r   229  425    264     446
# 39891   405     8       1     1         r   301  269    329     290
#
#                                     word                      short  haspunct  \
# 13188                حَدِيدٌ﴾[سورةق:٢٢].            حديد﴾[سورةق٢٢].    ﴾[٢٢].
# 13271       الأُجَاجِ».[سورةالفرقان:٣٥؛]     الأجاج[سورةالفرقان٣٥؛]     [٣٥؛]
# 13281      لِشَارِبِهِ»[سورةالفرقان:٣٥؛]     لشاربه[سورةالفرقان٣٥؛]     [٣٥؛]
# 13563       ٱلفَوٰحِشَ﴾[سورةالأعراف:٣٣].    ٱلفوحش﴾[سورةالأعراف٣٣].    ﴾[٣٣].
# 20261            اللهِ»[سورةآلعمران:٩٤].       الله[سورةآلعمران٩٤].     [٩٤].
# 20286      وَالأَبْرَصَ[سورةالمائدة:٠١١]    والأبرص[سورةالمائدة٠١١]     [٠١١]
# 26972        وَسَلَامًا[سورةالأنبياء:٩٦]     وسلاما[سورةالأنبياء٩٦]      [٩٦]
# 27202             اللهِ[سورةالأسراء:٤٤]،       الله[سورةالأسراء٤٤]،     [٤٤]،
# 27823       المَسِّ[سورةالأنبياء:٣٨‐٤٨]،   المس[سورةالأنبياء٣٨‐٤٨]،  [٣٨‐٤٨]،
# 31090    خَيرًاكَثِيرًا[سورةالبقرة:٩٦٢].  خيراكثيرا[سورةالبقرة٩٦٢].    [٩٦٢].
# 31220  خَيْـرًاكَثِيرًا[سورةالبقرة:٩٦٢].  خيراكثيرا[سورةالبقرة٩٦٢].    [٩٦٢].
# 31832             عَظِيمٌ[سورةلقمان:٣١].         عظيم[سورةلقمان٣١].     [٣١].
# 32466       سُخْـرِيٍّا﴾[سورةالزخرف:٢٣].      سخريا﴾[سورةالزخرف٢٣].    ﴾[٢٣].
# 32529         دَرَجَاتٍ﴾[سورةالزخرف:٢٣].      درجات﴾[سورةالزخرف٢٣].    ﴾[٢٣].
# 33577           حَيٍّ﴾[سورةالأنبياء:٠٣]،       حي﴾[سورةالأنبياء٠٣]،    ﴾[٠٣]،
# 36297         فٰسِقِيْنَ﴾[سورةالزخرف:٤٥]       فسقين﴾[سورةالزخرف٤٥]     ﴾[٤٥]
# 39891          عَلَينَا[سورةالأحزاب:٣٤]،      علينا[سورةالأحزاب٣٤]،     [٣٤]،
#
#       punctAfter punctBefore QunawiMS poetryMeter  poetryVerse  fass lwcvl  \
# 13188                             27b                     <NA>    10
# 13271         ».                  28a                     <NA>    10
# 13281          »                  28a                     <NA>    10
# 13563                             28b                     <NA>    10
# 20261          »                  41a                     <NA>    15
# 20286                             41a                     <NA>    15
# 26972                             53b                     <NA>    18
# 27202                           53aII                     <NA>    19
# 27823                             54b                     <NA>    19
# 31090                             61a                     <NA>    22
# 31220                             61a                     <NA>    23
# 31832                             62a                     <NA>    23
# 32466                             63b                     <NA>    24
# 32529                             63b                     <NA>    24
# 33577                             65b                     <NA>    25
# 36297                             70b                     <NA>    25
# 39891                             77b                     <NA>    27
#
#       quran
# 13188
# 13271
# 13281
# 13563
# 20261
# 20286
# 26972
# 27202
# 27823
# 31090
# 31220
# 31832
# 32466
# 32529
# 33577
# 36297
# 39891

# %%
for i in iqtibas:
    SliceAndDice(i-1,1)
    AddAndSpread(i)

# %%
fusus[(fusus.short.str.contains('\\d\]',regex=True))&(fusus.short.str.len()<5)&(fusus.short.str.contains('|'.join(abc.LETTERS)))]
# Out:
# Empty DataFrame
# Columns: [page, line, column, span, direction, left, top, right, bottom, word, short, haspunct, punctAfter, punctBefore, QunawiMS, poetryMeter, poetryVerse, fass, lwcvl, quran]
# Index: []

# %%
fusus.iloc[fusus[(fusus.short.str.fullmatch('\\d.*\]'))].index-1].word.str.contains(pat='\[').tolist()
# Out:
# [True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True]

# %% [markdown]
# 398,10 and 330,14

# %%
fusus[(fusus.page==57)&(fusus.line==4)]
# Out:
#       page  line  column  span direction  left  top  right  bottom  \
# 5049    57     4       1     1         r   381  165    385     186
# 5050    57     4       1     1         r   362  165    381     186
# 5051    57     4       1     1         r   341  165    362     186
# 5052    57     4       1     1         r   313  165    341     186
# 5053    57     4       1     1         r   285  165    313     186
# 5054    57     4       1     1         r   268  165    285     186
# 5055    57     4       1     1         r   226  165    268     186
# 5056    57     4       1     1         r   188  165    226     186
# 5057    57     4       1     1         r   147  165    188     186
# 5058    57     4       1     1         r   109  165    147     186
#
#                word     short haspunct punctAfter punctBefore QunawiMS  \
# 5049            لَو        لو                                      11b
# 5050          أَنَّ        أن                                      11b
# 5051         نُوحًا      نوحا                                      11b
# 5052         جَمَعَ       جمع                                      11b
# 5053      لِقَومِهِ     لقومه                                      11b
# 5054          بَينَ       بين                                      11b
# 5055  الدَعْوَتَينِ  الدعوتين                                      11b
# 5056  لَأَجَابُوهُ؛   لأجابوه                   ؛                  11b
# 5057    فَدَعَاهُمْ    فدعاهم                                      11b
# 5058     ﴿جِهَارًا﴾   ﴿جهارا﴾       ﴿﴾                             11b
#
#      poetryMeter  poetryVerse  fass lwcvl quran
# 5049                     <NA>     3
# 5050                     <NA>     3
# 5051                     <NA>     3
# 5052                     <NA>     3
# 5053                     <NA>     3
# 5054                     <NA>     3
# 5055                     <NA>     3
# 5056                     <NA>     3
# 5057                     <NA>     3
# 5058                     <NA>     3        71:8

# %%
def ShowContext(i):
    print(str(fusus.iloc[i-1].word)+ " "+str(fusus.iloc[i].word)+ " "+str(fusus.iloc[i+1].word)+ " "+str(fusus.iloc[i+2].word)+ " "+str(fusus.iloc[i+3].word))

# %%
for i in fusus[(fusus.quran=="")&(fusus.word.str.contains(abc.QURANCLOSE))].index:
    print(i)
    ShowContext(i)
    print(" ")
# Out:
# 5826
# فِي ٱلأَرْضِ﴾. وَإِذَا دُفِنْتَ فِيهَا،
#
# 5869
# إِنْ تَذَرْهُمْ﴾ أَيْ: تَدَعُهُمْ وَتَـتْـرُكُهُمْ
#
# 5896
# ﴿وَلَا يَلِدُوْا﴾ أَي: مَايُنْتِجُونَ، وَلَايُظْهِرُونَ
#
# 6170
# رَبَّكَ الأَعْلَىٰ﴾ [الأعلىٰ : ١]،
#
# 6241
# فَجَعَلَ ﴿عَلِيٍّا﴾ نَعْتًا لِلْمَكَانِ. ﴿وَإِذْ
#
# 6718
# ٱفْعَلْ مَاتُـؤمَرُ﴾ [الصافات: ٢٠١]. وَالوَلَدُ
#
# 6731
# ﴿بِذِبْحٍ عَظِيمٍ﴾ [الصافات: ٧٠١]. فَظَهَرَ
#
# 6753
# مِنْهَا زَوْجَهَا﴾ [النساء: ١]، فَمَا
#
# 7504
# أَغْرَاضَهُمْ، فَـ﴿يُكْشَفُ﴾ لَهُمْ ﴿عَنْ سَاقٍ﴾
#
# 7550
# ﴿لَوْ شَاءَ﴾؛ ﴿لَوْ﴾ حَـرْفُ ٱمْتِنَاعِ
#
# 7551
# شَاءَ﴾؛ ﴿لَوْ﴾ حَـرْفُ ٱمْتِنَاعِ الٱمْتِنَاعِ.
#
# 7584
# وَمَعْنَىٰ ﴿لَهَدَىٰكُمْ﴾: لَبَيَّنَ لَـكُمْ. وَمَاكُلُّ
#
# 8257
# الٱخْتِبَارُ، ﴿ٱلمُبِينُ﴾، أَي: الظَّاهِرُ. يَعْنِي:
#
# 9292
# فكَانَتْ ﴿راَضِيَةً﴾ بِمَا يَظْهَرُ فِيهَا
#
# 9300
# رَبَّهَا، ﴿مَرْضِيَّةً﴾ تِلْكَ الأَفْعَالُ؛ لِأَنَّكُلَّ
#
# 10365
# وَرَضُوا عَنْهُ﴾ هٰذَا جَـزَاءٌ بِمَا
#
# 10981
# كَمَآ أُمِرْتَ﴾، فَشَـيَّـبَتْهُ ﴿كَمَآ أُمِرْتَ﴾
#
# 12725
# مَغْضُوبٍ عَلَيهِمْ﴾، مِنْ هٰذَا الوَجهِ
#
# 13723
# عَلَىٰ العَرشِ﴾ فَهٰذَا أَيضًا تَحْدِيدٌ.
#
# 15258
# مِنْهُ وَرِضْوٰنٍ﴾ [التوبة: ١٢]. وَقَالَ
#
# 15267
# بِعَذَابٍ أَلِيمٍ﴾ [التوبة: ٤٣]. فَأَثَّـرَ
#
# 15961
# زِدْنِى عِلْمًا﴾، ﴿رَبِّ زِدْنِى عِلْمًا﴾،
#
# 15964
# زِدْنِى عِلْمًا﴾، ﴿رَبِّ زِدْنِى عِلْمًا﴾
#
# 16433
# ٱلَّذِيْنَ ٱتَّبَعُوا﴾، [البقرة: ٦٦١]. والرُّسُلِ
#
# 16590
# مِنَ ٱللهِ﴾ فِي هُوِيَّتِهِ ﴿مَالَمْ
#
# 16824
# ﴿خَلْقٍ جَدِيْدٍ﴾ [سورةقٓ:٥١]. فِي عَيْنٍ
#
# 17459
# لَا يَعْلَمُونَ﴾ ﴿يَعْلَمُونَ ظَاهِـراً مِنَ
#
# 17975
# مَنْ يَشَاءُ﴾ [البقرة: ٢٧٢]. وَزَادَ
#
# 20600
# ﴿فَإِذَا سَوَّيْتُهُ﴾ [الحجر: ٩٢] نَفَخَ
#
# 21342
# الْجَمْعِ. فَـ﴿قَالَ﴾ ― وَقَدَّمَ التَّنْـزِيَهَ
#
# 21451
# ﴿إِنَّكَ أَنْتَ﴾ [المائدة: ٦١١] فَجَاءَ
#
# 21534
# بِالٱسْمِ ﴿ٱللهَ﴾ لِٱخْتِلَافِ العُبَّادِ فِي
#
# 21637
# ﴿أَقَيْمُوْا الصَّلَاةَ﴾ [البقرة: ٣٤]، فَهُوَ
#
# 21648
# ٱغْفِرْ لِيْ﴾ [الأعراف: ١٥١]، فَهُوَ
#
# 21842
# فَجَاءَ بِـ﴿كُلِّ﴾ لِلعُمُوْمِ، وَبِـ﴿شَيْءٍ﴾ لِكَونِهِ
#
# 21844
# لِلعُمُوْمِ، وَبِـ﴿شَيْءٍ﴾ لِكَونِهِ أَنْكَـرَ النَّـكِرَاتِ،
#
# 22395
# أُلقِىَ إِلَىَّكِتَابٌكَرِيمٌ﴾ [النمل: ٩٢] أَي:
#
# 22663
# ثُمَّ قَولُهُ:﴿مُلكاً﴾ [النساء: ٤٥] فَلَمْ
#
# 23653
# الحُكْمِ، ﴿وَكُلٍّا﴾ آتَاهُ ﴿ٱللهُ حُكْمًا
#
# 24055
# جَمِيْعًا مِنْهُ﴾ [الجاثية: ٣١]، وَقَدْ
#
# 24278
# زِدْنِيْ عِلْمًا﴾ [طٰه ٰ:٤١١]، فَـٱمْتَثَلَ
#
# 24511
# أُسْوَةً حَسَنَةً﴾ [الأحزاب: ١٢]، وَأَيُّ
#
# 30829
# اللهَ قَتَلَهُمْ﴾ [سورةالأنفال:٧١]. وَمَا قَتَلَهُمْ
#
# 31348
# ﴿لَطِيفًا خَبِيرًا﴾. سُمِّيَ بِهِمَا اللهُ
#
# 32037
# إِلَىٰ إِلٰهِكَ﴾ فَسَمَّاهُإِلٰهًا بِطَرِيقِ التَّنْبِيهِ
#
# 32048
# الإِلٰهِيَّةِ. ﴿لَأُحَـرِّقَنَّهُ﴾ فَإِنَّ حَيَوَانِيَّةَ الإِنْسَانِ
#
# 33018
# فَطْـرَةِ ﴿بَلَىٰ﴾، فَـكَانَ مُوسَىٰ مَجْمُوعَ
#
# 35670
# شَيْءٍ عَلِيمٌ﴾، ﴿إِنْكُنْتُمْ تَعْقِلُوْنَ﴾ أَي:
#
# 38845
# ٱلرَّحْمٰنِ ٱلرَّحِيْمِ﴾، يَقُوْلُ اللهُ: «ذَكَرَنِي
#
# 38855
# رَبِّ ٱلعَـٰلَمِيْنَ﴾، يَقُوْلُ اللهُ: «حَمِدَنِي
#
# 38863
# ﴿ٱلرَّحْمٰنِ ٱلرَّحِيْمِ﴾، يَقُوْلُ اللهُ: «أَثْنَىٰ
#
# 38873
# يَوْمِ الدِّيْنِ﴾، يَقُوْلُ اللهُ: «مَجَّدَنِي
#
# 38895
# وَإِيَّاكَ نَسْتَعِْيْنُ﴾، يَقُوْلُ اللهُ: «هٰذِهِ
#
# 38926
# ٱلضَّـآ لِّيْنَ﴾، يَقُوْلُ الله: «فَهٰؤُلَاءِ

# %%
fusus.iloc[3339].word.split('!')[0][:-1]
# Out:
# 'الأَولِيَاءِ'

# %%
fusus[(fusus.page==391)&(fusus.line==1)]
# Out:
#        page  line  column  span direction  left  top  right  bottom  \
# 37830   391     1       1     1         r   320   87    402     108
# 37831   391     1       1     1         r   283   87    320     108
# 37832   391     1       1     1         r   269   87    283     108
# 37833   391     1       1     1         r   237   87    269     108
# 37834   391     1       1     1         r   186   87    231     108
# 37835   391     1       1     1         r   170   87    186     108
# 37836   391     1       1     1         r   118   87    168     108
# 37837   391     1       1     1         r    83   87    118     108
#
#                       word       short haspunct punctAfter punctBefore  \
# 37830  مُذَكَّرٌ―وَعَادَةُ  مذكر―وعادة        ―
# 37831            العَـرَبِ       العرب
# 37832                 أَنْ          أن
# 37833            تُغَلِّبَ        تغلب
# 37834          التّذَكِيرَ     التذكير
# 37835               عَلَىٰ         على
# 37836           التَأنِيثِ     التأنيث
# 37837           فَتَقُولُ:       فتقول                   :
#
#       QunawiMS poetryMeter  poetryVerse  fass lwcvl quran
# 37830      75a                     <NA>    27
# 37831      75a                     <NA>    27
# 37832      75a                     <NA>    27
# 37833      75a                     <NA>    27
# 37834      75a                     <NA>    27
# 37835      75a                     <NA>    27
# 37836      75a                     <NA>    27
# 37837      75a                     <NA>    27

# %%
def ChangeQuran(r,s,a):
    fusus.iloc[r, fusus.columns.get_loc("quran")] = str(s)+":"+str(a)
    fusus.iloc[r, fusus.columns.get_loc("word")] = fusus.iloc[r].word.split('[')[0]
    fusus.iloc[r, fusus.columns.get_loc("short")] = fusus.iloc[r].short.split('[')[0]
    if fusus.iloc[r].haspunct[0]==abc.QURANOPEN:
        fusus.iloc[r, fusus.columns.get_loc("haspunct")] = abc.QURANOPEN+abc.QURANCLOSE
    else:
        fusus.iloc[r, fusus.columns.get_loc("haspunct")] = abc.QURANCLOSE

# %%
fusus.iloc[3339, fusus.columns.get_loc("word")] = fusus.iloc[3339].word.split('!')[0][:-1]
fusus.iloc[3339, fusus.columns.get_loc("short")] = fusus.iloc[3339].short.split('!')[0][:-1]
fusus.iloc[3339, fusus.columns.get_loc("haspunct")] = ""
fusus.iloc[3339, fusus.columns.get_loc("punctAfter")] = "؟!"
# fusus.iloc[13997, fusus.columns.get_loc("haspunct")] = ""
# fusus.iloc[13998, fusus.columns.get_loc("haspunct")] = ""
# fusus.iloc[13998, fusus.columns.get_loc("punctAfter")] = ":"
# fusus.iloc[13997, fusus.columns.get_loc("punctAfter")] = "؛"

# %%
someMore = fusus[(fusus.quran=="")&(fusus.short.str.contains('\['))&(fusus.short.str.contains('\]'))&(fusus.short.str.contains(abc.QURANCLOSE))].short.str.split('\]').str[0].str.split('\[').str[1].str.replace('سورة','').str.replace('،','').str.replace('اقتباس','').tolist()

# %%
contentMore = []
for x in someMore:
    sura = ""
    aya = ""
    for i in x:
        if i in abc.LETTERS:
            sura += i
        elif i in abc.NUMBERS:
            aya = i+aya
    sura = abc.QURAN_SURAS[sura] 
    aya = int(str(list(map(int, re.findall(r'\d+', aya)))[0]))
    contentMore.append(str(sura)+":"+str(aya))

# %%
for i in range(len(indexMore)):
    fusus.iloc[indexMore[i], fusus.columns.get_loc("quran")] = contentMore[i]
    fusus.iloc[indexMore[i], fusus.columns.get_loc("word")] = fusus.iloc[indexMore[i]].word.split('[')[0]
    fusus.iloc[indexMore[i], fusus.columns.get_loc("short")] = fusus.iloc[indexMore[i]].short.split('[')[0]
    if fusus.iloc[indexMore[i]].haspunct[0]==abc.QURANOPEN:
        fusus.iloc[indexMore[i], fusus.columns.get_loc("haspunct")] = abc.QURANOPEN+abc.QURANCLOSE
    else:
        fusus.iloc[indexMore[i], fusus.columns.get_loc("haspunct")] = abc.QURANCLOSE

# %%
fusus.to_csv('fusus.csv',index=False)

# %%
from pandasgui import show

# %%
fusus.iloc[413].word[1:]
# Out:
# 'كَمَا'

# %%
fusus[fusus.haspunct.str.contains("﴾")]
# Out:
#        page  line  column  span direction  left  top  right  bottom  \
# 22498   245    17       1     1         r   320  503    373     524
#
#                    word        short haspunct punctAfter punctBefore QunawiMS  \
# 22498  قَولُهُ:﴿مُلكاً﴾  قوله:﴿ملكا﴾      :﴿﴾                             46a
#
#       poetryMeter  poetryVerse  fass lwcvl quran
# 22498                     <NA>    16        4:54

# %%
fusus.iloc[13424, fusus.columns.get_loc("word")] = fusus.iloc[13424].word[:-1]
fusus.iloc[13424, fusus.columns.get_loc("short")] = fusus.iloc[13424].short[:-1]
fusus.iloc[13424, fusus.columns.get_loc("haspunct")] = ""
fusus.iloc[13425, fusus.columns.get_loc("punctAfter")] += "―"
# fusus.iloc[25919, fusus.columns.get_loc("word")] = ""
# fusus.iloc[25920, fusus.columns.get_loc("punctAfter")] += "―"
# fusus.iloc[28041, fusus.columns.get_loc("word")] = ""
# fusus.iloc[28042, fusus.columns.get_loc("punctAfter")] += "―"
# fusus.iloc[28046, fusus.columns.get_loc("word")] = ""
# fusus.iloc[28047, fusus.columns.get_loc("punctAfter")] += "―"

# fusus.iloc[28059, fusus.columns.get_loc("word")] = ""
# fusus.iloc[28060, fusus.columns.get_loc("punctAfter")] += "―"
# fusus.iloc[28063, fusus.columns.get_loc("word")] = ""
# fusus.iloc[28064, fusus.columns.get_loc("punctAfter")] += "―"

# %%
fusus.iloc[37766].short[:-1]
# Out:
# 'النساء'

# %%
fusus.haspunct.unique().tolist()
# Out:
# ['', ':﴿', '؟﴿', ':﴿﴾', '―']
