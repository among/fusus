# %% [markdown]
# # Annotating the Fusus for Quran citations
# All citations from the quran seem to be cited accurately by the edition. The task is, thus, to extract the information from the `word` column. This is not easy since there is no one single pattern that picks up all Quran citations. Let's explore.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import arabicABC as abc

# %%
fusus = pd.read_csv('fusus.csv', dtype={"page":int, "line":int, "column":int, "span":int, "direction": str, 
                                        "left":"Int64", "top":"Int64", "right":"Int64", "bottom":"Int64", 
                                        "word":str, "short":str, "haspunct":str, "punctAfter":str, "punctBefore":str, 
                                        "QunawiMS":str, "poetryMeter":str, "poetryVerse":"Int64", "fass":"Int64", "lwcvl":str, "quran":str})
fusus.word = fusus.word.fillna('')
fusus.short = fusus.short.fillna('')
fusus.haspunct = fusus.haspunct.fillna('')
fusus.punctAfter = fusus.punctAfter.fillna('')
fusus.punctBefore = fusus.punctBefore.fillna('')
fusus.poetryMeter = fusus.poetryMeter.fillna('')
fusus.lwcvl = fusus.lwcvl.fillna('')
fusus.quran = fusus.quran.fillna('')

# %%
fusus.head()
# Out:
#    page  line  column  span direction  left  top  right  bottom         word  \
# 0     8     2       1     1         r   356  197    384     218     الحَمْدُ
# 1     8     2       1     1         r   341  197    356     218        لِلهِ
# 2     8     2       1     1         r   312  197    341     218  مُـنَـزِّلِ
# 3     8     2       1     1         r   274  197    312     218     الحِكَمِ
# 4     8     2       1     1         r   260  197    274     218       عَلَىٰ
#
#    short haspunct punctAfter punctBefore QunawiMS poetryMeter  poetryVerse  \
# 0  الحمد                                       1b                     <NA>
# 1    لله                                       1b                     <NA>
# 2   منزل                                       1b                     <NA>
# 3  الحكم                                       1b                     <NA>
# 4    على                                       1b                     <NA>
#
#    fass lwcvl quran
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %% [markdown]
# ### Different elements of a Quran citation

# %%
print(fusus[fusus.word.str.contains(pat=abc.QURANCLOSE)].shape)
print(fusus[fusus.word.str.contains(pat=abc.QURANOPEN)].shape)
print(fusus[fusus.word.str.contains(pat="\[")].shape)
print(fusus[fusus.word.str.contains(pat="\]")].shape)
print(fusus[fusus.short.str.contains(pat="\[")].shape)
print(fusus[fusus.short.str.contains(pat="\]")].shape)
print(fusus[fusus.word.str.contains(pat="سورة")].shape)
# Out:
# (520, 20)
# (520, 20)
# (582, 20)
# (581, 20)
# (505, 20)
# (504, 20)
# (485, 20)

# %% [markdown]
# ### Generally you would think that ﴾﴿ indicates a Quran citation.  ﴿ gives 520 and ﴾ gives 520. So there seem to be 520 Quran citations.
# But note that the chapter titles were also adorned with these brackets (which have since been cleaned).

# %%
fusus[fusus.word.str.contains(pat=abc.QURANOPEN)]
# Out:
# page                       28
# line                        8
# column                      1
# span                        1
# direction                   r
# left                      307
# top                       278
# right                     345
# bottom                    299
# word           ﴿يٰـٓـأَيُّهَا
# short                  ﴿يأيها
# haspunct                    ﴿
# punctAfter
# punctBefore
# QunawiMS                   5b
# poetryMeter
# poetryVerse              <NA>
# fass                        1
# lwcvl
# quran
# Name: 2003, dtype: object

# %%
fusus[fusus.word.str.contains(pat=abc.QURANCLOSE)]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 432      16     6       1     1         r   79.0  217.0  133.0  238.0
# 819      20     6       1     1         r  192.0  217.0  219.0  238.0
# 1768     26    11       1     1         r  273.0  347.0  308.0  368.0
# 2020     28     9       1     1         r  138.0  304.0  225.0  325.0
# 2024     28    10       1     1         r  236.0  330.0  325.0  351.0
# ...     ...   ...     ...   ...       ...    ...    ...    ...    ...
# 40982   405     4       1     1         r   79.0  165.0  157.0  186.0
# 41127   407     2       1     1         r  173.0  113.0  262.0  134.0
# 41177   407     7       1     1         r  232.0  243.0  331.0  264.0
# 41187   407     8       1     1         r  193.0  269.0  295.0  290.0
# 41363   409     5       1     1         r  165.0  191.0  266.0  212.0
#
#                             word                 short haspunct punctAfter  \
# 432            الأَمْـرُكُلُّهُ﴾             الأمركله﴾        ﴾
# 819                     فِيهَا﴾،                فيها﴾،       ﴾،
# 1768                 بِيَدَىَّ﴾،                بيدى﴾،       ﴾،
# 2020   وَنِسَـآءً﴾.[سورةالنساء:   ونساء﴾.[سورةالنساء:     ﴾.[:
# 2024    رَبَّـكُمْ﴾؛[سورةالنساء:    ربكم﴾؛[سورةالنساء:     ﴾؛[:
# ...                          ...                   ...      ...        ...
# 40982       مَعَاذِيْـرَهُ﴾[سورة         معاذيره﴾[سورة       ﴾[
# 41127  وَتَسْبِيحَهُ﴾[سورةالنور:   وتسبيحه﴾[سورةالنور:      ﴾[:
# 41177   بِحَمْدِهِ﴾[سورةالإسراء:   بحمده﴾[سورةالإسراء:      ﴾[:
# 41187  ﴿بِحَمْدِهِ﴾[سورةالإسراء:  ﴿بحمده﴾[سورةالإسراء:     ﴿﴾[:
# 41363  ٱلسَّبِيْلَ﴾[سورةالأحزاب:  ٱلسبيل﴾[سورةالأحزاب:      ﴾[:
#
#       punctBefore QunawiMS poetryMeter poetryVerse fass
# 432                     2b
# 819                     3a
# 1768                    5a
# 2020                    5b
# 2024                    5b
# ...           ...      ...         ...         ...  ...
# 40982                  77b
# 41127                  77b
# 41177                  78a
# 41187                  78a
# 41363                  78a
#
# [520 rows x 18 columns]

# %%
chapterPages = fusus.groupby(['fass']).first().page.tolist()

# %%
for i in range(40952,41119):
    fusus.iloc[i, fusus.columns.get_loc("word")] = ""
    fusus.iloc[i, fusus.columns.get_loc("short")] = ""

# %%
fusus[(fusus.page==58)&(fusus.line==3)]
# Out:
#       page  line  column  span direction  left  top  right  bottom  \
# 5217    58     3       1     1         r   366  139    402     160
# 5218    58     3       1     1         r   336  139    366     160
# 5219    58     3       1     1         r   285  141    336     159
# 5220    58     3       1     1         r   255  143    270     158
# 5221    58     3       1     1         r   207  139    255     160
# 5222    58     3       1     1         r   181  139    207     160
# 5223    58     3       1     1         r   100  139    181     160
#
#                      word             short haspunct punctAfter punctBefore  \
# 5217           أُخْرِجَتْ             أخرجت
# 5218           لِلنَّاسِ﴾            للناس﴾        ﴾
# 5219         [سورةالبقرة:      [سورةالبقرة:       [:
# 5220                 ٠١١]              ٠١١]     ٠١١]
# 5221         فَــ﴿لَـيْسَ             ف﴿ليس        ﴿
# 5222           كَمِثْلِهِ             كمثله
# 5223  شَيءٌ﴾[سورةالشورىٰ:  شيء﴾[سورةالشورى:      ﴾[:
#
#      QunawiMS poetryMeter  poetryVerse  fass lwcvl quran
# 5217      12a                     <NA>     3
# 5218      12a                     <NA>     3
# 5219      12a                     <NA>     3
# 5220      12a                     <NA>     3
# 5221      12a                     <NA>     3
# 5222      12a                     <NA>     3
# 5223      12a                     <NA>     3

# %%
fusus[fusus.short=="فحققت"]
# Out:
#     page  line  column  span direction  left  top  right  bottom         word  \
# 92    10     2       1     1         r   348  113    384     134  فَحَقَّقْتُ
#
#     short haspunct punctAfter punctBefore QunawiMS poetryMeter  poetryVerse  \
# 92  فحققت                                       1b                     <NA>
#
#     fass lwcvl quran
# 92     0

# %%
fusus.iloc[39000, fusus.columns.get_loc("poetryVerse")] = 1
fusus.iloc[39000, fusus.columns.get_loc("poetryMeter")] = fusus.iloc[38999, fusus.columns.get_loc("word")]

fusus.iloc[38999, fusus.columns.get_loc("word")] = ""
fusus.iloc[38999, fusus.columns.get_loc("short")] = ""

# %%
fusus.to_csv('fusus.csv',index=False)

# %% [markdown]
# ### Note that in the edition it gives the sura number. This has not come through in the extraction and it is not at all available.
# Some minor cleaning was done: in two cases brackets were left in, and in two cases normal brackets were used instead of Quran-brackets.

# %%
98+357+10+6+6+13+14+14+17
# Out:
# 535

# %% [markdown]
# ### Does the word `سورة` always follow a Quran-close-bracket?
# 98 have in the same row. 357 in the next. 10 in 2 rows down. 6 in 3 rows down. 6 in 4 rows down. 13 in 5 rows down. 14 in 6 rows down. 14 in 7 rows down. 17 in 8 rows down. Which is 535, or 15 more than the actual total number, which shows there is already some crude overlap

# %%
fusus[fusus.word.str.contains(pat=abc.QURANCLOSE) & fusus.word.str.contains(pat='سورة')]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 2020     28     9       1     1         r  138.0  304.0  225.0  325.0
# 2024     28    10       1     1         r  236.0  330.0  325.0  351.0
# 5132     56     8       1     1         r  173.0  285.0  262.0  306.0
# 5137     57     1       1     1         r  284.0   87.0  372.0  108.0
# 5181     57     6       1     1         r  268.0  217.0  343.0  238.0
# ...     ...   ...     ...   ...       ...    ...    ...    ...    ...
# 40982   405     4       1     1         r   79.0  165.0  157.0  186.0
# 41127   407     2       1     1         r  173.0  113.0  262.0  134.0
# 41177   407     7       1     1         r  232.0  243.0  331.0  264.0
# 41187   407     8       1     1         r  193.0  269.0  295.0  290.0
# 41363   409     5       1     1         r  165.0  191.0  266.0  212.0
#
#                             word                 short haspunct punctAfter  \
# 2020   وَنِسَـآءً﴾.[سورةالنساء:   ونساء﴾.[سورةالنساء:     ﴾.[:
# 2024    رَبَّـكُمْ﴾؛[سورةالنساء:    ربكم﴾؛[سورةالنساء:     ﴾؛[:
# 5132          شَيءٌ﴾[سورةالشورى:      شيء﴾[سورةالشورى:      ﴾[:
# 5137     ٱلبَصِيْرُ﴾[سورةالشورى:   ٱلبصير﴾[سورةالشورى:      ﴾[:
# 5181        غَفَّارًا﴾.[سورةنوح:      غفارا﴾.[سورةنوح:     ﴾.[:
# ...                          ...                   ...      ...        ...
# 40982       مَعَاذِيْـرَهُ﴾[سورة         معاذيره﴾[سورة       ﴾[
# 41127  وَتَسْبِيحَهُ﴾[سورةالنور:   وتسبيحه﴾[سورةالنور:      ﴾[:
# 41177   بِحَمْدِهِ﴾[سورةالإسراء:   بحمده﴾[سورةالإسراء:      ﴾[:
# 41187  ﴿بِحَمْدِهِ﴾[سورةالإسراء:  ﴿بحمده﴾[سورةالإسراء:     ﴿﴾[:
# 41363  ٱلسَّبِيْلَ﴾[سورةالأحزاب:  ٱلسبيل﴾[سورةالأحزاب:      ﴾[:
#
#       punctBefore QunawiMS poetryMeter poetryVerse fass
# 2020                    5b
# 2024                    5b
# 5132                   11b
# 5137                   11b
# 5181                   11b
# ...           ...      ...         ...         ...  ...
# 40982                  77b
# 41127                  77b
# 41177                  78a
# 41187                  78a
# 41363                  78a
#
# [98 rows x 18 columns]

# %%
total = 0
for q in fusus[fusus.word.str.contains(pat=abc.QURANCLOSE)].index.tolist():
    if 'سورة' in fusus.iloc[q+1].word:
        total += 1
#         print(str(q+1) + " has " + fusus.iloc[q+1].word)
print(total)
# Out:
# 357

# %% [markdown]
# ### Another way is to look at square brackets, which seem to be used after a Quran citation.
# Here we can already find two cases in which the word `سورة` is not found.

# %%
fusus[fusus.word.str.contains(pat=abc.QURANCLOSE) & fusus.word.str.contains(pat='\[') & ~fusus.word.str.contains(pat='سورة')]
# Out:
#        page  line  column  span direction  left  top  right  bottom  \
# 39721   396    11       1     1         r   227  347    303     368
#
#                          word             short haspunct punctAfter  \
# 39721  أَنْفُسَهُمْ﴾[الأنعام:  أنفسهم﴾[الأنعام:      ﴾[:
#
#       punctBefore QunawiMS poetryMeter  poetryVerse  fass lwcvl quran
# 39721                  76a                     <NA>  <NA>

# %%
fusus.haspunct.unique().tolist()
# Out:
# ['',
#  '[',
#  ']',
#  '[٧٢٦',
#  ':.',
#  '―',
#  '﴿',
#  '﴾',
#  '[:',
#  '٣٢١]',
#  '﴾،',
#  '٠٣].',
#  '«»،',
#  '«».',
#  '«»',
#  '٥٧]',
#  '»،',
#  '﴾.[:',
#  '١]',
#  '﴾؛[:',
#  '٠٦]',
#  '١٣]',
#  '؟!',
#  '١٢]',
#  ':٠٥]',
#  '–',
#  '٣٥]',
#  '﴾.',
#  '٢]:',
#  '﴾[:',
#  '١١]',
#  '﴿﴾',
#  '٨]،',
#  '٩]،',
#  '٠١]',
#  ':﴿',
#  '٥–٦].',
#  '٠١١]',
#  '٥]',
#  '﴿﴾[:',
#  '٧]',
#  '﴾[',
#  '٢١]',
#  '١٢].',
#  '٦١]',
#  '٧].',
#  '٢]',
#  '٢٢]',
#  '٨٠١]',
#  '٥٨]',
#  '٣٢]',
#  '٣٣]',
#  '»؟',
#  '٣]',
#  '٤٣]',
#  '٤٢]',
#  '٠٢].',
#  '٥٢]',
#  '٦]',
#  '«»؛',
#  '٩٢]',
#  '٦٢]',
#  ':٥٥]',
#  '﴿﴾،',
#  '٧٢]',
#  '٨٢]',
#  '١٩].',
#  '﴾:[:',
#  '٨٨]',
#  '٧٥].',
#  '٥٣]',
#  '٥٣]،',
#  '١]،',
#  ':٥]،',
#  '٨٨]،',
#  '٣٢١]،',
#  '٠٦].',
#  '٧٥]،',
#  '٠٣]،',
#  '٥٧]،',
#  '[]',
#  '؟﴿',
#  '٢٠١].',
#  '٧٠١].',
#  ']،',
#  '٧٦]',
#  '٩٤١]،',
#  '؟»',
#  '٢٤]',
#  '٩٤١].',
#  '﴾؛',
#  '﴿﴾:',
#  '»:',
#  '٤٦١].',
#  '.:',
#  '٤].',
#  '٢٠١]،',
#  '٤٠١‐٥٠١]،',
#  '٣٤].',
#  '٦٠١]',
#  '٨٣].',
#  '٩٢].',
#  ':٠٥]،',
#  '٨٢–٩٢]',
#  '[]]',
#  '٨]',
#  '٧٤].',
#  '٤٥].',
#  '٢٣١]،',
#  '٩١]،',
#  '٧٢].',
#  '٧٢]،',
#  '٩١]؛',
#  '٦١]،',
#  '٩٤١]',
#  '٢١١]،',
#  ':«',
#  '٤]',
#  '٥].',
#  '٥]،',
#  '٠٠١]،',
#  '٠٠١]',
#  '٥٤]،',
#  '٦٤].',
#  '٣٢١].',
#  '«»؟',
#  '٣].',
#  '٥١].',
#  '٦٥].',
#  '٣٥؛',
#  '٢١]،',
#  '٦٦].',
#  '٦٨]',
#  '٢٢].',
#  '٢١].',
#  '..',
#  '٤٢]،',
#  '٥٢]،',
#  '٣٣].',
#  '[٦٨٥].',
#  '٦٥]،',
#  '٧٤]،',
#  '٩٢]،',
#  '؛:',
#  '﴾[:٩]،',
#  '٥١١].',
#  '٥١١]',
#  '٠٤]',
#  '٢٨]،',
#  '٥٦].',
#  '٧٦].',
#  '٨٣]،',
#  '٩٣]',
#  '٤٣].',
#  '؟».',
#  ':٠٥].',
#  ':٤١١]',
#  '٧٣]',
#  '٢٢]،',
#  '٧٣].',
#  '٧٣]،',
#  '٦٦١].',
#  '٧٤]',
#  '٥٢].',
#  '٤٠١]،',
#  '٠٨]',
#  '٠٨]،',
#  '٤٥]',
#  '٤٥]،',
#  '٦‐٧].',
#  '٨٨؛',
#  '٥٥١]،',
#  '٧]،',
#  '٩].',
#  '٢٧٢].',
#  '٠٦١]',
#  '٣٥٢].',
#  '٥٥].',
#  '١٧].',
#  '٩٥٢].',
#  '٠٦٢]،',
#  '٩٥٢]،',
#  '٨٥٢]،',
#  '٨٢].',
#  ':٤١١].',
#  '٢٤]،',
#  '«»:',
#  '٩١]',
#  '١٧١].',
#  '٩٤].',
#  '٠١١]،',
#  '٧١]،',
#  '٧٤]؟',
#  '٢٢١]',
#  '١٣].',
#  '٦١١].',
#  '٦١١]',
#  '٦١١]،',
#  '٧١١]،،',
#  '٧١١]',
#  '٧١١].',
#  '٧١١]،',
#  '٣٤]،',
#  '١٥١]،',
#  '﴾[٧١١]',
#  '٨١١].',
#  '٨١١]',
#  '٠٣]',
#  '﴿ی',
#  ':﴿﴾',
#  '٦٥١]،',
#  '١١]،',
#  '……………',
#  '٩٧]',
#  '٩٧].',
#  '٤٤]',
#  '٢٤].',
#  '٤٤].',
#  '٢٢١؛',
#  '٨٤]،',
#  '٠٩]',
#  '٨٤].',
#  '٤٤]،',
#  '٤]،',
#  '٦٣]،',
#  '٣١]،',
#  '٩٣]،',
#  '٩٣].',
#  ':٤١١]،',
#  '١٢]،',
#  '٤٨]،',
#  '٤٢١]',
#  '٦٢].',
#  '٠٩].',
#  '—',
#  '١٦].',
#  '٠٤]؟',
#  '٠٤]؛',
#  '٩٧١]',
#  '٩٦]',
#  '٠٥]',
#  '٨١١٦].',
#  '٦٦]،',
#  '٦٦]',
#  '٣،',
#  '٩٢،',
#  '١٠١]؛',
#  '٣٨‐٤٨]،',
#  '٧١،',
#  '٠٣،',
#  '١١].',
#  '«،',
#  '٦٥١].',
#  '٠٨١].',
#  '٤٢١].',
#  '٤٢١]؛',
#  '٠٦]،',
#  '٦٨١]',
#  '٩٦٢].',
#  '٧١].',
#  '٦١].',
#  '٧‐٨].',
#  '٦٢]،',
#  '٣١].',
#  '﴾[٠١١]',
#  '٣٥]،',
#  ':٤٩]،',
#  '٠٥١].',
#  ':٥٩]؟',
#  '٢٣].',
#  '٣٢]،',
#  '٣٠١]',
#  '٣٠١].',
#  '٢٢١]،',
#  '٥].:',
#  '٧٨]',
#  ':٠٤].',
#  '!»',
#  '٨٦]،',
#  '٦٧]،',
#  '٨٧]،',
#  '﴾؟',
#  '٤٢].',
#  '١٥]،',
#  '٨٢]،',
#  '٠٣]؟',
#  '١٣]،',
#  '٢٣]،',
#  '٠٧]،',
#  ':٢٧]',
#  '٢]﴿',
#  '٨٩]،',
#  '٨٩].',
#  '٢٩].',
#  '﴾[:٢٩]،',
#  '٩٢؛',
#  '٢٧].',
#  '…»',
#  '٨٢٢]،',
#  '٥١]',
#  '٦٥١]',
#  '٦٢،',
#  '٨٢،',
#  '٢٥]',
#  '٢٥١].',
#  '٢،',
#  '٥٤]',
#  '٥٤].',
#  '٤١–٥١]،',
#  '١٤]',
#  '[…]',
#  '[؟]',
#  '[٠٣٦']

# %%
fusus[(fusus.short.str.contains(pat="آله]"))]
# Out:
#     page  line  column  span direction  left  top  right  bottom    word  \
# 44     9     4       1     1         r   191  165    206     186  آلِهِ]
# 67     9     6       1     1         r   208  217    223     238  آلِهِ]
#
#    short haspunct punctAfter punctBefore QunawiMS poetryMeter  poetryVerse  \
# 44  آله]        ]                              1b                     <NA>
# 67  آله]        ]                              1b                     <NA>
#
#     fass lwcvl quran
# 44     0
# 67     0

# %%
fusus.iloc[6788, fusus.columns.get_loc("short")]
# Out:
# 'ما'

# %%
for i in fusus[(fusus.short.str.contains(pat="\]"))&(fusus.page==31)].index:
    fusus.iloc[i, fusus.columns.get_loc("word")] = ""
    fusus.iloc[i, fusus.columns.get_loc("short")] = ""
    fusus.iloc[i, fusus.columns.get_loc("haspunct")] = ""

# %%
fusus.iloc[2295]
# Out:
# page             31
# line              5
# column            1
# span              1
# direction         r
# left            358
# top             211
# right           374
# bottom          232
# word              ]
# short             ]
# haspunct
# punctAfter
# punctBefore
# QunawiMS         6a
# poetryMeter
# poetryVerse    <NA>
# fass           <NA>
# lwcvl
# quran
# Name: 2295, dtype: object

# %%
fusus['word'].replace("", np.nan, inplace=True)
fusus.dropna(subset=['word'],inplace=True)
fusus[(fusus.page==410)]
# Out:
# Empty DataFrame
# Columns: [page, line, column, span, direction, left, top, right, bottom, word, short, haspunct, punctAfter, punctBefore, QunawiMS, poetryMeter, poetryVerse, fass, lwcvl, quran]
# Index: []

# %%
fusus.to_csv('fusus.csv',index=False)

# %%
fusus[(fusus.short.str.contains('\\d\]',regex=True))&(fusus.short.str.len()<5)&(fusus.short.str.contains('|'.join(abc.LETTERS)))]
# Out:
#        page  line  column  span direction  left  top  right  bottom    word  \
# 5257     58     7       1     1         r   197  243    226     264  ٥]مِنْ
# 9912    116    10       1     1         r   205  330    225     351   ٨]أَن
# 12672   144    11       1     1         r   199  347    223     368  ١]مِنْ
# 12678   144    12       1     1         r   302  373    328     394  ٢]مِنْ
# 33567   340     9       1     1         r   357  295    385     316  ٣]مَعَ
#
#       short haspunct punctAfter punctBefore QunawiMS poetryMeter  poetryVerse  \
# 5257   ٥]من       ٥]                             12a                     <NA>
# 9912   ٨]أن       ٨]                             21a                     <NA>
# 12672  ١]من       ١]                             26b                     <NA>
# 12678  ٢]من       ٢]                             26b                     <NA>
# 33567  ٣]مع       ٣]                             64b                     <NA>
#
#        fass lwcvl quran
# 5257      3
# 9912      7
# 12672     9
# 12678     9
# 33567    24

# %%
fusus.iloc[fusus[(fusus.short.str.fullmatch('\\d.*\]'))].index-1].word.str.contains(pat='\[').tolist()
# Out:
# [True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True]
