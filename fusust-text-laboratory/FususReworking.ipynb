# %% [markdown]
# # Introduction
# This folder works towards creating a 'right' csv-file of the Fusus al-hikam. Its origin is a TSV-file created by Dirk Roorda (accessed february 11) which has since then seen slight changes. This TSV-file is in turn based on the Lakhnawi edition of Ibn Arabi's Fusus al-hikam.
#
# ### Aim
# My aim to create a clean and ready file `fusus.csv`. It is to strictly encapsulate the text of Fusus al-hikam, ready to be machine-readable. As the text is groomed and cleaned, `fusus.csv` is undergoing change, with the underlying code not preserved. This is especially true for columns right of 'word'. The column 'short' is meant to be the cleanest. It has been stripped of diacritics, shaddas, tatwīl, spaces, and punctuation. The columns to the right are annotations on it.
#
# ### Credits
# Text by Ibn Arabi, copy by Sadr al-Din Qunawi (finished in the year 1233). Edition by Nizam al-Din Ahmad al-Husayni al-Lakhnawi (Beirut: 2013). First conversion by Dirk Roorda (January 2021). Finalization by Cornelis van Lit (February 2021). Mostly relying on Pandas, with some thankful use of a list of Arabic characters by Lakhdar Benzahia and Talha Javed Mukhtar for CLTK.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import arabicABC as abc

# %%
fusus = pd.read_csv('fusus.csv')
fusus = fusus.fillna('')

# %%
fusus.shape
# Out:
# (41532, 17)

# %% [markdown]
# Exploring a specific punctuation mark

# %%
punctMark = fusus[fusus['haspunct']=='٤١‐']
punctMark
# Out:
# Empty DataFrame
# Columns: [page, line, column, span, direction, left, top, right, bottom, word, short, haspunct, punctAfter, punctBefore, QunawiMS, poetryMeter, poetryVerse]
# Index: []

# %% [markdown]
# Moving punctuation from `short` to `After` and deleting from `haspunct` (aim is to get `haspunct` empty and delete it)

# %%
def SetPunctuation(row):
    position = punctMark.iloc[row] 
    punct = position.haspunct
    short = position.short
    if short[-2:] == punct:
        fusus.iloc[position.name, fusus.columns.get_loc('punctAfter')] = punct
        fusus.iloc[position.name, fusus.columns.get_loc('short')] = short.replace(punct,'')
        fusus.iloc[position.name, fusus.columns.get_loc('haspunct')] = ""

# %%
# Uncomment to set function in motion for all cases of the particular punctuation
# for i in range(0,len(punctMark)):
#     SetPunctuation(i)

# %% [markdown]
# Check results and possibly adjust details

# %%
# look at one
# look at line
fusus[(fusus['page']==67) & (fusus.line==6)]
# change one value
# fusus.iloc[8327, fusus.columns.get_loc("poetryVerse")] = "13"
# fusus.iloc[8326, fusus.columns.get_loc("haspunct")] = ""
# fusus.iloc[8326, fusus.columns.get_loc("word")] = ""
# fusus.iloc[8326, fusus.columns.get_loc("short")] = ""
# Out:
#       page  line  column  span direction   left    top  right bottom  \
# 6120    67     6       1     1         r  360.0  217.0  385.0  238.0
# 6121    67     6       1     1         r  333.0  217.0  360.0  238.0
# 6122    67     6       1     1         r  268.0  217.0  333.0  238.0
# 6123    67     6       1     1         r  235.0  221.0  249.0  236.0
# 6124    67     6       1     1         r  216.0  217.0  235.0  238.0
# 6125    67     6       1     1         r  169.0  217.0  216.0  238.0
# 6126    67     6       1     1         r  132.0  217.0  169.0  238.0
# 6127    67     6       1     1         r  113.0  217.0  132.0  238.0
# 6128    67     6       1     1         r   82.0  217.0  113.0  238.0
#
#                word         short haspunct punctAfter punctBefore QunawiMS  \
# 6120         ﴿رَبِّ           ﴿رب        ﴿                             13b
# 6121        ٱغْفِرْ          ٱغفر                                      13b
# 6122  لِى﴾[سورةنوح:  لى﴾[سورةنوح:      ﴾[:                             13b
# 6123            ٨٢]           ٨٢]      ٨٢]                             13b
# 6124           أَي:            أي                   :                  13b
# 6125   ٱسْتُـرْنِي،        ٱسترني                   ،                  13b
# 6126     وَٱسْتُـرْ         وٱستر                                      13b
# 6127           مِنْ            من                                      13b
# 6128       أَجْلِي،          أجلي                   ،                  13b
#
#      poetryMeter poetryVerse fass
# 6120
# 6121
# 6122
# 6123
# 6124
# 6125
# 6126
# 6127
# 6128

# %% [markdown]
# This code changes title lines into tagged titles.

# %%
fusus.iloc[y, fusus.columns.get_loc("short")] = fusus.iloc[y-1, fusus.columns.get_loc("short")] + fusus.iloc[y, fusus.columns.get_loc("short")]
fusus.iloc[y, fusus.columns.get_loc("word")] = fusus.iloc[y-1, fusus.columns.get_loc("word")] + fusus.iloc[y, fusus.columns.get_loc("word")]
fusus.iloc[y-1, fusus.columns.get_loc("short")] = ""
fusus.iloc[y-1, fusus.columns.get_loc("word")] = ""
fusus.iloc[y-1, fusus.columns.get_loc("haspunct")] = ""
fusus[(fusus['page']==p) & (fusus.line==l)]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 38383   377     1       1     1         r  354.0  108.0  376.0  136.0
# 38384   377     1       1     1         r  308.0  108.0  354.0  136.0
# 38385   377     1       1     1         r  268.0  108.0  308.0  136.0
# 38386   377     1       1     1         r  232.0  108.0  268.0  136.0
# 38387   377     1       1     1         r  204.0  108.0  220.0  136.0
# 38388   377     1       1     1         r  165.0  108.0  204.0  136.0
# 38389   377     1       1     1         r  105.0  108.0  165.0  136.0
#
#                   word    short haspunct punctAfter punctBefore QunawiMS  \
# 38383                                                                72b
# 38384       [٧٢]﴿فَصُّ  [٧٢]﴿فص        ﴿                             72b
# 38385         حِكْمَةٍ     حكمة                                      72b
# 38386     فَـرْدِيَّةٍ    فردية                                      72b
# 38387              فِي       في                                      72b
# 38388         كَلِمَةٍ     كلمة                                      72b
# 38389  مُحَمَّدِيَّةٍ﴾  محمدية﴾        ﴾                             72b
#
#       poetryMeter poetryVerse fass
# 38383
# 38384
# 38385
# 38386
# 38387
# 38388
# 38389

# %%
p = 377
l = 1
y = fusus[(fusus['page']==p) & (fusus.line==l)].iloc[0].name+1
d = 5
fusus[(fusus['page']==p) & (fusus.line==l)]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 38383   377     1       1     1         r  354.0  108.0  376.0  136.0
# 38384   377     1       1     1         r  308.0  108.0  354.0  136.0
# 38385   377     1       1     1         r  268.0  108.0  308.0  136.0
# 38386   377     1       1     1         r  232.0  108.0  268.0  136.0
# 38387   377     1       1     1         r  204.0  108.0  220.0  136.0
# 38388   377     1       1     1         r  165.0  108.0  204.0  136.0
# 38389   377     1       1     1         r  105.0  108.0  165.0  136.0
#
#                   word    short haspunct punctAfter punctBefore QunawiMS  \
# 38383             [٧٢]     [٧٢]     [٧٢]                             72b
# 38384           ﴿فَصُّ      ﴿فص        ﴿                             72b
# 38385         حِكْمَةٍ     حكمة                                      72b
# 38386     فَـرْدِيَّةٍ    فردية                                      72b
# 38387              فِي       في                                      72b
# 38388         كَلِمَةٍ     كلمة                                      72b
# 38389  مُحَمَّدِيَّةٍ﴾  محمدية﴾        ﴾                             72b
#
#       poetryMeter poetryVerse fass
# 38383
# 38384
# 38385
# 38386
# 38387
# 38388
# 38389

# %% [markdown]
# Which punctuation remains? We find out below

# %%
fusus.haspunct.value_counts().to_frame().head(60)
# Out:
#        haspunct
#           39041
# ﴿           469
# ﴾           346
# [:          317
# ―           300
# [            89
# «»           72
# ﴾[:          67
# »،           46
# «»،          46
# ﴾،           31
# ﴿﴾           29
# «».          23
# ﴾[           15
# ]            12
# ١١]          12
# ٨٢]           9
# ٤٢]           9
# ٧١١]          8
# :.            8
# ٧٢]           8
# []            8
# ﴿﴾[:          7
# ٦٢]           7
# ﴾.[:          7
# —             6
# ٤٤]           6
# ٩٢]           6
# ٨١١].         6
# :﴿            6
# ٦١١]          5
# ٥]            5
# ٣٥]           5
# ٧١١]،         5
# ٠٣]،          5
# :٠٥]،         5
# ٧٣]،          5
# ٢٢١]          5
# ٩٤].          5
# ٤].           4
# ٩].           4
# ٣٥؛           4
# ٣٣]           4
# ٣٢١]          4
# ٣].           4
# ٥١].          4
# ٧].           4
# ٥]،           4
# ٣٢]           4
# ١]            4
# ٥٢]           4
# ﴿﴾،           4
# ٤٥]           4
# ٥٨]           3
# ٣٤]،          3
# ٠٨]،          3
# ٢]            3
# ٧٣].          3
# ﴾.            3
# ٦٥].          3

# %%
puncs = fusus[fusus['haspunct']!=''].haspunct.unique().tolist()

# %%
fusus[(fusus['haspunct']!='')&(fusus['haspunct']!='﴿')&(fusus['haspunct']!='﴾')]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 43        9     4       1     1         r  206.0  165.0  219.0  186.0
# 44        9     4       1     1         r  191.0  165.0  206.0  186.0
# 58        9     5       1     1         r  104.0  191.0  124.0  212.0
# 59        9     5       1     1         r   79.0  191.0  104.0  212.0
# 66        9     6       1     1         r  223.0  217.0  236.0  238.0
# ...     ...   ...     ...   ...       ...    ...    ...    ...    ...
# 41470   410     2       1     1         r  134.0  115.0  190.0  133.0
# 41484   410     4       1     1         r  242.0  167.0  242.0  185.0
# 41495   410     5       1     1         r  196.0  193.0  196.0  211.0
# 41527   410     9       1     1         r  278.0  297.0  294.0  315.0
# 41528   410     9       1     1         r  261.0  297.0  278.0  315.0
#
#              word    short haspunct punctAfter punctBefore QunawiMS  \
# 43            [وَ       [و        [                              1b
# 44         آلِهِ]     آله]        ]                              1b
# 58           [٧٢٦     [٧٢٦     [٧٢٦                              1b
# 59            هـ]       ه]        ]                              1b
# 66            [وَ       [و        [                              1b
# ...           ...      ...      ...        ...         ...      ...
# 41470  [؟]صَاحِبُ  [؟]صاحب      [؟]                             78a
# 41484           ―        ―        ―                             78a
# 41495           ―        ―        ―                             78a
# 41527        [٠٣٦     [٠٣٦     [٠٣٦                             78a
# 41528         هـ]       ه]        ]                             78a
#
#       poetryMeter poetryVerse fass
# 43
# 44
# 58
# 59
# 66
# ...           ...         ...  ...
# 41470
# 41484
# 41495
# 41527
# 41528
#
# [1676 rows x 18 columns]

# %%
for punc in puncs:
    times = fusus[fusus['haspunct']==punc].shape[0]
    print(punc + " " + str(times))
# Out:
# [ 89
# ] 12
# [٧٢٦ 1
# [١]﴿ 1
# ﴾ 372
# :. 8
# ― 300
# ﴿ 487
# [: 317
# ٣٢١] 4
# ﴾، 31
# ٠٣]. 1
# «»، 46
# «». 23
# «» 72
# ٥٧] 2
# »، 46
# ﴾.[: 7
# ١] 4
# ﴾؛[: 3
# [١] 1
# [٢] 2
# [٣] 1
# [٤] 1
# [٥] 1
# [٦] 1
# [٧] 1
# [٨] 1
# [٩] 1
# [٠١] 2
# [١١] 2
# [٢١] 2
# [٣١] 2
# [٤١] 2
# [٥١] 2
# [٦١] 2
# [٧١] 2
# [٨١] 2
# [٩١] 2
# [٠٢] 2
# [١٢] 2
# [٢٢] 2
# [٣٢] 2
# [٤٢] 2
# [٥٢] 2
# [٦٢] 2
# [٧٢] 2
# ٠٦] 1
# ١٣] 2
# ؟! 1
# ١٢] 2
# :٠٥] 1
# – 2
# [٣]﴿ 1
# ٣٥] 5
# ﴾. 3
# ٢]: 1
# ﴾[: 67
# ١١] 12
# ﴿﴾ 29
# ٨]، 1
# ٩]، 3
# ٠١] 2
# :﴿ 6
# ٥–٦]. 1
# ٠١١] 3
# ٥] 5
# ﴿﴾[: 7
# ٧] 1
# ﴾[ 15
# ٢١] 2
# ١٢]. 2
# ٦١] 3
# ٧]. 4
# ٢] 3
# ٢٢] 1
# ٨٠١] 2
# ٥٨] 3
# ٣٢] 4
# ٣٣] 4
# »؟ 2
# ٣] 3
# ٤٣] 2
# ٤٢] 9
# ٠٢]. 1
# ٥٢] 4
# ٦] 2
# «»؛ 3
# ٩٢] 6
# ٦٢] 7
# ﴾.() 1
# :٥٥] 1
# ﴿﴾، 4
# ٧٢] 8
# ٨٢] 9
# ١٩]. 1
# ﴾:[: 1
# ٨٨] 1
# [٤]﴿ 1
# ٧٥]. 3
# ٥٣] 1
# ٥٣]، 1
# ١]، 2
# :٥]، 1
# ٨٨]، 1
# ٣٢١]، 3
# ٠٦]. 1
# ٧٥]، 1
# ٠٣]، 5
# ٥٧]، 2
# ؟﴿ 1
# ٢٠١]. 1
# ٧٠١]. 1
# [٥]﴿ 1
# [] 8
# ]، 1
# ٧٦] 1
# ٩٤١]، 1
# ؟» 2
# ٢٤] 3
# ٩٤١]. 3
# ﴾؛ 1
# ﴿﴾: 1
# »: 1
# ٤٦١]. 1
# .: 2
# ٤]. 4
# [٦]﴿ 1
# ٢٠١]، 1
# ٤٠١‐٥٠١]، 1
# ٣٤]. 1
# ٦٠١] 1
# ٨٣]. 1
# ٩٢]. 3
# [٧]﴿ 1
# :٠٥]، 5
# ٨٢–٩٢] 1
# []] 1
# ٨] 1
# ٧٤]. 1
# ٤٥]. 1
# [٨]﴿ 1
# ٢٣١]، 1
# ٩١]، 1
# ٧٢]. 2
# ٧٢]، 1
# ٩١]؛ 1
# ٦١]، 3
# ٩٤١] 1
# ٢١١]، 1
# [٩]﴿ 1
# :« 1
# ٤] 2
# ٥]. 3
# ٥]، 4
# ٠٠١]، 2
# ٠٠١] 1
# ٥٤]، 2
# ٦٤]. 1
# ٣٢١]. 2
# «»؟ 1
# ٣]. 4
# ٥١]. 4
# ٦٥]. 3
# ٣٥؛ 4
# ٢١]، 3
# ٦٦]. 2
# ٦٨] 1
# ٢٢]. 3
# ٢١]. 3
# .. 1
# ٤٢]، 3
# ٥٢]، 1
# ٣٣]. 1
# [٦٨٥]. 1
# ٦٥]، 2
# ٧٤]، 3
# ٩٢]، 3
# ؛: 1
# :٩]، 1
# ٥١١]. 2
# ٥١١] 1
# ٠٤] 1
# ٢٨]، 2
# ٥٦]. 1
# ٧٦]. 1
# ٨٣]، 1
# ٩٣] 3
# ٤٣]. 1
# ؟». 3
# :٠٥]. 1
# :٤١١] 1
# ٧٣] 1
# ٢٢]، 1
# ٧٣]. 3
# ٧٣]، 5
# ٦٦١]. 1
# ٧٤] 3
# ٥٢]. 1
# ٤٠١]، 1
# ٠٨] 2
# ٠٨]، 3
# ٤٥] 4
# ٤٥]، 2
# ٦‐٧]. 1
# ٨٨؛ 1
# ٥٥١]، 1
# ٧]، 2
# ٩]. 4
# ٢٧٢]. 1
# ٠٦١] 1
# ٣٥٢]. 1
# ٥٥]. 1
# ١٧]. 1
# ٩٥٢]. 1
# ٠٦٢]، 1
# ٩٥٢]، 2
# ٨٥٢]، 1
# ٨٢]. 1
# :٤١١]. 1
# ٢٤]، 3
# «»: 1
# ٩١] 2
# ١٧١]. 1
# ٩٤]. 5
# ٠١١]، 1
# ٧١]، 2
# ٧٤]؟ 1
# ٢٢١] 5
# ١٣]. 3
# ٦١١]. 3
# ٦١١] 5
# ٦١١]، 1
# ٧١١]،، 1
# ٧١١] 8
# ٧١١]. 3
# ٧١١]، 5
# ٣٤]، 3
# ١٥١]، 1
# ٨١١]. 6
# ٨١١] 2
# ٠٣] 3
# ﴿ی 1
# :﴿﴾ 1
# ٦٥١]، 2
# ١١]، 2
# …………… 2
# ٩٧] 1
# ٩٧]. 1
# ٤٤] 6
# ٢٤]. 1
# ٤٤]. 1
# ٢٢١؛ 2
# ٨٤]، 2
# ٠٩] 1
# ٨٤]. 1
# ٤٤]، 3
# ٤]، 1
# ٦٣]، 1
# ٣١]، 3
# ٩٣]، 1
# ٩٣]. 1
# :٤١١]، 1
# ١٢]، 3
# ٤٨]، 1
# ٤٢١] 1
# ٦٢]. 3
# ٠٩]. 1
# — 6
# ١٦]. 1
# ٠٤]؟ 1
# ٠٤]؛ 1
# ٩٧١] 1
# ٩٦] 1
# ٠٥] 1
# ٨١١٦]. 1
# ٦٦]، 1
# ٦٦] 3
# ٣، 1
# ٩٢، 1
# ١٠١]؛ 1
# ٣٨‐٤٨]، 1
# ٧١، 1
# ٠٣، 1
# ١١]. 1
# «، 1
# ٦٥١]. 1
# ٠٨١]. 1
# ٤٢١]. 1
# ٤٢١]؛ 1
# ٠٦]، 1
# ٦٨١] 1
# ٩٦٢]. 2
# ٧١]. 1
# ٦١]. 2
# ٤٣].() 1
# ٧‐٨]. 1
# ٦٢]، 1
# ٣١]. 1
# ٣٥]، 2
# :٤٩]، 3
# ٠٥١]. 1
# :٥٩]؟ 1
# ٢٣]. 2
# ٣٢]، 3
# ٣٠١] 2
# ٣٠١]. 1
# ٢٢١]، 1
# ٥].: 1
# ٧٨] 1
# :٠٤]. 1
# !» 1
# ٨٦]، 2
# ٦٧]، 1
# ٨٧]، 1
# ﴾؟ 1
# ٤٢]. 1
# ١٥]، 1
# ٨٢]، 1
# ٠٣]؟ 1
# ١٣]، 1
# ٢٣]، 2
# ٠٧]، 1
# :٢٧] 2
# ٢]﴿ 1
# ٨٩]، 1
# ٨٩]. 1
# ٢٩]. 1
# :٢٩]، 1
# ٩٢؛ 1
# ٢٧]. 1
# …» 1
# ٨٢٢]، 1
# ٥١] 1
# ٦٥١] 1
# ٦٢، 1
# ٨٢، 1
# ٢٥] 2
# ٢٥١]. 1
# ٢، 1
# ٥٤] 2
# ٥٤]. 1
# ٤١–٥١]، 1
# ١٤] 1
# […] 1
# [؟] 1
# [٠٣٦ 1

# %%
puncsLess = []
for punc in puncs:
    if '[' not in punc and ']' not in punc:
        puncsLess.append(punc)
print(puncsLess)
# Out:
# [':.', '―', '﴿', '﴾', '﴾،', '«»،', '«».', '«»', '»،', '؟!', '–', '﴾.', '﴿﴾', ':﴿', '»؟', '«»؛', '﴾.()', '﴿﴾،', '؟﴿', '؟»', '﴾؛', '﴿﴾:', '»:', '.:', ':«', '«»؟', '٣٥؛', '..', '؛:', '؟».', '٨٨؛', '«»:', '﴿ی', ':﴿﴾', '……………', '٢٢١؛', '—', '٣،', '٩٢،', '٧١،', '٠٣،', '«،', '!»', '﴾؟', '٩٢؛', '…»', '٦٢،', '٨٢،', '٢،']

# %%
for punc in puncsLess:
    times = fusus[fusus['haspunct']==punc].shape[0]
    print(punc + " " + str(times))
# Out:
# :. 8
# ― 300
# ﴿ 469
# ﴾ 346
# ﴾، 31
# «»، 46
# «». 23
# «» 72
# »، 46
# ؟! 1
# – 2
# ﴾. 3
# ﴿﴾ 29
# :﴿ 6
# »؟ 2
# «»؛ 3
# ﴾.() 1
# ﴿﴾، 4
# ؟﴿ 1
# ؟» 2
# ﴾؛ 1
# ﴿﴾: 1
# »: 1
# .: 2
# :« 1
# «»؟ 1
# ٣٥؛ 4
# .. 1
# ؛: 1
# ؟». 3
# ٨٨؛ 1
# «»: 1
# ﴿ی 1
# :﴿﴾ 1
# …………… 2
# ٢٢١؛ 2
# — 6
# ٣، 1
# ٩٢، 1
# ٧١، 1
# ٠٣، 1
# «، 1
# !» 1
# ﴾؟ 1
# ٩٢؛ 1
# …» 1
# ٦٢، 1
# ٨٢، 1
# ٢، 1

# %%
fusus[fusus.word.str.contains(pat='سورةنوح')]
# Out:
#       page  line  column  span direction   left    top  right bottom  \
# 5172    57     5       1     1         r  223.0  193.0  269.0  211.0
# 5181    57     6       1     1         r  268.0  217.0  343.0  238.0
# 5192    57     7       1     1         r  202.0  243.0  280.0  264.0
# 5308    58     7       1     1         r  245.0  245.0  291.0  263.0
# 5315    58     8       1     1         r  270.0  269.0  356.0  290.0
# 5362    58    14       1     1         r  328.0  425.0  368.0  446.0
# 5427    59     4       1     1         r  280.0  165.0  353.0  186.0
# 5481    59     9       1     1         r  149.0  295.0  198.0  316.0
# 5542    60     8       1     1         r  238.0  269.0  281.0  290.0
# 5647    61     7       1     1         r  250.0  243.0  292.0  264.0
# 5796    62    12       1     1         r  258.0  373.0  359.0  394.0
# 5806    62    14       1     1         r  255.0  425.0  348.0  446.0
# 5821    63     1       1     1         r  292.0   87.0  369.0  108.0
# 5889    64     3       1     1         r  245.0  139.0  364.0  160.0
# 5903    64     5       1     1         r  278.0  191.0  344.0  212.0
# 5924    65     2       1     1         r  165.0  113.0  249.0  134.0
# 5985    65    10       1     1         r  245.0  321.0  335.0  342.0
# 6023    66     5       1     1         r  196.0  191.0  293.0  212.0
# 6027    66     6       1     1         r  332.0  217.0  402.0  238.0
# 6032    66     7       1     1         r  188.0  243.0  278.0  264.0
# 6043    66     9       1     1         r  309.0  295.0  349.0  316.0
# 6059    66    10       1     1         r   79.0  321.0  163.0  342.0
# 6088    67     1       1     1         r  100.0   87.0  181.0  108.0
# 6094    67     3       1     1         r  309.0  139.0  385.0  160.0
# 6122    67     6       1     1         r  268.0  217.0  333.0  238.0
# 6141    67     9       1     1         r  293.0  295.0  385.0  316.0
# 6152    67    11       1     1         r  263.0  347.0  329.0  368.0
# 6157    67    12       1     1         r  296.0  373.0  339.0  394.0
# 6170    68     1       1     1         r  288.0   87.0  385.0  108.0
# 6174    68     1       1     1         r  100.0   87.0  203.0  108.0
# 6179    68     3       1     1         r  254.0  139.0  346.0  160.0
# 6190    68     4       1     1         r  134.0  165.0  231.0  186.0
#
#                                  word                 short haspunct  \
# 5172                        [سورةنوح:             [سورةنوح:       [:
# 5181             غَفَّارًا﴾.[سورةنوح:      غفارا﴾.[سورةنوح:     ﴾.[:
# 5192             فِـرَارًا﴾.[سورةنوح:      فرارا﴾.[سورةنوح:     ﴾.[:
# 5308                        [سورةنوح:             [سورةنوح:       [:
# 5315            ﴿وَنَهَارًا﴾[سورةنوح:     ﴿ونهارا﴾[سورةنوح:     ﴿﴾[:
# 5362                        [سورةنوح:             [سورةنوح:       [:
# 5427             بِأَمْوٰلٍ﴾[سورةنوح:       بأمول﴾[سورةنوح:      ﴾[:
# 5481                        [سورةنوح:             [سورةنوح:       [:
# 5542                        [سورةنوح:             [سورةنوح:       [:
# 5647                        [سورةنوح:             [سورةنوح:       [:
# 5796    أَضَلُّوْاكَثِيْرًا﴾[سورةنوح:  أضلواكثيرا﴾[سورةنوح:      ﴾[:
# 5806        ٱلظَّـٰلِمِيْنَ﴾[سورةنوح:     ٱلظلمين﴾[سورةنوح:      ﴾[:
# 5821              ضَلَـٰلًا﴾[سورةنوح:        ضللا﴾[سورةنوح:      ﴾[:
# 5889  خَطِـيٓـىَٔــٰتِهِمْ﴾؛[سورةنوح:   خطيىٔتهم﴾؛[سورةنوح:     ﴾؛[:
# 5903                 نَارًا﴾[سورةنوح:        نارا﴾[سورةنوح:      ﴾[:
# 5924            أَنْصَارًا﴾.[سورةنوح:     أنصارا﴾.[سورةنوح:     ﴾.[:
# 5985               ٱلأَرْضِ﴾[سورةنوح:       ٱلأرض﴾[سورةنوح:      ﴾[:
# 6023         ٱلكَافِـرِيْنَ﴾[سورةنوح:    ٱلكافرين﴾[سورةنوح:      ﴾[:
# 6027            ثِيَابَهَمْ﴾[سورةنوح:      ثيابهم﴾[سورةنوح:      ﴾[:
# 6032          ءَاذَانِهِمْ﴾.[سورةنوح:    ءاذانهم﴾.[سورةنوح:     ﴾.[:
# 6043                        [سورةنوح:             [سورةنوح:       [:
# 6059               عِبَادَكَ﴾[سورةنوح        عبادك﴾[سورةنوح       ﴾[
# 6088              فَاجِـرًا﴾[سورةنوح:       فاجرا﴾[سورةنوح:      ﴾[:
# 6094             ﴿كَفَّارًا﴾[سورةنوح:      ﴿كفارا﴾[سورةنوح:     ﴿﴾[:
# 6122                    لِى﴾[سورةنوح:          لى﴾[سورةنوح:      ﴾[:
# 6141         ﴿وَلِوٰلِدَىَّ﴾[سورةنوح:     ﴿ولولدى﴾[سورةنوح:     ﴿﴾[:
# 6152                بَيْتِى﴾[سورةنوح:        بيتى﴾[سورةنوح:      ﴾[:
# 6157                        [سورةنوح:             [سورةنوح:       [:
# 6170     ﴿وَلِلْمُؤمِنِيْنَ﴾[سورةنوح:  ﴿وللمؤمنين﴾[سورةنوح:     ﴿﴾[:
# 6174       ﴿وَٱلمُؤمِنَـٰتُ﴾[سورةنوح:   ﴿وٱلمؤمنت﴾[سورةنوح:     ﴿﴾[:
# 6179       ٱلظَّـٰلِمِيْنَ﴾:[سورةنوح:    ٱلظلمين﴾:[سورةنوح:     ﴾:[:
# 6190      ﴿إِلَّاتَـبَارًا﴾[سورةنوح:  ﴿إلاتبارا﴾[سورةنوح:     ﴿﴾[:
#
#      punctAfter punctBefore QunawiMS poetryMeter poetryVerse fass
# 5172                             11b
# 5181                             11b
# 5192                             12a
# 5308                             12a
# 5315                             12a
# 5362                             12a
# 5427                             12a
# 5481                             12b
# 5542                             12b
# 5647                             12b
# 5796                             13a
# 5806                             13a
# 5821                             13a
# 5889                             13a
# 5903                             13a
# 5924                             13a
# 5985                             13a
# 6023                             13a
# 6027                             13a
# 6032                             13a
# 6043                             13b
# 6059                             13b
# 6088                             13b
# 6094                             13b
# 6122                             13b
# 6141                             13b
# 6152                             13b
# 6157                             13b
# 6170                             13b
# 6174                             13b
# 6179                             13b
# 6190                             13b

# %% [markdown]
# Some more functionality to check what is going on

# %%
 fusus[fusus.word.str.contains(pat='سورة')&~fusus.word.str.contains(pat='\[')]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 5973     65     8       1     1         r  139.0  273.0  188.0  288.0
# 13140   149     2       1     1         r  196.0  117.0  245.0  132.0
# 13311   150    10       1     1         r   79.0  325.0  118.0  340.0
# 13319   151     1       1     1         r  156.0   91.0  195.0  106.0
# 13533   152    13       1     1         r   79.0  403.0  112.0  418.0
# 13619   153     7       1     1         r  190.0  247.0  239.0  262.0
# 13621   153     7       1     1         r  120.0  247.0  157.0  262.0
# 13632   153     9       1     1         r  362.0  299.0  402.0  314.0
# 13634   153     9       1     1         r  291.0  299.0  329.0  314.0
# 13941   156     1       1     1         r  188.0   91.0  241.0  106.0
# 18112   193     8       1     1         r   79.0  273.0  120.0  288.0
# 20792   217     2       1     1         r  114.0  117.0  166.0  132.0
# 20818   217     5       1     1         r  147.0  195.0  195.0  210.0
# 27723   286    13       1     1         r  113.0  403.0  163.0  418.0
# 27960   288     4       1     1         r  100.0  213.0  149.0  228.0
# 28519   293     1       1     1         r  197.0   91.0  246.0  106.0
# 28524   293     2       1     1         r  366.0  117.0  402.0  132.0
# 28622   293    12       1     1         r  186.0  377.0  235.0  392.0
# 31977   324     4       1     1         r  284.0  169.0  326.0  184.0
# 32128   326     4       1     1         r  193.0  176.0  237.0  191.0
# 32753   330    15       1     1         r  327.0  455.0  371.0  470.0
# 33410   336     8       1     1         r  318.0  273.0  370.0  288.0
# 33474   336    14       1     1         r  318.0  429.0  370.0  444.0
# 34545   346     3       1     1         r   79.0  143.0  129.0  158.0
# 37317   367    14       1     1         r  134.0  429.0  186.0  444.0
# 38613   381     1       1     1         r  373.0   91.0  402.0  106.0
# 40446   399     3       1     1         r  123.0  139.0  178.0  154.0
# 40449   399     4       1     1         r  333.0  165.0  402.0  180.0
# 41018   405     8       1     1         r  210.0  273.0  264.0  288.0
#
#                        word                 short haspunct punctAfter  \
# 5973            سورةالرحمن:            سورةالرحمن                   :
# 13140          سورةالفاتحة:           سورةالفاتحة                   :
# 13311              سورةفاطر              سورةفاطر
# 13319             سورةفاطر:              سورةفاطر                   :
# 13533                 سورةق                 سورةق
# 13619          سورةالفرقان:           سورةالفرقان                   :
# 13621             سورةفاطر:              سورةفاطر                   :
# 13632          سورةالفرقان:           سورةالفرقان                   :
# 13634             سورةفاطر:              سورةفاطر                   :
# 13941          سورةالأعراف:           سورةالأعراف                   :
# 18112            سورةالنساء            سورةالنساء
# 20792          سورةآلعمران:           سورةآلعمران                   :
# 20818          سورةالمائدة:           سورةالمائدة                   :
# 27723         سورةالأنبياء:          سورةالأنبياء                   :
# 27960          سورةالأسراء:           سورةالأسراء                   :
# 28519           سورةالحديد:            سورةالحديد                   :
# 28524           سورةالبقرة:            سورةالبقرة                   :
# 28622         سورةالأنبياء:          سورةالأنبياء                   :
# 31977           سورةالبقرة:            سورةالبقرة                   :
# 32128           سورةالبقرة:            سورةالبقرة                   :
# 32753            سورةلقمان:             سورةلقمان                   :
# 33410           سورةالزخرف:            سورةالزخرف                   :
# 33474           سورةالزخرف:            سورةالزخرف                   :
# 34545          سورةالأنبياء          سورةالأنبياء
# 37317           سورةالزخرف:            سورةالزخرف                   :
# 38613                سورةص:                 سورةص                   :
# 40446          سورةالفاتحة:           سورةالفاتحة                   :
# 40449  المقصودقراءةالسورةفي  المقصودقراءةالسورةفي
# 41018          سورةالأحزاب:           سورةالأحزاب                   :
#
#       punctBefore QunawiMS poetryMeter poetryVerse fass
# 5973                   13a
# 13140                  27a
# 13311                  27b
# 13319                  27b
# 13533                  27b
# 13619                  28a
# 13621                  28a
# 13632                  28a
# 13634                  28a
# 13941                  28b
# 18112                  36a
# 20792                  41a
# 20818                  41a
# 27723                  53b
# 27960                53aII
# 28519                  54a
# 28524                  54a
# 28622                  54b
# 31977                  61a
# 32128                  61a
# 32753                  62a
# 33410                  63b
# 33474                  63b
# 34545                  65b
# 37317                  70b
# 38613                  73a
# 40446                  76b
# 40449                  76b
# 41018                  77b

# %%
fusus[fusus.word.str.contains(pat='سورة')].word.unique().tolist()
# Out:
# ['[سورةالبقرة:',
#  '[سورةص:',
#  'وَنِسَـآءً﴾.[سورةالنساء:',
#  'رَبَّـكُمْ﴾؛[سورةالنساء:',
#  '[سورةغافر',
#  '[سورةمحمد:',
#  '[سورةالحجر:',
#  '[سورةطـٰه',
#  '[سورةفصلت:',
#  '[سورةالفاتحة:',
#  'شَيءٌ﴾[سورةالشورى:',
#  'ٱلبَصِيْرُ﴾[سورةالشورى:',
#  '[سورةالشورى:',
#  '[سورة',
#  '[سورةنوح:',
#  'غَفَّارًا﴾.[سورةنوح:',
#  'فِـرَارًا﴾.[سورةنوح:',
#  'شَيءٌ﴾[سورةالشورىٰ:',
#  '﴿وَنَهَارًا﴾[سورةنوح:',
#  '[سورةالشورىٰ:',
#  'شَىءٌ﴾[سورةالشورى:',
#  'مِدْرَارًا﴾[سورة',
#  'بِأَمْوٰلٍ﴾[سورةنوح:',
#  'فِيْهِ﴾[سورةالحديد:',
#  '[سورةالإسراء:',
#  'اللهِ﴾[سورة',
#  'بَصِيْرِةٍ﴾.[سورةيوسف:',
#  '[سورةالإسرىٰ:',
#  'سَمُّوْهُمْ﴾[سورةالرعد:',
#  'زُلْفَىٰٓ﴾.[سورةالزمر:',
#  'أَسْلِمُوْا﴾[سورةالحج:',
#  'المُخْبِتِيْنَ﴾؛[سورةالحج:',
#  'أَضَلُّوْاكَثِيْرًا﴾[سورةنوح:',
#  'ٱلظَّـٰلِمِيْنَ﴾[سورةنوح:',
#  'ضَلَـٰلًا﴾[سورةنوح:',
#  'خَطِـيٓـىَٔــٰتِهِمْ﴾؛[سورةنوح:',
#  'نَارًا﴾[سورةنوح:',
#  '[سورةالتكوير:',
#  'أَنْصَارًا﴾.[سورةنوح:',
#  'سورةالرحمن:',
#  'ٱلأَرْضِ﴾[سورةنوح:',
#  'أُخْـرَىٰ﴾[سورةطٰه',
#  'ٱلكَافِـرِيْنَ﴾[سورةنوح:',
#  'ثِيَابَهَمْ﴾[سورةنوح:',
#  'ءَاذَانِهِمْ﴾.[سورةنوح:',
#  'عِبَادَكَ﴾[سورةنوح',
#  'فَاجِـرًا﴾[سورةنوح:',
#  '﴿كَفَّارًا﴾[سورةنوح:',
#  'لِى﴾[سورةنوح:',
#  'قَدْرِهِ﴾[سورةالأنعام:',
#  '﴿وَلِوٰلِدَىَّ﴾[سورةنوح:',
#  'بَيْتِى﴾[سورةنوح:',
#  '﴿وَلِلْمُؤمِنِيْنَ﴾[سورةنوح:',
#  '﴿وَٱلمُؤمِنَـٰتُ﴾[سورةنوح:',
#  'ٱلظَّـٰلِمِيْنَ﴾:[سورةنوح:',
#  '﴿إِلَّاتَـبَارًا﴾[سورةنوح:',
#  'وَجْهَهُ﴾[سورةالقصص:',
#  '[سورةمريم:',
#  '[سورةطٰه',
#  '[سورةالقصص',
#  '[سورةهود:',
#  '[سورةصٓ:',
#  '[سورةالأنعام:',
#  '[سورةالقلم:',
#  '[سورةالأنعام',
#  'مَعْلُوٌم﴾[سورةالصافات:',
#  '[سورةالأحزاب:',
#  '[سورةالصافات:',
#  '[سورةيوسف:',
#  'فُـرْقَانًا﴾[سورةالأنفال:',
#  '[سورةالفجر:',
#  '[سورةالبينة:',
#  '[سورةابراهيم:',
#  '[سورةالأحقاف:',
#  '[سورةآلعمران:',
#  '[سورةالحديد:',
#  '[سورةالفرقان:',
#  'بِكُمْ﴾[سورةالأحقاف:',
#  '[سورةالإخلاص:',
#  '[سورةفاطر:',
#  'سورةالفاتحة:',
#  'سورةفاطر',
#  'سورةفاطر:',
#  '[سورةالمائدة:',
#  '[سورةالواقعة:',
#  'سورةق',
#  '[سورةقٓ:',
#  'سورةالفرقان:',
#  '[سورةالأحقاف',
#  'سورةالأعراف:',
#  '[سورةالعنكبوت',
#  'ٱللهِ﴾[سورةالبقرة:',
#  '[سورةالبقرة',
#  '[سورةالنساء:',
#  '[سورةيٰسٓ:',
#  '[سورةعبس:',
#  '[سورةالأحزاب',
#  '[سورةطـٰـه',
#  'قَلْبٌ﴾[سورةقٓ:',
#  '[سورةآل',
#  '[سورةق:',
#  '[سورةالزُّمَر:',
#  'صُنْعًا﴾[سورةالكهف:',
#  '[سورةهود',
#  '[سورةالروم:',
#  '[سورةالروم',
#  '[سورةالحج:',
#  'سورةالنساء',
#  '[سورةالمزمل:',
#  '[سورةالقصص:',
#  '[سورةالأعراف:',
#  '[سورةالنحل:',
#  '[سورةطٰـه',
#  'ٱلمَوْتَىٰ﴾[سورةالبقرة:',
#  'ٱلسَّجُوْدِ﴾[سورةالقلم:',
#  'سورةآلعمران:',
#  'سورةالمائدة:',
#  '[سورةالتوبة:',
#  '[سورةصٓ',
#  '[سورةالمائدة',
#  '[ْسورةالمائدة:',
#  '[سورةال',
#  '[سورةالفتح:',
#  '﴾[سورةالمائدة:',
#  '[سورةالنمل:',
#  'جَدِيدٍ﴾[سورةقٓ:',
#  '[سورةالأنبياء:',
#  '[اقتباسسورةيونس:',
#  '[سورةالنمل',
#  'وَيَعْقُـوبَ﴾[سورةالأنعام:',
#  'مَعَهُمْ﴾[سورةصٓ',
#  'فَضْلًا﴾[سورةسبأ:',
#  'ٱلشَّـكُورُ﴾[سورةسبأ:',
#  'ٱقْتَدِهْ﴾[سورةالأنعام:',
#  'لَفَسَدَتَا﴾[سورةالأنبيا:',
#  '[سورةالأنفال:',
#  'مِثْلَهَا﴾[سورةالشورى:',
#  'اللهِ﴾[سورةالشورىٰ:',
#  'الأَمْرُكُلُّهُ﴾[سورةهود:',
#  'سورةالأنبياء:',
#  'الأَمْرُكَلُّهُ﴾[سورةهود:',
#  'الأَمْرُكُلُّهُ﴾[سورةهود',
#  'حَىٌّ﴾[سورةالأنبياء:',
#  'سورةالأسراء:',
#  'فَوْقِهِمْ﴾[سورةالنحل:',
#  'عِبَادِهِ﴾[سورةالأنعام:',
#  'وَالإِنْجِيْلَ﴾[سورةالمائدة:',
#  'رَبَّهِمْ﴾[سورةالمائدة:',
#  'فَوْقِهِم﴾[سورةالمائدة:',
#  'أَرْجُلِهِمْ﴾[سورةالمائدة:',
#  'مُغتَسَلٌ﴾[سورةصٓ:',
#  'عَلَيهِ﴾[سورةهود:',
#  'سورةالحديد:',
#  'سورةالبقرة:',
#  'أَوَّابٌ﴾[سورةصٓ:',
#  'وَرَسُوْلَهُ﴾[سورةالأحزاب:',
#  'سَمِيَّا﴾[سورةمريم:',
#  'وَلِيٍّا﴾[سورةمريم:',
#  'ٱلجَنَّةِ﴾[سورةالتحريم:',
#  'يَعْقُوبَ﴾[سورةمريم:',
#  'حَيٍّا﴾[سورةمريم:',
#  'شَىءٍ﴾[سورةالأعراف',
#  'وَمَاتَأَخَّرَ﴾[سورةالفتح',
#  'ٱلبَصِيرُ﴾[سورةالشورىٰ:',
#  'رِسَالَاتِهِ﴾[سورةالأنعام:',
#  'لَـكُمْ﴾[سورةغافر:',
#  '[سورةالأنفال',
#  '[سورةلقمان:',
#  '﴾[سورةلقمان:',
#  '[سورةالزلزال:',
#  'سورةلقمان:',
#  '[سورةالإس',
#  '﴾[سورةمريم:',
#  'سورةالزخرف:',
#  '﴾[سورةالرحمن:',
#  '[سورةالجاثية:',
#  '[سورةالجاثية',
#  '[سورةالزمر',
#  '[سورةالزمر:',
#  '[سورةالرعد:',
#  'سورةالأنبياء',
#  '[اقتباسسورةيوسف',
#  'وَمِنْهَاجًا﴾[سورة',
#  '[سورةالكهف:',
#  '[سورةالحشر:',
#  '[سورةالشعراء:',
#  '[سورةالنازعات:',
#  'قَاضٍ﴾[سورةطٰه',
#  '[سورةغافر:',
#  '[سورةيونس:',
#  '[سورةي',
#  'رُوحِى﴾[سورةالحجر:',
#  'سورةص:',
#  '[سورةالسجدة:',
#  'خَلْقَهُ﴾[سورةطٰه',
#  'يَقُوْلُوْنَ﴾[سورةالنور:',
#  'بِاللهِ﴾[سورةالعنكبوت',
#  'ٱلخٰسِرُوْنَ﴾[سورةالعنكبوت',
#  'المقصودقراءةالسورةفي',
#  '[سورةالعنكبوت:',
#  'مَعَاذِيْـرَهُ﴾[سورة',
#  'سورةالأحزاب:',
#  'وَتَسْبِيحَهُ﴾[سورةالنور:',
#  'بِحَمْدِهِ﴾[سورةالإسراء:',
#  '﴿بِحَمْدِهِ﴾[سورةالإسراء:',
#  'ٱلسَّبِيْلَ﴾[سورةالأحزاب:']

# %%
fusus[fusus.short.str.contains(pat='٦٢،')]
# Out:
#        page  line  column  span direction   left    top  right bottom word  \
# 40046   396     5       1     1         r  330.0  195.0  343.0  210.0  ٦٢،
#
#       short haspunct punctAfter punctBefore QunawiMS poetryMeter poetryVerse  \
# 40046   ٦٢،      ٦٢،                             76a
#
#       fass
# 40046

# %%
lijst = punctMark.index.tolist()

# %%
helelijst = []
for l in lijst:
    helelijst.append(l-1)
    helelijst.append(l)

# %% [markdown]
# first need to clean up `[zahr -#]`, which refer to MS Qunawi, and only then the poetry metre. Poetry can consist of two words (majzūʾ in front). 29817/304-9 needs to be split. Folio 53 is counted twice (in the MS).

# %%
for l in lijst:
    fusus.iloc[l, fusus.columns.get_loc("poetryVerse")] = "9"
#     fusus.iloc[l, fusus.columns.get_loc("poetryMeter")] = fusus.iloc[l-1, fusus.columns.get_loc("word")]
    fusus.iloc[l, fusus.columns.get_loc("word")] = fusus.iloc[l, fusus.columns.get_loc("word")][2:]
    fusus.iloc[l, fusus.columns.get_loc("short")] = fusus.iloc[l, fusus.columns.get_loc("short")][2:]
    fusus.iloc[l, fusus.columns.get_loc("haspunct")] = ""
#     fusus.iloc[l-1, fusus.columns.get_loc("word")] = ""
#     fusus.iloc[l-1, fusus.columns.get_loc("short")] = ""
#     fusus.iloc[l-1, fusus.columns.get_loc("haspunct")] = ""

# %%
# These are the words right before poetry starts: indicate meter.
fusus.iloc[helelijst].sort_index()
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 226      12     4       2     1         r  154.0  165.0  187.0  186.0
# 227      12     5       1     1         r  345.0  191.0  374.0  212.0
# 1951     28     2       2     1         r   89.0  113.0  113.0  134.0
# 1952     28     3       1     1         r  353.0  139.0  402.0  160.0
# 5099     56     4       2     1         r  101.0  174.0  124.0  195.0
# 5100     56     5       1     1         r  364.0  200.0  402.0  221.0
# 7132     79    11       2     1         r   85.0  356.0  109.0  377.0
# 7133     79    12       1     1         r  362.0  382.0  402.0  403.0
# 8078     91     4       2     1         r   95.0  165.0  129.0  186.0
# 8079     91     5       1     1         r  299.0  191.0  366.0  212.0
# 8228     94     6       1     1         r  150.0  284.0  177.0  305.0
# 8229     95     1       1     1         r  337.0   87.0  366.0  108.0
# 8932    104    11       1     1         r  119.0  363.0  140.0  384.0
# 8933    104    12       1     1         r  303.0  389.0  366.0  410.0
# 9055    106     8       1     1         r  146.0  269.0  178.0  290.0
# 9056    106     9       1     1         r  343.0  295.0  366.0  316.0
# 9417    109     3       1     1         r  120.0  139.0  148.0  160.0
# 9418    109     4       1     1         r  328.0  165.0  366.0  186.0
# 9950    115     8       2     1         r  115.0  276.0  137.0  297.0
# 9951    115     9       1     1         r  324.0  302.0  366.0  323.0
# 10141   117     9       2     1         r  134.0  295.0  169.0  316.0
# 10142   117    10       1     1         r  319.0  321.0  366.0  342.0
# 10264   119     6       1     1         r  154.0  217.0  181.0  238.0
# 10265   119     7       1     1         r  328.0  243.0  366.0  264.0
# 13100   148     4       2     1         r  107.0  209.0  135.0  230.0
# 13101   148     5       1     1         r  326.0  235.0  374.0  256.0
# 13204   149    11       2     1         r  129.0  347.0  158.0  368.0
# 13205   149    12       1     1         r  301.0  373.0  346.0  394.0
# 14398   160    15       2     1         r  137.0  451.0  171.0  472.0
# 14399   161     1       1     1         r  297.0   87.0  348.0  108.0
# 15121   167     4       2     1         r  104.0  227.0  154.0  248.0
# 15122   167     5       1     1         r  348.0  253.0  384.0  274.0
# 16630   179     8       2     1         r  140.0  278.0  163.0  299.0
# 16631   179     9       1     1         r  336.0  304.0  367.0  325.0
# 20370   212     6       1     1         r  163.0  268.0  244.0  289.0
# 20371   212     7       1     1         r  330.0  294.0  374.0  315.0
# 21524   224    10       2     1         r  141.0  321.0  173.0  342.0
# 21525   224    11       1     1         r  314.0  347.0  346.0  368.0
# 21992   231     4       2     1         r  101.0  174.0  126.0  195.0
# 21993   231     5       1     1         r  309.0  200.0  346.0  221.0
# 27012   277     4       2     1         r   95.0  165.0  127.0  186.0
# 27013   277     5       1     1         r  357.0  191.0  392.0  212.0
# 32087   325     4       2     1         r  127.0  183.0  152.0  204.0
# 32088   325     5       1     1         r  336.0  209.0  384.0  230.0
#
#                             word        short haspunct punctAfter punctBefore  \
# 226                   فَعُـــوْا         فعوا
# 227                        ثُمَّ           ثم
# 1951                   نَعْــنِي         نعني
# 1952                  فَالـكُلُّ        فالكل
# 5099                    سَيِّدًا         سيدا
# 5100                      فَمَنْ          فمن
# 7132                     بَصَـرُ          بصر
# 7133                     جَمِّعْ          جمع
# 8078                  أَجْحَدُهُ        أجحده
# 8079             فَـيَعْـرِفُنِي      فيعرفني
# 8228                    مِيزَانِ        ميزان
# 8229                       وَلَا          ولا
# 8932                     عَابِرُ         عابر
# 8933              وَمَاحُـكْمُهُ      وماحكمه
# 9055                   الوَاسِعُ       الواسع
# 9056                         لَو           لو
# 9417                      ضَنْكِ          ضنك
# 9418                      فَمِنْ          فمن
# 9950                      عَهْدُ          عهد
# 9951                    فَـكُلُّ          فكل
# 10141                    الحَقِّ         الحق
# 10142               وَنَـزِّهْهُ        ونزهه
# 10264                  مُبَايِنُ        مباين
# 10265                    نَعِيمَ         نعيم
# 13100                  وَعَلِيمْ        وعليم
# 13101                  وَلَهٰذَا        ولهذا
# 13204                   الخَلْقُ        الخلق
# 13205                  فَحَقِّقْ         فحقق
# 14398                 يَغْـتَذِي        يغتذي
# 14399                فَـوُجُودِي       فوجودي
# 15121              السَّـبَاسِبْ      السباسب
# 15122                  فَـأَمَّا         فأما
# 16630                   عَمَّـهْ          عمه
# 16631                      فَمَا          فما
# 20370  تَدْعُـوهَابِسِجِّيــــنِ  تدعوهابسجين
# 20371                   لِأَجْلِ         لأجل
# 21524                مَـوْلَانَا       مولانا
# 21525                    وَإنَّا         وإنا
# 21992                     نَعَسْ          نعس
# 21993                  فَـيَـرَى         فيرى
# 27012                كَمَاكُنَّا       كماكنا
# 27013                    فَمِنهُ         فمنه
# 32087                    يَشَاءُ         يشاء
# 32088             مَشِيْىَٔـتُهُ      مشيىٔته
#
#       QunawiMS poetryMeter poetryVerse
# 226         2a
# 227         2a                       3
# 1951        5b
# 1952        5b                       3
# 5099       11b
# 5100       11b                       3
# 7132       15b
# 7133       15b                       3
# 8078       17a
# 8079       17a                       3
# 8228       17b
# 8229       17b                       3
# 8932       19a
# 8933       19a                       3
# 9055       19a
# 9056       19a                       3
# 9417       20a
# 9418       20a                       3
# 9950       21a
# 9951       21a                       3
# 10141      21b
# 10142      21b                       3
# 10264      21b
# 10265      21b                       3
# 13100      27a
# 13101      27a                       3
# 13204      27a
# 13205      27a                       3
# 14398      29b
# 14399      29b                       3
# 15121      30b
# 15122      30b                       3
# 16630      33b
# 16631      33b                       3
# 20370      40a
# 20371      40a                       3
# 21524      42b
# 21525      42b                       3
# 21992      43b
# 21993      43b                       3
# 27012      52b
# 27013      52b                       3
# 32087      61a
# 32088      61a                       3

# %%
majzu = fusus[fusus.word=='[مَجْـزُوءُ'].index.tolist()
for i in majzu:
    fusus.iloc[i, fusus.columns.get_loc("word")] += " " + fusus.iloc[i+1, fusus.columns.get_loc("word")]
    fusus.iloc[i, fusus.columns.get_loc("short")] += " " + fusus.iloc[i+1, fusus.columns.get_loc("short")]
    fusus.iloc[i, fusus.columns.get_loc("haspunct")] += fusus.iloc[i+1, fusus.columns.get_loc("haspunct")]
    fusus.iloc[i+1, fusus.columns.get_loc("word")] = ""
    fusus.iloc[i+1, fusus.columns.get_loc("short")] = ""
    fusus.iloc[i+1, fusus.columns.get_loc("haspunct")] = ""

# %%
allwahj = fusus[(fusus.word.str.contains(pat='ظهر')) & (fusus.word.str.contains(pat='\[')) & (fusus.word.str.contains(pat='\]'))].index.tolist()

# %%
for i in allwahj:
    fusus.iloc[i, fusus.columns.get_loc("haspunct")] = ""

# %%
fusus[(fusus.word.str.contains(pat='وجه')) & (fusus.word.str.contains(pat='\[')) & (fusus.word.str.contains(pat='\]'))]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 188      11     4       1     1         r   79.0  165.0  119.0  186.0
# 644      18    11       1     1         r  160.0  347.0  197.0  368.0
# 1149     22    14       1     1         r  311.0  425.0  350.0  446.0
# 1613     25    11       1     1         r  149.0  347.0  186.0  368.0
# 2116     29     6       1     1         r  206.0  217.0  242.0  238.0
# ...     ...   ...     ...   ...       ...    ...    ...    ...    ...
# 39086   384     6       1     1         r   79.0  217.0  100.0  238.0
# 39631   389     9       1     1         r  334.0  302.0  352.0  323.0
# 40123   395     4       1     1         r  305.0  165.0  319.0  186.0
# 40711   400     7       1     1         r   79.0  243.0  110.0  264.0
# 41299   407     4       1     1         r  240.0  165.0  255.0  186.0
#
#           word short haspunct punctAfter punctBefore QunawiMS
# 188     [٢وجه]                                             2a
# 644     [٣وجه]                                             3a
# 1149    [٤وجه]                                             4a
# 1613    [٥وجه]                                             5a
# 2116    [٦وجه]                                             6a
# ...        ...   ...      ...        ...         ...      ...
# 39086  [٤٧وجه]                                            74a
# 39631  [٥٧وجه]                                            75a
# 40123  [٦٧وجه]                                            76a
# 40711  [٧٧وجه]                                            77a
# 41299  [٨٧وجه]                                            78a
#
# [78 rows x 15 columns]

# %%
fusus.head()
# Out:
#    page  line  column  span direction   left    top  right  bottom  \
# 0     8     2       1     1         r  356.0  197.0  384.0   218.0
# 1     8     2       1     1         r  341.0  197.0  356.0   218.0
# 2     8     2       1     1         r  312.0  197.0  341.0   218.0
# 3     8     2       1     1         r  274.0  197.0  312.0   218.0
# 4     8     2       1     1         r  260.0  197.0  274.0   218.0
#
#           word  short haspunct punctAfter punctBefore QunawiMS
# 0     الحَمْدُ  الحمد      NaN        NaN         NaN       1b
# 1        لِلهِ    لله      NaN        NaN         NaN       1b
# 2  مُـنَـزِّلِ   منزل      NaN        NaN         NaN       1b
# 3     الحِكَمِ  الحكم      NaN        NaN         NaN       1b
# 4       عَلَىٰ    على      NaN        NaN         NaN       1b

# %% [markdown]
# Still have to get the QunawiMS annotated to the first next word

# %%
fusus[(fusus.poetryVerse != "")]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 215      12     3       1     1         r  339.0  139.0  374.0  160.0
# 221      12     4       1     1         r  343.0  165.0  374.0  186.0
# 227      12     5       1     1         r  345.0  191.0  374.0  212.0
# 233      12     6       1     1         r  346.0  217.0  374.0  238.0
# 240      12     7       1     1         r  338.0  243.0  374.0  264.0
# ...     ...   ...     ...   ...       ...    ...    ...    ...    ...
# 32088   325     5       1     1         r  336.0  209.0  384.0  230.0
# 32096   326     1       1     1         r  346.0   87.0  384.0  108.0
# 32105   326     2       1     1         r  350.0  113.0  384.0  134.0
# 38791   382     9       1     1         r  358.0  304.0  397.0  325.0
# 38799   382    10       1     1         r  356.0  330.0  394.0  351.0
#
#                  word    short haspunct punctAfter punctBefore QunawiMS  \
# 215            فَمِنَ      فمن                                       2a
# 221          فَإِذَا    فإذا                                       2a
# 227             ثُمَّ       ثم                                       2a
# 233             ثُمَّ       ثم                                       2a
# 240            هٰذِهِ      هذه                                       2a
# ...               ...      ...      ...        ...         ...      ...
# 32088  مَشِيْىَٔـتُهُ  مشيىٔته                                      61a
# 32096        يُـرِيدُ     يريد                                      61a
# 32105         فَهٰذَا     فهذا                                      61a
# 38791        يَحِـنُّ      يحن                                      73b
# 38799       وَتَهْفُو    وتهفو                                      73b
#
#             poetryMeter poetryVerse
# 215    [مجـزوء الخفيف]          1.0
# 221                             2.0
# 227                             3.0
# 233                             4.0
# 240                             5.0
# ...                 ...         ...
# 32088                           3.0
# 32096                           4.0
# 32105                           5.0
# 38791   [المُتَقَارِبُ]         1.0
# 38799                           2.0
#
# [135 rows x 17 columns]

# %%
fusus.QunawiMS = fusus.QunawiMS.ffill()

# %%
wahj = fusus[fusus.word=='ظهر]'].index.tolist()
for i in wahj:
    print(str(fusus.iloc[[i-1,i]].word.tolist()[0]) + str(fusus.iloc[[i-1,i]].word.tolist()[1])+ " at " + str(fusus.iloc[[i-1,i]].index.tolist()[0]))
# Out:
# [٠١ظهر] at 4446
# [١١ظهر] at 4951
# [٢١ظهر] at 5462
# ٧][٣١ظهر] at 6041
# [٤١ظهر] at 6565
# [٥١ظهر] at 7111
# [٦١ظهر] at 7621
# [٧١ظهر] at 8117
# [٨١ظهر] at 8595
# [٩١ظهر] at 9114
# [٠٢ظهر] at 9628
# [١٢ظهر] at 10156
# [٢٢ظهر] at 10610
# [٣٢ظهر] at 11164
# [٤٢ظهر] at 11702
# [٥٢ظهر] at 12239
# [٦٢ظهر] at 12826
# [٧٢ظهر] at 13333
# [٨٢ظهر] at 13923
# [٩٢ظهر] at 14440
# [٠٣ظهر] at 14967
# [١٣ظهر] at 15533
# [٢٣ظهر] at 16082
# [٣٣ظهر] at 16628
# [٤٣ظهر] at 17172
# [٥٣ظهر] at 17710
# [٦٣ظهر] at 18246
# [٧٣ظهر] at 18832
# [٨٣ظهر] at 19370
# [٩٣ظهر] at 19950
# [٠٤ظهر] at 20485
# [١٤ظهر] at 21073
# [٢٤ظهر] at 21594
# [٣٤ظهر] at 22039
# [٤٤ظهر] at 22586
# [٥٤ظهر] at 23189
# [٦٤ظهر] at 23747
# [٧٤ظهر] at 24279
# [٨٤ظهر] at 24856
# [٩٤ظهر] at 25431
# [١٥ظهر] at 26554
# [٢٥ظهر] at 27067
# [٣٥ظهر] at 27564
# [٣٥‐أظهر] at 28099
# [٤٥ظهر] at 28659
# [٥٥ظهر] at 29188
# [٦٥ظهر] at 29752
# [٧٥ظهر] at 30252
# [٨٥ظهر] at 30753
# [٩٥ظهر] at 31278
# [٠٦ظهر] at 31816
# [١٦ظهر] at 32327
# [٢٦ظهر] at 32882
# [٣٦ظهر] at 33419
# [٤٦ظهر] at 33962
# [٥٦ظهر] at 34506
# [٦٦ظهر] at 35018
# [٧٦ظهر] at 35587
# [٨٦ظهر] at 36085
# [٩٦ظهر] at 36626
# [٠٧ظهر] at 37199
# [١٧ظهر] at 37731
# [٢٧ظهر] at 38281
# [٣٧ظهر] at 38815
# [٤٧ظهر] at 39357
# [٥٧ظهر] at 39880
# [٦٧ظهر] at 40418
# [٧٧ظهر] at 41008

# %%
fusus[(fusus['page']==47) & (fusus.line==7)]
# Out:
#       page  line  column  span direction   left    top  right bottom  \
# 4189    47     7       1     1         r  388.0  243.0  402.0  264.0
# 4190    47     7       1     1         r  368.0  243.0  388.0  264.0
# 4191    47     7       1     1         r  357.0  243.0  368.0  264.0
# 4192    47     7       1     1         r  335.0  243.0  357.0  264.0
# 4193    47     7       1     1         r  312.0  243.0  335.0  264.0
# 4194    47     7       1     1         r  295.0  243.0  312.0  264.0
# 4195    47     7       1     1         r  257.0  243.0  295.0  264.0
# 4196    47     7       1     1         r  238.0  243.0  257.0  264.0
# 4197    47     7       1     1         r  221.0  243.0  235.0  264.0
# 4198    47     7       1     1         r  193.0  243.0  221.0  264.0
# 4199    47     7       1     1         r  180.0  243.0  193.0  264.0
# 4201    47     7       1     1         r  119.0  243.0  153.0  264.0
# 4202    47     7       1     1         r   79.0  243.0  114.0  264.0
#
#               word    short haspunct punctAfter punctBefore QunawiMS
# 4189          مِنَ       من                                       9b
# 4190        اللهِ،     الله                   ،                   9b
# 4191           لَا       لا                                       9b
# 4192          مِنْ       من                                       9b
# 4193         رُوحٍ      روح                                       9b
# 4194          مِنَ       من                                       9b
# 4195  الأَرْوَاحِ،  الأرواح                   ،                   9b
# 4196          بَلْ       بل                                       9b
# 4197          مِنْ       من                                       9b
# 4198      رُوْحِهِ     روحه                                       9b
# 4199       [١١وجه]                                               10a
# 4201     تُكَوِّنُ     تكون                                      10a
# 4202    المَادَّةُ   المادة                                      10a

# %%
wajh = fusus[(fusus.word.str.contains(pat='وجه'))].index.tolist()

# %%
fusus = fusus.drop(fusus.index[wajh])

# %%
fusus.shape
# Out:
# (41454, 17)

# %%
print(fusus.QunawiMS.unique().tolist())
# Out:
# ['1b', '2a', '2b', '3a', '3b', '4a', '4b', '5a', '5b', '6a', '6b', '7a', '7b', '8a', '8b', '9a', '9b', '10a', '10b', '11a', '11b', '12a', '12b', '13a', '13b', '14a', '14b', '15a', '15b', '16a', '16b', '17a', '17b', '18a', '18b', '19a', '19b', '20a', '20b', '21a', '21b', '22a', '22b', '23a', '23b', '24a', '24b', '25a', '25b', '26a', '26b', '27a', '27b', '28a', '28b', '29a', '29b', '30a', '30b', '31a', '31b', '32a', '32b', '33a', '33b', '34a', '34b', '35a', '35b', '36a', '36b', '37a', '37b', '38a', '38b', '39a', '39b', '40a', '40b', '41a', '41b', '42a', '42b', '43a', '43b', '44a', '44b', '45a', '45b', '46a', '46b', '47a', '47b', '48a', '48b', '49a', '49b', '50a', '50b', '51a', '51b', '52a', '52b', '53a', '53b', '53aII', '53bII', '54a', '54b', '55a', '55b', '56a', '56b', '57a', '57b', '58a', '58b', '59a', '59b', '60a', '60b', '61a', '61b', '62a', '62b', '63a', '63b', '64a', '64b', '65a', '65b', '66a', '66b', '67a', '67b', '68a', '68b', '69a', '69b', '70a', '70b', '71a', '71b', '72a', '72b', '73a', '73b', '74a', '74b', '75a', '75b', '76a', '76b', '77a', '77b', '78a']
