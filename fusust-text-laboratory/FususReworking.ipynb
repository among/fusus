# %% [markdown]
# # Introduction
# This folder works towards creating a 'right' csv-file of the Fusus al-hikam. Its origin is a TSV-file created by Dirk Roorda (accessed february 11) which has since then seen slight changes. This TSV-file is in turn based on the Lakhnawi edition of Ibn Arabi's Fusus al-hikam.
#
# ### Aim
# My aim to create a clean and ready file `fusus.csv`. It is to strictly encapsulate the text of Fusus al-hikam, ready to be machine-readable. As the text is groomed and cleaned, `fusus.csv` is undergoing change, with the underlying code not preserved. This is especially true for columns right of 'word'. The column 'short' is meant to be the cleanest. It has been stripped of diacritics, shaddas, tatwīl, spaces, and punctuation. The columns to the right are annotations on it.
#
# ### Credits
# Text by Ibn Arabi (finished in the year 1233). Edition by Nizam al-Din Ahmad al-Husayni al-Lakhnawi (Beirut: 2013). First conversion by Dirk Roorda (January 2021). Finalization by Cornelis van Lit (February 2021). Mostly relying on Pandas, with some thankful use of a list of Arabic characters by Lakhdar Benzahia and Talha Javed Mukhtar for CLTK.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import arabicABC as abc

# %%
# fusus = pd.read_csv('fusus.csv')
fusus = fusus.fillna('')

# %%
fusus.head()
# Out:
#    page  line  column  span direction   left    top  right bottom  \
# 0     8     2       1     1         r  356.0  197.0  384.0  218.0
# 1     8     2       1     1         r  341.0  197.0  356.0  218.0
# 2     8     2       1     1         r  312.0  197.0  341.0  218.0
# 3     8     2       1     1         r  274.0  197.0  312.0  218.0
# 4     8     2       1     1         r  260.0  197.0  274.0  218.0
#
#           word  short haspunct punctAfter punctBefore QunawiMS
# 0     الحَمْدُ  الحمد                                       1b
# 1        لِلهِ    لله                                       1b
# 2  مُـنَـزِّلِ   منزل                                       1b
# 3     الحِكَمِ  الحكم                                       1b
# 4       عَلَىٰ    على                                       1b

# %% [markdown]
# Exploring a specific punctuation mark

# %%
punctMark = fusus[fusus['haspunct']=='١‐']
punctMark
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 216      12     3       1     1         r  339.0  139.0  374.0  160.0
# 1930     28     1       1     1         r  358.0   87.0  402.0  108.0
# 5085     56     3       1     1         r  367.0  148.0  402.0  169.0
# 7123     79    10       1     1         r  358.0  330.0  402.0  351.0
# 8086     91     3       1     1         r  295.0  139.0  366.0  160.0
# 8178     92     6       1     1         r  306.0  222.0  386.0  243.0
# 8225     94     3       1     1         r  330.0  206.0  366.0  227.0
# 8932    104     8       1     1         r  315.0  285.0  366.0  306.0
# 9061    106     5       1     1         r  319.0  191.0  366.0  212.0
# 9420    108    16       1     1         r  326.0  477.0  366.0  498.0
# 9960    115     7       1     1         r  327.0  250.0  366.0  271.0
# 10034   116     6       1     1         r  335.0  217.0  366.0  238.0
# 10158   117     8       1     1         r  340.0  269.0  366.0  290.0
# 10274   119     3       1     1         r  335.0  139.0  366.0  160.0
# 13126   148     3       1     1         r  336.0  183.0  374.0  204.0
# 13231   149    10       1     1         r  320.0  321.0  346.0  342.0
# 14435   160    13       1     1         r  319.0  399.0  347.0  420.0
# 14720   163     3       1     1         r  326.0  146.0  349.0  167.0
# 15156   167     3       1     1         r  354.0  201.0  384.0  222.0
# 16672   179     7       1     1         r  331.0  252.0  367.0  273.0
# 18851   198     4       1     1         r  322.0  165.0  366.0  186.0
# 18881   198     9       1     1         r  331.0  309.0  367.0  330.0
# 20421   212     3       1     1         r  343.0  190.0  374.0  211.0
# 21590   224     8       1     1         r  300.0  269.0  346.0  290.0
# 22057   231     3       1     1         r  302.0  148.0  346.0  169.0
# 25418   261     2       1     1         r  318.0  120.0  345.0  141.0
# 27089   277     3       1     1         r  364.0  139.0  395.0  160.0
# 29818   305     1       1     1         r  357.0   87.0  402.0  108.0
# 32187   325     3       1     1         r  358.0  157.0  384.0  178.0
# 38933   382     9       1     1         r  358.0  304.0  397.0  325.0
#
#                    word      short haspunct punctAfter punctBefore QunawiMS
# 216            ١‐فَمِنَ      ١‐فمن       ١‐                              2a
# 1930        ١‐فَالكُلُّ    ١‐فالكل       ١‐                              5b
# 5085         ١‐فَـإِنْ     ١‐فإن       ١‐                             11b
# 7123        ١‐فَالحَقُّ    ١‐فالحق       ١‐                             15b
# 8086   ١‐فَـيَحْمَدُنِي  ١‐فيحمدني       ١‐                             17a
# 8178         ١‐فَنَحْنُ     ١‐فنحن       ١‐                             17b
# 8225          ١‐فِدَاءُ     ١‐فداء       ١‐                             17b
# 8932    ١‐فَلِلْوَاحِدِ  ١‐فللواحد       ١‐                             19a
# 9061       ١‐يَاخَالِقَ   ١‐ياخالق       ١‐                             19a
# 9420      ١‐فَـوَقْـتًا    ١‐فوقتا       ١‐                             20a
# 9960         ١‐فَأَنْتَ     ١‐فأنت       ١‐                             21a
# 10034          ١‐فَلَمْ      ١‐فلم       ١‐                             21a
# 10158           ١‐فَلَا      ١‐فلا       ١‐                             21b
# 10274          ١‐فَلَمْ      ١‐فلم       ١‐                             21b
# 13126          ١‐إِنَّ      ١‐إن       ١‐                             27a
# 13231          ١‐إِذَا     ١‐إذا       ١‐                             27a
# 14435          ١‐فَهُوَ      ١‐فهو       ١‐                             29a
# 14720           ١‐فَلَا      ١‐فلا       ١‐                             30a
# 15156            ١‐مِنَ       ١‐من       ١‐                             30b
# 16672          ١‐فَمَنْ      ١‐فمن       ١‐                             33b
# 18851       ١‐فَالكُلُّ    ١‐فالكل       ١‐                             37b
# 18881         ١‐فَقَـدْ      ١‐فقد       ١‐                             37b
# 20421            ١‐عَنْ       ١‐عن       ١‐                             40a
# 21590    ١‐فَلَـوْلَاهُ   ١‐فلولاه       ١‐                             42a
# 22057       ١‐فَالكُلُّ    ١‐فالكل       ١‐                             43b
# 25418       ١‐إِنَّمَا    ١‐إنما       ١‐                             49a
# 27089          ١‐فَمَنْ      ١‐فمن       ١‐                             52b
# 29818      ١‐فَرَحْمَةُ    ١‐فرحمة       ١‐                             56b
# 32187          ١‐إِذْا     ١‐إذا       ١‐                             61a
# 38933        ١‐يَحِـنُّ      ١‐يحن       ١‐                             73b

# %% [markdown]
# Moving punctuation from `short` to `After` and deleting from `haspunct` (aim is to get `haspunct` empty and delete it)

# %%
def SetPunctuation(row):
    position = punctMark.iloc[row] 
    punct = position.haspunct
    short = position.short
    if short[-2:] == punct:
        fusus.iloc[position.name, fusus.columns.get_loc('punctAfter')] = punct
        fusus.iloc[position.name, fusus.columns.get_loc('short')] = short.replace(punct,'')
        fusus.iloc[position.name, fusus.columns.get_loc('haspunct')] = ""

# %%
# Uncomment to set function in motion for all cases of the particular punctuation
# for i in range(0,len(punctMark)):
#     SetPunctuation(i)

# %% [markdown]
# Check results and possibly adjust details

# %%
# look at one
# fusus.iloc[26816]
# look at line
# fusus[(fusus['page']==273) & (fusus.line==8)]
# change one value
# fusus.iloc[6041, fusus.columns.get_loc("word")] = '[٣١ظهر]'
fusus[(fusus['page']==47) & (fusus.line==7)]
# Out:
#       page  line  column  span direction   left    top  right bottom  \
# 4189    47     7       1     1         r  388.0  243.0  402.0  264.0
# 4190    47     7       1     1         r  368.0  243.0  388.0  264.0
# 4191    47     7       1     1         r  357.0  243.0  368.0  264.0
# 4192    47     7       1     1         r  335.0  243.0  357.0  264.0
# 4193    47     7       1     1         r  312.0  243.0  335.0  264.0
# 4194    47     7       1     1         r  295.0  243.0  312.0  264.0
# 4195    47     7       1     1         r  257.0  243.0  295.0  264.0
# 4196    47     7       1     1         r  238.0  243.0  257.0  264.0
# 4197    47     7       1     1         r  221.0  243.0  235.0  264.0
# 4198    47     7       1     1         r  193.0  243.0  221.0  264.0
# 4199    47     7       1     1         r  180.0  243.0  193.0  264.0
# 4200    47     7       1     1         r  153.0  243.0  180.0  264.0
# 4201    47     7       1     1         r  119.0  243.0  153.0  264.0
# 4202    47     7       1     1         r   79.0  243.0  114.0  264.0
#
#               word    short haspunct punctAfter punctBefore QunawiMS
# 4189          مِنَ       من                                       9b
# 4190        اللهِ،     الله                   ،                   9b
# 4191           لَا       لا                                       9b
# 4192          مِنْ       من                                       9b
# 4193         رُوحٍ      روح                                       9b
# 4194          مِنَ       من                                       9b
# 4195  الأَرْوَاحِ،  الأرواح                   ،                   9b
# 4196          بَلْ       بل                                       9b
# 4197          مِنْ       من                                       9b
# 4198      رُوْحِهِ     روحه                                       9b
# 4199       [١١وجه]                                               10a
# 4200                               ]                             10a
# 4201     تُكَوِّنُ     تكون                                      10a
# 4202    المَادَّةُ   المادة                                      10a

# %%
fusus.iloc[6041].word[2:]
# fusus.iloc[6040, fusus.columns.get_loc("word")]
# Out:
# '[٣١ظهر]'

# %% [markdown]
# Which punctuation remains? We find out below

# %%
puncs = fusus[fusus['haspunct']!=''].haspunct.unique().tolist()

# %%
puncsLess = []
for punc in puncs:
    if '[' not in punc and ']' not in punc:
        puncsLess.append(punc)
print(puncsLess)
# Out:
# ['١‐', '٢‐', '٣‐', '٤‐', '٥‐', '﴾', ':.', '―', '﴿', '﴾،', '«»،', '«».', '«»', '»،', '؟!', '–', '﴾.', '﴿﴾', ':﴿', '»؟', '«»؛', '﴾.()', '﴿﴾،', '؟﴿', '؟»', '﴾؛', '﴿﴾:', '»:', '.:', '٦‐', '٧‐', '٨‐', '٩‐', '٠١‐', '١١‐', '٢١‐', '٣١‐', ':«', '«»؟', '٣٥؛', '..', '؛:', '؟».', '٨٨؛', '«»:', '﴿ی', ':﴿﴾', '……………', '٢٢١؛', '—', '٣،', '٩٢،', '٧١،', '٠٣،', '«،', '!»', '﴾؟', '٩٢؛', '…»', '٦٢،', '٨٢،', '٢،']

# %%
for punc in puncsLess:
    times = fusus[fusus['haspunct']==punc].shape[0]
    print(punc + " " + str(times))
# Out:
# ١‐ 30
# ٢‐ 30
# ٣‐ 23
# ٤‐ 17
# ٥‐ 13
# ﴾ 372
# :. 8
# ― 300
# ﴿ 487
# ﴾، 31
# «»، 46
# «». 23
# «» 72
# »، 46
# ؟! 1
# – 2
# ﴾. 3
# ﴿﴾ 29
# :﴿ 6
# »؟ 2
# «»؛ 3
# ﴾.() 1
# ﴿﴾، 4
# ؟﴿ 1
# ؟» 2
# ﴾؛ 1
# ﴿﴾: 1
# »: 1
# .: 2
# ٦‐ 8
# ٧‐ 4
# ٨‐ 3
# ٩‐ 2
# ٠١‐ 2
# ١١‐ 2
# ٢١‐ 1
# ٣١‐ 1
# :« 1
# «»؟ 1
# ٣٥؛ 4
# .. 1
# ؛: 1
# ؟». 3
# ٨٨؛ 1
# «»: 1
# ﴿ی 1
# :﴿﴾ 1
# …………… 2
# ٢٢١؛ 2
# — 6
# ٣، 1
# ٩٢، 1
# ٧١، 1
# ٠٣، 1
# «، 1
# !» 1
# ﴾؟ 1
# ٩٢؛ 1
# …» 1
# ٦٢، 1
# ٨٢، 1
# ٢، 1

# %% [markdown]
# Some more functionality to check what is going on

# %%
fusus.haspunct.str.contains(pat='').value_counts()
# Out:
# True    41683
# Name: haspunct, dtype: int64

# %%
fusus[fusus.haspunct.str.contains(pat='١١')]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 2200     30     6       1     1         r  360.0  242.0  374.0  263.0
# 4199     47     7       1     1         r  180.0  243.0  193.0  264.0
# 4684     51     4       1     1         r  294.0  235.0  307.0  256.0
# 4951     54     3       1     1         r   79.0  139.0   99.0  160.0
# 5138     56     8       1     1         r  143.0  289.0  155.0  304.0
# ...     ...   ...     ...   ...       ...    ...    ...    ...    ...
# 28155   289     4       1     1         r   82.0  169.0  115.0  184.0
# 29325   298     5       1     1         r  275.0  195.0  289.0  210.0
# 30752   314    10       1     1         r  130.0  325.0  142.0  340.0
# 30760   314    11       1     1         r  159.0  351.0  174.0  366.0
# 32999   331     9       1     1         r  126.0  299.0  141.0  314.0
#
#           word    short haspunct punctAfter punctBefore
# 2200      [١١]     [١١]     [١١]
# 4199       [١١      [١١      [١١
# 4684       [١١      [١١      [١١
# 4951       [١١      [١١      [١١
# 5138       ١١]      ١١]      ١١]
# ...        ...      ...      ...        ...         ...
# 28155  ٨١و١٦].  ٨١و١٦].   ٨١١٦].
# 29325     ١١].     ١١].     ١١].
# 30752      ١١]      ١١]      ١١]
# 30760     ١١]،     ١١]،     ١١]،
# 32999     ٠١١]     ٠١١]     ٠١١]
#
# [68 rows x 14 columns]

# %%
lijst = punctMark.index.tolist()
lijst = [x-1 for x in lijst]
lijst
# Out:
# [215,
#  1929,
#  5084,
#  7122,
#  8085,
#  8177,
#  8224,
#  8931,
#  9060,
#  9419,
#  9959,
#  10033,
#  10157,
#  10273,
#  13125,
#  13230,
#  14434,
#  14719,
#  15155,
#  16671,
#  18850,
#  18880,
#  20420,
#  21589,
#  22056,
#  25417,
#  27088,
#  29817,
#  32186,
#  38932]

# %% [markdown]
# first need to clean up `[zahr -#]`, which refer to MS Qunawi, and only then the poetry metre. Poetry can consist of two words (majzūʾ in front). 29817/304-9 needs to be split. Folio 53 is counted twice (in the MS).

# %%
# These are the words right before poetry starts: indicate meter.
fusus.iloc[lijst]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 215      12     2       1     1         r  323.0  113.0  371.0  134.0
# 1929     27    14       1     1         r  364.0  425.0  402.0  446.0
# 5084     56     2       1     1         r  364.0  122.0  402.0  143.0
# 7122     79     9       1     1         r  364.0  295.0  402.0  316.0
# 8085     91     2       1     1         r  325.0  113.0  366.0  134.0
# 8177     92     5       1     1         r  325.0  196.0  366.0  217.0
# 8224     94     2       1     1         r  364.0  175.0  402.0  196.0
# 8931    104     7       1     1         r  364.0  250.0  402.0  271.0
# 9060    106     4       1     1         r  355.0  165.0  402.0  186.0
# 9419    108    15       1     1         r  364.0  451.0  402.0  472.0
# 9959    115     6       1     1         r  327.0  217.0  366.0  238.0
# 10033   116     5       1     1         r  361.0  191.0  402.0  212.0
# 10157   117     7       1     1         r  331.0  243.0  361.0  264.0
# 10273   119     2       1     1         r  361.0  113.0  402.0  134.0
# 13125   148     2       1     1         r  365.0  159.0  402.0  180.0
# 13230   149     9       1     1         r  334.0  295.0  367.0  316.0
# 14434   160    12       1     1         r  323.0  373.0  366.0  394.0
# 14719   163     2       1     1         r  353.0  113.0  402.0  134.0
# 15155   167     2       1     1         r  350.0  177.0  384.0  198.0
# 16671   179     6       1     1         r  334.0  217.0  367.0  238.0
# 18850   198     3       1     1         r  314.0  139.0  366.0  160.0
# 18880   198     8       1     1         r  333.0  276.0  366.0  297.0
# 20420   212     2       1     1         r  361.0  166.0  402.0  187.0
# 21589   224     7       1     1         r  305.0  243.0  338.0  264.0
# 22056   231     2       1     1         r  147.0  113.0  180.0  134.0
# 25417   261     1       1     1         r  330.0   87.0  366.0  108.0
# 27088   277     2       1     1         r  361.0  113.0  402.0  134.0
# 29817   304     9       1     1         r  159.0  295.0  249.0  316.0
# 32186   325     2       1     1         r  347.0  133.0  384.0  154.0
# 38932   382     8       1     1         r  353.0  269.0  402.0  290.0
#
#                         word             short haspunct punctAfter  \
# 215                  الخفيف]           الخفيف]        ]
# 1929                [البسيط]          [البسيط]       []
# 5084                [الطويل]          [الطويل]       []
# 7122                [البسيط]          [البسيط]       []
# 8085          الــوَافِــرِ]           الوافر]        ]
# 8177          الــوَافِــرِ]           الوافر]        ]
# 8224                [الطويل]          [الطويل]       []
# 8931                [الطويل]          [الطويل]       []
# 9060            [الســريــع]          [السريع]       []
# 9419                [الطويل]          [الطويل]       []
# 9959                البسـيط]           البسيط]        ]
# 10033              [الطـويل]          [الطويل]       []
# 10157                                                 ]
# 10273              [الطـويل]          [الطويل]       []
# 13125          [الـرَّمَـلُ]           [الرمل]       []
# 13230               الوافـر]           الوافر]        ]
# 14434                الخفيف]           الخفيف]        ]
# 14719        [المُتَقَارِبُ]        [المتقارب]       []
# 15155           [الوَافِـرُ]          [الوافر]       []
# 16671            الوَافِـرِ]           الوافر]        ]
# 18850       [المُـجْـتَـثُّ]          [المجتث]       []
# 18880            الوَافِـرِ]           الوافر]        ]
# 20420              [البسـيط]          [البسيط]       []
# 21589               الوافـر]           الوافر]        ]
# 22056            الرَّجَـزِ]            الرجز]        ]
# 25417            الـرَّمَـل]            الرمل]        ]
# 27088              [الطـويل]          [الطويل]       []
# 29817  المَسْأَلَةِ.[البسيط]  المسألة.[البسيط]      .[]
# 32186          [الـوَافِـرُ]          [الوافر]       []
# 38932        [المُتَقَارِبُ]        [المتقارب]       []
#
#       punctBefore QunawiMS
# 215                     2a
# 1929                    5b
# 5084                   11b
# 7122                   15b
# 8085                   17a
# 8177                   17b
# 8224                   17b
# 8931                   19a
# 9060                   19a
# 9419                   20a
# 9959                   21a
# 10033                  21a
# 10157                  21b
# 10273                  21b
# 13125                  27a
# 13230                  27a
# 14434                  29a
# 14719                  30a
# 15155                  30b
# 16671                  33b
# 18850                  37b
# 18880                  37b
# 20420                  40a
# 21589                  42a
# 22056                  43b
# 25417                  49a
# 27088                  52b
# 29817                  56b
# 32186                  61a
# 38932                  73b

# %%
allwahj = fusus[(fusus.word.str.contains(pat='ظهر')) & (fusus.word.str.contains(pat='\[')) & (fusus.word.str.contains(pat='\]'))].index.tolist()

# %%
for i in allwahj:
    fusus.iloc[i, fusus.columns.get_loc("haspunct")] = ""

# %%
fusus[(fusus.word.str.contains(pat='وجه')) & (fusus.word.str.contains(pat='\[')) & (fusus.word.str.contains(pat='\]'))]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 188      11     4       1     1         r   79.0  165.0  119.0  186.0
# 644      18    11       1     1         r  160.0  347.0  197.0  368.0
# 1149     22    14       1     1         r  311.0  425.0  350.0  446.0
# 1613     25    11       1     1         r  149.0  347.0  186.0  368.0
# 2116     29     6       1     1         r  206.0  217.0  242.0  238.0
# ...     ...   ...     ...   ...       ...    ...    ...    ...    ...
# 39086   384     6       1     1         r   79.0  217.0  100.0  238.0
# 39631   389     9       1     1         r  334.0  302.0  352.0  323.0
# 40123   395     4       1     1         r  305.0  165.0  319.0  186.0
# 40711   400     7       1     1         r   79.0  243.0  110.0  264.0
# 41299   407     4       1     1         r  240.0  165.0  255.0  186.0
#
#           word short haspunct punctAfter punctBefore QunawiMS
# 188     [٢وجه]                                             2a
# 644     [٣وجه]                                             3a
# 1149    [٤وجه]                                             4a
# 1613    [٥وجه]                                             5a
# 2116    [٦وجه]                                             6a
# ...        ...   ...      ...        ...         ...      ...
# 39086  [٤٧وجه]                                            74a
# 39631  [٥٧وجه]                                            75a
# 40123  [٦٧وجه]                                            76a
# 40711  [٧٧وجه]                                            77a
# 41299  [٨٧وجه]                                            78a
#
# [78 rows x 15 columns]

# %%
fusus.head()
# Out:
#    page  line  column  span direction   left    top  right  bottom  \
# 0     8     2       1     1         r  356.0  197.0  384.0   218.0
# 1     8     2       1     1         r  341.0  197.0  356.0   218.0
# 2     8     2       1     1         r  312.0  197.0  341.0   218.0
# 3     8     2       1     1         r  274.0  197.0  312.0   218.0
# 4     8     2       1     1         r  260.0  197.0  274.0   218.0
#
#           word  short haspunct punctAfter punctBefore QunawiMS
# 0     الحَمْدُ  الحمد      NaN        NaN         NaN       1b
# 1        لِلهِ    لله      NaN        NaN         NaN       1b
# 2  مُـنَـزِّلِ   منزل      NaN        NaN         NaN       1b
# 3     الحِكَمِ  الحكم      NaN        NaN         NaN       1b
# 4       عَلَىٰ    على      NaN        NaN         NaN       1b

# %% [markdown]
# Still have to get the QunawiMS annotated to the first next word

# %%
fusus[(fusus.QunawiMS.notna())]
# Out:
#        page  line  column  span direction   left    top  right  bottom  \
# 0         8     2       1     1         r  356.0  197.0  384.0   218.0
# 1         8     2       1     1         r  341.0  197.0  356.0   218.0
# 2         8     2       1     1         r  312.0  197.0  341.0   218.0
# 3         8     2       1     1         r  274.0  197.0  312.0   218.0
# 4         8     2       1     1         r  260.0  197.0  274.0   218.0
# ...     ...   ...     ...   ...       ...    ...    ...    ...     ...
# 41678   410     9       1     1         r  278.0  297.0  294.0   315.0
# 41679   410     9       1     1         r  261.0  297.0  278.0   315.0
# 41680   410     9       1     1         r  227.0  297.0  261.0   315.0
# 41681   410     9       1     1         r  215.0  297.0  227.0   315.0
# 41682   410     9       1     1         r  191.0  297.0  215.0   315.0
#
#               word   short haspunct punctAfter punctBefore QunawiMS
# 0         الحَمْدُ   الحمد      NaN        NaN         NaN       1b
# 1            لِلهِ     لله      NaN        NaN         NaN       1b
# 2      مُـنَـزِّلِ    منزل      NaN        NaN         NaN       1b
# 3         الحِكَمِ   الحكم      NaN        NaN         NaN       1b
# 4           عَلَىٰ     على      NaN        NaN         NaN       1b
# ...            ...     ...      ...        ...         ...      ...
# 41678         [٠٣٦    [٠٣٦     [٠٣٦        NaN         NaN      78a
# 41679          هـ]      ه]        ]        NaN         NaN      78a
# 41680   وَالحَمْدُ  والحمد      NaN        NaN         NaN      78a
# 41681        لِلهِ     لله      NaN        NaN         NaN      78a
# 41682    وَحْدَهُ.    وحده      NaN          .         NaN      78a
#
# [41683 rows x 15 columns]

# %%
fusus.QunawiMS = fusus.QunawiMS.ffill()

# %%
wahj = fusus[fusus.word=='ظهر]'].index.tolist()
for i in wahj:
    print(str(fusus.iloc[[i-1,i]].word.tolist()[0]) + str(fusus.iloc[[i-1,i]].word.tolist()[1])+ " at " + str(fusus.iloc[[i-1,i]].index.tolist()[0]))
# Out:
# [٠١ظهر] at 4446
# [١١ظهر] at 4951
# [٢١ظهر] at 5462
# ٧][٣١ظهر] at 6041
# [٤١ظهر] at 6565
# [٥١ظهر] at 7111
# [٦١ظهر] at 7621
# [٧١ظهر] at 8117
# [٨١ظهر] at 8595
# [٩١ظهر] at 9114
# [٠٢ظهر] at 9628
# [١٢ظهر] at 10156
# [٢٢ظهر] at 10610
# [٣٢ظهر] at 11164
# [٤٢ظهر] at 11702
# [٥٢ظهر] at 12239
# [٦٢ظهر] at 12826
# [٧٢ظهر] at 13333
# [٨٢ظهر] at 13923
# [٩٢ظهر] at 14440
# [٠٣ظهر] at 14967
# [١٣ظهر] at 15533
# [٢٣ظهر] at 16082
# [٣٣ظهر] at 16628
# [٤٣ظهر] at 17172
# [٥٣ظهر] at 17710
# [٦٣ظهر] at 18246
# [٧٣ظهر] at 18832
# [٨٣ظهر] at 19370
# [٩٣ظهر] at 19950
# [٠٤ظهر] at 20485
# [١٤ظهر] at 21073
# [٢٤ظهر] at 21594
# [٣٤ظهر] at 22039
# [٤٤ظهر] at 22586
# [٥٤ظهر] at 23189
# [٦٤ظهر] at 23747
# [٧٤ظهر] at 24279
# [٨٤ظهر] at 24856
# [٩٤ظهر] at 25431
# [١٥ظهر] at 26554
# [٢٥ظهر] at 27067
# [٣٥ظهر] at 27564
# [٣٥‐أظهر] at 28099
# [٤٥ظهر] at 28659
# [٥٥ظهر] at 29188
# [٦٥ظهر] at 29752
# [٧٥ظهر] at 30252
# [٨٥ظهر] at 30753
# [٩٥ظهر] at 31278
# [٠٦ظهر] at 31816
# [١٦ظهر] at 32327
# [٢٦ظهر] at 32882
# [٣٦ظهر] at 33419
# [٤٦ظهر] at 33962
# [٥٦ظهر] at 34506
# [٦٦ظهر] at 35018
# [٧٦ظهر] at 35587
# [٨٦ظهر] at 36085
# [٩٦ظهر] at 36626
# [٠٧ظهر] at 37199
# [١٧ظهر] at 37731
# [٢٧ظهر] at 38281
# [٣٧ظهر] at 38815
# [٤٧ظهر] at 39357
# [٥٧ظهر] at 39880
# [٦٧ظهر] at 40418
# [٧٧ظهر] at 41008

# %%
fusus[(fusus['page']==47) & (fusus.line==7)]
# Out:
#       page  line  column  span direction   left    top  right bottom  \
# 4189    47     7       1     1         r  388.0  243.0  402.0  264.0
# 4190    47     7       1     1         r  368.0  243.0  388.0  264.0
# 4191    47     7       1     1         r  357.0  243.0  368.0  264.0
# 4192    47     7       1     1         r  335.0  243.0  357.0  264.0
# 4193    47     7       1     1         r  312.0  243.0  335.0  264.0
# 4194    47     7       1     1         r  295.0  243.0  312.0  264.0
# 4195    47     7       1     1         r  257.0  243.0  295.0  264.0
# 4196    47     7       1     1         r  238.0  243.0  257.0  264.0
# 4197    47     7       1     1         r  221.0  243.0  235.0  264.0
# 4198    47     7       1     1         r  193.0  243.0  221.0  264.0
# 4199    47     7       1     1         r  180.0  243.0  193.0  264.0
# 4201    47     7       1     1         r  119.0  243.0  153.0  264.0
# 4202    47     7       1     1         r   79.0  243.0  114.0  264.0
#
#               word    short haspunct punctAfter punctBefore QunawiMS
# 4189          مِنَ       من                                       9b
# 4190        اللهِ،     الله                   ،                   9b
# 4191           لَا       لا                                       9b
# 4192          مِنْ       من                                       9b
# 4193         رُوحٍ      روح                                       9b
# 4194          مِنَ       من                                       9b
# 4195  الأَرْوَاحِ،  الأرواح                   ،                   9b
# 4196          بَلْ       بل                                       9b
# 4197          مِنْ       من                                       9b
# 4198      رُوْحِهِ     روحه                                       9b
# 4199       [١١وجه]                                               10a
# 4201     تُكَوِّنُ     تكون                                      10a
# 4202    المَادَّةُ   المادة                                      10a

# %%
fusus[(fusus.haspunct.str.contains(pat='\['))]
# Out:
#        page  line  column  span direction   left    top  right bottom  \
# 43        9     4       1     1         r  206.0  165.0  219.0  186.0
# 58        9     5       1     1         r  104.0  191.0  124.0  212.0
# 66        9     6       1     1         r  223.0  217.0  236.0  238.0
# 214      12     2       1     1         r  371.0  113.0  402.0  134.0
# 276      13     5       1     1         r  311.0  207.0  326.0  225.0
# ...     ...   ...     ...   ...       ...    ...    ...    ...    ...
# 41338   407     8       1     1         r  193.0  269.0  295.0  290.0
# 41514   409     5       1     1         r  165.0  191.0  266.0  212.0
# 41562   409    11       1     1         r  292.0  349.0  311.0  367.0
# 41621   410     2       1     1         r  134.0  115.0  190.0  133.0
# 41678   410     9       1     1         r  278.0  297.0  294.0  315.0
#
#                             word                 short haspunct punctAfter  \
# 43                           [وَ                    [و        [
# 58                          [٧٢٦                  [٧٢٦     [٧٢٦
# 66                           [وَ                    [و        [
# 214                      [مجـزوء                [مجزوء        [
# 276                        [بقية                 [بقية        [
# ...                          ...                   ...      ...        ...
# 41338  ﴿بِحَمْدِهِ﴾[سورةالإسراء:  ﴿بحمده﴾[سورةالإسراء:     ﴿﴾[:
# 41514  ٱلسَّبِيْلَ﴾[سورةالأحزاب:  ٱلسبيل﴾[سورةالأحزاب:      ﴾[:
# 41562                        […]                   […]      […]
# 41621                 [؟]صَاحِبُ               [؟]صاحب      [؟]
# 41678                       [٠٣٦                  [٠٣٦     [٠٣٦
#
#       punctBefore QunawiMS
# 43                      1b
# 58                      1b
# 66                      1b
# 214                     2a
# 276                     2a
# ...           ...      ...
# 41338                  78a
# 41514                  78a
# 41562                  78a
# 41621                  78a
# 41678                  78a
#
# [602 rows x 15 columns]

# %%
empty = fusus[fusus.word==""].index.tolist()

# %%
fusus.drop(fusus.index[empty], inplace=True)

# %%
fusus.shape
# Out:
# (41545, 15)
