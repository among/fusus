# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np
import cv2
from clean import CleanupEngine
from image import showarray, cluster

# %%
CL = CleanupEngine(PREOCR_INPUT='test', OCR_INPUT='test/clean')
C = CL.config

# %%
for acc in np.arange(0.69, 0.725, 0.01):
  print(f"acc={acc}")
  pim = CL.testClean('line', element=["doubleOpen", "doubleClose"], acc=acc)
  print("---")
# Out:
# acc=0.69
# ---
# acc=0.7
# ---
# acc=0.71
# ---
# acc=0.72
# ---
