# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from readable import Readable

# %%
RB = Readable(PREOCR_INPUT='test', OCR_INPUT='test/clean')

# %%
rIm = RB.start('page')
rIm.normalize()
rIm.histogram()

# %%
# rIm.show(stage="histogram")

# %%
rIm.margins(bands={"narrow"})
rIm.show(stage="demarginedC")

# %%
pim = CL.start('page2')
pim.normalize()
pim.histogram()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3eaaae681057> in <module>
# ----> 1 pim = CL.start('page2')
#       2 pim.normalize()
#       3 pim.histogram()
#
# NameError: name 'CL' is not defined

# %%
pim.margins()
pim.show(stage="demarginedC")
