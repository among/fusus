# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from clean import CleanupEngine

# %%
CL = CleanupEngine(PREOCR_INPUT='test', OCR_INPUT='test/clean')

# %%
pim = CL.start('page')
pim.normalize()
pim.histogram()

# %%
pim.margins(upperLeeway=10, lowerLeeway=0)
pim.show(stage="demarginedC")

# %%
pim = CL.start('page2')
pim.normalize()
pim.histogram()

# %%
pim.margins()
pim.show(stage="demarginedC")
