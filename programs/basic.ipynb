# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from clean import CleanupEngine

# %%
CL = CleanupEngine(PREOCR_INPUT='test', OCR_INPUT='test/clean')

# %%
pim = CL.testClean('char', element="comma", bw=0, acc=0.8)

# %%
for acc in np.arange(0.62, 0.685, 0.01):
  for bw in range(0, 10):
    print(f"acc={acc} bw={bw}")
    pim = CL.testClean('char', element="comma", bw=bw, acc=acc)
    print("---")
# Out:
# acc=0.62 bw=0
# ---
# acc=0.62 bw=1
# ---
# acc=0.62 bw=2
# ---
# acc=0.62 bw=3
# ---
# acc=0.62 bw=4
# ---
# acc=0.62 bw=5
# ---
# acc=0.62 bw=6
# ---
# acc=0.62 bw=7
# ---
# acc=0.62 bw=8
# ---
# acc=0.62 bw=9
# ---
# acc=0.63 bw=0
# ---
# acc=0.63 bw=1
# ---
# acc=0.63 bw=2
# ---
# acc=0.63 bw=3
# ---
# acc=0.63 bw=4
# ---
# acc=0.63 bw=5
# ---
# acc=0.63 bw=6
# ---
# acc=0.63 bw=7
# ---
# acc=0.63 bw=8
# ---
# acc=0.63 bw=9
# ---
# acc=0.64 bw=0
# ---
# acc=0.64 bw=1
# ---
# acc=0.64 bw=2
# ---
# acc=0.64 bw=3
# ---
# acc=0.64 bw=4
# ---
# acc=0.64 bw=5
# ---
# acc=0.64 bw=6
# ---
# acc=0.64 bw=7
# ---
# acc=0.64 bw=8
# ---
# acc=0.64 bw=9
# ---
# acc=0.65 bw=0
# ---
# acc=0.65 bw=1
# ---
# acc=0.65 bw=2
# ---
# acc=0.65 bw=3
# ---
# acc=0.65 bw=4
# ---
# acc=0.65 bw=5
# ---
# acc=0.65 bw=6
# ---
# acc=0.65 bw=7
# ---
# acc=0.65 bw=8
# ---
# acc=0.65 bw=9
# ---
# acc=0.66 bw=0
# ---
# acc=0.66 bw=1
# ---
# acc=0.66 bw=2
# ---
# acc=0.66 bw=3
# ---
# acc=0.66 bw=4
# ---
# ...

# %%
for acc in np.arange(0.69, 0.725, 0.01):
  for bw in range(0, 4):
    print(f"acc={acc} bw={bw}")
    pim = CL.testClean('line', element=["doubleOpen", "doubleClose"], bw=bw, acc=acc)
    print("---")
# Out:
# acc=0.69 bw=0
# ---
# acc=0.69 bw=1
# ---
# acc=0.69 bw=2
# ---
# acc=0.69 bw=3
# ---
# acc=0.7 bw=0
# ---
# acc=0.7 bw=1
# ---
# acc=0.7 bw=2
# ---
# acc=0.7 bw=3
# ---
# acc=0.71 bw=0
# ---
# acc=0.71 bw=1
# ---
# acc=0.71 bw=2
# ---
# acc=0.71 bw=3
# ---
# acc=0.72 bw=0
# ---
# acc=0.72 bw=1
# ---
# acc=0.72 bw=2
# ---
# acc=0.72 bw=3
# ---

# %%
pim = CL.testClean('page', element="comma", bw=0, acc=0.8)

# %%
pim.showCleanInfo()
# Out:
# comma        with border 0: 22 x in 44 points
# 	cluster of size  2 with accuracy  0.90 reached by  1 points - chosen (288, 912)
# 	cluster of size  1 with accuracy  0.90 reached by  1 points - chosen (465, 391)
# 	cluster of size  2 with accuracy  0.91 reached by  1 points - chosen (561, 922)
# 	cluster of size  3 with accuracy  0.87 reached by  1 points - chosen (650, 602)
# 	cluster of size  2 with accuracy  0.89 reached by  1 points - chosen (652, 949)
# 	cluster of size  2 with accuracy  0.86 reached by  1 points - chosen (655, 1209)
# 	cluster of size  2 with accuracy  0.85 reached by  1 points - chosen (745, 1137)
# 	cluster of size  2 with accuracy  0.88 reached by  1 points - chosen (749, 1488)
# 	cluster of size  2 with accuracy  0.90 reached by  1 points - chosen (834, 816)
# 	cluster of size  3 with accuracy  0.83 reached by  1 points - chosen (929, 1338)
# 	cluster of size  2 with accuracy  0.86 reached by  1 points - chosen (1014, 473)
# ...
