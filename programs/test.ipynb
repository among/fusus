# %%
# %load_ext autoreload
# %autoreload 2

# %%
from clean import CleanupEngine

# %%
from parameters import ELEMENT_DIR

# %%
CL = CleanupEngine(ELEMENT_DIR)

# %%
(pImg, showRep) = CL.treatImage('../cleanIn', '../cleanOut', 'qay_Page_1', destroy=False)

# %%
pImg.show()

# %%
pImg.show(stage="histogram")

# %%
pImg.show(stage="demargined")

# %%
pImg.show(stage="clean")

# %%
pImg.show(stage="cleanC")

# %%
(pImg, showRep) = CL.treatImage('../cleanIn', '../cleanOut', 'qay_Page_1', destroy=True)

# %%
pImg.show(stage="clean")
