# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from pipeline.exe import Exe

# %%
X = Exe(PREOCR_INPUT='test', OCR_INPUT='test/clean')

# %% [markdown]
# We show the band in which we look for the comma (the band is called `narrow`).
# There are also `broad` and `inter` bands.
# And there is a `main` band, directly derived from the histogram.

# %%
rIm = X.start('qay_Page_1')
rIm.normalize()
rIm.histogram()
rIm.margins()
rIm.clean(mark="comma", line=None)
rIm.showBands("boxed", {"narrow"})
rIm.show(stage="boxed")
# Out:
#    |      |                  comma   22 times
#    |    -0.00s cleaning done

# %%
rIm.showCleanInfo()
# Out:
#    |   comma        with border 4:
#    |    22 hits in 74 points
#    |    0 connected hits removed from 22 candidate hits
#    |   	 hit with accuracy  0.91 with connectivity   0.00 reached by (288, 898)
#    |   	 hit with accuracy  0.92 with connectivity   0.00 reached by (472, 379)
#    |   	 hit with accuracy  0.91 with connectivity   0.00 reached by (560, 911)
#    |   	 hit with accuracy  0.92 with connectivity   0.00 reached by (650, 1200)
#    |   	 hit with accuracy  0.90 with connectivity   0.00 reached by (651, 940)
#    |   	 hit with accuracy  0.91 with connectivity   0.00 reached by (654, 592)
#    |   	 hit with accuracy  0.89 with connectivity   0.00 reached by (741, 1480)
#    |   	 hit with accuracy  0.89 with connectivity   0.00 reached by (742, 1129)
#    |   	 hit with accuracy  0.92 with connectivity   0.00 reached by (835, 809)
#    |   	 hit with accuracy  0.93 with connectivity   0.00 reached by (923, 1333)
# ...

# %%
rIm = X.testClean('qay_Page_3', mark="comma2", bw=4, acc=0.6, ratio=0.05)
rIm.showCleanInfo()
# Out:
#    |      |                 comma2   23 times
#    |    2m 53s cleaning done
#    |   comma2       with border 4:
#    |    23 hits in 1456 points
#    |    267 connected hits removed from 290 candidate hits
#    |   	 hit with accuracy  0.67 with connectivity   0.00 reached by (163, 1550)
#    |   	 hit with accuracy  0.67 with connectivity   0.00 reached by (163, 1578)
#    |   	*hit with accuracy  0.60 with connectivity * 0.23 reached by (166, 1279)
#    |   	*hit with accuracy  0.62 with connectivity * 0.26 reached by (170, 1238)
#    |   	*hit with accuracy  0.75 with connectivity * 0.09 reached by (181, 1308)
#    |   	*hit with accuracy  0.70 with connectivity * 0.11 reached by (244, 1282)
#    |   	*hit with accuracy  0.72 with connectivity * 0.19 reached by (269, 1147)
#    |   	 hit with accuracy  0.88 with connectivity   0.00 reached by (269, 1435)
#    |   	*hit with accuracy  0.66 with connectivity * 0.06 reached by (271, 1470)
# ...

# %%
rIm = X.testClean('page2', mark="comma", bw=4, acc=0.65, ratio=0.05)
rIm.showCleanInfo()
# Out:
#    |      |                  comma  102 times
#    |    3m 04s cleaning done
#    |   comma        with border 4:
#    |    102 hits in 658 points
#    |    151 connected hits removed from 253 candidate hits
#    |   	*hit with accuracy  0.72 with connectivity * 0.43 reached by (55, 1462)
#    |   	*hit with accuracy  0.72 with connectivity * 0.25 reached by (76, 1212)
#    |   	 hit with accuracy  0.68 with connectivity   0.00 reached by (178, 1082)
#    |   	 hit with accuracy  0.66 with connectivity   0.00 reached by (181, 1043)
#    |   	*hit with accuracy  0.74 with connectivity * 0.44 reached by (197, 221)
#    |   	*hit with accuracy  0.70 with connectivity * 0.73 reached by (201, 400)
#    |   	*hit with accuracy  0.66 with connectivity * 0.44 reached by (201, 1367)
#    |   	*hit with accuracy  0.66 with connectivity * 0.54 reached by (209, 922)
#    |   	*hit with accuracy  0.67 with connectivity * 0.61 reached by (210, 1060)
# ...
