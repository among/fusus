# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from fusus.exe import Exe

# %%
X = Exe(PREOCR_INPUT='test', OCR_INPUT='test/clean')

# %%
rImg = X.testClean('char', mark="comma", bw=4, acc=0.65, ratio=0.01)
# Out:
#    |      |                  comma    1 times
#    |    -0.00s cleaning done

# %%
rImg.showCleanInfo()
# Out:
#    |   comma        with border 4:
#    |    1 hits in 3 points
#    |    0 connected hits removed from 1 candidate hits
#    |   	 hit with accuracy  0.71 with connectivity   0.00 reached by (22, 21)
#    |   1 marks wiped clean

# %%
rImg = X.testClean('char2', mark="comma", bw=4, acc=0.65, ratio=0.01)
# Out:
#    |      |                  comma    1 times
#    |       34s cleaning done

# %%
rImg.showCleanInfo()
# Out:
#    |   comma        with border 4:
#    |    1 hits in 7 points
#    |    1 connected hits removed from 2 candidate hits
#    |   	*hit with accuracy  0.74 with connectivity * 0.44 reached by (35, 22)
#    |   	 hit with accuracy  0.66 with connectivity   0.00 reached by (39, 8)
#    |   1 marks wiped clean

# %%
rImg = X.testClean('char3', mark="comma", bw=4, acc=0.65, ratio=0.01)
# Out:
#    |    1m 02s cleaning done

# %%
rImg.showCleanInfo()
# Out:
#    |   comma        with border 4:
#    |    0 hits in 1 points
#    |    1 connected hits removed from 1 candidate hits
#    |   	*hit with accuracy  0.67 with connectivity * 0.20 reached by (44, 4)
#    |   0 marks wiped clean

# %%
rImg = X.testClean('line2', mark="comma", bw=4, acc=0.65, ratio=0.01)
# Out:
#    |      |                  comma    2 times
#    |    1m 28s cleaning done

# %%
rImg.showCleanInfo()
# Out:
#    |   comma        with border 4:
#    |    2 hits in 15 points
#    |    2 connected hits removed from 4 candidate hits
#    |   	 hit with accuracy  0.86 with connectivity   0.00 reached by (51, 315)
#    |   	 hit with accuracy  0.88 with connectivity   0.00 reached by (58, 1235)
#    |   	*hit with accuracy  0.65 with connectivity * 0.20 reached by (60, 1086)
#    |   	*hit with accuracy  0.67 with connectivity * 0.20 reached by (69, 702)
#    |   2 marks wiped clean
