# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from fusus.exe import Exe

# %%
X = Exe(PREOCR_INPUT='test', OCR_INPUT='test/clean')

# %%
rIm = X.start('page')
rIm.normalize()
rIm.histogram()
# rIm.show(stage="histogram")
rIm.margins()
rIm.showBands("demarginedC", {"narrow"})
rIm.show(stage="demarginedC")

# %%
rIm = X.start('page2')
rIm.normalize()
rIm.histogram()
# rIm.show(stage="histogram")
rIm.margins()
rIm.showBands("demarginedC", {"narrow"})
rIm.show(stage="demarginedC")
