# %% [markdown]
# # Getting the divider

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pipeline.exe import Exe

# %% [markdown]
# Declare where the input files for cleaning are, and where the cleaned ones will be delivered.

# %%
X = Exe(PREOCR_INPUT='../cleanIn', OCR_INPUT='../cleanOut')

# %%
rImg = X.start('qay_Page_3')
rImg.normalize()
rImg.histogram()
rImg.margins()
rImg.showBands("histogram", showBands={'main'})
rImg.show(stage="histogram")
rImg.show(stage="rotated")
rImg.show(stage="demargined")
